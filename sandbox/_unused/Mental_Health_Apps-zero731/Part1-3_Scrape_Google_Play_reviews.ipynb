# %% [markdown]
# # Part I.III - Obtain Google Play Reviews

# %%
## Import necessary libraries

# retrieves app info AND reviews from Google Play
from google_play_scraper import app, Sort, reviews, reviews_all

# pretty print data structures
from pprint import pprint

# for storing in MongoDB
import pymongo
from pymongo import MongoClient

import datetime as dt
from tzlocal import get_localzone

import random
import time

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
## Read in file containing app details, 
  ## need the app IDs for scraping stores
app_df = pd.read_csv('Data/mha_app_info.csv')
app_df.head()
# Out:
#                          app_name  iOS  iOS_revs  \
# 0                        Aloe Bud    1      3000
# 1                            Aura    1     22100
# 2                      BetterHelp    1     32400
# 3                   Breathe2Relax    1       200
# 4  Breathwrk: Breathing Exercises    1     10400
#
#                    iOS_app_name  iOS_app_id  android  android_revs  \
# 0                      aloe-bud  1318382054        0             0
# 1         aura-meditation-sleep  1114223104        1         10400
# 2  betterhelp-online-counseling   995252384        1         15300
# 3                 breathe2relax   425720246        1          1100
# 4                     breathwrk  1481804500        0             0
#
#                 android_appID
# 0                         NaN
# 1              com.aurahealth
# 2              com.betterhelp
# 3  org.t2health.breathe2relax
# 4                         NaN

# %%
## Store list of app ids and names to loop through for Google Play
google_play_apps = app_df.copy()
google_play_apps = google_play_apps.loc[google_play_apps['android']==1]

google_play_names = list(google_play_apps['app_name'])
google_play_ids = list(google_play_apps['android_appID'])

# %%
## Check number of apps found in Google Play
len(google_play_ids)
# Out:
# 53

# %% [markdown]
# ## Set Up MongoDB for Project

# %%
## Set up Mongo client
client = MongoClient(host='localhost', port=27018)

# %%
## Database for project
mha_proj_db = client['mha_proj_db']

# %%
## Set up new collection within project db
google_play_rvws = mha_proj_db['google_play_rvws']

# %%
# google_play_rvws.drop()

# %% [markdown]
# ## Scrape Reviews from Google Play

# %%
## Loop through apps to get reviews
for app_name, app_id in zip(google_play_names, google_play_ids):
    
    # Get start time
    start = dt.datetime.now(tz=get_localzone())
    fmt= "%m/%d/%y - %T %p"    
    
    # Print starting output for app
    print('---'*20)
    print('---'*20)    
    print(f'***** {app_name} started at {start.strftime(fmt)}')
    print()
    
    # Empty list for storing reviews
    app_reviews = []
    
    # Number of reviews to scrape per batch
    count = 200
    
    # To keep track of how many batches have been completed
    batch_num = 0
    
    
    # Retrieve reviews (and continuation_token) with reviews function
    rvws, token = reviews(
        app_id,           # found in app's url
        lang='en',        # defaults to 'en'
        country='us',     # defaults to 'us'
        sort=Sort.NEWEST, # start with most recent
        count=count       # batch size
    )
    
    
    # For each review obtained
    for r in rvws:
        r['app_name'] = app_name # add key for app's name
        r['app_id'] = app_id     # add key for app's id
     
    
    # Add the list of review dicts to overall list
    app_reviews.extend(rvws)
    
    # Increase batch count by one
    batch_num +=1 
    print(f'Batch {batch_num} completed.')
    
    # Wait 1 to 5 seconds to start next batch
    time.sleep(random.randint(20,30))
    
    
    
    # Append review IDs to list prior to starting next batch
    pre_review_ids = []
    for rvw in app_reviews:
        pre_review_ids.append(rvw['reviewId'])
    
    
    # Loop through at most max number of batches
    for batch in range(4999):
        rvws, token = reviews( # store continuation_token
            app_id,
            lang='en',
            country='us',
            sort=Sort.NEWEST,
            count=count,
            # using token obtained from previous batch
            continuation_token=token
        )
        
        # Append unique review IDs from current batch to new list
        new_review_ids = []
        for r in rvws:
            new_review_ids.append(r['reviewId'])
            
            # And add keys for name and id to ea review dict
            r['app_name'] = app_name # add key for app's name
            r['app_id'] = app_id     # add key for app's id
     
        # Add the list of review dicts to main app_reviews list
        app_reviews.extend(rvws)
        
        # Increase batch count by one
        batch_num +=1
        
        # Break loop and stop scraping for current app if most recent batch
          # did not add any unique reviews
        all_review_ids = pre_review_ids + new_review_ids
        if len(set(pre_review_ids)) == len(set(all_review_ids)):
            print(f'No reviews left to scrape. Completed {batch_num} batches.\n')
            break
        
        # all_review_ids becomes pre_review_ids to check against 
          # for next batch
        pre_review_ids = all_review_ids
        
        
        # At every 100th batch
        if batch_num%100==0:
            
            # print update on number of batches
            print(f'Batch {batch_num} completed.')
            
            # insert reviews into collection
            google_play_rvws.insert_many(app_reviews)
            
            # print update about num reviews inserted
            store_time = dt.datetime.now(tz=get_localzone())
            print(f"""
            Successfully inserted {len(app_reviews)} {app_name} 
            reviews into collection at {store_time.strftime(fmt)}.\n
            """)
            
            # empty our list for next round of 100 batches
            app_reviews = []
        
        # Wait 1 to 5 seconds to start next batch
        time.sleep(random.randint(1,5))
      
    
    # Print update when max number of batches has been reached
      # OR when last batch didn't add any unique reviews
    print(f'Done scraping {app_name}.')
    print(f'Scraped a total of {len(set(pre_review_ids))} unique reviews.\n')
    
    
    # Insert remaining reviews into collection
    google_play_rvws.insert_many(app_reviews)
    
    # Get end time
    end = dt.datetime.now(tz=get_localzone())
    
    # Print ending output for app
    print(f"""
    Successfully inserted all {app_name} reviews into collection
    at {end.strftime(fmt)}.\n
    """)
    print(f'Time elapsed for {app_name}: {end-start}')
    print('---'*20)
    print('---'*20)
    print('\n')
    
    # Wait 1 to 5 seconds to start scraping next app
    time.sleep(random.randint(1,5))
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Aura started at 03/24/21 - 08:07:07 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 16 batches.
#
# Done scraping Aura.
# Scraped a total of 2892 unique reviews.
#
#
#     Successfully inserted all Aura reviews into collection
#     at 03/24/21 - 08:08:38 AM.
#
#
# Time elapsed for Aura: 0:01:30.331102
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** BetterHelp started at 03/24/21 - 08:08:40 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 27 batches.
#
# Done scraping BetterHelp.
# Scraped a total of 5117 unique reviews.
#
#
#     Successfully inserted all BetterHelp reviews into collection
#     at 03/24/21 - 08:10:31 AM.
#
#
# Time elapsed for BetterHelp: 0:01:51.809191
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Breathe2Relax started at 03/24/21 - 08:10:32 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
#
# Done scraping Breathe2Relax.
# Scraped a total of 304 unique reviews.
#
#
#     Successfully inserted all Breathe2Relax reviews into collection
#     at 03/24/21 - 08:11:07 AM.
#
#
# Time elapsed for Breathe2Relax: 0:00:34.972505
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Breethe: Meditation & Sleep started at 03/24/21 - 08:11:09 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 7 batches.
#
# Done scraping Breethe: Meditation & Sleep.
# Scraped a total of 1131 unique reviews.
#
#
#     Successfully inserted all Breethe: Meditation & Sleep reviews into collection
#     at 03/24/21 - 08:11:52 AM.
#
#
# Time elapsed for Breethe: Meditation & Sleep: 0:00:42.539134
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Calm started at 03/24/21 - 08:11:55 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 Calm
#             reviews into collection at 03/24/21 - 08:18:16 AM.
#
#
# Batch 200 completed.
#
#             Successfully inserted 20000 Calm
#             reviews into collection at 03/24/21 - 08:24:36 AM.
#
#
# Batch 300 completed.
#
#             Successfully inserted 20000 Calm
#             reviews into collection at 03/24/21 - 08:30:54 AM.
#
#
# No reviews left to scrape. Completed 397 batches.
#
# Done scraping Calm.
# Scraped a total of 79008 unique reviews.
#
#
#     Successfully inserted all Calm reviews into collection
#     at 03/24/21 - 08:36:45 AM.
#
#
# Time elapsed for Calm: 0:24:50.555878
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** CBT Thought Diary started at 03/24/21 - 08:36:47 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 5 batches.
#
# Done scraping CBT Thought Diary.
# Scraped a total of 762 unique reviews.
#
#
#     Successfully inserted all CBT Thought Diary reviews into collection
#     at 03/24/21 - 08:37:26 AM.
#
#
# Time elapsed for CBT Thought Diary: 0:00:38.072508
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Daylio started at 03/24/21 - 08:37:28 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 Daylio
#             reviews into collection at 03/24/21 - 08:44:18 AM.
#
#
# Batch 200 completed.
#
#             Successfully inserted 20000 Daylio
#             reviews into collection at 03/24/21 - 08:51:04 AM.
#
#
# No reviews left to scrape. Completed 221 batches.
#
# Done scraping Daylio.
# Scraped a total of 43860 unique reviews.
#
#
#     Successfully inserted all Daylio reviews into collection
#     at 03/24/21 - 08:52:31 AM.
#
#
# Time elapsed for Daylio: 0:15:03.819416
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** DBT Coach started at 03/24/21 - 08:52:35 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
#
# Done scraping DBT Coach.
# Scraped a total of 335 unique reviews.
#
#
#     Successfully inserted all DBT Coach reviews into collection
#     at 03/24/21 - 08:53:09 AM.
#
#
# Time elapsed for DBT Coach: 0:00:33.895405
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** eMoods started at 03/24/21 - 08:53:12 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 10 batches.
#
# Done scraping eMoods.
# Scraped a total of 1631 unique reviews.
#
#
#     Successfully inserted all eMoods reviews into collection
#     at 03/24/21 - 08:54:06 AM.
#
#
# Time elapsed for eMoods: 0:00:53.991642
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** eQuoo: Emotional Fitness Game started at 03/24/21 - 08:54:10 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 8 batches.
#
# Done scraping eQuoo: Emotional Fitness Game.
# Scraped a total of 1357 unique reviews.
#
#
#     Successfully inserted all eQuoo: Emotional Fitness Game reviews into collection
#     at 03/24/21 - 08:55:06 AM.
#
#
# Time elapsed for eQuoo: Emotional Fitness Game: 0:00:55.799783
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Fabulous started at 03/24/21 - 08:55:10 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 Fabulous
#             reviews into collection at 03/24/21 - 09:01:35 AM.
#
#
# Batch 200 completed.
#
#             Successfully inserted 20000 Fabulous
#             reviews into collection at 03/24/21 - 09:07:57 AM.
#
#
# Batch 300 completed.
#
#             Successfully inserted 20000 Fabulous
#             reviews into collection at 03/24/21 - 09:15:16 AM.
#
#
# No reviews left to scrape. Completed 335 batches.
#
# Done scraping Fabulous.
# Scraped a total of 66494 unique reviews.
#
#
#     Successfully inserted all Fabulous reviews into collection
#     at 03/24/21 - 09:17:27 AM.
#
#
# Time elapsed for Fabulous: 0:22:16.539543
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** GG OCD started at 03/24/21 - 09:17:32 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping GG OCD.
# Scraped a total of 82 unique reviews.
#
#
#     Successfully inserted all GG OCD reviews into collection
#     at 03/24/21 - 09:17:53 AM.
#
#
# Time elapsed for GG OCD: 0:00:21.704662
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** GG Self Care started at 03/24/21 - 09:17:56 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping GG Self Care.
# Scraped a total of 16 unique reviews.
#
#
#     Successfully inserted all GG Self Care reviews into collection
#     at 03/24/21 - 09:18:17 AM.
#
#
# Time elapsed for GG Self Care: 0:00:20.460836
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** GG Self Esteem started at 03/24/21 - 09:18:21 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping GG Self Esteem.
# Scraped a total of 140 unique reviews.
#
#
#     Successfully inserted all GG Self Esteem reviews into collection
#     at 03/24/21 - 09:18:50 AM.
#
#
# Time elapsed for GG Self Esteem: 0:00:28.831031
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Ginger started at 03/24/21 - 09:18:54 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
#
# Done scraping Ginger.
# Scraped a total of 329 unique reviews.
#
#
#     Successfully inserted all Ginger reviews into collection
#     at 03/24/21 - 09:19:29 AM.
#
#
# Time elapsed for Ginger: 0:00:35.290168
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Habitica started at 03/24/21 - 09:19:32 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 25 batches.
#
# Done scraping Habitica.
# Scraped a total of 4655 unique reviews.
#
#
#     Successfully inserted all Habitica reviews into collection
#     at 03/24/21 - 09:21:34 AM.
#
#
# Time elapsed for Habitica: 0:02:02.136830
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Happify started at 03/24/21 - 09:21:36 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 6 batches.
#
# Done scraping Happify.
# Scraped a total of 855 unique reviews.
#
#
#     Successfully inserted all Happify reviews into collection
#     at 03/24/21 - 09:22:21 AM.
#
#
# Time elapsed for Happify: 0:00:44.635189
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Happyfeed started at 03/24/21 - 09:22:26 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping Happyfeed.
# Scraped a total of 119 unique reviews.
#
#
#     Successfully inserted all Happyfeed reviews into collection
#     at 03/24/21 - 09:22:53 AM.
#
#
# Time elapsed for Happyfeed: 0:00:26.875699
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Headspace started at 03/24/21 - 09:22:55 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 Headspace
#             reviews into collection at 03/24/21 - 09:30:46 AM.
#
#
# Batch 200 completed.
#
#             Successfully inserted 20000 Headspace
#             reviews into collection at 03/24/21 - 09:36:51 AM.
#
#
# No reviews left to scrape. Completed 266 batches.
#
# Done scraping Headspace.
# Scraped a total of 52968 unique reviews.
#
#
#     Successfully inserted all Headspace reviews into collection
#     at 03/24/21 - 09:42:45 AM.
#
#
# Time elapsed for Headspace: 0:19:50.076168
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Healthy Minds Program started at 03/24/21 - 09:42:46 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping Healthy Minds Program.
# Scraped a total of 194 unique reviews.
#
#
#     Successfully inserted all Healthy Minds Program reviews into collection
#     at 03/24/21 - 09:43:13 AM.
#
#
# Time elapsed for Healthy Minds Program: 0:00:27.083369
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** HearMe started at 03/24/21 - 09:43:18 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 5 batches.
#
# Done scraping HearMe.
# Scraped a total of 634 unique reviews.
#
#
#     Successfully inserted all HearMe reviews into collection
#     at 03/24/21 - 09:43:53 AM.
#
#
# Time elapsed for HearMe: 0:00:35.456697
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** I Am Sober started at 03/24/21 - 09:43:56 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 38 batches.
#
# Done scraping I Am Sober.
# Scraped a total of 7341 unique reviews.
#
#
#     Successfully inserted all I Am Sober reviews into collection
#     at 03/24/21 - 09:46:35 AM.
#
#
# Time elapsed for I Am Sober: 0:02:38.890567
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** InnerHour: Self-Care Therapy started at 03/24/21 - 09:46:38 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 14 batches.
#
# Done scraping InnerHour: Self-Care Therapy.
# Scraped a total of 2537 unique reviews.
#
#
#     Successfully inserted all InnerHour: Self-Care Therapy reviews into collection
#     at 03/24/21 - 09:47:57 AM.
#
#
# Time elapsed for InnerHour: Self-Care Therapy: 0:01:19.191399
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Insight Timer started at 03/24/21 - 09:47:59 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 Insight Timer
#             reviews into collection at 03/24/21 - 09:54:46 AM.
#
#
# No reviews left to scrape. Completed 131 batches.
#
# Done scraping Insight Timer.
# Scraped a total of 25674 unique reviews.
#
#
#     Successfully inserted all Insight Timer reviews into collection
#     at 03/24/21 - 09:57:58 AM.
#
#
# Time elapsed for Insight Timer: 0:09:58.393304
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Lyf started at 03/24/21 - 09:58:00 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 5 batches.
#
# Done scraping Lyf.
# Scraped a total of 698 unique reviews.
#
#
#     Successfully inserted all Lyf reviews into collection
#     at 03/24/21 - 09:58:44 AM.
#
#
# Time elapsed for Lyf: 0:00:44.020755
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Meditopia: Meditation Coach started at 03/24/21 - 09:58:49 AM
# Batch 1 completed.
# No reviews left to scrape. Completed 11 batches.
#
# Done scraping Meditopia: Meditation Coach.
# Scraped a total of 1963 unique reviews.
#
#
#     Successfully inserted all Meditopia: Meditation Coach reviews into collection
#     at 03/24/21 - 09:59:59 AM.
#
#
# Time elapsed for Meditopia: Meditation Coach: 0:01:09.868200
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** MindDoc started at 03/24/21 - 10:00:00 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 40 batches.
#
# Done scraping MindDoc.
# Scraped a total of 7667 unique reviews.
#
#
#     Successfully inserted all MindDoc reviews into collection
#     at 03/24/21 - 10:02:50 AM.
#
#
# Time elapsed for MindDoc: 0:02:50.805281
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** MindShift CBT started at 03/24/21 - 10:02:51 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 4 batches.
#
# Done scraping MindShift CBT.
# Scraped a total of 421 unique reviews.
#
#
#     Successfully inserted all MindShift CBT reviews into collection
#     at 03/24/21 - 10:03:18 AM.
#
#
# Time elapsed for MindShift CBT: 0:00:26.442037
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Moodfit started at 03/24/21 - 10:03:20 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
#
# Done scraping Moodfit.
# Scraped a total of 216 unique reviews.
#
#
#     Successfully inserted all Moodfit reviews into collection
#     at 03/24/21 - 10:03:56 AM.
#
#
# Time elapsed for Moodfit: 0:00:36.018445
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** MoodMission started at 03/24/21 - 10:04:01 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping MoodMission.
# Scraped a total of 68 unique reviews.
#
#
#     Successfully inserted all MoodMission reviews into collection
#     at 03/24/21 - 10:04:32 AM.
#
#
# Time elapsed for MoodMission: 0:00:31.055333
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** MyLife Meditation started at 03/24/21 - 10:04:34 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 42 batches.
#
# Done scraping MyLife Meditation.
# Scraped a total of 8138 unique reviews.
#
#
#     Successfully inserted all MyLife Meditation reviews into collection
#     at 03/24/21 - 10:07:42 AM.
#
#
# Time elapsed for MyLife Meditation: 0:03:08.489075
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** NOCD started at 03/24/21 - 10:07:43 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping NOCD.
# Scraped a total of 148 unique reviews.
#
#
#     Successfully inserted all NOCD reviews into collection
#     at 03/24/21 - 10:08:07 AM.
#
#
# Time elapsed for NOCD: 0:00:23.984588
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** PTSD Coach started at 03/24/21 - 10:08:11 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
#
# Done scraping PTSD Coach.
# Scraped a total of 339 unique reviews.
#
#
#     Successfully inserted all PTSD Coach reviews into collection
#     at 03/24/21 - 10:08:37 AM.
#
#
# Time elapsed for PTSD Coach: 0:00:25.203303
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Reflectly started at 03/24/21 - 10:08:38 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 80 batches.
#
# Done scraping Reflectly.
# Scraped a total of 15645 unique reviews.
#
#
#     Successfully inserted all Reflectly reviews into collection
#     at 03/24/21 - 10:14:59 AM.
#
#
# Time elapsed for Reflectly: 0:06:21.504496
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Remente started at 03/24/21 - 10:15:02 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 13 batches.
#
# Done scraping Remente.
# Scraped a total of 2308 unique reviews.
#
#
#     Successfully inserted all Remente reviews into collection
#     at 03/24/21 - 10:16:09 AM.
#
#
# Time elapsed for Remente: 0:01:07.090501
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Rise Up + Recover started at 03/24/21 - 10:16:14 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 2 batches.
#
# Done scraping Rise Up + Recover.
# Scraped a total of 162 unique reviews.
#
#
#     Successfully inserted all Rise Up + Recover reviews into collection
#     at 03/24/21 - 10:16:38 AM.
#
#
# Time elapsed for Rise Up + Recover: 0:00:23.809442
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Rootd started at 03/24/21 - 10:16:42 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 4 batches.
#
# Done scraping Rootd.
# Scraped a total of 436 unique reviews.
#
#
#     Successfully inserted all Rootd reviews into collection
#     at 03/24/21 - 10:17:13 AM.
#
#
# Time elapsed for Rootd: 0:00:30.529044
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** RR Eating Disorder Management started at 03/24/21 - 10:17:15 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 14 batches.
#
# Done scraping RR Eating Disorder Management.
# Scraped a total of 2468 unique reviews.
#
#
#     Successfully inserted all RR Eating Disorder Management reviews into collection
#     at 03/24/21 - 10:18:22 AM.
#
#
# Time elapsed for RR Eating Disorder Management: 0:01:07.672256
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Sanvello started at 03/24/21 - 10:18:24 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 30 batches.
#
# Done scraping Sanvello.
# Scraped a total of 5791 unique reviews.
#
#
#     Successfully inserted all Sanvello reviews into collection
#     at 03/24/21 - 10:20:30 AM.
#
#
# Time elapsed for Sanvello: 0:02:05.425703
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Shine started at 03/24/21 - 10:20:33 AM
# Batch 1 completed.
# No reviews left to scrape. Completed 19 batches.
#
# Done scraping Shine.
# Scraped a total of 3458 unique reviews.
#
#
#     Successfully inserted all Shine reviews into collection
#     at 03/24/21 - 10:21:57 AM.
#
#
# Time elapsed for Shine: 0:01:24.653236
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Smiling Mind started at 03/24/21 - 10:22:02 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 9 batches.
#
# Done scraping Smiling Mind.
# Scraped a total of 1566 unique reviews.
#
#
#     Successfully inserted all Smiling Mind reviews into collection
#     at 03/24/21 - 10:23:02 AM.
#
#
# Time elapsed for Smiling Mind: 0:00:59.879870
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Sober Time started at 03/24/21 - 10:23:04 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 44 batches.
#
# Done scraping Sober Time.
# Scraped a total of 8501 unique reviews.
#
#
#     Successfully inserted all Sober Time reviews into collection
#     at 03/24/21 - 10:26:29 AM.
#
#
# Time elapsed for Sober Time: 0:03:24.854541
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** SuperBetter started at 03/24/21 - 10:26:32 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 11 batches.
#
# Done scraping SuperBetter.
# Scraped a total of 1954 unique reviews.
#
#
#     Successfully inserted all SuperBetter reviews into collection
#     at 03/24/21 - 10:27:42 AM.
#
#
# Time elapsed for SuperBetter: 0:01:10.213348
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Talk Life started at 03/24/21 - 10:27:45 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 54 batches.
#
# Done scraping Talk Life.
# Scraped a total of 10419 unique reviews.
#
#
#     Successfully inserted all Talk Life reviews into collection
#     at 03/24/21 - 10:31:16 AM.
#
#
# Time elapsed for Talk Life: 0:03:30.541594
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Talkspace started at 03/24/21 - 10:31:17 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 11 batches.
#
# Done scraping Talkspace.
# Scraped a total of 1840 unique reviews.
#
#
#     Successfully inserted all Talkspace reviews into collection
#     at 03/24/21 - 10:32:15 AM.
#
#
# Time elapsed for Talkspace: 0:00:58.064164
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Ten Percent Happier started at 03/24/21 - 10:32:19 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 27 batches.
#
# Done scraping Ten Percent Happier.
# Scraped a total of 5108 unique reviews.
#
#
#     Successfully inserted all Ten Percent Happier reviews into collection
#     at 03/24/21 - 10:34:21 AM.
#
#
# Time elapsed for Ten Percent Happier: 0:02:01.693378
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** The Mighty started at 03/24/21 - 10:34:25 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 8 batches.
#
# Done scraping The Mighty.
# Scraped a total of 1211 unique reviews.
#
#
#     Successfully inserted all The Mighty reviews into collection
#     at 03/24/21 - 10:35:11 AM.
#
#
# Time elapsed for The Mighty: 0:00:45.975299
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Virtual Hope Box started at 03/24/21 - 10:35:16 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
#
# Done scraping Virtual Hope Box.
# Scraped a total of 257 unique reviews.
#
#
#     Successfully inserted all Virtual Hope Box reviews into collection
#     at 03/24/21 - 10:35:44 AM.
#
#
# Time elapsed for Virtual Hope Box: 0:00:28.334087
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Waking Up: Guided Meditation started at 03/24/21 - 10:35:45 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 47 batches.
#
# Done scraping Waking Up: Guided Meditation.
# Scraped a total of 9038 unique reviews.
#
#
#     Successfully inserted all Waking Up: Guided Meditation reviews into collection
#     at 03/24/21 - 10:39:10 AM.
#
#
# Time elapsed for Waking Up: Guided Meditation: 0:03:24.994849
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** What's Up? started at 03/24/21 - 10:39:11 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 6 batches.
#
# Done scraping What's Up?.
# Scraped a total of 947 unique reviews.
#
#
#     Successfully inserted all What's Up? reviews into collection
#     at 03/24/21 - 10:39:46 AM.
#
#
# Time elapsed for What's Up?: 0:00:35.234178
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Wisdo started at 03/24/21 - 10:39:51 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 6 batches.
#
# Done scraping Wisdo.
# Scraped a total of 936 unique reviews.
#
#
#     Successfully inserted all Wisdo reviews into collection
#     at 03/24/21 - 10:41:25 AM.
#
#
# Time elapsed for Wisdo: 0:01:34.214228
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Woebot started at 03/24/21 - 10:41:28 AM
#
# Batch 1 completed.
# No reviews left to scrape. Completed 22 batches.
#
# Done scraping Woebot.
# Scraped a total of 4091 unique reviews.
#
#
#     Successfully inserted all Woebot reviews into collection
#     at 03/24/21 - 10:43:05 AM.
#
#
# Time elapsed for Woebot: 0:01:36.297658
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Wysa started at 03/24/21 - 10:43:06 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#             Successfully inserted 20000 Wysa
#             reviews into collection at 03/24/21 - 10:49:25 AM.
#
#
# No reviews left to scrape. Completed 138 batches.
#
# Done scraping Wysa.
# Scraped a total of 27354 unique reviews.
#
#
#     Successfully inserted all Wysa reviews into collection
#     at 03/24/21 - 10:51:54 AM.
#
#
# Time elapsed for Wysa: 0:08:47.885762
# ------------------------------------------------------------
# ------------------------------------------------------------

# %% [markdown]
# ### Initial Exploration of Google Play Reviews

# %%
## Query collection to get DataFrame with all reviews
gp_rvw_df = pd.DataFrame(list(google_play_rvws.find({})))
gp_rvw_df.head()
# Out:
#                         _id  \
# 0  605b2bc5212470a175e95299
# 1  605b2bc5212470a175e9529a
# 2  605b2bc5212470a175e9529b
# 3  605b2bc5212470a175e9529c
# 4  605b2bc5212470a175e9529d
#
#                                             reviewId           userName  \
# 0  gp:AOqpTOGEfB5SuxUR45DJRzXJ13FFXszz7sHe0-EHZg9...       Melanie Loya
# 1  gp:AOqpTOEN7u1-0qBPlPuUQOydnhZucb7zs5I4edD6-7r...          Deb Perez
# 2  gp:AOqpTOHckNKYL0-HbSxg7mzO7YjQJ73fGmlpcW-H4uX...         Zvon Davis
# 3  gp:AOqpTOHx1iKm-H5IA8Rn7GDMz72FNxb2SHEJs0HcKkA...  Mary Ellen Gambon
# 4  gp:AOqpTOGA3muyUwk8gsdm92NYEy4R9L88BGaJLaC571U...       Amie Sandlin
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/-jQ70Y4S...
# 2  https://play-lh.googleusercontent.com/-cjE-8ul...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0                                            Awesome      5              0
# 1                              Great to help u sleep      5              0
# 2                             Very calming, love it!      5              0
# 3  I was able to sleep like a baby on the first u...      5              0
# 4        Improvement in thoughts, feelings and life!      5              0
#
#   reviewCreatedVersion                  at  \
# 0                2.4.2 2021-03-22 05:59:22
# 1                2.4.2 2021-03-21 20:29:44
# 2                2.4.2 2021-03-21 09:17:13
# 3                2.4.2 2021-03-21 09:09:57
# 4                2.4.2 2021-03-20 16:28:42
#
#                                         replyContent           repliedAt  \
# 0  Thanks for taking out time to rate us. It real... 2021-03-23 20:30:23
# 1  Thank you for your feedback. Glad to hear that... 2021-03-23 20:29:17
# 2       Glad you like it! :) Thanks for your review! 2021-03-23 20:27:04
# 3  We are pleased that you enjoyed the app. If th... 2021-03-23 20:26:24
# 4  Thank you for your review. Enjoy using the app... 2021-03-23 20:30:04
#
#   app_name          app_id
# 0     Aura  com.aurahealth
# 1     Aura  com.aurahealth
# 2     Aura  com.aurahealth
# 3     Aura  com.aurahealth
# 4     Aura  com.aurahealth

# %%
## Check total number of reviews scraped and stored in collection
len(gp_rvw_df)
# Out:
# 431908

# %%
## Check number of unique reviews stored in collection
gp_rvw_df['reviewId'].nunique()
# Out:
# 421583

# %%
## Total of 10325 duplicate reviews in collection
len(gp_rvw_df) - gp_rvw_df['reviewId'].nunique()
# Out:
# 10325

# %%
## Drop duplicate reviews
gp_rvw_df = gp_rvw_df.drop(columns=['_id'])
gp_rvw_df = gp_rvw_df.drop_duplicates(['reviewId'])
print(len(gp_rvw_df))
gp_rvw_df['reviewId'].nunique()
# Out:
# 421583
# 421583

# %%
## Also save df to csv
# gp_rvw_df.to_csv('Data/google_play_rvws.csv', index=False)

# %%
pd.read_csv('Data/google_play_rvws.csv')
# Out:
#                                                  reviewId  \
# 0       gp:AOqpTOGEfB5SuxUR45DJRzXJ13FFXszz7sHe0-EHZg9...
# 1       gp:AOqpTOEN7u1-0qBPlPuUQOydnhZucb7zs5I4edD6-7r...
# 2       gp:AOqpTOHckNKYL0-HbSxg7mzO7YjQJ73fGmlpcW-H4uX...
# 3       gp:AOqpTOHx1iKm-H5IA8Rn7GDMz72FNxb2SHEJs0HcKkA...
# 4       gp:AOqpTOGA3muyUwk8gsdm92NYEy4R9L88BGaJLaC571U...
# ...                                                   ...
# 421578  gp:AOqpTOHj3wM0-mJxNg3DGPRoUbq8A8q8fGjtBf8G-tP...
# 421579  gp:AOqpTOHXIS7_gR1Soe1VYl6zXQ7UeOZDuAj1ftclfzb...
# 421580  gp:AOqpTOEPiEXyZn-UjBu_J5LmdF2TY9XCigYmvTwtUL6...
# 421581  gp:AOqpTOHQEuLNWcKhTAFMl4JJFBeqjXZ4aFOCPhurxz0...
# 421582  gp:AOqpTOEtSZNPtjhOKwQz8dsqaiddguYd3IN3ZTwX5mF...
#
#                       userName  \
# 0                 Melanie Loya
# 1                    Deb Perez
# 2                   Zvon Davis
# 3            Mary Ellen Gambon
# 4                 Amie Sandlin
# ...                        ...
# 421578  palwinder Singh wadali
# 421579            shampa singh
# 421580            Swami Nathan
# 421581            Amulya Singh
# 421582        Chinmaya Vempati
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a-/AOh14...
# 1       https://play-lh.googleusercontent.com/-jQ70Y4S...
# 2       https://play-lh.googleusercontent.com/-cjE-8ul...
# 3       https://play-lh.googleusercontent.com/a-/AOh14...
# 4       https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                   ...
# 421578  https://play-lh.googleusercontent.com/a-/AOh14...
# 421579  https://play-lh.googleusercontent.com/a-/AOh14...
# 421580  https://play-lh.googleusercontent.com/a-/AOh14...
# 421581  https://play-lh.googleusercontent.com/a-/AOh14...
# 421582  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                   content  score  \
# 0                                                 Awesome      5
# 1                                   Great to help u sleep      5
# 2                                  Very calming, love it!      5
# 3       I was able to sleep like a baby on the first u...      5
# 4             Improvement in thoughts, feelings and life!      5
# ...                                                   ...    ...
# 421578                                           Loved it      5
# 421579  Sometimes we just need a ear or sometimes the ...      5
# 421580  Innovative thinking,... feeling good while int...      5
# 421581                                      Great concept      5
# 421582  App makes a difference, feels like I'm talking...      5
#
#         thumbsUpCount reviewCreatedVersion                   at  \
# 0                   0                2.4.2  2021-03-22 05:59:22
# 1                   0                2.4.2  2021-03-21 20:29:44
# 2                   0                2.4.2  2021-03-21 09:17:13
# 3                   0                2.4.2  2021-03-21 09:09:57
# 4                   0                2.4.2  2021-03-20 16:28:42
# ...               ...                  ...                  ...
# 421578              0                  NaN  2016-10-28 02:31:14
# 421579              2                0.1.6  2016-10-24 08:14:25
# 421580              0                0.1.5  2016-10-16 11:03:57
# 421581              2                  NaN  2016-10-12 12:31:21
# 421582              3                0.1.3  2016-10-08 02:45:03
#
#                                              replyContent  \
# 0       Thanks for taking out time to rate us. It real...
# 1       Thank you for your feedback. Glad to hear that...
# 2            Glad you like it! :) Thanks for your review!
# 3       We are pleased that you enjoyed the app. If th...
# 4       Thank you for your review. Enjoy using the app...
# ...                                                   ...
# 421578                                                NaN
# 421579                                                NaN
# 421580                                                NaN
# 421581                                                NaN
# 421582                                                NaN
#
#                   repliedAt app_name          app_id
# 0       2021-03-23 20:30:23     Aura  com.aurahealth
# 1       2021-03-23 20:29:17     Aura  com.aurahealth
# 2       2021-03-23 20:27:04     Aura  com.aurahealth
# 3       2021-03-23 20:26:24     Aura  com.aurahealth
# 4       2021-03-23 20:30:04     Aura  com.aurahealth
# ...                     ...      ...             ...
# 421578                  NaN     Wysa    bot.touchkin
# 421579                  NaN     Wysa    bot.touchkin
# 421580                  NaN     Wysa    bot.touchkin
# 421581                  NaN     Wysa    bot.touchkin
# 421582                  NaN     Wysa    bot.touchkin
#
# [421583 rows x 12 columns]

# %%
client.close()

# %%
## Check number of reviews of each score
gp_rvw_df['score'].value_counts()
# Out:
# 5    299787
# 4     50742
# 1     41445
# 3     17147
# 2     12458
# 0         4
# Name: score, dtype: int64

# %%
## Investigate reviews with score of 0
gp_rvw_df.loc[gp_rvw_df['score']==0]
# Out:
#                                                  reviewId       userName  \
# 136599  lg:AOqpTOGsj_LVg67dhWdCAq9tKTZc0-0XEVJg2XDecQk...  A Google user
# 136617  lg:AOqpTOEGU8eCnOPE2e4R9OySOzvjPBpxOjOzkNLBLqI...  A Google user
# 302669  lg:AOqpTOHuDt_mvw1uaEczz0mR-0TesuygXb4QTtzmS6-...  A Google user
# 302770  lg:AOqpTOF-aG0BhkhdpKEL6V_yHtV6KQAtSqb-AYH2LH4...  A Google user
#
#                                                 userImage  \
# 136599  https://play-lh.googleusercontent.com/EGemoI2N...
# 136617  https://play-lh.googleusercontent.com/EGemoI2N...
# 302669  https://play-lh.googleusercontent.com/EGemoI2N...
# 302770  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 136599  Is there a way to use this app for two people?...      0
# 136617  Would be nice to have a symbol for the levels ...      0
# 302669                        Mindfully magnificent _/|\_      0
# 302770                      Exactly as described. Thanks.      0
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 136599              0                  1.0 2011-02-03 22:06:42         None
# 136617              0                  1.0 2010-12-18 21:32:30         None
# 302669              0                8.3.2 2012-05-03 19:50:18         None
# 302770              0                8.3.1 2011-02-14 21:44:42         None
#
#        repliedAt       app_name                          app_id
# 136599       NaT         eMoods                      my.tracker
# 136617       NaT         eMoods                      my.tracker
# 302669       NaT  Insight Timer  com.spotlightsix.zentimerlite2
# 302770       NaT  Insight Timer  com.spotlightsix.zentimerlite2

# %%
## Plot distribution of review scores
plt.figure(figsize=(8,6))
g = sns.countplot(data=gp_rvw_df, x='score', palette='nipy_spectral');

# %%
## Check which apps had so many reviews that they were
  ## so new that earliest review 
  ## doesn't go all the way back to March 2020
for app in gp_rvw_df['app_name'].unique():
    
    earliest_rvw = min(gp_rvw_df.loc[gp_rvw_df['app_name']==app]['at'])
    
    if earliest_rvw > dt.datetime(2020, 2, 28): 
    
        print(f"""Earliest review for {app}: 
            {min(gp_rvw_df.loc[gp_rvw_df['app_name']==app]['at'])}\n""")
# Out:
# Earliest review for GG Self Care:
#             2020-03-20 23:44:00

# %%
temp_list = []

for app in gp_rvw_df['app_name'].unique():
    
    app_slice = gp_rvw_df.loc[gp_rvw_df['app_name']==app].copy()
    
    cutoff_date = dt.datetime(2020, 2, 28)
    
    total_count = len(app_slice)
    
    count_from_Mar2020 = len(app_slice.loc[app_slice['at']>cutoff_date])
    
    earliest_rvw = min(app_slice['at'])
    
    temp_dict = {}
    temp_dict['app_name'] = app
    temp_dict['total_rvws'] = total_count
    temp_dict['rvws_since_Mar2020'] = count_from_Mar2020
    temp_dict['earliest_rvw'] = earliest_rvw
    
    temp_list.append(temp_dict)
    
app_Mar2020 = pd.DataFrame(temp_list)
app_Mar2020
# Out:
#                          app_name  total_rvws  rvws_since_Mar2020  \
# 0                            Aura        2892                 849
# 1                      BetterHelp        5117                2340
# 2                   Breathe2Relax         304                  33
# 3     Breethe: Meditation & Sleep        1131                 381
# 4                            Calm       79008               18578
# 5               CBT Thought Diary         762                 500
# 6                          Daylio       43860                4956
# 7                       DBT Coach         335                 178
# 8                          eMoods        1631                  88
# 9   eQuoo: Emotional Fitness Game        1357                 664
# 10                       Fabulous       66494               15708
# 11                         GG OCD          82                  32
# 12                   GG Self Care          16                  16
# 13                 GG Self Esteem         140                  35
# 14                         Ginger         329                  39
# 15                       Habitica        4655                 870
# 16                        Happify         855                 126
# 17                      Happyfeed         119                  72
# 18                      Headspace       52968               13699
# 19          Healthy Minds Program         194                 179
# 20                         HearMe         634                 627
# 21                     I Am Sober        7341                3159
# 22   InnerHour: Self-Care Therapy        2537                1278
# 23                  Insight Timer       25674               10651
# 24                            Lyf         698                 296
# 25    Meditopia: Meditation Coach        1963                1399
# 26                        MindDoc        7667                2069
# 27                  MindShift CBT         421                  98
# 28                        Moodfit         216                  91
# 29                    MoodMission          68                   8
# 30              MyLife Meditation        8138                3293
# 31                           NOCD         148                  77
# 32                     PTSD Coach         339                 223
# 33                      Reflectly       15645                5880
# 34                        Remente        2308                 267
# 35              Rise Up + Recover         162                  15
# 36                          Rootd         436                 235
# 37  RR Eating Disorder Management        2468                 296
# 38                       Sanvello        5791                2160
# 39                          Shine        3458                1756
# 40                   Smiling Mind        1566                 540
# 41                     Sober Time        8501                1871
# 42                    SuperBetter        1954                 110
# 43                      Talk Life       10419                2251
# 44                      Talkspace        1840                 569
# 45            Ten Percent Happier        5108                1646
# 46                     The Mighty        1211                 823
# 47               Virtual Hope Box         257                  27
# 48   Waking Up: Guided Meditation        9038                5471
# 49                     What's Up?         947                 109
# 50                          Wisdo         936                 145
# 51                         Woebot        4091                1330
# 52                           Wysa       27354               14691
#
#           earliest_rvw
# 0  2017-03-21 19:33:22
# 1  2014-11-21 16:39:51
# 2  2011-12-23 15:20:52
# 3  2016-01-26 14:16:12
# 4  2014-08-01 03:05:55
# 5  2014-07-08 08:59:50
# 6  2015-08-21 05:07:56
# 7  2019-03-06 15:48:18
# 8  2010-10-13 08:57:44
# 9  2017-12-26 15:12:59
# 10 2013-12-01 15:02:32
# 11 2016-12-13 14:45:46
# 12 2020-03-20 23:44:00
# 13 2017-12-11 07:55:09
# 14 2013-04-24 22:16:53
# 15 2015-12-10 17:04:30
# 16 2015-05-01 03:45:32
# 17 2019-05-21 15:13:55
# 18 2012-01-07 04:59:19
# 19 2018-06-27 07:35:14
# 20 2019-12-13 19:20:27
# 21 2014-04-19 09:45:16
# 22 2017-09-08 09:45:54
# 23 2010-12-25 13:30:12
# 24 2016-03-01 06:04:06
# 25 2017-03-07 14:48:30
# 26 2017-06-20 17:36:04
# 27 2013-06-17 16:42:31
# 28 2017-02-28 10:50:39
# 29 2017-02-08 02:26:37
# 30 2014-09-29 10:34:25
# 31 2018-12-12 16:32:15
# 32 2016-08-28 14:26:40
# 33 2017-09-26 07:02:27
# 34 2015-05-22 11:57:42
# 35 2015-02-24 01:49:50
# 36 2017-10-14 02:05:56
# 37 2011-12-09 06:18:56
# 38 2015-01-27 00:20:51
# 39 2018-12-28 21:08:17
# 40 2014-10-08 23:04:47
# 41 2015-02-23 17:46:55
# 42 2014-11-30 13:23:17
# 43 2013-11-03 14:07:47
# 44 2014-12-06 01:30:44
# 45 2017-10-24 06:48:12
# 46 2019-09-03 19:42:30
# 47 2014-02-27 15:30:44
# 48 2018-08-06 18:41:39
# 49 2015-03-11 04:15:59
# 50 2018-04-26 16:36:19
# 51 2018-03-10 22:50:38
# 52 2016-10-08 02:45:03

# %%
client.close()
