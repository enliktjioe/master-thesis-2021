# %% [markdown]
# # Part I.I - Obtain App Info Data

# %%
## Import necessary libraries

# retrieves app info from App Store
from itunes_app_scraper.scraper import AppStoreScraper
# retrieves reviews from App Store
from app_store_scraper import AppStore

# retrieves app info AND reviews from Google Play
from google_play_scraper import app, Sort, reviews, reviews_all

# pretty print data structures
from pprint import pprint

# for storing in MongoDB
import pymongo
from pymongo import MongoClient

import datetime as dt
from tzlocal import get_localzone

import random
import time

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
## Read in file containing app details, 
  ## need the app IDs for scraping stores
app_df = pd.read_csv('Data/mha_app_info.csv')
app_df.head()
# Out:
#                          app_name  iOS  iOS_revs  \
# 0                        Aloe Bud    1      3000
# 1                            Aura    1     22100
# 2                      BetterHelp    1     32400
# 3                   Breathe2Relax    1       200
# 4  Breathwrk: Breathing Exercises    1     10400
#
#                    iOS_app_name  iOS_app_id  android  android_revs  \
# 0                      aloe-bud  1318382054        0             0
# 1         aura-meditation-sleep  1114223104        1         10400
# 2  betterhelp-online-counseling   995252384        1         15300
# 3                 breathe2relax   425720246        1          1100
# 4                     breathwrk  1481804500        0             0
#
#                 android_appID
# 0                         NaN
# 1              com.aurahealth
# 2              com.betterhelp
# 3  org.t2health.breathe2relax
# 4                         NaN

# %%
## Store list of app ids to loop through for both stores
app_store_ids = list(app_df['iOS_app_id'])
google_play_ids = list(app_df['android_appID'].dropna())

# %%
## Check number of apps found in App Store
len(app_store_ids)
# Out:
# 64

# %%
## Only 47 of the total 56 are also available for Android
len(google_play_ids)
# Out:
# 53

# %% [markdown]
# ## Set Up MongoDB for Project

# %%
## Set up Mongo client
client = MongoClient(host='localhost', port=27018)

# %%
## Set up new database for project
mha_proj_db = client['mha_proj_db']

# %% [markdown]
# ## Scrape General Info about Each App
# ### Scrape App Info from App Store

# %%
## Set up App Store Scraper
scraper = AppStoreScraper()
app_store_list = list(scraper.get_multiple_app_details(app_store_ids))
pprint(app_store_list)
# Out:
# https://itunes.apple.com/lookup?id=1318382054&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1114223104&country=nl&entity=software
# https://itunes.apple.com/lookup?id=995252384&country=nl&entity=software
# https://itunes.apple.com/lookup?id=425720246&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1481804500&country=nl&entity=software
# https://itunes.apple.com/lookup?id=920161006&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1450365119&country=nl&entity=software
# https://itunes.apple.com/lookup?id=571800810&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1010391170&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1194023242&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1452264969&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1184456130&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1318726049&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1203637303&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1140486359&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1489604281&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1300107718&country=nl&entity=software
# https://itunes.apple.com/lookup?id=515118602&country=nl&entity=software
# https://itunes.apple.com/lookup?id=994882113&country=nl&entity=software
# https://itunes.apple.com/lookup?id=730601963&country=nl&entity=software
# https://itunes.apple.com/lookup?id=707073943&country=nl&entity=software
# https://itunes.apple.com/lookup?id=493145008&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1326310617&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1417672401&country=nl&entity=software
# https://itunes.apple.com/lookup?id=672904239&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1296605806&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1323264990&country=nl&entity=software
# https://itunes.apple.com/lookup?id=337472899&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1439590239&country=nl&entity=software
# https://itunes.apple.com/lookup?id=909556526&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1190294015&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1052216403&country=nl&entity=software
# https://itunes.apple.com/lookup?id=634684825&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1054458809&country=nl&entity=software
# https://itunes.apple.com/lookup?id=427064987&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1140332763&country=nl&entity=software
# https://itunes.apple.com/lookup?id=778848692&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1063365447&country=nl&entity=software
# https://itunes.apple.com/lookup?id=430646302&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1241229134&country=nl&entity=software
# https://itunes.apple.com/lookup?id=961633456&country=nl&entity=software
# https://itunes.apple.com/lookup?id=509287014&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1289018369&country=nl&entity=software
# https://itunes.apple.com/lookup?id=457360959&country=nl&entity=software
# https://itunes.apple.com/lookup?id=922968861&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1444244578&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1293721589&country=nl&entity=software
# https://itunes.apple.com/lookup?id=560442518&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1158895079&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1506576652&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1312926037&country=nl&entity=software
# https://itunes.apple.com/lookup?id=536634968&country=nl&entity=software
# https://itunes.apple.com/lookup?id=449804588&country=nl&entity=software
# https://itunes.apple.com/lookup?id=661829386&country=nl&entity=software
# https://itunes.apple.com/lookup?id=992210239&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1432324582&country=nl&entity=software
# https://itunes.apple.com/lookup?id=825099621&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1307736395&country=nl&entity=software
# https://itunes.apple.com/lookup?id=968251160&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1273601356&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1305375832&country=nl&entity=software
# https://itunes.apple.com/lookup?id=693833917&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1166585565&country=nl&entity=software
# https://itunes.apple.com/lookup?id=1060691513&country=nl&entity=software
# [{'advisories': '',
#   'appletvScreenshotUrls': '',
#   'artistId': 1170681391,
#   'artistName': 'Aloebud LLC',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/aloebud-llc/id1170681391?uo=4',
#   'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Purple123/v4/3f/88/01/3f880181-259a-a8b0-54db-3c8cecd48f9f/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is4-ssl.mzstatic.com/image/thumb/Purple123/v4/3f/88/01/3f880181-259a-a8b0-54db-3c8cecd48f9f/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Purple123/v4/3f/88/01/3f880181-259a-a8b0-54db-3c8cecd48f9f/source/60x60bb.jpg',
#   'averageUserRating': 4.61538,
#   'averageUserRatingForCurrentVersion': 4.61538,
#   'bundleId': 'club.aloe.Aloe',
#   'contentAdvisoryRating': '4+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2020-06-25T21:20:25Z',
#   'description': 'Aloe Bud is your all-in-one, self-care pocket companion. We '
#                  'gently bring awareness to self-care activities, using '
#                  'encouraging push notifications, rather than guilt or shame. '
#                  'Helpful reminders from yourself, to yourself; saved within '
#                  'Aloe Bud so you can keep doing you! What areas of self-care '
#                  'do you need more of in your life?\n'
#                  '\n'
#                  "Whether you're trying to stay hydrated, or need reminders to "
#                  'get in touch with friends. Check-in and reflect on yourself '
#                  'in real-time or as you need.\n'
#                  '\n'
#                  'Hydrate\n'
#                  'Move\n'
#                  'Breathe\n'
#                  'Health\n'
#                  'Break\n'
#                  'Rest\n'
#                  'Fuel\n'
#                  'Refresh\n'
#                  'People\n'
#                  'Stimulate\n'
#                  'Motivate\n'
#                  '\n'
#                  'ACTIVITY CARDS\n'
#                  'Add activity cards to your personal dashboard, according to '
#                  'what you believe needs extra attention today or in the near '
#                  'future. Activity cards cover everything, from the mundane '
#                  '(such as filling up water bottles and remembering to take '
#                  'screen breaks) to the larger picture (journaling about '
#                  'personal relationships and remembering who or what you’re '
#                  'grateful for).\n'
#                  '\n'
#                  'SCHEDULED REMINDERS (OPT-IN)\n'
#                  'Aloe Bud sends reminders only when asked and can be set at '
#                  'specific times from daily to weekdays, weekends, or any '
#                  'other arrangement you can think of. Reminders bring '
#                  'awareness to important activities, that get lost among other '
#                  'priorities.\n'
#                  '\n'
#                  'Create and develop self-care routines that work for you. '
#                  'Aloe Bud brings awareness to physical, mental and emotional '
#                  'needs throughout the day using unobtrusive push '
#                  'notifications. \n'
#                  '\n'
#                  'RECENT ACTIVITY LOG\n'
#                  'Celebrate tiny victories in your personal activity log, that '
#                  'can be accessed when you touch the icon at the top. Scroll '
#                  'through recently completed check in’s and reflections and '
#                  'look back on your progress day by day.\n'
#                  '\n'
#                  'It’s not meant to and should not replace mental health care '
#                  'or the support of loved ones, but it is a valuable—and '
#                  'free—tool to help bridge gaps in making self-care as '
#                  'accessible and personal as possible.\n'
#                  '\n'
#                  'Aloe Bud can be fully enjoyed for free, but if you would '
#                  'like to enhance your experience and help support our growth, '
#                  'we offer optional in-app purchases. It allows you to add as '
#                  'many self-care activities check in’s, journal and activity '
#                  'log entries, as well as unlimited customization reminder '
#                  'schedules. Premium features are optional and not required to '
#                  'have a full experience. Premium features are enhancements '
#                  'and expansions to our in-app content.\n'
#                  '\n'
#                  'PREMIUM FEATURES\n'
#                  'Premium Reminders: For $1.99 unlock an expansion pack of '
#                  'gentle reminders + the ability to enable or disable reminder '
#                  'messages.\n'
#                  'Custom Reminders: For $3.99 unlock the ability to write your '
#                  'own personal reminders for any activity of your choice +  '
#                  'the ability to enable, disable, + the ability to enable or '
#                  'disable reminder messages.\n'
#                  'Reminders Bundle: For $4.99, save and unlock everything '
#                  'currently available. Does not apply to any future premium '
#                  'features added.\n'
#                  '\n'
#                  'PRIVACY POLICY\n'
#                  'All data remains on your device and is kept there until the '
#                  'app has been deleted from your device. We collect '
#                  'non-personal, or identify-able analytical data to improve '
#                  'your experiences.\n'
#                  '\n'
#                  'Read more in our Privacy Policy http://aloebud.com/privacy\n'
#                  '\n'
#                  'Twitter: @aloebud\n'
#                  'Instagram: @aloebud\n'
#                  'Facebook: facebook.com/aloebud\n'
#                  'News updates: aloebud.com\n'
#                  '\n'
#                  'Designed out of the pure necessity of their own mental '
#                  'health struggles; Aloe Bud creator, Amber Discko searched '
#                  'the App Store for something, anything to help with basic '
#                  'self-care. After trying and ignoring countless self-care '
#                  'apps and feeling guilty for doing so, finding one that met '
#                  'their needs and lifestyle became frustrating. Amber believed '
#                  'there was no better time to start designing a gentle, '
#                  'all-in-one personal care app, using their own experiences, '
#                  'affinity for pixel art and the needs of their communities to '
#                  'bring this simple idea to life.',
#   'features': 'gameCenter,iosUniversal',
#   'fileSizeBytes': '16335872',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6012',
#   'genres': 'Gezondheid en fitness,Lifestyle',
#   'ipadScreenshotUrls': 'https://is3-ssl.mzstatic.com/image/thumb/Purple123/v4/07/82/b1/0782b1de-3d77-5545-d7db-4865fc2d2ad1/mzl.theddwyl.png/576x768bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple123/v4/ff/c5/57/ffc55703-fe4e-fcc6-d72c-9246fbd7971d/mzl.iuqlrblm.png/576x768bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/e8/46/97/e846970f-b023-22c0-f4a7-31a4438d4e71/mzl.ibazjtet.png/576x768bb.png',
#   'isGameCenterEnabled': True,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN',
#   'minimumOsVersion': '11.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2018-04-25T07:00:00Z',
#   'releaseNotes': 'iOS 13 Support\n'
#                   'Rate the App prompt\n'
#                   'Sound Effect Settings\n'
#                   'Decreased Sound Effect Volume',
#   'screenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/Purple123/v4/a9/54/23/a9542348-35de-43b6-725e-e1945e16fd14/pr_source.png/392x696bb.png,https://is5-ssl.mzstatic.com/image/thumb/Purple123/v4/ca/8e/9d/ca8e9d05-3e35-9712-43dc-340663325c41/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/68/21/15/68211551-4cba-2de7-b081-1ee41b82ebae/pr_source.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple113/v4/81/5a/e1/815ae1dd-bce7-fe59-08ef-e4c527424e19/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/f8/9e/5e/f89e5e1f-fe49-6ba7-6b9d-ed7027948f55/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/f2/0b/f0/f20bf047-08d2-d68e-5f75-2a2ed9d23276/pr_source.png/392x696bb.png',
#   'sellerName': 'Aloebud LLC',
#   'sellerUrl': 'http://aloebud.com',
#   'supportedDevices': 'iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#   'trackCensoredName': 'Aloe Bud',
#   'trackContentRating': '4+',
#   'trackId': 1318382054,
#   'trackName': 'Aloe Bud',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/aloe-bud/id1318382054?uo=4',
#   'userRatingCount': 52,
#   'userRatingCountForCurrentVersion': 52,
#   'version': '1.1',
#   'wrapperType': 'software'},
#  {'advisories': '',
#   'appletvScreenshotUrls': '',
#   'artistId': 1042329742,
#   'artistName': 'Aura Health Inc.',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/aura-health-inc/id1042329742?uo=4',
#   'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Purple114/v4/a9/28/5b/a9285b94-930e-afa6-c2e7-11b86221f563/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is2-ssl.mzstatic.com/image/thumb/Purple114/v4/a9/28/5b/a9285b94-930e-afa6-c2e7-11b86221f563/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Purple114/v4/a9/28/5b/a9285b94-930e-afa6-c2e7-11b86221f563/source/60x60bb.jpg',
#   'averageUserRating': 4.49554,
#   'averageUserRatingForCurrentVersion': 4.49554,
#   'bundleId': 'com.AuraMobile',
#   'contentAdvisoryRating': '4+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2021-03-19T02:14:42Z',
#   'description': '** As loved by Apple (Best of 2017, #1 New Apps We Love), '
#                  'TechCrunch, Forbes, TeenVogue, and more!\n'
#                  '\n'
#                  'Aura: Reduce stress & anxiety, improve focus, and sleep '
#                  'better using daily mindfulness meditations, life coaching, '
#                  'stories, and music. All personalized to you based on your '
#                  'mood. \n'
#                  '\n'
#                  'Do you wish to control your stress and anxiety better? Are '
#                  'you seeking more positivity? Have you tried other '
#                  "mindfulness meditation apps but couldn't form a habit around "
#                  'them? It’s time to try Aura, the simplest solution to '
#                  'reducing stress and increasing positivity through 3-minute '
#                  'meditations.\n'
#                  '\n'
#                  'Aura is the best, AI-driven app for anyone interested in '
#                  'reducing stress & anxiety. Aura provides short and sweet, '
#                  'personalized mindfulness meditations, life coaching, '
#                  'stories, and music whenever you need to make you happier. '
#                  'Listen to guided meditations depending on how you feel, or '
#                  'enjoy sounds of nature.\n'
#                  '\n'
#                  'Start your journey to control your stress and anxiety with '
#                  'Aura. \n'
#                  '\n'
#                  'AURA FREE FEATURES: \n'
#                  '\n'
#                  'Meditations to Relieve Stress & Anxiety\n'
#                  '• Relieve stress & anxiety with a free daily 3-minute guided '
#                  'meditation session\n'
#                  '• Personalized meditations chosen specifically for you\n'
#                  '• Listen to specific meditations to put you in the right '
#                  'headspace\n'
#                  '• Save meditations to listen again at a later time\n'
#                  '• Not sure how you feel? Listen to unguided meditations with '
#                  'the sounds of nature\n'
#                  '\n'
#                  'Improve Your Mindfulness\n'
#                  '• Improve your mindfulness by rating your experience\n'
#                  '• Aura will learn about your stress and anxiety levels and '
#                  'provide a better mediation session every time\n'
#                  '\n'
#                  'Track Your Mood\n'
#                  '• Track your mood and learn about your mood patterns\n'
#                  '• Receive insight to how you’re feeling and visually see '
#                  'yourself improve\n'
#                  '• Aura is integrated with Apple Health so you can track your '
#                  'mood, meditation, and more\n'
#                  '\n'
#                  'Reminders & Notifications\n'
#                  '• Mindful breather + reminders – Take a mindful break '
#                  'whenever you need\n'
#                  '• Receive daily reminders for mindful breathers to keep calm '
#                  'during the day\n'
#                  '\n'
#                  'Aura Community\n'
#                  '• Connect with Aura’s teachers and other Aura members to '
#                  'share experiences, support and more\n'
#                  '• Learn where others are in their journey to relieving '
#                  'stress and anxiety\n'
#                  '\n'
#                  'Gratitude Reflections\n'
#                  '• Express gratitude as a habit through daily reflections\n'
#                  '• Share what you are grateful for with others in the Aura '
#                  'community\n'
#                  '\n'
#                  'Aura integrates with Apple Health app\n'
#                  '• Save your meditation and sleep sessions to your Apple '
#                  'Health app with Mindful Minutes\n'
#                  '\n'
#                  'AURA PREMIUM FEATURES: \n'
#                  '• Meditations 24/7, whenever you need\n'
#                  '• Choose 3- or 7- or >10- minute meditation durations '
#                  'depending on your availability and comfort\n'
#                  '• Save unlimited meditations and listen whenever you want\n'
#                  '• Download meditations for offline use\n'
#                  '\n'
#                  'Start your day with energy and purpose, and decrease stress '
#                  'while increasing positivity.\n'
#                  '\n'
#                  'Download the best meditation app now to start relieving '
#                  'stress and anxiety.\n'
#                  '\n'
#                  '“Aura creates positivity throughout the day through simple '
#                  "morning mindfulness... I absolutely can't go a day without "
#                  'it.”\n'
#                  '\n'
#                  '-Stephanie L., LinkedIn\n'
#                  '\n'
#                  'Premium - Monthly subscription: $11.99 / month\n'
#                  'Premium - Yearly subscription: $4.99 / month billed every 12 '
#                  'months at $59.99\n'
#                  'Premium - Lifetime: $399, one-time charge\n'
#                  '\n'
#                  'Your payment will be handled by Apple. \n'
#                  'iTunes payment information:\n'
#                  'Payment will be charged to iTunes account at confirmation of '
#                  'purchase. Subscription automatically renews unless '
#                  'auto-renew is turned off at least 24-hours before the end of '
#                  'the current period. Account will be charged for renewal '
#                  'within 24-hours prior to the end of the current period, and '
#                  'identify the cost of the renewal. Subscriptions may be '
#                  'managed by the user and auto-renewal may be turned off by '
#                  "going to the user's Account Settings after purchase. No "
#                  'cancellation of the current subscription is allowed during '
#                  'active subscription period. Any unused portion of a free '
#                  'trial period will be forfeited when a subscription is '
#                  'purchased.\n'
#                  '\n'
#                  'Read more about our terms and conditions:\n'
#                  'Privacy Policy: http://aurahealth.io/privacy-policy/\n'
#                  'Terms of Use: http://aurahealth.io/terms-of-service/',
#   'features': 'iosUniversal',
#   'fileSizeBytes': '217529344',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6012',
#   'genres': 'Gezondheid en fitness,Lifestyle',
#   'ipadScreenshotUrls': 'https://is3-ssl.mzstatic.com/image/thumb/Purple123/v4/bf/c4/1a/bfc41a71-b823-ac8d-1e38-415caae9cc83/mzl.rhkcsvfx.png/576x768bb.png,https://is5-ssl.mzstatic.com/image/thumb/Purple113/v4/57/a7/45/57a745e8-a1fe-64a3-7bd2-18ca9bbac9dc/mzl.yfitmvcf.png/576x768bb.png,https://is3-ssl.mzstatic.com/image/thumb/Purple123/v4/12/7a/b0/127ab0e3-a69c-92a3-5645-6401a86a8755/mzl.ljoqowji.png/576x768bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/85/47/e6/8547e6ac-6fb9-1cae-adab-33918bac5eb1/mzl.hwmtptpx.png/576x768bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple113/v4/97/dc/40/97dc40ba-e382-f024-77e4-587b868ecf23/mzl.wpthbrzh.png/576x768bb.png',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN',
#   'minimumOsVersion': '9.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2016-10-11T02:56:47Z',
#   'releaseNotes': 'Thank you for using Aura! This update contains our new iOS '
#                   '14 Widget, performance improvements, new content, and bug '
#                   'fixes. \n'
#                   'Enjoy! -Aura Team',
#   'screenshotUrls': 'https://is5-ssl.mzstatic.com/image/thumb/Purple113/v4/61/bb/0f/61bb0f5d-29cb-e823-6a19-7510c32b3932/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/fd/64/5d/fd645d70-737c-a3e6-81b3-999cf45ba3e5/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/34/34/fb/3434fb60-b69c-ec1b-7137-83aa6e81aa92/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/a4/95/39/a495390f-7c53-dc65-5720-26cb13e09fd5/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/da/ca/fe/dacafe13-a1d1-99c2-c58e-9a287eb5bc0b/pr_source.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple123/v4/47/3f/88/473f8864-a5a5-1966-b276-aa3a0ee00fe2/pr_source.png/392x696bb.png',
#   'sellerName': 'Aura Health Inc.',
#   'sellerUrl': 'http://www.aurahealth.io',
#   'supportedDevices': 'iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-iPhone4S,iPadThirdGen-iPadThirdGen,iPadThirdGen4G-iPadThirdGen4G,iPhone5-iPhone5,iPodTouchFifthGen-iPodTouchFifthGen,iPadFourthGen-iPadFourthGen,iPadFourthGen4G-iPadFourthGen4G,iPadMini-iPadMini,iPadMini4G-iPadMini4G,iPhone5c-iPhone5c,iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,Watch4-Watch4,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,Watch5-Watch5,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular,WatchSE-WatchSE,WatchSECellular-WatchSECellular,Watch6-Watch6,Watch6Cellular-Watch6Cellular',
#   'trackCensoredName': 'Aura: Meditation & Sleep',
#   'trackContentRating': '4+',
#   'trackId': 1114223104,
#   'trackName': 'Aura: Meditation & Sleep',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/aura-meditation-sleep/id1114223104?uo=4',
#   'userRatingCount': 224,
#   'userRatingCountForCurrentVersion': 224,
#   'version': '3.11.6',
#   'wrapperType': 'software'},
#  {'advisories': 'Soms/Milde medische/behandelingsinformatie',
#   'appletvScreenshotUrls': '',
#   'artistId': 995252383,
#   'artistName': 'BetterHelp',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/betterhelp/id995252383?uo=4',
#   'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Purple114/v4/a4/65/38/a465385f-2921-3a41-6c85-6b00e5341604/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is3-ssl.mzstatic.com/image/thumb/Purple114/v4/a4/65/38/a465385f-2921-3a41-6c85-6b00e5341604/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Purple114/v4/a4/65/38/a465385f-2921-3a41-6c85-6b00e5341604/source/60x60bb.jpg',
#   'averageUserRating': 4.61904,
#   'averageUserRatingForCurrentVersion': 4.61904,
#   'bundleId': 'com.ionicframework.betterhelp369708',
#   'contentAdvisoryRating': '12+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2021-01-26T17:09:00Z',
#   'description': 'BetterHelp is the convenient way to get professional help '
#                  'from licensed therapists and counselors online. With over '
#                  '10,000 trained, experienced and accredited counselors '
#                  'covering a wide range of areas – from depression and anxiety '
#                  'to family and couples therapy – it’s never been easier to '
#                  'receive personal, professional help when you need it. \n'
#                  '\n'
#                  '\n'
#                  '-------------------------------------------\n'
#                  'BETTERHELP – FEATURES\n'
#                  '-------------------------------------------\n'
#                  '• Over 10,000 counselors & therapists with different areas '
#                  'of expertise\n'
#                  '• All counselors are licensed, trained, accredited and '
#                  'highly experienced\n'
#                  '• Match with an available counselor who is the best fit for '
#                  'your needs\n'
#                  '• Unlimited private one on one communication with your '
#                  'therapist\n'
#                  '• Schedule live sessions with your counselor or use the '
#                  'secure messenger\n'
#                  '• Gain access to constructive, educational group webinars \n'
#                  '\n'
#                  '\n'
#                  'PROFESSIONAL HELP, PERSONALIZED FOR YOU\n'
#                  '\n'
#                  'Facing obstacles alone can be daunting – receiving support '
#                  'and guidance from a professional counselor has been shown to '
#                  'make huge, positive changes to help you overcome personal '
#                  'challenges. When you sign up we’ll match you to an available '
#                  'counselor who fits your objectives, preferences and the type '
#                  'of issues you’re dealing with. Different counselors have '
#                  'different approaches and areas of expertise so we’ll work '
#                  'with you to find the right person who can achieve the best '
#                  'results for you. \n'
#                  '\n'
#                  '\n'
#                  'LICENSED AND TRAINED COUNSELORS & THERAPISTS\n'
#                  '\n'
#                  'There are over 10,000 counselors in BetterHelp, each with at '
#                  'least 3 years and 2,000 hours of hands-on experience. They '
#                  'are licensed, trained, experienced and accredited '
#                  'psychologists (PhD/PsyD), marriage and family therapists '
#                  '(MFT), clinical social workers (LCSW), licensed professional '
#                  'counselors (LPC), or similar credentials. \n'
#                  '\n'
#                  'All of our therapists have a Master’s Degree or a Doctorate '
#                  'Degree in their respective field. They have been qualified '
#                  'and certified by their state professional board are '
#                  'completing the necessary education, exams, training and '
#                  'practice. \n'
#                  '\n'
#                  '\n'
#                  'HOW DOES IT WORK?\n'
#                  '\n'
#                  'You and your counselor will get your own secure “room”. This '
#                  'will be your private place to communicate day or night. You '
#                  'can access this room from any internet connected device, '
#                  'wherever you are. \n'
#                  '\n'
#                  'You can write about yourself, the things going on in your '
#                  'life, ask questions and discuss the challenges you’re '
#                  'facing. Your counselor will login to the same room and '
#                  'respond with feedback, insights and guidance. This ongoing '
#                  'one-on-one dialogue is the foundation of your work with your '
#                  'counselor. \n'
#                  '\n'
#                  'Together you’ll work towards making a positive change in '
#                  'your life, accomplishing your goals and overcoming your '
#                  'problems. \n'
#                  '\n'
#                  '\n'
#                  'HOW MANY SESSIONS CAN I HAVE?\n'
#                  '\n'
#                  'You aren’t limited to a certain number of messages '
#                  '(“sessions”). The frequency of your sessions depends on your '
#                  'availability and the interaction between you and your '
#                  'counselor. You may prefer to have 3-4 short interactions per '
#                  'week, or 1 very long and thorough session. You can use the '
#                  'service as much or as little as you like, depending on your '
#                  'needs. Your therapist will work to accommodate your changing '
#                  'needs in a timely manner. \n'
#                  '\n'
#                  '\n'
#                  'YOU DESERVE TO BE HAPPY.\n'
#                  '\n'
#                  'WE ARE HERE TO HELP MAKE IT HAPPEN – DOWNLOAD BETTERHELP '
#                  'TODAY!',
#   'features': 'iosUniversal',
#   'fileSizeBytes': '34968576',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6012',
#   'genres': 'Gezondheid en fitness,Lifestyle',
#   'ipadScreenshotUrls': 'https://is3-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/6c/4d/96/6c4d96fc-acac-e831-2acd-de08763fd4a2/2697e84b-e83f-4d54-bc73-b9d4e3be3e8c_ipad-1.jpg/576x768bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/bc/fc/f8/bcfcf830-eb06-58dc-bda1-bb27d4f00ab5/1df7129a-a8f4-40e6-b0ad-441516bc946a_ipad-2.jpg/576x768bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/64/e8/b4/64e8b403-ac25-239d-db65-8f866f290ca2/0d3f6f90-292d-4397-a07d-d9d14a796a64_ipad-3.jpg/576x768bb.jpg,https://is1-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/20/ef/88/20ef88a4-6f49-3c75-f29a-fd5d4f1548ee/927784bf-d89a-405f-b211-4d1e27291487_ipad-4.jpg/576x768bb.jpg,https://is2-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/fd/ee/db/fdeedb7c-4d56-0c8f-409a-d7ae29264a82/b2e6459c-1e2b-4ed2-8777-8b843ce9e441_ipad-5.jpg/576x768bb.jpg,https://is1-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/37/76/a3/3776a3b4-e858-dba3-9d1b-2ab5da77ac6c/2031a9a4-3a70-420b-b64b-b7a6a1bbbbe5_ipad-2.jpg/576x768bb.jpg',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN',
#   'minimumOsVersion': '12.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2015-07-11T02:30:33Z',
#   'releaseNotes': 'Thank you for using BetterHelp! We are constantly improving '
#                   'our app and delivering enhancements to the App Store. Every '
#                   "update is a boost to the app's stability, speed, and "
#                   'security.\n'
#                   '- This version updates more libraries for iOS 14.',
#   'screenshotUrls': 'https://is4-ssl.mzstatic.com/image/thumb/Purple114/v4/68/10/af/6810afdf-6195-4f59-1705-b95d7b1034f6/mzl.zgzrhmbo.png/392x696bb.png,https://is3-ssl.mzstatic.com/image/thumb/Purple114/v4/84/21/39/84213941-54f0-9afa-c8b3-5c3ca66097fc/mzl.biqnchca.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple124/v4/81/84/d5/8184d50a-2fdd-8470-b3de-8f03fef9d442/mzl.clsbonae.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple114/v4/15/ac/58/15ac58e3-d499-62ba-ef83-b94dc72dd474/mzl.zsblcyze.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/Purple114/v4/be/bc/e9/bebce9df-1466-40db-6552-bc3959021603/mzl.uxjxadfn.png/392x696bb.png',
#   'sellerName': 'Compile, Inc.',
#   'sellerUrl': 'https://www.betterhelp.com',
#   'supportedDevices': 'iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#   'trackCensoredName': 'BetterHelp - Online Counseling',
#   'trackContentRating': '12+',
#   'trackId': 995252384,
#   'trackName': 'BetterHelp - Online Counseling',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/betterhelp-online-counseling/id995252384?uo=4',
#   'userRatingCount': 42,
#   'userRatingCountForCurrentVersion': 42,
#   'version': '9.9',
#   'wrapperType': 'software'},
#  {'advisories': '',
#   'appletvScreenshotUrls': '',
#   'artistId': 499648345,
#   'artistName': 'National Center for Telehealth & Technology',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/national-center-for-telehealth-technology/id499648345?uo=4',
#   'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Purple125/v4/3e/72/10/3e7210ed-80bc-979d-2511-1aa752736a58/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is1-ssl.mzstatic.com/image/thumb/Purple125/v4/3e/72/10/3e7210ed-80bc-979d-2511-1aa752736a58/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Purple125/v4/3e/72/10/3e7210ed-80bc-979d-2511-1aa752736a58/source/60x60bb.jpg',
#   'averageUserRating': 4.83333,
#   'averageUserRatingForCurrentVersion': 4.83333,
#   'bundleId': 'org.t2health.BreatheTwoRelax',
#   'contentAdvisoryRating': '4+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2018-05-21T17:15:00Z',
#   'description': 'Breathe2Relax is a portable stress management tool which '
#                  'provides detailed information on the effects of stress on '
#                  'the body and instructions and practice exercises to help '
#                  'users learn the stress management skill called diaphragmatic '
#                  'breathing.Breathing exercises have been documented to '
#                  'decrease the body’s ‘fight-or-flight’ (stress) response, and '
#                  'help with mood stabilization, anger control, and anxiety '
#                  'management. Breathe2Relax can be used as a stand-alone '
#                  'stress reduction tool, or can be used in tandem with '
#                  'clinical care directed by a healthcare worker. Breathe2Relax '
#                  'now uses HealthKit and your Apple Watch device to measure '
#                  'your heart rate throughout your breathing exercise to help '
#                  'provide an even more complete picture of the relaxation '
#                  'experienced.',
#   'features': 'iosUniversal',
#   'fileSizeBytes': '39609344',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6020',
#   'genres': 'Gezondheid en fitness,Geneeskunde',
#   'ipadScreenshotUrls': 'https://is4-ssl.mzstatic.com/image/thumb/Purple125/v4/f9/31/6e/f9316ef9-92bd-5752-1bf4-21113e11180e/pr_source.png/576x768bb.png,https://is3-ssl.mzstatic.com/image/thumb/Purple115/v4/41/1f/42/411f42fa-bed5-a2ec-1a10-738c5e38426b/pr_source.png/576x768bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple125/v4/88/f9/97/88f9973a-538e-bf8a-61f6-ebaacd84b4b0/pr_source.png/576x768bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple125/v4/60/5a/ed/605aed39-31c0-faeb-061d-a1143af4eea3/pr_source.png/576x768bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple115/v4/47/3f/98/473f98e9-eac1-3896-c48c-03b91bbe3258/pr_source.png/576x768bb.png',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN',
#   'minimumOsVersion': '9.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2011-03-22T20:13:41Z',
#   'releaseNotes': 'You can now take advantage of your Apple Watch and '
#                   'HealthKit to help illuminate the impact of a breathing '
#                   'exercise had by tracking your heart rate while you breathe.',
#   'screenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/Purple125/v4/b0/1a/b9/b01ab9bc-cf8c-aa66-3616-880fe376f844/pr_source.png/392x696bb.png,https://is5-ssl.mzstatic.com/image/thumb/Purple115/v4/fe/d3/e8/fed3e890-92fe-8fde-1c68-d34c257054a7/pr_source.png/392x696bb.png,https://is5-ssl.mzstatic.com/image/thumb/Purple115/v4/33/7a/56/337a56b0-d2f1-4407-ee8f-2ed2ab5c9abb/pr_source.png/392x696bb.png,https://is3-ssl.mzstatic.com/image/thumb/Purple125/v4/92/37/7d/92377d91-bbf3-62c3-0bd8-66d71f291b18/pr_source.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple125/v4/8d/63/b6/8d63b6c0-8ee3-6b2e-7aa4-debf9874b766/pr_source.png/392x696bb.png',
#   'sellerName': 'National Center for Telehealth & Technology',
#   'sellerUrl': 'http://www.t2health.dcoe.mil',
#   'supportedDevices': 'iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-iPhone4S,iPadThirdGen-iPadThirdGen,iPadThirdGen4G-iPadThirdGen4G,iPhone5-iPhone5,iPodTouchFifthGen-iPodTouchFifthGen,iPadFourthGen-iPadFourthGen,iPadFourthGen4G-iPadFourthGen4G,iPadMini-iPadMini,iPadMini4G-iPadMini4G,iPhone5c-iPhone5c,iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,Watch4-Watch4,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,Watch5-Watch5,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular,WatchSE-WatchSE,WatchSECellular-WatchSECellular,Watch6-Watch6,Watch6Cellular-Watch6Cellular',
#   'trackCensoredName': 'Breathe2Relax',
#   'trackContentRating': '4+',
#   'trackId': 425720246,
#   'trackName': 'Breathe2Relax',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/breathe2relax/id425720246?uo=4',
#   'userRatingCount': 6,
#   'userRatingCountForCurrentVersion': 6,
#   'version': '1.7.7',
#   'wrapperType': 'software'},
#  {'advisories': '',
#   'appletvScreenshotUrls': '',
#   'artistId': 1481804499,
#   'artistName': 'Breathwork Inc.',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/breathwork-inc/id1481804499?uo=4',
#   'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Purple124/v4/cb/9d/00/cb9d0056-24ef-f8b7-a432-576a71d73583/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is2-ssl.mzstatic.com/image/thumb/Purple124/v4/cb/9d/00/cb9d0056-24ef-f8b7-a432-576a71d73583/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Purple124/v4/cb/9d/00/cb9d0056-24ef-f8b7-a432-576a71d73583/source/60x60bb.jpg',
#   'averageUserRating': 4.7195,
#   'averageUserRatingForCurrentVersion': 4.7195,
#   'bundleId': 'com.breathwrk.ios',
#   'contentAdvisoryRating': '4+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2021-03-20T05:10:50Z',
#   'description': 'Breathwrk guides you through quick and powerful breathing '
#                  'exercises that eliminate stress & anxiety, increase energy, '
#                  'improve endurance, and help you fall asleep. Learn and '
#                  'practice a variety of science-backed breathing methods that '
#                  'are guided by original music, vibrations, and visuals.\n'
#                  ' \n'
#                  'Modern research has shown that by controlling your breath '
#                  'you can regulate stress levels, improve mood, decrease '
#                  'fatigue, lower blood pressure, curve insomnia, increase your '
#                  'athletic performance and more! With just a few minutes of '
#                  'Breathwrk per day, you can master the same exercises used by '
#                  'psychotherapists, olympic athletes, yogis, sleep doctors, '
#                  'navy seals, neuroscientists, and breath experts!\n'
#                  ' \n'
#                  'Choose from a vast library of exercises on everything from '
#                  'increasing your focus and productivity to reducing stress, '
#                  'stopping an anxiety attack, uplifting your mood, and more! '
#                  'Breathwrk can be used in certain moments, like before a big '
#                  'meeting or exam, or daily to wake up, regulate stress '
#                  'levels, and go to sleep. You can also set reminders or '
#                  'follow curated daily habits in the app to get the most out '
#                  'of your lungs. \n'
#                  ' \n'
#                  'With Breathwrk you can fully customize your breathing '
#                  'experience. Explore different sounds and music from Grammy '
#                  'Award winning artist DJ White Shadow, feel the breathing '
#                  'patterns with advanced vibrations, and choose between unique '
#                  'visuals.\n'
#                  ' \n'
#                  'Join the hundreds of thousands worldwide already breathing '
#                  'with Breathwrk. Our users range from 7 to 77 years old, and '
#                  'include psychologists, college students, marathon trainers, '
#                  'parents of children with disabilities, Navy SEALs and more!\n'
#                  ' \n'
#                  'Unlike other mindfulness methods which take a lot of time '
#                  'and practice, Breathwrk is easy to learn and works fast on '
#                  'BOTH the mind and body! It has been scientifically proven '
#                  'that the pattern and way in which you breathe actually '
#                  'effects your mental and physical state. \n'
#                  "Breathwrk's integration with Apple Health will help you keep "
#                  'track of your mindful minutes, building your practice '
#                  'overtime.\n'
#                  ' \n'
#                  'Your breath is the remote control to your nervous system! '
#                  'Control your breath, control your life!\n'
#                  ' \n'
#                  'FEATURED IN:\n'
#                  'Goop, Vogue, Recomendo, The Skimm, and more!\n'
#                  ' \n'
#                  'EXERCISES INCLUDE: \n'
#                  '*Calm\n'
#                  '*Sleep\n'
#                  '*Awake\n'
#                  '*Energize\n'
#                  '*Anxiety Ease\n'
# ...
#                  'period\n'
#                  '• Account will be charged for renewal within 24-hours prior '
#                  'to the end of the current period\n'
#                  '• Any unused portion of a free trial period, if offered, '
#                  'will be forfeited when the user purchases a subscription to '
#                  'that publication, where applicable\n'
#                  '\n'
#                  'Read more about our terms and conditions here -\n'
#                  'http://beta.touchkin.com/wysa-terms.html\n'
#                  '\n'
#                  'Read more about our privacy policy here - \n'
#                  'http://beta.touchkin.com/privacy-policy.html',
#   'features': '',
#   'fileSizeBytes': '74232832',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6012',
#   'genres': 'Gezondheid en fitness,Lifestyle',
#   'ipadScreenshotUrls': '',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN',
#   'minimumOsVersion': '10.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2016-10-23T05:04:05Z',
#   'releaseNotes': 'Bug fixes.',
#   'screenshotUrls': 'https://is1-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/99/c5/32/99c532f5-588d-a27f-1206-5effce427fb1/49b42f41-dec0-4329-ae12-2630084d0bf7_1.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/7e/06/73/7e0673ef-d7e6-843a-1fc9-762a14ba63ee/6306ca96-83bf-4c61-802e-d9348b5cf5ba_2.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/5d/4c/3b/5d4c3b62-adb5-1d97-843e-39bda251d2e1/80ac1420-1cff-4923-8909-e47fb6dfda9b_3.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/67/e6/c7/67e6c786-0d59-c272-645e-81eebdb33513/d0f869dc-41e9-4229-b432-0e8dc7999197_4.png/392x696bb.png,https://is3-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/f4/bc/c4/f4bcc483-d389-37d3-e01c-bbfe7582da06/f45dabb2-64eb-47bc-b247-db106c586f5d_5.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/0e/6e/4d/0e6e4d57-6e12-e991-2a80-055161b3dd35/1d1b073c-b75b-481d-9818-a8374c3300dd_6.png/392x696bb.png,https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/68/6e/36/686e3634-d6fc-c741-cdf7-78f785d13a61/3fb0b3ce-6d77-4ba9-b7a9-6a03776bf2b0_7.png/392x696bb.png',
#   'sellerName': 'Touchkin eServices Private Limited',
#   'sellerUrl': 'http://www.wysa.io',
#   'supportedDevices': 'iPhone5-iPhone5,iPadFourthGen-iPadFourthGen,iPadFourthGen4G-iPadFourthGen4G,iPhone5c-iPhone5c,iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#   'trackCensoredName': 'Wysa: Sleep Depression Support',
#   'trackContentRating': '12+',
#   'trackId': 1166585565,
#   'trackName': 'Wysa: Sleep Depression Support',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/wysa-sleep-depression-support/id1166585565?uo=4',
#   'userRatingCount': 88,
#   'userRatingCountForCurrentVersion': 88,
#   'version': '5.9',
#   'wrapperType': 'software'},
#  {'advisories': 'Soms/Milde medische/behandelingsinformatie',
#   'appletvScreenshotUrls': '',
#   'artistId': 1289788840,
#   'artistName': 'Youper, Inc.',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/youper-inc/id1289788840?uo=4',
#   'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Purple114/v4/60/fd/cf/60fdcffb-55a5-81a8-0283-0e6b291dc2df/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is4-ssl.mzstatic.com/image/thumb/Purple114/v4/60/fd/cf/60fdcffb-55a5-81a8-0283-0e6b291dc2df/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Purple114/v4/60/fd/cf/60fdcffb-55a5-81a8-0283-0e6b291dc2df/source/60x60bb.jpg',
#   'averageUserRating': 4.76923,
#   'averageUserRatingForCurrentVersion': 4.76923,
#   'bundleId': 'br.com.youper',
#   'contentAdvisoryRating': '12+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2021-03-16T11:47:10Z',
#   'description': '** App of the day ** - Apple\n'
#                  '** Your pandemic therapist ** - Bloomberg \n'
#                  '** A truly holistic approach to wellbeing ** - Google\n'
#                  '\n'
#                  'Created by therapists, Youper combines Cognitive Behavioral '
#                  'Therapy (CBT), Dialectical Behavior Therapy (DBT), '
#                  'Acceptance and Commitment Therapy (ACT), and '
#                  'Mindfulness-based cognitive therapy with Artificial '
#                  'Intelligence (AI) to make therapy accessible for everyone.\n'
#                  '\n'
#                  "Youper's chatbot style makes the therapy exercises feel like "
#                  'a conversation with a caring and supportive friend.\n'
#                  '\n'
#                  'Join millions of people using Youper to relieve stress, '
#                  'anxiety, and depression. Youper empowers you to take control '
#                  'of your mental health using quick guided therapy exercises '
#                  'to increase happiness, find motivation, feel more calm, '
#                  'practice gratitude, improve sleep, increase mindfulness, '
#                  'stop worrying, change negative thinking, deal with difficult '
#                  'situations, and improve your behavior.\n'
#                  '\n'
#                  'Youper is fully personalized to you. So, that’s okay if you '
#                  'have never tried therapy before - Youper will guide you '
#                  'every step of the way, and if you are seeing a therapist, it '
#                  'works well alongside therapy by supporting you between '
#                  'sessions and helping you track your progress. \n'
#                  '\n'
#                  'Youper also provides access to an entire library of soothing '
#                  'and calming audio tracks to help relax you physically and '
#                  'mentally, to get you into a better headspace, and help you '
#                  'breethe through challenging moments.\n'
#                  '\n'
#                  'With Youper you can also understand and monitor symptoms of '
#                  'anxiety, depression, social anxiety, borderline personality, '
#                  'and post-traumatic stress. \n'
#                  '\n'
#                  'There’s also a personality test to help you gain fascinating '
#                  'insights about yourself.\n'
#                  '\n'
#                  'Youper is available 24/7 - wherever and whenever you need '
#                  'it. More than 80% of users say that they felt better a few '
#                  'minutes after downloading and using Youper. Try it for free '
#                  'now, and start feeling better today. \n'
#                  '\n'
#                  'Apple Health integration\n'
#                  'Integrate your mindfulness sessions with Apple Health to '
#                  'make self-help and self-care easy.\n'
#                  ' \n'
#                  'Subscription pricing and terms\n'
#                  'Premium features are available with subscriptions starting '
#                  'at $14.99/month or $89.99/year. Pricing in countries outside '
#                  'of the United States may vary, and actual charges may be '
#                  'converted to your local currency. Your subscription will '
#                  'automatically renew at the end of each term, and your credit '
#                  'card will be charged through your Store Account. You can '
#                  'turn off auto-renew at any time from your Store Account '
#                  'settings, but refunds will not be provided for any unused '
#                  'portion of the term.\n'
#                  ' \n'
#                  'Youper does not provide diagnosis or treatment. It is not a '
#                  'replacement for professional help, but it can support you to '
#                  'take care of your mental health and works alongside therapy '
#                  'or other treatments if you are seeing a doctor or '
#                  'therapist.\n'
#                  ' \n'
#                  'Terms and conditions: https://www.youper.ai/terms-of-use\n'
#                  'Privacy policy: https://www.youper.ai/privacy-policy\n'
#                  'Support center: https://youper.ai/support',
#   'features': 'iosUniversal',
#   'fileSizeBytes': '122712064',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6020,6013',
#   'genres': 'Geneeskunde,Gezondheid en fitness',
#   'ipadScreenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/Purple114/v4/8f/4e/d7/8f4ed786-4cb0-bca8-635a-898aab9f23f0/cda7e1b7-9938-4e2d-bc9d-e1f3bfd6255b_Store_Images_-_Tablet_9.0-001.jpg/576x768bb.jpg,https://is1-ssl.mzstatic.com/image/thumb/Purple114/v4/e5/f2/0a/e5f20adf-d920-bcb2-eb2f-d95d84804a11/32d2bba5-9fbf-4cfe-885f-eff55fe4efb2_Store_Images_-_Tablet_9.0-002.jpg/576x768bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/Purple124/v4/85/21/e7/8521e786-111f-0b5e-06f6-66488891d00d/e342c46a-c1d5-409a-903f-6871c9fde3a0_Store_Images_-_Tablet_9.0-003.jpg/576x768bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/Purple114/v4/68/c5/64/68c564c3-3de0-0aaf-25a0-de43151209b2/5a928faf-3ea3-4cb1-b3e6-cd056d71b261_Store_Images_-_Tablet_9.0-004.jpg/576x768bb.jpg,https://is3-ssl.mzstatic.com/image/thumb/Purple114/v4/b3/16/0e/b3160e4d-7661-5912-b5f6-a5bf9656ca59/2acd55d8-3bd8-48c3-8d96-1c034bce4f77_Store_Images_-_Tablet_9.0-005.jpg/576x768bb.jpg,https://is3-ssl.mzstatic.com/image/thumb/Purple114/v4/4a/00/e9/4a00e904-7e4b-e9c8-c03f-7f1d3462b6c9/4fb999fd-27e7-4658-91a0-236fc050defa_Store_Images_-_Tablet_9.0-006.jpg/576x768bb.jpg,https://is2-ssl.mzstatic.com/image/thumb/Purple114/v4/88/69/c9/8869c90c-17cf-bc19-0bdd-b6d4e68ed052/2d368bd8-bd38-44f5-a2aa-50564f4d261f_Store_Images_-_Tablet_9.0-007.jpg/576x768bb.jpg,https://is2-ssl.mzstatic.com/image/thumb/Purple124/v4/29/cf/35/29cf35cf-7528-e501-1d83-0f29fcd33529/3e276480-87d5-4670-9a19-ccea7a334761_Store_Images_-_Tablet_9.0-008.jpg/576x768bb.jpg',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN',
#   'minimumOsVersion': '11.0',
#   'price': 0.0,
#   'primaryGenreId': 6020,
#   'primaryGenreName': 'Medical',
#   'releaseDate': '2016-03-22T20:47:26Z',
#   'releaseNotes': 'Thanks for using Youper! This update contains some bug '
#                   'fixes and performance improvements. \n'
#                   '\n'
#                   'Youper 9 brings a new experience for helping you increase '
#                   'happiness, lower stress, and beat anxiety and depression '
#                   'using quick therapy exercises.',
#   'screenshotUrls': 'https://is4-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/64/ea/bd/64eabd83-c69c-9e95-f69b-d813e3d8e291/cff2c3f9-315b-417e-953b-07e00e7afde5_9.00.100_-_Store_Images_iPhone_-_Working-001.jpg/392x696bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/30/6b/f4/306bf4d7-5b50-91b6-f9f1-c43674f606f5/0280e0e5-3335-4c1f-bc76-79a01090c789_9.00.100_-_Store_Images_iPhone_-_Working-002.jpg/392x696bb.jpg,https://is3-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/94/ba/c1/94bac1f3-df01-a3ea-98f3-a546cd616983/28fc2d27-c9fc-4bbc-a2f4-bef007ace84e_9.00.100_-_Store_Images_iPhone_-_Working-003.jpg/392x696bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/dc/e1/16/dce116d6-ad3f-38e1-a873-83f4350b3df8/b80af885-1af3-4bd9-9dc6-b242bcb285ce_9.00.100_-_Store_Images_iPhone_-_Working-004.jpg/392x696bb.jpg,https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/bf/33/eb/bf33eb8c-1f3c-2dcc-f759-9fd1f14e9947/be1c7daa-a37c-4516-9778-1fcfd7fe2591_9.00.100_-_Store_Images_iPhone_-_Working-005.jpg/392x696bb.jpg,https://is3-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/6d/e6/a0/6de6a057-8a0b-fb6f-13db-dc66bb7fbbaf/51f8187c-0cad-49a6-a893-63b9a3d28199_9.00.100_-_Store_Images_iPhone_-_Working-006.jpg/392x696bb.jpg,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/24/e7/ec/24e7ecff-b5ed-d0ed-868b-fd9c9b11bc52/e8d3665c-1b86-4c07-8d6f-1cbad5de2a9d_9.00.100_-_Store_Images_iPhone_-_Working-007.jpg/392x696bb.jpg,https://is3-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/f0/ac/f8/f0acf8c9-0833-a883-0b5e-d609ff27979f/1a52d0b1-735f-4a91-9447-8276edb1bf92_9.00.100_-_Store_Images_iPhone_-_Working-008.jpg/392x696bb.jpg,https://is5-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/56/08/fd/5608fdb9-2e51-7a36-053f-8fed5382080e/16b48f50-7628-4351-9520-462572b8e8a1_9.00.100_-_Store_Images_iPhone_-_Working-009.jpg/392x696bb.jpg',
#   'sellerName': 'YOUPER, INC.',
#   'sellerUrl': 'https://www.youper.ai',
#   'supportedDevices': 'iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#   'trackCensoredName': 'Youper: Self-Guided Therapy',
#   'trackContentRating': '12+',
#   'trackId': 1060691513,
#   'trackName': 'Youper: Self-Guided Therapy',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/youper-self-guided-therapy/id1060691513?uo=4',
#   'userRatingCount': 130,
#   'userRatingCountForCurrentVersion': 130,
#   'version': '9.02.007',
#   'wrapperType': 'software'}]

# %%
## Successfully got data for all 64 apps in App Store
len(app_store_list)
# Out:
# 64

# %%
## Print results obtained for first app: Aloe Bud
pprint(app_store_list[0])
# Out:
# {'advisories': '',
#  'appletvScreenshotUrls': '',
#  'artistId': 1170681391,
#  'artistName': 'Aloebud LLC',
#  'artistViewUrl': 'https://apps.apple.com/nl/developer/aloebud-llc/id1170681391?uo=4',
#  'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Purple123/v4/3f/88/01/3f880181-259a-a8b0-54db-3c8cecd48f9f/source/100x100bb.jpg',
#  'artworkUrl512': 'https://is4-ssl.mzstatic.com/image/thumb/Purple123/v4/3f/88/01/3f880181-259a-a8b0-54db-3c8cecd48f9f/source/512x512bb.jpg',
#  'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Purple123/v4/3f/88/01/3f880181-259a-a8b0-54db-3c8cecd48f9f/source/60x60bb.jpg',
#  'averageUserRating': 4.61538,
#  'averageUserRatingForCurrentVersion': 4.61538,
#  'bundleId': 'club.aloe.Aloe',
#  'contentAdvisoryRating': '4+',
#  'currency': 'EUR',
#  'currentVersionReleaseDate': '2020-06-25T21:20:25Z',
#  'description': 'Aloe Bud is your all-in-one, self-care pocket companion. We '
#                 'gently bring awareness to self-care activities, using '
#                 'encouraging push notifications, rather than guilt or shame. '
#                 'Helpful reminders from yourself, to yourself; saved within '
#                 'Aloe Bud so you can keep doing you! What areas of self-care '
#                 'do you need more of in your life?\n'
#                 '\n'
#                 "Whether you're trying to stay hydrated, or need reminders to "
#                 'get in touch with friends. Check-in and reflect on yourself '
#                 'in real-time or as you need.\n'
#                 '\n'
#                 'Hydrate\n'
#                 'Move\n'
#                 'Breathe\n'
#                 'Health\n'
#                 'Break\n'
#                 'Rest\n'
#                 'Fuel\n'
#                 'Refresh\n'
#                 'People\n'
#                 'Stimulate\n'
#                 'Motivate\n'
#                 '\n'
#                 'ACTIVITY CARDS\n'
#                 'Add activity cards to your personal dashboard, according to '
#                 'what you believe needs extra attention today or in the near '
#                 'future. Activity cards cover everything, from the mundane '
#                 '(such as filling up water bottles and remembering to take '
#                 'screen breaks) to the larger picture (journaling about '
#                 'personal relationships and remembering who or what you’re '
#                 'grateful for).\n'
#                 '\n'
#                 'SCHEDULED REMINDERS (OPT-IN)\n'
#                 'Aloe Bud sends reminders only when asked and can be set at '
#                 'specific times from daily to weekdays, weekends, or any other '
#                 'arrangement you can think of. Reminders bring awareness to '
#                 'important activities, that get lost among other priorities.\n'
#                 '\n'
#                 'Create and develop self-care routines that work for you. Aloe '
#                 'Bud brings awareness to physical, mental and emotional needs '
#                 'throughout the day using unobtrusive push notifications. \n'
#                 '\n'
#                 'RECENT ACTIVITY LOG\n'
#                 'Celebrate tiny victories in your personal activity log, that '
#                 'can be accessed when you touch the icon at the top. Scroll '
#                 'through recently completed check in’s and reflections and '
#                 'look back on your progress day by day.\n'
#                 '\n'
#                 'It’s not meant to and should not replace mental health care '
#                 'or the support of loved ones, but it is a valuable—and '
#                 'free—tool to help bridge gaps in making self-care as '
#                 'accessible and personal as possible.\n'
#                 '\n'
#                 'Aloe Bud can be fully enjoyed for free, but if you would like '
#                 'to enhance your experience and help support our growth, we '
#                 'offer optional in-app purchases. It allows you to add as many '
#                 'self-care activities check in’s, journal and activity log '
#                 'entries, as well as unlimited customization reminder '
#                 'schedules. Premium features are optional and not required to '
#                 'have a full experience. Premium features are enhancements and '
#                 'expansions to our in-app content.\n'
#                 '\n'
#                 'PREMIUM FEATURES\n'
#                 'Premium Reminders: For $1.99 unlock an expansion pack of '
#                 'gentle reminders + the ability to enable or disable reminder '
#                 'messages.\n'
#                 'Custom Reminders: For $3.99 unlock the ability to write your '
#                 'own personal reminders for any activity of your choice +  the '
#                 'ability to enable, disable, + the ability to enable or '
#                 'disable reminder messages.\n'
#                 'Reminders Bundle: For $4.99, save and unlock everything '
#                 'currently available. Does not apply to any future premium '
#                 'features added.\n'
#                 '\n'
#                 'PRIVACY POLICY\n'
#                 'All data remains on your device and is kept there until the '
#                 'app has been deleted from your device. We collect '
#                 'non-personal, or identify-able analytical data to improve '
#                 'your experiences.\n'
#                 '\n'
#                 'Read more in our Privacy Policy http://aloebud.com/privacy\n'
#                 '\n'
#                 'Twitter: @aloebud\n'
#                 'Instagram: @aloebud\n'
#                 'Facebook: facebook.com/aloebud\n'
#                 'News updates: aloebud.com\n'
#                 '\n'
#                 'Designed out of the pure necessity of their own mental health '
#                 'struggles; Aloe Bud creator, Amber Discko searched the App '
#                 'Store for something, anything to help with basic self-care. '
#                 'After trying and ignoring countless self-care apps and '
#                 'feeling guilty for doing so, finding one that met their needs '
#                 'and lifestyle became frustrating. Amber believed there was no '
#                 'better time to start designing a gentle, all-in-one personal '
#                 'care app, using their own experiences, affinity for pixel art '
#                 'and the needs of their communities to bring this simple idea '
#                 'to life.',
#  'features': 'gameCenter,iosUniversal',
#  'fileSizeBytes': '16335872',
#  'formattedPrice': 'Gratis',
#  'genreIds': '6013,6012',
#  'genres': 'Gezondheid en fitness,Lifestyle',
#  'ipadScreenshotUrls': 'https://is3-ssl.mzstatic.com/image/thumb/Purple123/v4/07/82/b1/0782b1de-3d77-5545-d7db-4865fc2d2ad1/mzl.theddwyl.png/576x768bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple123/v4/ff/c5/57/ffc55703-fe4e-fcc6-d72c-9246fbd7971d/mzl.iuqlrblm.png/576x768bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/e8/46/97/e846970f-b023-22c0-f4a7-31a4438d4e71/mzl.ibazjtet.png/576x768bb.png',
#  'isGameCenterEnabled': True,
#  'isVppDeviceBasedLicensingEnabled': True,
#  'kind': 'software',
#  'languageCodesISO2A': 'EN',
#  'minimumOsVersion': '11.0',
#  'price': 0.0,
#  'primaryGenreId': 6013,
#  'primaryGenreName': 'Health & Fitness',
#  'releaseDate': '2018-04-25T07:00:00Z',
#  'releaseNotes': 'iOS 13 Support\n'
#                  'Rate the App prompt\n'
#                  'Sound Effect Settings\n'
#                  'Decreased Sound Effect Volume',
#  'screenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/Purple123/v4/a9/54/23/a9542348-35de-43b6-725e-e1945e16fd14/pr_source.png/392x696bb.png,https://is5-ssl.mzstatic.com/image/thumb/Purple123/v4/ca/8e/9d/ca8e9d05-3e35-9712-43dc-340663325c41/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/68/21/15/68211551-4cba-2de7-b081-1ee41b82ebae/pr_source.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/Purple113/v4/81/5a/e1/815ae1dd-bce7-fe59-08ef-e4c527424e19/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/f8/9e/5e/f89e5e1f-fe49-6ba7-6b9d-ed7027948f55/pr_source.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/Purple123/v4/f2/0b/f0/f20bf047-08d2-d68e-5f75-2a2ed9d23276/pr_source.png/392x696bb.png',
#  'sellerName': 'Aloebud LLC',
#  'sellerUrl': 'http://aloebud.com',
#  'supportedDevices': 'iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#  'trackCensoredName': 'Aloe Bud',
#  'trackContentRating': '4+',
#  'trackId': 1318382054,
#  'trackName': 'Aloe Bud',
#  'trackViewUrl': 'https://apps.apple.com/nl/app/aloe-bud/id1318382054?uo=4',
#  'userRatingCount': 52,
#  'userRatingCountForCurrentVersion': 52,
#  'version': '1.1',
#  'wrapperType': 'software'}

# %%
pd.DataFrame(app_store_list)
# Out:
#                                        screenshotUrls  \
# 0   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                    ipadScreenshotUrls appletvScreenshotUrls  \
# 0   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 4
# ..                                                ...                   ...
# 59
# 60  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 62
# 63  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                          artworkUrl60  \
# 0   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                         artworkUrl512  \
# 0   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                         artworkUrl100  \
# 0   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                         artistViewUrl  \
# 0   https://apps.apple.com/nl/developer/aloebud-ll...
# 1   https://apps.apple.com/nl/developer/aura-healt...
# 2   https://apps.apple.com/nl/developer/betterhelp...
# 3   https://apps.apple.com/nl/developer/national-c...
# 4   https://apps.apple.com/nl/developer/breathwork...
# ..                                                ...
# 59  https://apps.apple.com/nl/developer/wisdo/id12...
# 60  https://apps.apple.com/nl/developer/woebot-lab...
# 61  https://apps.apple.com/nl/developer/akilan-raj...
# 62  https://apps.apple.com/nl/developer/touchkin/i...
# 63  https://apps.apple.com/nl/developer/youper-inc...
#
#                                      supportedDevices  \
# 0   iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 1   iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 2   iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 3   iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 4   iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# ..                                                ...
# 59  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 60  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 61  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 62  iPhone5-iPhone5,iPadFourthGen-iPadFourthGen,iP...
# 63  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
#
#                                            advisories  isGameCenterEnabled  \
# 0                                                                     True
# 1                                                                    False
# 2          Soms/Milde medische/behandelingsinformatie                False
# 3                                                                    False
# 4                                                                    False
# ..                                                ...                  ...
# 59  Regelmatig/Intense medische/behandelingsinform...                False
# 60  Soms/Milde medische/behandelingsinformatie,Som...                False
# 61                                                                   False
# 62         Soms/Milde medische/behandelingsinformatie                False
# 63         Soms/Milde medische/behandelingsinformatie                False
#
#     ...   version wrapperType    artistId  \
# 0   ...       1.1    software  1170681391
# 1   ...    3.11.6    software  1042329742
# 2   ...       9.9    software   995252383
# 3   ...     1.7.7    software   499648345
# 4   ...     5.0.3    software  1481804499
# ..  ...       ...         ...         ...
# 59  ...      2.75    software  1266661757
# 60  ...    3.27.2    software  1305375831
# 61  ...      3.21    software   693833920
# 62  ...       5.9    software  1040527118
# 63  ...  9.02.007    software  1289788840
#
#                                      artistName  \
# 0                                   Aloebud LLC
# 1                              Aura Health Inc.
# 2                                    BetterHelp
# 3   National Center for Telehealth & Technology
# 4                               Breathwork Inc.
# ..                                          ...
# 59                                        Wisdo
# 60                              Woebot Labs Inc
# 61                             Akilan Rajendran
# 62                                     Touchkin
# 63                                 Youper, Inc.
#
#                                      genres price  \
# 0           Gezondheid en fitness,Lifestyle  0.00
# 1           Gezondheid en fitness,Lifestyle  0.00
# 2           Gezondheid en fitness,Lifestyle  0.00
# 3         Gezondheid en fitness,Geneeskunde  0.00
# 4                     Gezondheid en fitness  0.00
# ..                                      ...   ...
# 59  Gezondheid en fitness,Sociaal netwerken  0.00
# 60          Gezondheid en fitness,Lifestyle  0.00
# 61          Gezondheid en fitness,Lifestyle  5.49
# 62          Gezondheid en fitness,Lifestyle  0.00
# 63        Geneeskunde,Gezondheid en fitness  0.00
#
#                                           description  \
# 0   Aloe Bud is your all-in-one, self-care pocket ...
# 1   ** As loved by Apple (Best of 2017, #1 New App...
# 2   BetterHelp is the convenient way to get profes...
# 3   Breathe2Relax is a portable stress management ...
# 4   Breathwrk guides you through quick and powerfu...
# ..                                                ...
# 59  Wisdo is a friendly, safe place to share life ...
# 60  Meet Woebot! Your friendly self-care expert. W...
# 61  We maken ons vaak zorgen en worden ongerust ov...
# 62  Wysa is used by more than a million people fro...
# 63  ** App of the day ** - Apple\n** Your pandemic...
#
#                                bundleId userRatingCount  \
# 0                        club.aloe.Aloe              52
# 1                        com.AuraMobile             224
# 2   com.ionicframework.betterhelp369708              42
# 3          org.t2health.BreatheTwoRelax               6
# 4                     com.breathwrk.ios             164
# ..                                  ...             ...
# 59                      com.wisdo.wisdo              63
# 60                     io.woebot.alpha0             147
# 61                com.akilan.worrywatch               2
# 62                         bot.touchkin              88
# 63                        br.com.youper             130
#
#                          _id
# 0   605a2105fa456042d0948f3e
# 1   605a2105fa456042d0948f3f
# 2   605a2105fa456042d0948f40
# 3   605a2105fa456042d0948f41
# 4   605a2105fa456042d0948f42
# ..                       ...
# 59  605a2105fa456042d0948f79
# 60  605a2105fa456042d0948f7a
# 61  605a2105fa456042d0948f7b
# 62  605a2105fa456042d0948f7c
# 63  605a2105fa456042d0948f7d
#
# [64 rows x 45 columns]

# %% [markdown]
# #### Store Scraped App Store Data in New MongoDB Collection

# %%
## Set up new collection within project db
app_store_info = mha_proj_db['app_store_info']

## Insert app details into app_store_info collection
app_store_info.insert_many(app_store_list)

# %%
## Check that the new db for the project exists
  ## (lazily created upon insertion of data into a collection)
list(client.list_databases())
# Out:
# [{'name': 'admin', 'sizeOnDisk': 32768.0, 'empty': False},
#  {'name': 'config', 'sizeOnDisk': 12288.0, 'empty': False},
#  {'name': 'local', 'sizeOnDisk': 32768.0, 'empty': False},
#  {'name': 'mha_proj_db', 'sizeOnDisk': 8192.0, 'empty': False}]

# %%
# Turns query (here, basically SELECT *) into a list and creates df from that list of dicts
app_store_info_df = pd.DataFrame(list(app_store_info.find({})))
app_store_info_df
# Out:
#                          _id  \
# 0   605a2105fa456042d0948f3e
# 1   605a2105fa456042d0948f3f
# 2   605a2105fa456042d0948f40
# 3   605a2105fa456042d0948f41
# 4   605a2105fa456042d0948f42
# ..                       ...
# 59  605a2105fa456042d0948f79
# 60  605a2105fa456042d0948f7a
# 61  605a2105fa456042d0948f7b
# 62  605a2105fa456042d0948f7c
# 63  605a2105fa456042d0948f7d
#
#                                        screenshotUrls  \
# 0   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                    ipadScreenshotUrls appletvScreenshotUrls  \
# 0   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 4
# ..                                                ...                   ...
# 59
# 60  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 62
# 63  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                          artworkUrl60  \
# 0   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                         artworkUrl512  \
# 0   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                         artworkUrl100  \
# 0   https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2   https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3   https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4   https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# ..                                                ...
# 59  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 60  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 61  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 62  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 63  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                         artistViewUrl  \
# 0   https://apps.apple.com/nl/developer/aloebud-ll...
# 1   https://apps.apple.com/nl/developer/aura-healt...
# 2   https://apps.apple.com/nl/developer/betterhelp...
# 3   https://apps.apple.com/nl/developer/national-c...
# 4   https://apps.apple.com/nl/developer/breathwork...
# ..                                                ...
# 59  https://apps.apple.com/nl/developer/wisdo/id12...
# 60  https://apps.apple.com/nl/developer/woebot-lab...
# 61  https://apps.apple.com/nl/developer/akilan-raj...
# 62  https://apps.apple.com/nl/developer/touchkin/i...
# 63  https://apps.apple.com/nl/developer/youper-inc...
#
#                                      supportedDevices  \
# 0   iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 1   iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 2   iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 3   iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 4   iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# ..                                                ...
# 59  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 60  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 61  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 62  iPhone5-iPhone5,iPadFourthGen-iPadFourthGen,iP...
# 63  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
#
#                                            advisories  ...  currency  \
# 0                                                      ...       EUR
# 1                                                      ...       EUR
# 2          Soms/Milde medische/behandelingsinformatie  ...       EUR
# 3                                                      ...       EUR
# 4                                                      ...       EUR
# ..                                                ...  ...       ...
# 59  Regelmatig/Intense medische/behandelingsinform...  ...       EUR
# 60  Soms/Milde medische/behandelingsinformatie,Som...  ...       EUR
# 61                                                     ...       EUR
# 62         Soms/Milde medische/behandelingsinformatie  ...       EUR
# 63         Soms/Milde medische/behandelingsinformatie  ...       EUR
#
#      version wrapperType    artistId  \
# 0        1.1    software  1170681391
# 1     3.11.6    software  1042329742
# 2        9.9    software   995252383
# 3      1.7.7    software   499648345
# 4      5.0.3    software  1481804499
# ..       ...         ...         ...
# 59      2.75    software  1266661757
# 60    3.27.2    software  1305375831
# 61      3.21    software   693833920
# 62       5.9    software  1040527118
# 63  9.02.007    software  1289788840
#
#                                      artistName  \
# 0                                   Aloebud LLC
# 1                              Aura Health Inc.
# 2                                    BetterHelp
# 3   National Center for Telehealth & Technology
# 4                               Breathwork Inc.
# ..                                          ...
# 59                                        Wisdo
# 60                              Woebot Labs Inc
# 61                             Akilan Rajendran
# 62                                     Touchkin
# 63                                 Youper, Inc.
#
#                                      genres price  \
# 0           Gezondheid en fitness,Lifestyle  0.00
# 1           Gezondheid en fitness,Lifestyle  0.00
# 2           Gezondheid en fitness,Lifestyle  0.00
# 3         Gezondheid en fitness,Geneeskunde  0.00
# 4                     Gezondheid en fitness  0.00
# ..                                      ...   ...
# 59  Gezondheid en fitness,Sociaal netwerken  0.00
# 60          Gezondheid en fitness,Lifestyle  0.00
# 61          Gezondheid en fitness,Lifestyle  5.49
# 62          Gezondheid en fitness,Lifestyle  0.00
# 63        Geneeskunde,Gezondheid en fitness  0.00
#
#                                           description  \
# 0   Aloe Bud is your all-in-one, self-care pocket ...
# 1   ** As loved by Apple (Best of 2017, #1 New App...
# 2   BetterHelp is the convenient way to get profes...
# 3   Breathe2Relax is a portable stress management ...
# 4   Breathwrk guides you through quick and powerfu...
# ..                                                ...
# 59  Wisdo is a friendly, safe place to share life ...
# 60  Meet Woebot! Your friendly self-care expert. W...
# 61  We maken ons vaak zorgen en worden ongerust ov...
# 62  Wysa is used by more than a million people fro...
# 63  ** App of the day ** - Apple\n** Your pandemic...
#
#                                bundleId userRatingCount
# 0                        club.aloe.Aloe              52
# 1                        com.AuraMobile             224
# 2   com.ionicframework.betterhelp369708              42
# 3          org.t2health.BreatheTwoRelax               6
# 4                     com.breathwrk.ios             164
# ..                                  ...             ...
# 59                      com.wisdo.wisdo              63
# 60                     io.woebot.alpha0             147
# 61                com.akilan.worrywatch               2
# 62                         bot.touchkin              88
# 63                        br.com.youper             130
#
# [64 rows x 45 columns]

# %%
## Check columns of new df
app_store_info_df.columns
# Out:
# Index(['_id', 'screenshotUrls', 'ipadScreenshotUrls', 'appletvScreenshotUrls',
#        'artworkUrl60', 'artworkUrl512', 'artworkUrl100', 'artistViewUrl',
#        'supportedDevices', 'advisories', 'isGameCenterEnabled', 'kind',
#        'features', 'minimumOsVersion', 'trackCensoredName',
#        'languageCodesISO2A', 'fileSizeBytes', 'sellerUrl', 'formattedPrice',
#        'contentAdvisoryRating', 'averageUserRatingForCurrentVersion',
#        'userRatingCountForCurrentVersion', 'averageUserRating', 'trackViewUrl',
#        'trackContentRating', 'releaseDate', 'trackId', 'trackName',
#        'sellerName', 'primaryGenreName', 'genreIds',
#        'isVppDeviceBasedLicensingEnabled', 'currentVersionReleaseDate',
#        'releaseNotes', 'primaryGenreId', 'currency', 'version', 'wrapperType',
#        'artistId', 'artistName', 'genres', 'price', 'description', 'bundleId',
#        'userRatingCount'],
#       dtype='object')

# %%
## Also save df to csv
app_store_info_df.to_csv('Data/app_store_info.csv', index=False)

# %%
app_store_info_df = pd.read_csv('Data/app_store_info.csv')
app_store_info_df.drop(columns='_id', inplace=True)
app_store_info_df.head()
# Out:
#                                       screenshotUrls  \
# 0  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                   ipadScreenshotUrls  appletvScreenshotUrls  \
# 0  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 1  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 3  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 4                                                NaN                    NaN
#
#                                         artworkUrl60  \
# 0  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                        artworkUrl512  \
# 0  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                        artworkUrl100  \
# 0  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                        artistViewUrl  \
# 0  https://apps.apple.com/nl/developer/aloebud-ll...
# 1  https://apps.apple.com/nl/developer/aura-healt...
# 2  https://apps.apple.com/nl/developer/betterhelp...
# 3  https://apps.apple.com/nl/developer/national-c...
# 4  https://apps.apple.com/nl/developer/breathwork...
#
#                                     supportedDevices  \
# 0  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 1  iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 2  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 3  iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 4  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
#
#                                    advisories  isGameCenterEnabled  ...  \
# 0                                         NaN                 True  ...
# 1                                         NaN                False  ...
# 2  Soms/Milde medische/behandelingsinformatie                False  ...
# 3                                         NaN                False  ...
# 4                                         NaN                False  ...
#
#   currency version  wrapperType    artistId  \
# 0      EUR     1.1     software  1170681391
# 1      EUR  3.11.6     software  1042329742
# 2      EUR     9.9     software   995252383
# 3      EUR   1.7.7     software   499648345
# 4      EUR   5.0.3     software  1481804499
#
#                                     artistName  \
# 0                                  Aloebud LLC
# 1                             Aura Health Inc.
# 2                                   BetterHelp
# 3  National Center for Telehealth & Technology
# 4                              Breathwork Inc.
#
#                               genres price  \
# 0    Gezondheid en fitness,Lifestyle   0.0
# 1    Gezondheid en fitness,Lifestyle   0.0
# 2    Gezondheid en fitness,Lifestyle   0.0
# 3  Gezondheid en fitness,Geneeskunde   0.0
# 4              Gezondheid en fitness   0.0
#
#                                          description  \
# 0  Aloe Bud is your all-in-one, self-care pocket ...
# 1  ** As loved by Apple (Best of 2017, #1 New App...
# 2  BetterHelp is the convenient way to get profes...
# 3  Breathe2Relax is a portable stress management ...
# 4  Breathwrk guides you through quick and powerfu...
#
#                               bundleId  userRatingCount
# 0                       club.aloe.Aloe               52
# 1                       com.AuraMobile              224
# 2  com.ionicframework.betterhelp369708               42
# 3         org.t2health.BreatheTwoRelax                6
# 4                    com.breathwrk.ios              164
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Scrape App Info from Google Play

# %%
## Set up loop to get similar app data from Google Play
google_play_list = []

for i in google_play_ids:
    info = app(i)
    del info['comments']
    google_play_list.append(info)

pprint(google_play_list)
# Out:
# [{'adSupported': None,
#   'androidVersion': '4.1',
#   'androidVersionText': '4.1 and up',
#   'appId': 'com.aurahealth',
#   'containsAds': False,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': '<b>Find peace everyday with Aura</b> - discover thousands of '
#                  'meditations to relieve stress, anxiety, improve sleep, relax '
#                  'and more - personalized just for you.\r\n'
#                  '\r\n'
#                  'Featured on: Forbes, The Oprah Magazine, The New York Times, '
#                  'Women’s & Men’s Health, and more!\r\n'
#                  '\r\n'
#                  'Aura is the ultimate & personalized meditation and '
#                  'mindfulness app. With Aura, you have unlimited access to '
#                  'meditations (guided and unguided), life coaching, and '
#                  'stories from top coaches and therapists around the world.\r\n'
#                  '\r\n'
#                  'Here are a few reasons why our community of 5 million loves '
#                  'Aura!\r\n'
#                  '\r\n'
#                  '<b>Access a massive soundtrack library</b>\r\n'
#                  'We’re proud of having one of the world’s largest & most '
#                  'diverse libraries of meditation content.\r\n'
#                  '\r\n'
#                  'Enjoy thousands of meditations, stories and life coaching '
#                  'from top mindfulness and life coaches around the world. We '
#                  'feature diverse perspectives, voices, and teachings so you '
#                  'find the best fit for you.\r\n'
#                  '\r\n'
#                  '<b>Only 3 minutes a day</b>\r\n'
#                  'With Aura, it’s easy to create a daily, simple habit of '
#                  'self-care. Relax, become more mindful and reap the benefits '
#                  'in just 3 minutes a day. We’ll send you meditation reminders '
#                  'to help you create a new, healthy habit - if you want us '
#                  'to!\r\n'
#                  '\r\n'
#                  '<b>Improve your sleep</b>\r\n'
#                  'Aura features meditations for sleep, as well as sleep '
#                  'stories, music and sounds to help with insomnia.\r\n'
#                  '\r\n'
#                  '<b>Proven to reduce stress and anxiety</b>\r\n'
#                  ' A perfect wellness coach for beginners who want to learn '
#                  'how to meditate, especially for stress and anxiety relief\r\n'
#                  '\r\n'
#                  '<b>Personalized meditations</b>\r\n'
#                  'When you use the app and rate your experience, Aura will '
#                  'learn more about you to provide more relevant, personalized '
#                  "suggestions for next time. Aura has the world's most "
#                  'advanced personalization engine powered by the latest '
#                  'research in machine learning.\r\n'
#                  '\r\n'
#                  '<b>Meditation for every situation</b>\r\n'
#                  'Aura has a huge collection of meditations, divided into '
#                  'categories such as sleep, anxiety, happiness, parenting, '
#                  'morning and more!\r\n'
#                  'We have meditations and coaching lessons for everybody, no '
#                  'matter your goals.\r\n'
#                  '\r\n'
#                  '<b>Meditation & mindfulness for beginners</b>\r\n'
#                  'Aura has plenty of content for you, whether you’re '
#                  'experienced or brand new looking for an app to help you '
#                  'learn how to meditate.\r\n'
#                  '\r\n'
#                  '<b>Gratitude journal</b>\r\n'
#                  'Self-reflection and gratitude has profound benefits on your '
#                  'wellbeing and overall outlook on life. Try writing down some '
#                  'things you’re grateful for each day in the journal!\r\n'
#                  '\r\n'
#                  '<b>Track & improve your mood</b>\r\n'
#                  'Become more aware of your mood and emotions with our mood '
#                  'tracker. Learn about your mood patterns and visually see '
#                  'yourself improve over time.\r\n'
#                  '\r\n'
#                  '<b>Nature & relaxation sounds</b>\r\n'
#                  'Whether you need to take a moment to relax during the day, '
#                  'or you want some nature sounds to help you sleep – listen to '
#                  'thunder, rain, forest sounds and more.\r\n'
#                  '\r\n'
#                  '<b>Unguided meditations</b>\r\n'
#                  'We have a library of meditation music, hypnosis and unguided '
#                  'meditations complete with handy timer!\r\n'
#                  '\r\n'
#                  '<b>Try 7-days completely free! </b>\r\n'
#                  'Aura is free for everybody – you get a free 3 minute session '
#                  'every 2 hours, every day. A premium subscription is '
#                  'available for users who want unlimited access to Aura’s '
#                  'content.\r\n'
#                  '\r\n'
#                  'Transform your daily wellbeing, emotional health, and sleep '
#                  'with Aura today. Become your calm, grounded, resilient self '
#                  "with the world's best mindfulness meditations and "
#                  'stories.\r\n'
#                  '\r\n'
#                  "We're here to support you at hello@aurahealth.io.",
#   'descriptionHTML': '<b>Find peace everyday with Aura</b> - discover '
#                      'thousands of meditations to relieve stress, anxiety, '
#                      'improve sleep, relax and more - personalized just for '
#                      'you.<br><br>Featured on: Forbes, The Oprah Magazine, The '
#                      'New York Times, Women’s &amp; Men’s Health, and '
#                      'more!<br><br>Aura is the ultimate &amp; personalized '
#                      'meditation and mindfulness app. With Aura, you have '
#                      'unlimited access to meditations (guided and unguided), '
#                      'life coaching, and stories from top coaches and '
#                      'therapists around the world.<br><br>Here are a few '
#                      'reasons why our community of 5 million loves '
#                      'Aura!<br><br><b>Access a massive soundtrack '
#                      'library</b><br>We’re proud of having one of the world’s '
#                      'largest &amp; most diverse libraries of meditation '
#                      'content.<br><br>Enjoy thousands of meditations, stories '
#                      'and life coaching from top mindfulness and life coaches '
#                      'around the world. We feature diverse perspectives, '
#                      'voices, and teachings so you find the best fit for '
#                      'you.<br><br><b>Only 3 minutes a day</b><br>With Aura, '
#                      'it’s easy to create a daily, simple habit of self-care. '
#                      'Relax, become more mindful and reap the benefits in just '
#                      '3 minutes a day. We’ll send you meditation reminders to '
#                      'help you create a new, healthy habit - if you want us '
#                      'to!<br><br><b>Improve your sleep</b><br>Aura features '
#                      'meditations for sleep, as well as sleep stories, music '
#                      'and sounds to help with insomnia.<br><br><b>Proven to '
#                      'reduce stress and anxiety</b><br> A perfect wellness '
#                      'coach for beginners who want to learn how to meditate, '
#                      'especially for stress and anxiety '
#                      'relief<br><br><b>Personalized meditations</b><br>When '
#                      'you use the app and rate your experience, Aura will '
#                      'learn more about you to provide more relevant, '
#                      'personalized suggestions for next time. Aura has the '
#                      'world&#39;s most advanced personalization engine powered '
#                      'by the latest research in machine '
#                      'learning.<br><br><b>Meditation for every '
#                      'situation</b><br>Aura has a huge collection of '
#                      'meditations, divided into categories such as sleep, '
#                      'anxiety, happiness, parenting, morning and more!<br>We '
#                      'have meditations and coaching lessons for everybody, no '
#                      'matter your goals.<br><br><b>Meditation &amp; '
#                      'mindfulness for beginners</b><br>Aura has plenty of '
#                      'content for you, whether you’re experienced or brand new '
#                      'looking for an app to help you learn how to '
#                      'meditate.<br><br><b>Gratitude '
#                      'journal</b><br>Self-reflection and gratitude has '
#                      'profound benefits on your wellbeing and overall outlook '
#                      'on life. Try writing down some things you’re grateful '
#                      'for each day in the journal!<br><br><b>Track &amp; '
#                      'improve your mood</b><br>Become more aware of your mood '
#                      'and emotions with our mood tracker. Learn about your '
#                      'mood patterns and visually see yourself improve over '
#                      'time.<br><br><b>Nature &amp; relaxation '
#                      'sounds</b><br>Whether you need to take a moment to relax '
#                      'during the day, or you want some nature sounds to help '
#                      'you sleep – listen to thunder, rain, forest sounds and '
#                      'more.<br><br><b>Unguided meditations</b><br>We have a '
#                      'library of meditation music, hypnosis and unguided '
#                      'meditations complete with handy timer!<br><br><b>Try '
#                      '7-days completely free! </b><br>Aura is free for '
#                      'everybody – you get a free 3 minute session every 2 '
#                      'hours, every day. A premium subscription is available '
#                      'for users who want unlimited access to Aura’s '
#                      'content.<br><br>Transform your daily wellbeing, '
#                      'emotional health, and sleep with Aura today. Become your '
#                      'calm, grounded, resilient self with the world&#39;s best '
#                      'mindfulness meditations and stories.<br><br>We&#39;re '
#                      'here to support you at hello@aurahealth.io.',
#   'developer': 'Aura Health - Mindfulness, Sleep, Meditations',
#   'developerAddress': '2 Embarcadero Center, Fl 8\nSan Francisco, CA 94111',
#   'developerEmail': 'hello@aurahealth.io',
#   'developerId': 'Aura+Health+-+Mindfulness,+Sleep,+Meditations',
#   'developerInternalID': '8194778368040078712',
#   'developerWebsite': 'http://www.aurahealth.io',
#   'editorsChoice': False,
#   'free': True,
#   'genre': 'Health & Fitness',
#   'genreId': 'HEALTH_AND_FITNESS',
#   'headerImage': 'https://play-lh.googleusercontent.com/MM9yM7r1sToRMEXZEq_YcSMcc0uFkClEs91VF5hnaazVytyH5Nptd5n2ZAlD4wCxW00d',
#   'histogram': [547, 248, 208, 935, 8594],
#   'icon': 'https://play-lh.googleusercontent.com/xMwzEkyE60VeKJlQRt4WhvFRAItiLTagnKwPTBL2BY69_nmnm07CwOIl-ug8QU-9og',
#   'inAppProductPrice': '$5.99 - $399.99 per item',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'offersIAP': True,
#   'originalPrice': None,
#   'price': 0,
#   'privacyPolicy': 'https://www.aurahealth.io/privacy-policy/',
#   'ratings': 10532,
#   'recentChanges': None,
#   'recentChangesHTML': None,
#   'released': 'Mar 21, 2017',
#   'reviews': 3407,
#   'sale': False,
#   'saleText': None,
#   'saleTime': None,
#   'score': 4.5930123,
#   'screenshots': ['https://play-lh.googleusercontent.com/IEVbR6hjwN2x8v_z9dNuk4z8M2nd-qK0dOmxp8lOpakXz5SGZbmgoj5ugOQ7YEcsBW11',
#                   'https://play-lh.googleusercontent.com/MKNrkBNDFNsO5T6-mwz-ozra2gWXlgvOXsOLB77UvbE3d6-HTaAqQbDW0PRlA4b3Z0Q',
#                   'https://play-lh.googleusercontent.com/KqQYHI78iPv3nwZdmn6HwxW12mrrwgGXlPfVVmf4e6a9h8gy5jC85HpdJyd-SAjxwYLU',
#                   'https://play-lh.googleusercontent.com/C6xbFFoDqVaflclQNZ6WtojSeUZMQdkOIHnrza1Bt7XsiZv3ZcgL7C0i3U_I8A-peeKW',
#                   'https://play-lh.googleusercontent.com/lBpGP7nU_tAwwymdJtGZJYTR08W3FAlARL_QLqzspOZIDb8G4VYnNvW6gjMxfdyDH_E',
#                   'https://play-lh.googleusercontent.com/6f5UNjosblZIhxJF8KT3qU8KJRduV-XM6K8uLO4sDHUvmvKiAzF7JWEMPOr-r3XmJZM'],
#   'size': '57M',
#   'summary': "1000s of Meditations from world's best coaches. Relax, sleep & "
#              'reduce anxiety!',
#   'summaryHTML': '1000s of Meditations from world&#39;s best coaches. Relax, '
#                  'sleep &amp; reduce anxiety!',
#   'title': 'Aura: Meditations, Sleep & Mindfulness',
#   'updated': 1605694888,
#   'url': 'https://play.google.com/store/apps/details?id=com.aurahealth&hl=en&gl=us',
#   'version': '2.4.2',
#   'video': None,
#   'videoImage': None},
#  {'adSupported': None,
#   'androidVersion': '6.0',
#   'androidVersionText': '6.0 and up',
#   'appId': 'com.betterhelp',
#   'containsAds': False,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': 'BetterHelp is the convenient way to get professional help '
#                  'from licensed therapists and counselors. With over 15,000 '
#                  'trained, experienced and accredited counselors covering a '
#                  'wide range of areas – from depression and anxiety to family '
#                  'and couples therapy – it’s never been easier to receive '
#                  'personal, professional help when you need it.\r\n'
#                  ' \r\n'
#                  '-------------------------------------------\r\n'
#                  'BETTERHELP – FEATURES\r\n'
#                  '-------------------------------------------\r\n'
#                  '• Over 15,000 counselors & therapists with different areas '
#                  'of expertise\r\n'
#                  '• All counselors are licensed, trained, accredited and '
#                  'highly experienced\r\n'
#                  '• Match with an available counselor who is the best fit for '
#                  'your needs\r\n'
#                  '• Unlimited private one on one communication with your '
#                  'therapist\r\n'
#                  '• Schedule live sessions with your counselor or use the '
#                  'secure messenger\r\n'
#                  '• Gain access to constructive, educational group webinars\r\n'
#                  ' \r\n'
#                  'PROFESSIONAL HELP, PERSONALIZED FOR YOU\r\n'
#                  'Facing obstacles alone can be daunting – receiving support '
#                  'and guidance from a professional counselor has been shown to '
#                  'make huge, positive changes to help you overcome personal '
#                  'challenges. When you sign up we’ll match you to an available '
#                  'counselor who fits your objectives, preferences and the type '
#                  'of issues you’re dealing with. Different counselors have '
#                  'different approaches and areas of expertise so we’ll work '
#                  'with you to find the right person who can achieve the best '
#                  'results for you.\r\n'
#                  ' \r\n'
#                  'LICENSED AND TRAINED COUNSELORS & THERAPISTS\r\n'
#                  'There are over 15,000 counselors in BetterHelp, each with at '
#                  'least 3 years and 1,000 hours of hands-on experience. They '
#                  'are licensed, trained, experienced and accredited '
#                  'psychologists (PhD/PsyD), marriage and family therapists '
#                  '(MFT), clinical social workers (LCSW), licensed professional '
#                  'counselors (LPC), or similar credentials.\r\n'
#                  ' \r\n'
#                  'All of our therapists have a Master’s Degree or a Doctorate '
#                  'Degree in their respective fields. They have been qualified '
#                  'and certified by their state professional board and have '
#                  'completed the necessary education, exams, training and '
#                  'practice.\r\n'
#                  ' \r\n'
#                  'HOW DOES IT WORK?\r\n'
#                  'After filling out our questionnaire, you will be matched '
#                  'with a licensed counselor based on your needs and '
#                  'preferences. You and your counselor will get your own secure '
#                  'and private “counseling room” where you can message your '
#                  'counselor at any time, from any internet-connected device, '
#                  'wherever you are. You can also schedule a session so speak '
#                  'live with your counselor over video or phone.\r\n'
#                  ' \r\n'
#                  'You can write or talk about yourself, the things going on in '
#                  'your life, ask questions and discuss the challenges you’re '
#                  'facing and your counselor will provide feedback, insights '
#                  'and guidance. This ongoing one-on-one dialogue is the '
#                  'foundation of your work with your counselor.\r\n'
#                  ' \r\n'
#                  'Together you’ll work towards making a positive change in '
#                  'your life, accomplishing your goals and overcoming your '
#                  'problems.\r\n'
#                  ' \r\n'
#                  'HOW MUCH DOES IT COST?\r\n'
#                  'The cost of counseling through BetterHelp ranges from $60 to '
#                  '$90 per week (billed every 4 weeks) and it is based on your '
#                  'location, preferences, and therapist availability. Unlike '
#                  'traditional in-office therapy which can cost over $150 for a '
#                  'single session, your BetterHelp membership includes '
#                  'unlimited text, video, audio messaging as well as weekly '
#                  'live sessions. The subscription is billed and renewed every '
#                  '4 weeks and includes both the use of the secured site and '
#                  'the counseling service itself. You can cancel your '
#                  'membership at any time for any reason.\r\n'
#                  ' \r\n'
#                  ' \r\n'
#                  'YOU DESERVE TO BE HAPPY.\r\n'
#                  ' \r\n'
#                  'WE ARE HERE TO HELP MAKE IT HAPPEN – DOWNLOAD BETTERHELP '
#                  'TODAY!',
#   'descriptionHTML': 'BetterHelp is the convenient way to get professional '
#                      'help from licensed therapists and counselors. With over '
#                      '15,000 trained, experienced and accredited counselors '
#                      'covering a wide range of areas – from depression and '
#                      'anxiety to family and couples therapy – it’s never been '
#                      'easier to receive personal, professional help when you '
#                      'need it.<br> '
#                      '<br>-------------------------------------------<br>BETTERHELP '
#                      '– '
#                      'FEATURES<br>-------------------------------------------<br>• '
#                      'Over 15,000 counselors &amp; therapists with different '
#                      'areas of expertise<br>• All counselors are licensed, '
#                      'trained, accredited and highly experienced<br>• Match '
#                      'with an available counselor who is the best fit for your '
#                      'needs<br>• Unlimited private one on one communication '
#                      'with your therapist<br>• Schedule live sessions with '
#                      'your counselor or use the secure messenger<br>• Gain '
#                      'access to constructive, educational group webinars<br> '
#                      '<br>PROFESSIONAL HELP, PERSONALIZED FOR YOU<br>Facing '
#                      'obstacles alone can be daunting – receiving support and '
#                      'guidance from a professional counselor has been shown to '
#                      'make huge, positive changes to help you overcome '
#                      'personal challenges. When you sign up we’ll match you to '
#                      'an available counselor who fits your objectives, '
#                      'preferences and the type of issues you’re dealing with. '
#                      'Different counselors have different approaches and areas '
#                      'of expertise so we’ll work with you to find the right '
#                      'person who can achieve the best results for you.<br> '
#                      '<br>LICENSED AND TRAINED COUNSELORS &amp; '
#                      'THERAPISTS<br>There are over 15,000 counselors in '
#                      'BetterHelp, each with at least 3 years and 1,000 hours '
#                      'of hands-on experience. They are licensed, trained, '
#                      'experienced and accredited psychologists (PhD/PsyD), '
#                      'marriage and family therapists (MFT), clinical social '
#                      'workers (LCSW), licensed professional counselors (LPC), '
#                      'or similar credentials.<br> <br>All of our therapists '
#                      'have a Master’s Degree or a Doctorate Degree in their '
#                      'respective fields. They have been qualified and '
#                      'certified by their state professional board and have '
#                      'completed the necessary education, exams, training and '
#                      'practice.<br> <br>HOW DOES IT WORK?<br>After filling out '
#                      'our questionnaire, you will be matched with a licensed '
#                      'counselor based on your needs and preferences. You and '
#                      'your counselor will get your own secure and private '
#                      '“counseling room” where you can message your counselor '
#                      'at any time, from any internet-connected device, '
#                      'wherever you are. You can also schedule a session so '
#                      'speak live with your counselor over video or phone.<br> '
#                      '<br>You can write or talk about yourself, the things '
#                      'going on in your life, ask questions and discuss the '
#                      'challenges you’re facing and your counselor will provide '
#                      'feedback, insights and guidance. This ongoing one-on-one '
#                      'dialogue is the foundation of your work with your '
#                      'counselor.<br> <br>Together you’ll work towards making a '
#                      'positive change in your life, accomplishing your goals '
#                      'and overcoming your problems.<br> <br>HOW MUCH DOES IT '
#                      'COST?<br>The cost of counseling through BetterHelp '
#                      'ranges from $60 to $90 per week (billed every 4 weeks) '
#                      'and it is based on your location, preferences, and '
#                      'therapist availability. Unlike traditional in-office '
#                      'therapy which can cost over $150 for a single session, '
#                      'your BetterHelp membership includes unlimited text, '
#                      'video, audio messaging as well as weekly live sessions. '
#                      'The subscription is billed and renewed every 4 weeks and '
#                      'includes both the use of the secured site and the '
#                      'counseling service itself. You can cancel your '
#                      'membership at any time for any reason.<br> <br> <br>YOU '
#                      'DESERVE TO BE HAPPY.<br> <br>WE ARE HERE TO HELP MAKE IT '
#                      'HAPPEN – DOWNLOAD BETTERHELP TODAY!',
#   'developer': 'BetterHelp - Therapy Made Easy',
#   'developerAddress': None,
#   'developerEmail': 'contact@betterhelp.com',
#   'developerId': 'BetterHelp+-+Therapy+Made+Easy',
#   'developerInternalID': '8471454122300503722',
#   'developerWebsite': 'https://www.betterhelp.com',
#   'editorsChoice': False,
#   'free': True,
#   'genre': 'Health & Fitness',
#   'genreId': 'HEALTH_AND_FITNESS',
#   'headerImage': 'https://play-lh.googleusercontent.com/96QFQfn1bvx3KqsA1wwDUYiwcYoAinpNYPWUX0b73BE6GojypqaKXUF1POM5Ld_y-g',
#   'histogram': [1489, 286, 276, 1450, 12136],
#   'icon': 'https://play-lh.googleusercontent.com/fdCP2dFi0J7VjMpT0ms3xJrExr4B_vS98dfcAVTWQFfrzFrVbl8Ua5LfEwyXyb1qCQ',
#   'inAppProductPrice': None,
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'offersIAP': False,
#   'originalPrice': None,
#   'price': 0,
#   'privacyPolicy': 'https://www.betterhelp.com/privacy',
#   'ratings': 15637,
#   'recentChanges': 'Thank you for using BetterHelp! We are constantly '
#                    'improving our app and delivering enhancements to the App '
#                    "Store. Every update is a boost to the app's stability, "
#                    'speed, and security.',
#   'recentChangesHTML': 'Thank you for using BetterHelp! We are constantly '
#                        'improving our app and delivering enhancements to the '
#                        'App Store. Every update is a boost to the app&#39;s '
#                        'stability, speed, and security.',
#   'released': 'Nov 17, 2014',
#   'reviews': 5344,
#   'sale': False,
#   'saleText': None,
#   'saleTime': None,
#   'score': 4.435962,
#   'screenshots': ['https://play-lh.googleusercontent.com/b77_ZDuKy36R8b0OtjRS6rW1Xn2bM2PL_b3Ig-ikpbnuW1v1wULN1LhWJSYXlEt7jU8',
#                   'https://play-lh.googleusercontent.com/Zk2MBf1jiKxla3qRqxH2LAOP7zThoOMXXYFuZAWo-lrVeWX-4_LJnuMlnSb2Kp7oSWA',
#                   'https://play-lh.googleusercontent.com/j6ZzTCgZMSAleLnbMBd9JdmNx0_3dkjK2zhGcAuS07cM0ZPDcwGOghvH26-g4ylreqk',
#                   'https://play-lh.googleusercontent.com/G4_GnOhwVJHxgSVhcqZAjQJKBKqjS1_299Oi2sAXTbXP_UQolQcPCBlnUCpYoSbSEowr',
#                   'https://play-lh.googleusercontent.com/yq7dNiloE-1XsyrAWl6pVw9XkPsfFMlOS3jDSaKg3n_cT41jiZlyqf6l21xAN7zOTyE'],
#   'size': '39M',
#   'summary': 'Get counseling from a licensed therapist, manage and improve '
#              'your mental health',
#   'summaryHTML': 'Get counseling from a licensed therapist, manage and improve '
#                  'your mental health',
#   'title': 'BetterHelp: Online Counseling & Therapy',
#   'updated': 1616437130,
#   'url': 'https://play.google.com/store/apps/details?id=com.betterhelp&hl=en&gl=us',
#   'version': '1.64',
#   'video': 'https://www.youtube.com/embed/b4KMB7mnlJw?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/b4KMB7mnlJw/hqdefault.jpg'},
#  {'adSupported': None,
#   'androidVersion': '4.4',
#   'androidVersionText': '4.4 and up',
#   'appId': 'org.t2health.breathe2relax',
#   'containsAds': False,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': 'Breathe2Relax is a portable stress management tool which '
#                  'provides detailed information on the effects of stress on '
#                  'the body and instructions and practice exercises to help '
#                  'users learn the stress management skill called diaphragmatic '
#                  'breathing.Breathing exercises have been documented to '
#                  'decrease the body’s ‘fight-or-flight’ (stress) response, and '
#                  'help with mood stabilization, anger control, and anxiety '
#                  'management. Breathe2Relax can be used as a stand-alone '
#                  'stress reduction tool, or can be used in tandem with '
#                  'clinical care directed by a healthcare worker.',
#   'descriptionHTML': 'Breathe2Relax is a portable stress management tool which '
#                      'provides detailed information on the effects of stress '
#                      'on the body and instructions and practice exercises to '
#                      'help users learn the stress management skill called '
#                      'diaphragmatic breathing.Breathing exercises have been '
#                      'documented to decrease the body’s ‘fight-or-flight’ '
#                      '(stress) response, and help with mood stabilization, '
#                      'anger control, and anxiety management. Breathe2Relax can '
#                      'be used as a stand-alone stress reduction tool, or can '
#                      'be used in tandem with clinical care directed by a '
#                      'healthcare worker.',
#   'developer': 'T2',
#   'developerAddress': None,
#   'developerEmail': 'usarmy.jblm.medcom-mamc.mbx.t2products@mail.mil',
#   'developerId': 'T2',
#   'developerInternalID': '5298048485350465783',
#   'developerWebsite': 'http://t2health.dcoe.mil/apps/breathe2relax',
#   'editorsChoice': False,
#   'free': True,
#   'genre': 'Health & Fitness',
#   'genreId': 'HEALTH_AND_FITNESS',
#   'headerImage': 'https://play-lh.googleusercontent.com/kPd9PcmxX5PHg6PdIjy_46RcS7c8hc6m2TTt-zrXe03nq5hzlPnE1CqLZROi7uEVpQc',
#   'histogram': [350, 70, 120, 130, 440],
#   'icon': 'https://play-lh.googleusercontent.com/blgBoxuRBDwOqpcxvUDXl9oca0IaUpYV9AzEfslm_j3WxJzY_JJswIytBBuCZ2g85kvE',
#   'inAppProductPrice': None,
#   'installs': '100,000+',
#   'minInstalls': 100000,
#   'offersIAP': False,
#   'originalPrice': None,
#   'price': 0,
#   'privacyPolicy': 'https://www.health.mil/Military-Health-Topics/Privacy-and-Civil-Liberties',
#   'ratings': 1110,
#   'recentChanges': 'App has been migrated to our Defense Health Agency '
#                    'account.',
#   'recentChangesHTML': 'App has been migrated to our Defense Health Agency '
#                        'account.',
#   'released': 'Oct 24, 2011',
#   'reviews': 349,
#   'sale': False,
#   'saleText': None,
#   'saleTime': None,
#   'score': 3.2162163,
#   'screenshots': ['https://play-lh.googleusercontent.com/0O0Qu2B0DhnyJRFntYk4rWh-N_1eQjk5jNTdC72A-cZh8NI-N97UdmuXK_ewSdpsUw',
#                   'https://play-lh.googleusercontent.com/3La8FDpNYObRfZbHLUsjoPeZZiW8alY5YDS299mC3Ku4bn20Sdrf9En7QFwlwL3S9g',
#                   'https://play-lh.googleusercontent.com/XV1CvySyeZ9aiWAIADe993Dv48fLos1hPleRHZfowoYQMVEQg9HxGItt6YqCw_hsKBZi',
#                   'https://play-lh.googleusercontent.com/2qzX8BSn_DYpRGXbKE1YoTMzeRYGI08BT0oAkRRptQ94yt7hGfqtXQGjNd_Pe6FIASUM'],
#   'size': '3.1M',
#   'summary': 'Breathe2Relax is a stress management tool to help learn '
#              'diaphragmatic breathing.',
#   'summaryHTML': 'Breathe2Relax is a stress management tool to help learn '
#                  'diaphragmatic breathing.',
#   'title': 'Breathe2Relax',
#   'updated': 1610041510,
#   'url': 'https://play.google.com/store/apps/details?id=org.t2health.breathe2relax&hl=en&gl=us',
#   'version': '4.0.0',
#   'video': None,
#   'videoImage': None},
#  {'adSupported': None,
#   'androidVersion': '7.0',
#   'androidVersionText': '7.0 and up',
#   'appId': 'com.Meditation.app',
#   'containsAds': False,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': 'Breathe mindfulness, peace and restful sleep into your '
#                  'life. \r\n'
#                  '\r\n'
#                  'De-stress, be happier & healthier with over 1500 guided '
#                  'meditations, soothing music, nature sounds, inspirational '
#                  'talks  and much more from \r\n'
#                  'leading experts in their field. \r\n'
#                  '\r\n'
#                  '<u> Recommended by People & InStyle. </u>\r\n'
#                  '  \r\n'
#                  'Can’t sleep? Choose from a wide variety of content to help '
#                  "you get the restful sleep you need. You'll find premade "
#                  'sleep music playlists, nature sounds, guided meditations '
#                  'tracks, sleep stories, hypnotherapy sessions, calming '
#                  'videos, breathe techniques and more. \r\n'
#                  '\r\n'
#                  'Deal with life’s challenges with <b>guided meditation</b> '
#                  'series, inspirational talks and masterclasses from '
#                  '<b>mindfulness coach Lynne Goldberg </b> & New York Times '
#                  'best-selling personal growth experts. \r\n'
#                  '\r\n'
#                  'Main Features\r\n'
#                  '\r\n'
#                  '¥        <b>Relaxation Music and Sleep Sounds  </b> Hours of '
#                  'carefully selected nature melodies to help you relax, '
#                  'meditate, focus & sleep more soundly. \r\n'
#                  '\r\n'
#                  '¥        <b>Calm Music Playlists</b> for various moods and '
#                  'occasions and the ability to create your own playlists. \r\n'
#                  '\r\n'
#                  '¥        <b>Sleep Stories </b> and sleep meditations '
#                  'narrated to lull even the  most hardcore insomniacs into a '
#                  'night of deep sleep.\r\n'
#                  '\r\n'
#                  '¥        <b>Bedtime Visualizations</b> and guided imagery to '
#                  'absorb healing and positive messages while falling '
#                  'asleep.\r\n'
#                  '\r\n'
#                  '¥        <b>Guided Meditations</b> Hundreds of series for '
#                  'whatever you’re dealing with in your life and to get you '
#                  'into a calm headspace.\r\n'
#                  '\r\n'
#                  '¥        <b>Alarm clock & morning meditations </b> to start '
#                  'your day on the right foot. \r\n'
#                  '\r\n'
#                  '¥        <b>Learn to Meditate</b> with a 12-week daily '
#                  'program and progressively bring more calm and clarity into '
#                  'your life. \r\n'
#                  '\r\n'
#                  '¥        <b>Inspirational talks and masterclasses</b> from '
#                  'some of the greatest personal growth teachers of our time to '
#                  'become more peaceful and help you enjoy your life better.\r\n'
#                  '\r\n'
#                  '¥        <b>Hypnotherapy Sessions</b> to help you tackle '
#                  'life’s challenges and to fall asleep easily for those who '
#                  'still have trouble sleeping. \r\n'
#                  '\r\n'
#                  '¥        <b>Breathing Exercises </b> and calming videos you '
#                  'can use to learn how to breathe deeper and calm down in a '
#                  'few minutes. \r\n'
#                  '\r\n'
#                  '\r\n'
#                  '¥        <b>Free version with lots of free meditations</b> '
#                  'on many subjects for as long as you want, or unlock all '
#                  'content with a Premium Membership! \r\n'
#                  '\r\n'
#                  '\r\n'
#                  'Bring more happiness, and peace of mind into your life with '
#                  'soothing music, short meditations, calming videos and '
#                  'breathe exercises you can use anytime, anywhere. \r\n'
#                  '\r\n'
#                  '\r\n'
#                  'Check out https://blog.breethe.com/ for info on the health '
#                  'benefits of mindfulness such as reducing anxiety, chronic '
#                  'insomnia & burnout.\r\n'
#                  '\r\n'
#                  '- Contact us at support@breethe.com. - \r\n'
#                  '\r\n'
#                  'For more info, consult '
#                  'https://breethe.com/more/terms-and-conditions/\r\n'
#                  'Copyright © 2015 OMG. I Can Meditate! Inc.',
#   'descriptionHTML': 'Breathe mindfulness, peace and restful sleep into your '
#                      'life. <br><br>De-stress, be happier &amp; healthier with '
#                      'over 1500 guided meditations, soothing music, nature '
#                      'sounds, inspirational talks  and much more from '
#                      '<br>leading experts in their field. <br><br><u> '
#                      'Recommended by People &amp; InStyle. </u><br>  <br>Can’t '
#                      'sleep? Choose from a wide variety of content to help you '
#                      'get the restful sleep you need. You&#39;ll find premade '
#                      'sleep music playlists, nature sounds, guided meditations '
#                      'tracks, sleep stories, hypnotherapy sessions, calming '
#                      'videos, breathe techniques and more. <br><br>Deal with '
#                      'life’s challenges with <b>guided meditation</b> series, '
#                      'inspirational talks and masterclasses from '
#                      '<b>mindfulness coach Lynne Goldberg </b> &amp; New York '
#                      'Times best-selling personal growth experts. <br><br>Main '
#                      'Features<br><br>¥        <b>Relaxation Music and Sleep '
#                      'Sounds  </b> Hours of carefully selected nature melodies '
#                      'to help you relax, meditate, focus &amp; sleep more '
#                      'soundly. <br><br>¥        <b>Calm Music Playlists</b> '
#                      'for various moods and occasions and the ability to '
#                      'create your own playlists. <br><br>¥        <b>Sleep '
#                      'Stories </b> and sleep meditations narrated to lull even '
#                      'the  most hardcore insomniacs into a night of deep '
#                      'sleep.<br><br>¥        <b>Bedtime Visualizations</b> and '
#                      'guided imagery to absorb healing and positive messages '
#                      'while falling asleep.<br><br>¥        <b>Guided '
#                      'Meditations</b> Hundreds of series for whatever you’re '
#                      'dealing with in your life and to get you into a calm '
#                      'headspace.<br><br>¥        <b>Alarm clock &amp; morning '
#                      'meditations </b> to start your day on the right foot. '
#                      '<br><br>¥        <b>Learn to Meditate</b> with a 12-week '
#                      'daily program and progressively bring more calm and '
#                      'clarity into your life. <br><br>¥        '
#                      '<b>Inspirational talks and masterclasses</b> from some '
#                      'of the greatest personal growth teachers of our time to '
#                      'become more peaceful and help you enjoy your life '
#                      'better.<br><br>¥        <b>Hypnotherapy Sessions</b> to '
#                      'help you tackle life’s challenges and to fall asleep '
#                      'easily for those who still have trouble sleeping. '
#                      '<br><br>¥        <b>Breathing Exercises </b> and calming '
#                      'videos you can use to learn how to breathe deeper and '
#                      'calm down in a few minutes. <br><br><br>¥        <b>Free '
#                      'version with lots of free meditations</b> on many '
#                      'subjects for as long as you want, or unlock all content '
#                      'with a Premium Membership! <br><br><br>Bring more '
#                      'happiness, and peace of mind into your life with '
#                      'soothing music, short meditations, calming videos and '
#                      'breathe exercises you can use anytime, anywhere. '
#                      '<br><br><br>Check out https://blog.breethe.com/ for info '
#                      'on the health benefits of mindfulness such as reducing '
#                      'anxiety, chronic insomnia &amp; burnout.<br><br>- '
#                      'Contact us at support@breethe.com. - <br><br>For more '
#                      'info, consult '
#                      'https://breethe.com/more/terms-and-conditions/<br>Copyright '
#                      '© 2015 OMG. I Can Meditate! Inc.',
#   'developer': 'Breethe',
#   'developerAddress': '754 des Fauvettes\nLongueuil, Quebec\nJ4G 2L6',
#   'developerEmail': 'support@breethe.com',
#   'developerId': 'Breethe',
#   'developerInternalID': '8674892394401317407',
#   'developerWebsite': 'https://www.breethe.com/',
#   'editorsChoice': False,
#   'free': True,
#   'genre': 'Health & Fitness',
#   'genreId': 'HEALTH_AND_FITNESS',
#   'headerImage': 'https://play-lh.googleusercontent.com/9Vw5goUVtpUFCfOWgpSqA633dex-KA2LAdjjpLk1gs3CcffAevYh5M2srr1Ysd9pmpk',
#   'histogram': [110, 60, 160, 411, 2566],
#   'icon': 'https://play-lh.googleusercontent.com/lBeI58AvO3vXYdPNd7jJhJAUigPbUu1CpXPiMvs5sP6bXwp6jy6mOrjy5gz1_AyTjg',
#   'inAppProductPrice': '$12.99 - $379.99 per item',
#   'installs': '500,000+',
#   'minInstalls': 500000,
#   'offersIAP': True,
#   'originalPrice': None,
#   'price': 0,
#   'privacyPolicy': 'https://main.breethe.com/privacy-policy',
#   'ratings': 3307,
#   'recentChanges': 'Create your own playlists and download tracks to play '
#                    'offline. Choose from over 1500 meditations, bedtime '
#                    'stories, hypnotherapy sessions, talks and sounds.',
#   'recentChangesHTML': 'Create your own playlists and download tracks to play '
#                        'offline. Choose from over 1500 meditations, bedtime '
#                        'stories, hypnotherapy sessions, talks and sounds.',
#   'released': 'Jan 25, 2016',
#   'reviews': 1223,
#   'sale': False,
#   'saleText': None,
#   'saleTime': None,
#   'score': 4.590909,
#   'screenshots': ['https://play-lh.googleusercontent.com/dvlZ3lKLdeNCCzKQTsRZE70nTX29wnULOyIltQcPWOGu2jcNwhmHmQHVPwPgs9qeQg',
#                   'https://play-lh.googleusercontent.com/bDyDU8_xS8hkMZP_WlGZWX8KXq-DdGJS1UEiwlBCCg3Ey1hqzhSsiG9Xrnhq48OpI3M',
#                   'https://play-lh.googleusercontent.com/x_SXAtD2FxORhLCjNpa9t7VViSaIXe1CXk_tvF63H2x5JoSKiADWj45Nsqm9mSXL0EI',
#                   'https://play-lh.googleusercontent.com/gD4uIdPcCOSamEseQeN4uMi00TPmesORqREQsgO6hHW-i3wo8LB4t24QsImoF1KVxObG',
#                   'https://play-lh.googleusercontent.com/vXOUDpxp0lWSpyT_mgoEAZRtM3AT8OtZi6SlDA9ExwLfO5WgaF9xcNKShhTyNGyZNJnu',
#                   'https://play-lh.googleusercontent.com/sKmPEGvTxZJjqw_CKtDL6Y3RbznGrR4xq-yRiLlX24ML70c-gq6aFsx29S308FnHFLM',
#                   'https://play-lh.googleusercontent.com/gEdEP_Zbitnqaw555_BQmxmMvX7s_nUaXmM1Elv5RIzA-zRnDM0ezsn1m6d09JHY5Q',
#                   'https://play-lh.googleusercontent.com/c33RYcB7IWPiOzZALsMehP5LlLvtaSwHiie0k0MP3HcZEgp4bazEnNlNNe6BG2mz6b8',
#                   'https://play-lh.googleusercontent.com/TNNLe5ovj2KTwLhYqKb-EK9-ORry0t_O9-kAq9D6QihgbEZw9MgqWfRl3GMSmZOO1T0',
#                   'https://play-lh.googleusercontent.com/zl8lQRxJvwm9XZyq2buaSMP4KBPczH5BXyysgILyh6obSTrw3dSv2VDqcoYhTw-G2ic',
#                   'https://play-lh.googleusercontent.com/DHDSAYiQSs-AXiHuQ2HCyp1k6htd47xHEyFyMy5QmDcCtmlAqWxlcIsuyFBnM0C91bk',
#                   'https://play-lh.googleusercontent.com/BgXyVkWEmZpmuux3ByTP3ixKSbKpRVUPYeLsBab7kCOZa5VALG6W-5qXJ4R6eqTiaV3M',
#                   'https://play-lh.googleusercontent.com/y2rC6m4J9HX3TvosW-1NXcHGhx3f32gkrKq2OnLRzU35qjbw1MBtzy00S8K2XL7Vkj29',
#                   'https://play-lh.googleusercontent.com/GvllYZFoVLvA4QN2y69WiyJ3ncr78E9_hU0PKfS7EvLtg5oEdIPVFbf10p_4w9BlzA',
#                   'https://play-lh.googleusercontent.com/7QC29tCzffCy8x-IQHUJ7CZeOAe0jNVPse1pS0Bsuq1dWpzi3hk_y49Ed6niS_aX-bDV',
#                   'https://play-lh.googleusercontent.com/eUlRgaW6nPmvwD2rxRw06FnnVMKDdZhLQM-P578cICcNkVlXqsiONxSuF7CMtXNGEW8'],
#   'size': '76M',
#   'summary': 'Sleep, relax, breathe and meditate with meditations, stories, '
#              'music and sounds',
#   'summaryHTML': 'Sleep, relax, breathe and meditate with meditations, '
#                  'stories, music and sounds',
#   'title': 'Breethe - Meditation & Sleep App',
#   'updated': 1614090448,
#   'url': 'https://play.google.com/store/apps/details?id=com.Meditation.app&hl=en&gl=us',
#   'version': '5.3.2',
#   'video': None,
#   'videoImage': None},
#  {'adSupported': None,
#   'androidVersion': 'Varies',
#   'androidVersionText': 'Varies with device',
#   'appId': 'com.calm.android',
#   'containsAds': False,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': 'Calm is a leading app for meditation and sleep. Join the '
#                  'millions experiencing lower stress, less anxiety, and more '
#                  'restful sleep with our guided meditations, Sleep Stories, '
#                  'breathing programs, masterclasses, and relaxing music. '
#                  'Recommended by top psychologists, therapists, and mental '
#                  'health experts.\r\n'
#                  '\r\n'
#                  'Calm is the perfect mindfulness app for beginners, but also '
#                  'includes hundreds of programs for intermediate and advanced '
#                  'users.\r\n'
#                  '\r\n'
#                  'Guided meditation sessions are available in lengths of 3, 5, '
#                  '10, 15, 20 or 25 minutes so you can choose the perfect '
#                  'length to fit with your schedule. Topics include:\r\n'
#                  '\r\n'
#                  '* Calming Anxiety\r\n'
#                  '* Managing Stress\r\n'
#                  '* Deep Sleep\r\n'
#                  '* Focus and Concentration\r\n'
#                  '* Relationships\r\n'
#                  '* Breaking Habits\r\n'
#                  '* Happiness\r\n'
#                  '* Gratitude\r\n'
#                  '* Self-Esteem\r\n'
#                  '* Body Scan\r\n'
#                  '* Loving-Kindness\r\n'
#                  '* Forgiveness\r\n'
#                  '* Non-judgement\r\n'
#                  '* Commuting to work or school\r\n'
#                  '* Mindfulness at College\r\n'
#                  '* Mindfulness at Work\r\n'
#                  '* Walking meditation\r\n'
#                  '* Calm Kids\r\n'
#                  '* And so much more...\r\n'
#                  '\r\n'
#                  'Also featuring:\r\n'
#                  '\r\n'
#                  '* An original Daily Calm every day: a new 10-minute program '
#                  'added daily to help ease you into the day or unwind with '
#                  'before bed\r\n'
#                  '* 100+ Sleep Stories: adult bedtime stories guaranteed to '
#                  'lull you to sleep\r\n'
#                  '* 7 and 21 day programs for both beginner and advanced '
#                  'users\r\n'
#                  '* Life-changing Calm Masterclasses taught by world-renowned '
#                  'experts\r\n'
#                  '* Breathing exercises to help you relax\r\n'
#                  '* Exclusive music engineered to help you focus, relax or '
#                  'sleep\r\n'
#                  '* Unguided timed meditation\r\n'
#                  '* Open-ended meditation\r\n'
#                  '* 30+ soothing nature sounds and scenes to use during '
#                  'meditation, yoga or to help you sleep\r\n'
#                  '\r\n'
#                  'Track your progress with:\r\n'
#                  '\r\n'
#                  '* Daily streaks\r\n'
#                  '* Time spent meditating\r\n'
#                  '\r\n'
#                  'Calm is loved by the press:\r\n'
#                  '\r\n'
#                  '* “I’m generally wary of meditation apps because they '
#                  'sometimes weave in too much mystic talk for my taste. But '
#                  'Calm instead contains guidance like ‘Concentrate on your '
#                  'body’” - New York Times\r\n'
#                  '\r\n'
#                  '* “In the frenetic, crazy, digital world we live in, '
#                  "sometimes it's necessary to take a step back and smell the "
#                  'roses” - Mashable\r\n'
#                  '\r\n'
#                  '* “Eliminating distraction...ended up helping me relax and '
#                  "realize that all the stuff I was stressing about wasn't that "
#                  'big a deal” - Tech Republic\r\n'
#                  '\r\n'
#                  '* “Found myself similarly refreshed afterwards” - '
#                  'TechCrunch\r\n'
#                  '\r\n'
#                  'Calm is free to download and use, and there are no ads. A '
#                  'subset of the programs and features are free forever.\r\n'
#                  '\r\n'
#                  'Some content is only available through an optional paid '
#                  'subscription. If you choose to subscribe, payment will be '
# ...
#   'version': '3.27.2',
#   'video': 'https://www.youtube.com/embed/KGh8dNkpZWk?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/KGh8dNkpZWk/hqdefault.jpg'},
#  {'adSupported': None,
#   'androidVersion': '4.1',
#   'androidVersionText': '4.1 and up',
#   'appId': 'bot.touchkin',
#   'containsAds': False,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': 'Imagine a mood tracker, mindfulness coach, anxiety helper, '
#                  'and mood-boosting buddy, all rolled into one. Wysa, your '
#                  'happiness buddy is that friendly and caring chatbot. Wysa is '
#                  'packed with daily spiritual meditation that improves mental '
#                  'health and is also a perfect way to bond over family '
#                  'meditation. Always there for you when you need someone to '
#                  'talk to, Wysa helps you keep track of your mood with '
#                  'friendly chats and helps fight stress and anxiety with its '
#                  'proven techniques and calming meditation and mindfulness '
#                  'audios. Checking in with Wysa regularly will improve your '
#                  'emotional health so you can track your happiness and mood. '
#                  'Talk to Wysa now and psy yourself up to fight off stress. '
#                  'Also, Wysa has mental health assessment with depression and '
#                  'anxiety tests.\r\n'
#                  '\r\n'
#                  'Wysa is your AI friend that you can chat with for free. Talk '
#                  'to the cute penguin or use its free mindfulness exercises '
#                  'for effective anxiety relief, depression and stress '
#                  'management. Its therapy based techniques and conversations '
#                  'make for a very cute and calming therapy chat app whether '
#                  "you're looking to cope better with mental disorders, to "
#                  'manage stress or to boost your mental health.\r\n'
#                  '\r\n'
#                  'Wysa, your happiness buddy, will support you through the big '
#                  'and small anxieties of life by using science as a foundation '
#                  'to strengthen your mental health. Research-backed, widely '
#                  'used techniques of CBT, DBT, Yoga and meditation are '
#                  'employed to support you with stress, anxiety, deep sleep, '
#                  'loss and other mental health and wellness needs.\r\n'
#                  '\r\n'
#                  'If you are dealing with stress, anxiety and depression or '
#                  'coping with low self-esteem, then talking to Wysa can help '
#                  'you relax and get unstuck - it’s empathetic, helpful, and '
#                  'will never judge. You will overcome your mental health '
#                  'obstacles, through empathetic conversation and free CBT '
#                  'therapy based technique. So, pour your heart out to your '
#                  'happiness buddy, Wysa as your identity will remain anonymous '
#                  'and your conversations are privacy protected.\r\n'
#                  '\r\n'
#                  'Used around the clock and trusted by 500,000 people, Wysa is '
#                  'an emotionally intelligent chatbot that uses AI to react to '
#                  'the emotions you express. Unlock tools and techniques that '
#                  'help you cope with challenges in a fun, conversational way. '
#                  'For extra support, you can avail guidance from a real human '
#                  'coach - a skilled psychologist who will take you through the '
#                  'advanced coaching sessions for your needs.\r\n'
#                  '\r\n'
#                  'You can use Wysa to rewire your mind to improve your '
#                  'emotional health. Fight off depression or get stress relief '
#                  'using cbt techniques and guided sleep meditations for '
#                  'optimal sleep. Here’s a look at what you can use Wysa for '
#                  '👇\r\n'
#                  '\r\n'
#                  '👂 Vent and talk through things or just reflect on your day '
#                  'with your AI chatbot\r\n'
#                  '💪 Practice CBT (Cognitive Behavioral Therapy) and DBT '
#                  'techniques to build resilience in a fun way\r\n'
#                  '📝 Use one of 40 conversational coaching tools which helps in '
#                  'dealing with Stress, Anxiety, Depression, Panic Attacks, '
#                  'Worry, Loss, or Conflict\r\n'
#                  '💆🏻 Relax, focus and sleep peacefully with the help of 20 '
#                  'mindfulness meditation exercises\r\n'
#                  '\r\n'
#                  '93% of the people who talk to Wysa - AI\r\n'
#                  'companion find it and the tools helpful\r\n'
#                  '- Build confidence, reduce self-doubt and improve your '
#                  'self-esteem: core meditation and mindfulness, visualisation, '
#                  'confidence visualisation techniques, advanced mindfulness '
#                  'for self-esteem\r\n'
#                  '- Manage anger: mindfulness meditation exercises for '
#                  'compassion, calming your thoughts and practice breathing\r\n'
#                  '- Manage anxious thoughts and anxiety: deep breathing, '
#                  'techniques for observing thoughts, visualization, and '
#                  'tension relief\r\n'
#                  '- Tired? Get a burst of energy! Visualisation and meditation '
#                  'exercises to increase positivity and get blissful sleep, '
#                  'quick yoga and physical exercises to get active\r\n'
#                  '- Dealing with worry: observe mindfulness, resolving '
#                  'technique, challenge negativity, practice breathing '
#                  'techniques\r\n'
#                  '- Manage conflict at work, school or in relationships: '
#                  'special mindfulness and visualization techniques like empty '
#                  'chair exercise, gratitude meditation, exercises to build '
#                  'skills in having difficult conversations',
#   'descriptionHTML': 'Imagine a mood tracker, mindfulness coach, anxiety '
#                      'helper, and mood-boosting buddy, all rolled into one. '
#                      'Wysa, your happiness buddy is that friendly and caring '
#                      'chatbot. Wysa is packed with daily spiritual meditation '
#                      'that improves mental health and is also a perfect way to '
#                      'bond over family meditation. Always there for you when '
#                      'you need someone to talk to, Wysa helps you keep track '
#                      'of your mood with friendly chats and helps fight stress '
#                      'and anxiety with its proven techniques and calming '
#                      'meditation and mindfulness audios. Checking in with Wysa '
#                      'regularly will improve your emotional health so you can '
#                      'track your happiness and mood. Talk to Wysa now and psy '
#                      'yourself up to fight off stress. Also, Wysa has mental '
#                      'health assessment with depression and anxiety '
#                      'tests.<br><br>Wysa is your AI friend that you can chat '
#                      'with for free. Talk to the cute penguin or use its free '
#                      'mindfulness exercises for effective anxiety relief, '
#                      'depression and stress management. Its therapy based '
#                      'techniques and conversations make for a very cute and '
#                      'calming therapy chat app whether you&#39;re looking to '
#                      'cope better with mental disorders, to manage stress or '
#                      'to boost your mental health.<br><br>Wysa, your happiness '
#                      'buddy, will support you through the big and small '
#                      'anxieties of life by using science as a foundation to '
#                      'strengthen your mental health. Research-backed, widely '
#                      'used techniques of CBT, DBT, Yoga and meditation are '
#                      'employed to support you with stress, anxiety, deep '
#                      'sleep, loss and other mental health and wellness '
#                      'needs.<br><br>If you are dealing with stress, anxiety '
#                      'and depression or coping with low self-esteem, then '
#                      'talking to Wysa can help you relax and get unstuck - '
#                      'it’s empathetic, helpful, and will never judge. You will '
#                      'overcome your mental health obstacles, through '
#                      'empathetic conversation and free CBT therapy based '
#                      'technique. So, pour your heart out to your happiness '
#                      'buddy, Wysa as your identity will remain anonymous and '
#                      'your conversations are privacy protected.<br><br>Used '
#                      'around the clock and trusted by 500,000 people, Wysa is '
#                      'an emotionally intelligent chatbot that uses AI to react '
#                      'to the emotions you express. Unlock tools and techniques '
#                      'that help you cope with challenges in a fun, '
#                      'conversational way. For extra support, you can avail '
#                      'guidance from a real human coach - a skilled '
#                      'psychologist who will take you through the advanced '
#                      'coaching sessions for your needs.<br><br>You can use '
#                      'Wysa to rewire your mind to improve your emotional '
#                      'health. Fight off depression or get stress relief using '
#                      'cbt techniques and guided sleep meditations for optimal '
#                      'sleep. Here’s a look at what you can use Wysa for '
#                      '👇<br><br>👂 Vent and talk through things or just reflect '
#                      'on your day with your AI chatbot<br>💪 Practice CBT '
#                      '(Cognitive Behavioral Therapy) and DBT techniques to '
#                      'build resilience in a fun way<br>📝 Use one of 40 '
#                      'conversational coaching tools which helps in dealing '
#                      'with Stress, Anxiety, Depression, Panic Attacks, Worry, '
#                      'Loss, or Conflict<br>💆🏻 Relax, focus and sleep '
#                      'peacefully with the help of 20 mindfulness meditation '
#                      'exercises<br><br>93% of the people who talk to Wysa - '
#                      'AI<br>companion find it and the tools helpful<br>- Build '
#                      'confidence, reduce self-doubt and improve your '
#                      'self-esteem: core meditation and mindfulness, '
#                      'visualisation, confidence visualisation techniques, '
#                      'advanced mindfulness for self-esteem<br>- Manage anger: '
#                      'mindfulness meditation exercises for compassion, calming '
#                      'your thoughts and practice breathing<br>- Manage anxious '
#                      'thoughts and anxiety: deep breathing, techniques for '
#                      'observing thoughts, visualization, and tension '
#                      'relief<br>- Tired? Get a burst of energy! Visualisation '
#                      'and meditation exercises to increase positivity and get '
#                      'blissful sleep, quick yoga and physical exercises to get '
#                      'active<br>- Dealing with worry: observe mindfulness, '
#                      'resolving technique, challenge negativity, practice '
#                      'breathing techniques<br>- Manage conflict at work, '
#                      'school or in relationships: special mindfulness and '
#                      'visualization techniques like empty chair exercise, '
#                      'gratitude meditation, exercises to build skills in '
#                      'having difficult conversations',
#   'developer': 'Touchkin',
#   'developerAddress': 'Touchkin Eservices Private Limited, No. 532, '
#                       '"Manjusha", First Floor, 2nd main, 16th Cross, II '
#                       'stage, Indiranagar, Bengaluru 560038',
#   'developerEmail': 'shubhankar@touchkin.com',
#   'developerId': '6520130637621273347',
#   'developerInternalID': '6520130637621273347',
#   'developerWebsite': 'https://www.wysa.io',
#   'editorsChoice': False,
#   'free': True,
#   'genre': 'Health & Fitness',
#   'genreId': 'HEALTH_AND_FITNESS',
#   'headerImage': 'https://play-lh.googleusercontent.com/yR58eh2WLT7Eh9b0d2gfYQK8YTlBYuFgGcfIj8f1mFWsEIefvzXYN1M-rAzsvv0Mj04',
#   'histogram': [1469, 476, 1360, 9027, 67373],
#   'icon': 'https://play-lh.googleusercontent.com/_2t27Nwv0sJgq3XsUCP-haxf0C17xzIEVtO4Pfrp_cSJG-VJAWzIC0DAlVF2kEx8ol2M',
#   'inAppProductPrice': '$1.49 - $199.99 per item',
#   'installs': '1,000,000+',
#   'minInstalls': 1000000,
#   'offersIAP': True,
#   'originalPrice': None,
#   'price': 0,
#   'privacyPolicy': 'http://beta.touchkin.com/privatepolicy.html',
#   'ratings': 79705,
#   'recentChanges': '- Get to the right ✅ tools and techniques 🛠faster than '
#                    'ever before, with the all new 🎀 Wysa design\r\n'
#                    '- Direct access to 🆘, and related resources. Please note '
#                    'this is not a crisis app.\r\n'
#                    '- Scroll ⬆ through the suggestion feed, to discover what '
#                    'Wysa thinks you may find interesting🤔. \r\n'
#                    '- Directly manage notifications 🔔 via settings ⚙\r\n'
#                    '- Convenient access to manage subscription 🗓 via settings '
#                    '⚙',
#   'recentChangesHTML': '- Get to the right ✅ tools and techniques 🛠faster than '
#                        'ever before, with the all new 🎀 Wysa design<br>- '
#                        'Direct access to 🆘, and related resources. Please note '
#                        'this is not a crisis app.<br>- Scroll ⬆ through the '
#                        'suggestion feed, to discover what Wysa thinks you may '
#                        'find interesting🤔. <br>- Directly manage notifications '
#                        '🔔 via settings ⚙<br>- Convenient access to manage '
#                        'subscription 🗓 via settings ⚙',
#   'released': 'Oct 6, 2016',
#   'reviews': 36506,
#   'sale': False,
#   'saleText': None,
#   'saleTime': None,
#   'score': 4.760902,
#   'screenshots': ['https://play-lh.googleusercontent.com/vNoHVmTfE387jNVpIKJ4oF7n3aRUVUIDKFFEI6XcDf3q6dj-Fz-Myn5c-OzVze_o5Cc',
#                   'https://play-lh.googleusercontent.com/T8snvAD4i-377lW0XUOd4OCfY8IL49xDfxikaY2UZlGa-fySGcKr2MNmp338My0RYtA0',
#                   'https://play-lh.googleusercontent.com/rVoKaxnAM_sk5QL0djZ6P06q7NOa8RE-HMBHhbA8DOBdrIpP9XBGPpvR2g65PHDYwVc',
#                   'https://play-lh.googleusercontent.com/MNqrxaOWzlru5pYq9Mw3UxEBnzO0-sE8B9JG9e_rYitLXIcyHy1IsePj0nFyLjr2jw',
#                   'https://play-lh.googleusercontent.com/AiqLWVaq2uyxU8_beGf-9NW_lCPlJz2ctPJ12pts2yPxPjp58NdlCWdbBlxV7T-15QXd',
#                   'https://play-lh.googleusercontent.com/wi8Q4Um-SZwjeetXdlX5e-ZZcEAKgj0DU04zXFF1o-ZabLHjxLYbyg5FTyU7wCm9KT4',
#                   'https://play-lh.googleusercontent.com/fp7gGQzTLdJYn4JUZLze4KPsp2KQJK44o1a7_0QIFx-XGp6CrpVpgHUJ--Rt8mF7H_U'],
#   'size': '8.4M',
#   'summary': 'Free therapy chat for mindfulness, mental health, stress check & '
#              'anxiety relief',
#   'summaryHTML': 'Free therapy chat for mindfulness, mental health, stress '
#                  'check &amp; anxiety relief',
#   'title': 'Wysa: anxiety, depression & sleep therapy chatbot',
#   'updated': 1615710511,
#   'url': 'https://play.google.com/store/apps/details?id=bot.touchkin&hl=en&gl=us',
#   'version': '2.5.9',
#   'video': 'https://www.youtube.com/embed/diOVSgJdH9k?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/diOVSgJdH9k/hqdefault.jpg'}]

# %%
## Successfully got data for all 53 apps in Google Play
len(google_play_list)
# Out:
# 53

# %%
pprint(google_play_list[8])
# Out:
# {'adSupported': None,
#  'androidVersion': 'Varies',
#  'androidVersionText': 'Varies with device',
#  'appId': 'my.tracker',
#  'containsAds': False,
#  'contentRating': 'Everyone',
#  'contentRatingDescription': None,
#  'currency': 'USD',
#  'description': 'Your privacy matters! eMoods never stores ANY of your data in '
#                 'the cloud or connects to any APIs.  No data ever leaves your '
#                 'phone without your explicit action.\r\n'
#                 '\r\n'
#                 'Managing your mood just became easier and more effective!  '
#                 'eMoods is a private and easy to use mood tracker and diary '
#                 'for journaling, graphing, reporting, and managing symptoms '
#                 'related to Bipolar, Depression, Anxiety, and other mood '
#                 'disorders.  Start tracking, notice your triggers, and take '
#                 'control of your mood and other symptoms!\r\n'
#                 '\r\n'
#                 'eMoods is a mood charting journal perfect for logging Bipolar '
#                 'I, Bipolar II, or any general kind of mood tracking!\r\n'
#                 '\r\n'
#                 'eMoods allows you to track medication changes so that you can '
#                 'safely make adjustments, titrations or medication tapers with '
#                 'the help of your doctor and learn about what works and what '
#                 "doesn't.  These insights can be used for titrating up to a "
#                 'new medication or for assistance in coming off a '
#                 'medication.\r\n'
#                 '\r\n'
#                 'eMoods allows you to send a monthly PDF report to your '
#                 'doctor\r\n'
#                 '\r\n'
#                 'eMoods is a free mood tracker app that lets you easily chart '
#                 'your daily highs and lows/depressed and elevated moods, '
#                 'sleep, medications, and other symptoms related to common mood '
#                 'disorders like Bipolar/Manic Depressive illness. \r\n'
#                 '\r\n'
#                 'Email a printable PDF report at the end of each month to your '
#                 'doctor or caregiver to help you identify triggers or other '
#                 'events that could lead to an episode or relapse.  View in-app '
#                 'graphs and printable charts to track trends and visualize '
#                 'your symptoms and triggers in between appointments.\r\n'
#                 '\r\n'
#                 'eMoods now includes a dark color theme and a '
#                 'colorblind-friendly color scheme.\r\n'
#                 '\r\n'
#                 'Mood journaling is part of cognitive behavioral therapy (CBT) '
#                 'and other treatments for bipolar, depression, and other mood '
#                 'and anxiety disorders.  Use this app with your doctor.\r\n'
#                 '\r\n'
#                 'This app is for charting daily extremes of moods and other '
#                 'symptoms, and does not log multiple moods and other symptoms '
#                 'per day.\r\n'
#                 '\r\n'
#                 'All features from version 1 of this app remain free.  '
#                 'Patronage is strictly optional.',
#  'descriptionHTML': 'Your privacy matters! eMoods never stores ANY of your '
#                     'data in the cloud or connects to any APIs.  No data ever '
#                     'leaves your phone without your explicit '
#                     'action.<br><br>Managing your mood just became easier and '
#                     'more effective!  eMoods is a private and easy to use mood '
#                     'tracker and diary for journaling, graphing, reporting, '
#                     'and managing symptoms related to Bipolar, Depression, '
#                     'Anxiety, and other mood disorders.  Start tracking, '
#                     'notice your triggers, and take control of your mood and '
#                     'other symptoms!<br><br>eMoods is a mood charting journal '
#                     'perfect for logging Bipolar I, Bipolar II, or any general '
#                     'kind of mood tracking!<br><br>eMoods allows you to track '
#                     'medication changes so that you can safely make '
#                     'adjustments, titrations or medication tapers with the '
#                     'help of your doctor and learn about what works and what '
#                     'doesn&#39;t.  These insights can be used for titrating up '
#                     'to a new medication or for assistance in coming off a '
#                     'medication.<br><br>eMoods allows you to send a monthly '
#                     'PDF report to your doctor<br><br>eMoods is a free mood '
#                     'tracker app that lets you easily chart your daily highs '
#                     'and lows/depressed and elevated moods, sleep, '
#                     'medications, and other symptoms related to common mood '
#                     'disorders like Bipolar/Manic Depressive illness. '
#                     '<br><br>Email a printable PDF report at the end of each '
#                     'month to your doctor or caregiver to help you identify '
#                     'triggers or other events that could lead to an episode or '
#                     'relapse.  View in-app graphs and printable charts to '
#                     'track trends and visualize your symptoms and triggers in '
#                     'between appointments.<br><br>eMoods now includes a dark '
#                     'color theme and a colorblind-friendly color '
#                     'scheme.<br><br>Mood journaling is part of cognitive '
#                     'behavioral therapy (CBT) and other treatments for '
#                     'bipolar, depression, and other mood and anxiety '
#                     'disorders.  Use this app with your doctor.<br><br>This '
#                     'app is for charting daily extremes of moods and other '
#                     'symptoms, and does not log multiple moods and other '
#                     'symptoms per day.<br><br>All features from version 1 of '
#                     'this app remain free.  Patronage is strictly optional.',
#  'developer': 'eMoods',
#  'developerAddress': 'PO Box 815\nGorham, ME 04038',
#  'developerEmail': 'info@emoodtracker.com',
#  'developerId': 'eMoods',
#  'developerInternalID': '6059804171755703885',
#  'developerWebsite': 'http://emoodtracker.com',
#  'editorsChoice': False,
#  'free': True,
#  'genre': 'Health & Fitness',
#  'genreId': 'HEALTH_AND_FITNESS',
#  'headerImage': 'https://play-lh.googleusercontent.com/36Stfj2t3lAeIU_QHaCphcfIY3w5EENNTtc0O2zl9KVwa-FnRtSEQKJGjZ6wGSg_oGw',
#  'histogram': [150, 60, 350, 710, 3032],
#  'icon': 'https://play-lh.googleusercontent.com/BjUIg0ycTGpMvuClqlkiRgWEQLm2X6AiGyJtxNhCSSakIaoYOUokJIr4gol-PQ97Zkc',
#  'inAppProductPrice': '$0.99 - $10.99 per item',
#  'installs': '100,000+',
#  'minInstalls': 100000,
#  'offersIAP': True,
#  'originalPrice': None,
#  'price': 0,
#  'privacyPolicy': 'https://emoodtracker.com/emoods-classic-reporting-app-privacy-policy/',
#  'ratings': 4302,
#  'recentChanges': '- Medication change indicator - view details on graph about '
#                   'days on which medication dosing changes were made to help '
#                   'learn from medication adjustments, titrations, or tapers '
#                   'you make with your doctor.\r\n'
#                   '- New resource:  free mental health screening from '
#                   'ConnectedMind.me\r\n'
#                   '- Bug fixes',
#  'recentChangesHTML': '- Medication change indicator - view details on graph '
#                       'about days on which medication dosing changes were made '
#                       'to help learn from medication adjustments, titrations, '
#                       'or tapers you make with your doctor.<br>- New '
#                       'resource:  free mental health screening from '
#                       'ConnectedMind.me<br>- Bug fixes',
#  'released': 'Oct 11, 2010',
#  'reviews': 2034,
#  'sale': False,
#  'saleText': None,
#  'saleTime': None,
#  'score': 4.490698,
#  'screenshots': ['https://play-lh.googleusercontent.com/kbbtofkEsIeK0WSchhYZZ_A6C-Db2MIjMe0Q6YWefxAfrZK7J6Qc4sRRMYHLaq5QfUU',
#                  'https://play-lh.googleusercontent.com/C9Gn4MhXO39T87CIE-i2CJ0Ii0Cg4szGdZAaB_W1yenelj6C8pP8M2KzRIna3XVj',
#                  'https://play-lh.googleusercontent.com/-BZkVSyczTkdFeV14c4SwqZMbLJ8ubHYeiNE4_086Blkfj8n5IIVKoJiwZGb3hJI7-s0',
#                  'https://play-lh.googleusercontent.com/P65PO4cTiWk3oB1Z3w1_fOP5h3AXDfB5dQIUO_Z_t1mgbwZgWXQkcpRiHl6q-0lTfQ',
#                  'https://play-lh.googleusercontent.com/M9fSWl_hB0qJT1vv9FRPahaooY0r1mYAJ1w6HZcTxuc3m3yjU9uYts6Ix-TpkvVpH_k'],
#  'size': 'Varies with device',
#  'summary': 'Track your mood in seconds and send detailed reports to your '
#             'doctor or therapist',
#  'summaryHTML': 'Track your mood in seconds and send detailed reports to your '
#                 'doctor or therapist',
#  'title': 'eMoods Bipolar Mood Tracker',
#  'updated': 1614890995,
#  'url': 'https://play.google.com/store/apps/details?id=my.tracker&hl=en&gl=us',
#  'version': 'Varies with device',
#  'video': None,
#  'videoImage': None}

# %% [markdown]
# #### Store Scraped App Data in New MongoDB Collection

# %%
## Set up new collection within project db
google_play_info = mha_proj_db['google_play_info']

# %%
## Insert app details into google_play_info collection
google_play_info.insert_many(google_play_list)

# %%
# Turns query (here, basically SELECT *) into a list and creates df from that list of dicts
google_play_info_df = pd.DataFrame(list(google_play_info.find({})))
google_play_info_df
# Out:
#                          _id  \
# 0   605a2224fa456042d0948f7e
# 1   605a2224fa456042d0948f7f
# 2   605a2224fa456042d0948f80
# 3   605a2224fa456042d0948f81
# 4   605a2224fa456042d0948f82
# 5   605a2224fa456042d0948f83
# 6   605a2224fa456042d0948f84
# 7   605a2224fa456042d0948f85
# 8   605a2224fa456042d0948f86
# 9   605a2224fa456042d0948f87
# 10  605a2224fa456042d0948f88
# 11  605a2224fa456042d0948f89
# 12  605a2224fa456042d0948f8a
# 13  605a2224fa456042d0948f8b
# 14  605a2224fa456042d0948f8c
# 15  605a2224fa456042d0948f8d
# 16  605a2224fa456042d0948f8e
# 17  605a2224fa456042d0948f8f
# 18  605a2224fa456042d0948f90
# 19  605a2224fa456042d0948f91
# 20  605a2224fa456042d0948f92
# 21  605a2224fa456042d0948f93
# 22  605a2224fa456042d0948f94
# 23  605a2224fa456042d0948f95
# 24  605a2224fa456042d0948f96
# 25  605a2224fa456042d0948f97
# 26  605a2224fa456042d0948f98
# 27  605a2224fa456042d0948f99
# 28  605a2224fa456042d0948f9a
# 29  605a2224fa456042d0948f9b
# 30  605a2224fa456042d0948f9c
# 31  605a2224fa456042d0948f9d
# 32  605a2224fa456042d0948f9e
# 33  605a2224fa456042d0948f9f
# 34  605a2224fa456042d0948fa0
# 35  605a2224fa456042d0948fa1
# 36  605a2224fa456042d0948fa2
# 37  605a2224fa456042d0948fa3
# 38  605a2224fa456042d0948fa4
# 39  605a2224fa456042d0948fa5
# 40  605a2224fa456042d0948fa6
# 41  605a2224fa456042d0948fa7
# 42  605a2224fa456042d0948fa8
# 43  605a2224fa456042d0948fa9
# 44  605a2224fa456042d0948faa
# 45  605a2224fa456042d0948fab
# 46  605a2224fa456042d0948fac
# 47  605a2224fa456042d0948fad
# 48  605a2224fa456042d0948fae
# 49  605a2224fa456042d0948faf
# 50  605a2224fa456042d0948fb0
# 51  605a2224fa456042d0948fb1
# 52  605a2224fa456042d0948fb2
#
#                                                 title  \
# 0              Aura: Meditations, Sleep & Mindfulness
# 1             BetterHelp: Online Counseling & Therapy
# 2                                       Breathe2Relax
# 3                    Breethe - Meditation & Sleep App
# 4                       Calm - Meditate, Sleep, Relax
# 5   CBT Thought Diary - Mood Tracker, Journal & Re...
# 6               Daylio - Diary, Journal, Mood Tracker
# 7       DBT Coach: (Dialectical Behavior Therapy app)
# 8                         eMoods Bipolar Mood Tracker
# 9                       eQuoo: Emotional Fitness Game
# 10         Fabulous: Daily Motivation & Habit Tracker
# 11                        GG OCD Anxiety & Depression
# 12          GG Self Care: Create a Positive Headspace
# 13                        GG Self Esteem & Confidence
# 14                           Ginger Emotional Support
# 15                        Habitica: Gamify Your Tasks
# 16                                            Happify
# 17     Happyfeed: Gratitude Journal & Daily Self-Care
# 18                      Headspace: Meditation & Sleep
# 19                              Healthy Minds Program
# 20                       HearMe | Empathy Not Therapy
# 21                                         I Am Sober
# 22  InnerHour Self-Care Therapy: Anxiety & Depression
# 23           Insight Timer - Meditation, Sleep, Music
# 24                             Lyf - You're not alone
# 25                      Meditopia: Anxiety, Breathing
# 26              MindDoc: Your Mental Health Companion
# 27           MindShift CBT - Anxiety and Panic Relief
# 28           Moodfit - Fitness for Your Mental Health
# 29    MoodMission - Cope with Stress, Moods & Anxiety
# 30  MyLife Meditation: Meditate, Relax & Sleep Better
# 31                            NOCD: OCD Treatment App
# 32                                         PTSD Coach
# 33  Reflectly: Diary, Gratitude Journal & Mood Tra...
# 34  Remente: Self Care, Mental Health, Personal Gr...
# 35                      Rise Up: Eating Disorder Help
# 36              Rootd - Panic Attack & Anxiety Relief
# 37                      RR Eating Disorder Management
# 38                     Sanvello: Anxiety & Depression
# 39                       Shine: Calm Anxiety & Stress
# 40                                       Smiling Mind
# 41  Sober Time - Sober Day Counter & Clean Time Clock
# 42                                        SuperBetter
# 43          TalkLife for Anxiety, Depression & Stress
# 44                     Talkspace Counseling & Therapy
# 45           Ten Percent Happier - Meditation & Sleep
# 46                                         The Mighty
# 47                                   Virtual Hope Box
# 48       Waking Up: Guided Meditation and Mindfulness
# 49                   What's Up? - A Mental Health App
# 50                            Wisdo: Health & Fitness
# 51                      Woebot: Your Self-Care Expert
# 52  Wysa: anxiety, depression & sleep therapy chatbot
#
#                                           description  \
# 0   <b>Find peace everyday with Aura</b> - discove...
# 1   BetterHelp is the convenient way to get profes...
# 2   Breathe2Relax is a portable stress management ...
# 3   Breathe mindfulness, peace and restful sleep i...
# 4   Calm is a leading app for meditation and sleep...
# 5   Do you feel like you're always stressed, anxio...
# 6   Daylio enables you to keep a private journal w...
# 7   This is the most comprehensive DBT app that ex...
# 8   Your privacy matters! eMoods never stores ANY ...
# 9   What happens when a psychologist teams up with...
# 10  ▌ Winner of Google's Material Design Award for...
# 11  "Most credible OCD App" (highest credibility s...
# 12  Created by Dr. Guy Doron, clinical therapist a...
# 13  Wish to build confidence and have higher self ...
# 14  Ginger offers confidential, around-the-clock e...
# 15  Treat your life like a game to stay motivated ...
# 16  Happify’s science-based activities and games c...
# 17  Happyfeed is a simple journal designed to impr...
# 18  Stress less. Sleep soundly. Get happy. Learn t...
# 19  Your path to well-being. Powered by science.\r...
# 20  Need to talk to someone or work through your f...
# 21  I Am Sober more than just a free sobriety coun...
# 22  <i>Make self-care a priority with InnerHour</i...
# 23  * Apps of the Year Winner - TIME magazine and ...
# 24  <b>Real people, real stories, completely judge...
# 25  A meditation app that touches your soul…\r\nMe...
# 26  Top mental health app with over 3,000,000 down...
# 27  Break free from anxiety and stress using this ...
# 28  ** Best Overall Mental Health App of 2020 ** -...
# 29  MoodMission helps you learn new and better way...
# 30  Learn to meditate and be more mindful with MyL...
# 31  Made by people with OCD, along with some of th...
# 32  PTSD Coach was designed for Veterans and milit...
# 33  Reflectly is the number one journaling app tha...
# 34  Small actions everyday <b>create life changing...
# 35  Look no further! Rise Up + Recover is just the...
# 36  Rootd is the award-winning, female led app for...
# 37  Recovery Record is the smart companion for man...
# 38  Whether you’re feeling anxious, lonely, overwh...
# 39  **2019 Google Play Award Standout Well-Being A...
# 40  Smiling Mind is a unique web and app-based pro...
# 41  Sober Time is a sober day counter with a built...
# 42  Resilience Training. Powered by the Science of...
# 43  TalkLife is all about support. Our community i...
# 44  Talkspace is the most convenient and affordabl...
# 45  Want to sleep better, be more mindful, improve...
# 46  The Mighty is the world's largest digital heal...
# 47  The Virtual Hope Box (VHB) is a smartphone app...
# 48  Start 2021 by taking care of your own mind. Co...
# 49  <small>In-app purchases for donations only</sm...
# 50  ** Best Personal Growth App - Google Play **\r...
# 51  WINNER OF THE 2019 GOOGLE PLAY AWARD FOR STAND...
# 52  Imagine a mood tracker, mindfulness coach, anx...
#
#                                       descriptionHTML  \
# 0   <b>Find peace everyday with Aura</b> - discove...
# 1   BetterHelp is the convenient way to get profes...
# 2   Breathe2Relax is a portable stress management ...
# 3   Breathe mindfulness, peace and restful sleep i...
# 4   Calm is a leading app for meditation and sleep...
# 5   Do you feel like you&#39;re always stressed, a...
# 6   Daylio enables you to keep a private journal w...
# 7   This is the most comprehensive DBT app that ex...
# 8   Your privacy matters! eMoods never stores ANY ...
# 9   What happens when a psychologist teams up with...
# 10  ▌ Winner of Google&#39;s Material Design Award...
# 11  &quot;Most credible OCD App&quot; (highest cre...
# 12  Created by Dr. Guy Doron, clinical therapist a...
# 13  Wish to build confidence and have higher self ...
# 14  Ginger offers confidential, around-the-clock e...
# 15  Treat your life like a game to stay motivated ...
# 16  Happify’s science-based activities and games c...
# 17  Happyfeed is a simple journal designed to impr...
# 18  Stress less. Sleep soundly. Get happy. Learn t...
# 19  Your path to well-being. Powered by science.<b...
# 20  Need to talk to someone or work through your f...
# 21  I Am Sober more than just a free sobriety coun...
# 22  <i>Make self-care a priority with InnerHour</i...
# 23  * Apps of the Year Winner - TIME magazine and ...
# 24  <b>Real people, real stories, completely judge...
# 25  A meditation app that touches your soul…<br>Me...
# 26  Top mental health app with over 3,000,000 down...
# 27  Break free from anxiety and stress using this ...
# 28  ** Best Overall Mental Health App of 2020 ** -...
# 29  MoodMission helps you learn new and better way...
# 30  Learn to meditate and be more mindful with MyL...
# 31  Made by people with OCD, along with some of th...
# 32  PTSD Coach was designed for Veterans and milit...
# 33  Reflectly is the number one journaling app tha...
# 34  Small actions everyday <b>create life changing...
# 35  Look no further! Rise Up + Recover is just the...
# 36  Rootd is the award-winning, female led app for...
# 37  Recovery Record is the smart companion for man...
# 38  Whether you’re feeling anxious, lonely, overwh...
# 39  **2019 Google Play Award Standout Well-Being A...
# 40  Smiling Mind is a unique web and app-based pro...
# 41  Sober Time is a sober day counter with a built...
# 42  Resilience Training. Powered by the Science of...
# 43  TalkLife is all about support. Our community i...
# 44  Talkspace is the most convenient and affordabl...
# 45  Want to sleep better, be more mindful, improve...
# 46  The Mighty is the world&#39;s largest digital ...
# 47  The Virtual Hope Box (VHB) is a smartphone app...
# 48  Start 2021 by taking care of your own mind. Co...
# 49  <small>In-app purchases for donations only</sm...
# 50  ** Best Personal Growth App - Google Play **<b...
# 51  WINNER OF THE 2019 GOOGLE PLAY AWARD FOR STAND...
# 52  Imagine a mood tracker, mindfulness coach, anx...
#
#                                               summary  \
# 0   1000s of Meditations from world's best coaches...
# 1   Get counseling from a licensed therapist, mana...
# 2   Breathe2Relax is a stress management tool to h...
# 3   Sleep, relax, breathe and meditate with medita...
# 4   Join the millions discovering the life-changin...
# 5   #1 Free Mood & Thought Journal. Lift your mood...
# 6   Self-Care Bullet Journal with Goals - Mood Dia...
# 7   A comprehensive DBT App for BPD, Anxiety, Depr...
# 8   Track your mood in seconds and send detailed r...
# 9                      Learn People Skills Having Fun
# 10  🎉 Daily routine planner to help you track your...
# 11  Self-manage your mental health with Dr. Guy Doron
# 12  Track your mood. Beat anxiety & Depression. Fi...
# 13  Daily affirmations to improve your self-esteem...
# 14  Confidential, around-the-clock emotional suppo...
# 15  Treat your life like a game to stay motivated ...
# 16  Science-based activities & games to help overc...
# 17  List 3 good things a day and track your happin...
# 18                            Meditation made simple.
# 19  Guided meditations & lessons to help you gain ...
# 20          Need to talk? Chat with a Listener in 30s
# 21                     A better you one day at a time
# 22  Therapy-based self-care tools for depression, ...
# 23  The most popular app in the World for Meditati...
# 24                         Support without judgement.
# 25                  Most personal mental wellness app
# 26  Mood tracking and self-management for depressi...
# 27  Self-help anxiety management app to relieve wo...
# 28  Moodfit provides tools & insights to improve y...
# 29  Use evidence-based CBT techniques to deal with...
# 30  Practice Mindfulness: Guided Meditation for Sl...
# 31  NOCD helps people with obsessive-compulsive di...
# 32  This app is for people who have or may have Po...
# 33  Daily quotes, morning motivation & positive af...
# 34  Get a life coach, mental health tracker & self...
# 35  The go-to app for your journey to recovery fro...
# 36  Overcome panic attacks and anxiety with Rootd'...
# 37  Recovery Record helps you manage your eating d...
# 38                       Therapy, Coaching, Self-Care
# 39                            Meditation & motivation
# 40                 Smiling Mind is modern meditation.
# 41  Sober Time is the #1 sober day counter that's ...
# 42  Resilience Training. Powered by the Science of...
# 43  Mental Health Support Community - Safe, Encour...
# 44  Talkspace - the leaders in Online Therapy with...
# 45  Get better at feeling good with meditations fr...
# 46                         Making health about people
# 47  VHB has simple tools to help with coping and p...
# 48  Practice self-care this year: daily mindfulnes...
# 49  For when you need a little extra help getting ...
# 50  Boost your mental wellness and self-care with ...
# 51  Anxiety, depression, & mindfulness tools to re...
# 52  Free therapy chat for mindfulness, mental heal...
#
#                                           summaryHTML     installs  \
# 0   1000s of Meditations from world&#39;s best coa...   1,000,000+
# 1   Get counseling from a licensed therapist, mana...   1,000,000+
# 2   Breathe2Relax is a stress management tool to h...     100,000+
# 3   Sleep, relax, breathe and meditate with medita...     500,000+
# 4   Join the millions discovering the life-changin...  10,000,000+
# 5   #1 Free Mood &amp; Thought Journal. Lift your ...     100,000+
# 6   Self-Care Bullet Journal with Goals - Mood Dia...  10,000,000+
# 7   A comprehensive DBT App for BPD, Anxiety, Depr...      50,000+
# 8   Track your mood in seconds and send detailed r...     100,000+
# 9                      Learn People Skills Having Fun      50,000+
# 10  🎉 Daily routine planner to help you track your...  10,000,000+
# 11  Self-manage your mental health with Dr. Guy Doron      10,000+
# 12  Track your mood. Beat anxiety &amp; Depression...       1,000+
# 13  Daily affirmations to improve your self-esteem...      50,000+
# 14  Confidential, around-the-clock emotional suppo...      50,000+
# 15  Treat your life like a game to stay motivated ...   1,000,000+
# 16  Science-based activities &amp; games to help o...     500,000+
# 17  List 3 good things a day and track your happin...      10,000+
# 18                            Meditation made simple.  10,000,000+
# 19  Guided meditations &amp; lessons to help you g...      50,000+
# 20          Need to talk? Chat with a Listener in 30s      10,000+
# 21                     A better you one day at a time   1,000,000+
# 22  Therapy-based self-care tools for depression, ...   1,000,000+
# 23  The most popular app in the World for Meditati...   5,000,000+
# 24                         Support without judgement.     100,000+
# 25                  Most personal mental wellness app  10,000,000+
# 26  Mood tracking and self-management for depressi...   1,000,000+
# 27  Self-help anxiety management app to relieve wo...     100,000+
# 28  Moodfit provides tools &amp; insights to impro...      10,000+
# 29  Use evidence-based CBT techniques to deal with...      50,000+
# 30  Practice Mindfulness: Guided Meditation for Sl...   1,000,000+
# 31  NOCD helps people with obsessive-compulsive di...      50,000+
# 32  This app is for people who have or may have Po...     100,000+
# 33  Daily quotes, morning motivation &amp; positiv...   1,000,000+
# 34  Get a life coach, mental health tracker &amp; ...   1,000,000+
# 35  The go-to app for your journey to recovery fro...      50,000+
# 36  Overcome panic attacks and anxiety with Rootd&...     100,000+
# 37  Recovery Record helps you manage your eating d...     100,000+
# 38                       Therapy, Coaching, Self-Care   1,000,000+
# 39                        Meditation &amp; motivation     100,000+
# 40                 Smiling Mind is modern meditation.     500,000+
# 41  Sober Time is the #1 sober day counter that&#3...     500,000+
# 42  Resilience Training. Powered by the Science of...     100,000+
# 43  Mental Health Support Community - Safe, Encour...   1,000,000+
# 44  Talkspace - the leaders in Online Therapy with...     100,000+
# 45  Get better at feeling good with meditations fr...     500,000+
# 46                         Making health about people      50,000+
# 47  VHB has simple tools to help with coping and p...     100,000+
# 48  Practice self-care this year: daily mindfulnes...     500,000+
# 49  For when you need a little extra help getting ...     500,000+
# 50  Boost your mental wellness and self-care with ...     100,000+
# 51  Anxiety, depression, &amp; mindfulness tools t...     100,000+
# 52  Free therapy chat for mindfulness, mental heal...   1,000,000+
#
#     minInstalls     score  ratings  ...  adSupported containsAds  \
# 0       1000000  4.593012    10532  ...         None       False
# 1       1000000  4.435962    15637  ...         None       False
# 2        100000  3.216216     1110  ...         None       False
# 3        500000  4.590909     3307  ...         None       False
# 4      10000000  4.065960   363315  ...         None       False
# 5        100000  4.476793     2362  ...         None       False
# 6      10000000  4.594634   317553  ...         True        True
# 7         50000  3.715596     1071  ...         None       False
# 8        100000  4.490698     4302  ...         None       False
# 9         50000  4.491443     4063  ...         True        True
# 10     10000000  4.521255   373085  ...         None       False
# 11        10000  4.220000      217  ...         None       False
# 12         1000  4.294117       68  ...         None       False
# 13        50000  4.140000      591  ...         None       False
# 14        50000  4.270000      840  ...         None       False
# 15      1000000  4.255727    18689  ...         None       False
# 16       500000  3.810409     2690  ...         True        True
# 17        10000  4.504950      290  ...         None       False
# 18     10000000  4.583892   209557  ...         None       False
# 19        50000  4.842593      508  ...         None       False
# 20        10000  4.431035     1713  ...         None       False
# 21      1000000  4.859635    24508  ...         None       False
# 22      1000000  4.533565     8601  ...         None       False
# 23      5000000  4.896036   110068  ...         None       False
# 24       100000  4.110236     1256  ...         None       False
# 25     10000000  4.526776   142552  ...         None       False
# 26      1000000  4.509101    35877  ...         None       False
# 27       100000  4.064748     1384  ...         None       False
# 28        10000  4.320000      459  ...         None       False
# 29        50000  3.297030      190  ...         None       False
# 30      1000000  4.621188    24802  ...         None       False
# 31        50000  4.550000      517  ...         None       False
# 32       100000  4.470000      907  ...         None       False
# 33      1000000  4.187415    36585  ...         None       False
# 34      1000000  4.253259    10732  ...         None       False
# 35        50000  4.217822      519  ...         None       False
# 36       100000  4.532710     2100  ...         None       False
# 37       100000  4.842752     4076  ...         None       False
# 38      1000000  4.506348    20402  ...         None       False
# 39       100000  4.768421     7558  ...         None       False
# 40       500000  3.934098     3490  ...         None       False
# 41       500000  4.714444    27132  ...         True        True
# 42       100000  4.446055     6184  ...         None       False
# 43      1000000  4.238490    32043  ...         True        True
# 44       100000  3.429936     3132  ...         None       False
# 45       500000  4.815928    13227  ...         None       False
# 46        50000  4.749141     2881  ...         None       False
# 47       100000  3.800000      790  ...         None       False
# 48       500000  4.866545    21813  ...         None       False
# 49       500000  4.233728     3386  ...         None       False
# 50       100000  3.912195     2056  ...         None       False
# 51       100000  4.728125     9590  ...         None       False
# 52      1000000  4.760902    79705  ...         None       False
#
#         released     updated              version  \
# 0   Mar 21, 2017  1605694888                2.4.2
# 1   Nov 17, 2014  1616437130                 1.64
# 2   Oct 24, 2011  1610041510                4.0.0
# 3   Jan 25, 2016  1614090448                5.3.2
# 4   Jul 30, 2014  1615619475   Varies with device
# 5   Jun 28, 2014  1615603980                4.2.1
# 6   Aug 17, 2015  1615879100               1.38.2
# 7   Feb 25, 2019  1614061574                3.2.5
# 8   Oct 11, 2010  1614890995   Varies with device
# 9    Jul 9, 2018  1591184573                3.4.3
# 10  Nov 29, 2013  1613218930                 3.67
# 11   Dec 3, 2016  1612093405                3.1.1
# 12  Mar 18, 2020  1611734211                0.3.2
# 13  Nov 13, 2017  1600676538                3.0.0
# 14  Apr 19, 2012  1616172149               5.14.2
# 15  Dec 10, 2015  1616053447                3.2.2
# 16  Apr 30, 2015  1614333615  1.63.0-738230ec93c0
# 17  May 16, 2019  1613764536                2.7.1
# 18   Jan 6, 2012  1615937160               4.38.0
# 19  Jan 12, 2018  1614641928                6.2.0
# 20  Dec 10, 2019  1602661940                3.3.2
# 21  Feb 18, 2014  1615824607                  6.3
# 22  Aug 22, 2017  1615287993               3.44.3
# 23  Dec 15, 2010  1613740970              15.12.7
# 24  Feb 22, 2016  1615846536              14.0.63
# 25   Mar 7, 2017  1616485184               3.14.2
# 26   Aug 2, 2017  1615542062                4.3.2
# 27   Jun 6, 2013  1603920190                2.0.4
# 28   Jan 4, 2017  1614704037                 2.21
# 29   Feb 7, 2017  1583109259               1.4.10
# 30  Sep 29, 2014  1614271324                  6.6
# 31  Dec 28, 2018  1615444270                3.7.4
# 32  Aug 15, 2016  1595442745                  3.2
# 33  Sep 25, 2017  1614507926               3.20.2
# 34  Feb 11, 2015  1616348645               1.7.18
# 35  Feb 22, 2015  1439888015                  1.2
# 36  Oct 13, 2017  1610995477               2.2.19
# 37  Nov 27, 2011  1614737509                5.6.8
# 38  Jan 26, 2015  1616162257               8.24.1
# 39  Dec 27, 2018  1616104420               4.14.1
# 40   Oct 6, 2014  1615971082                4.0.0
# 41   Jan 3, 2015  1616268175               4.0.25
# 42  Nov 29, 2014  1538698489               1.1.12
# 43  Oct 31, 2013  1616318550             5.7.71.6
# 44   Dec 4, 2014  1616093288               3.31.5
# 45  Nov 13, 2017  1608254703               2.13.0
# 46  Aug 27, 2019  1611687289                3.4.1
# 47  Feb 26, 2014  1552937719                1.5.9
# 48  Oct 28, 2018  1615327556               1.6.52
# 49   Mar 4, 2015  1594539278                2.3.6
# 50  Apr 26, 2018  1615889418    1.6.37-Production
# 51   Mar 8, 2018  1612804062               3.27.2
# 52   Oct 6, 2016  1615710511                2.5.9
#
#                                         recentChanges  \
# 0                                                None
# 1   Thank you for using BetterHelp! We are constan...
# 2   App has been migrated to our Defense Health Ag...
# 3   Create your own playlists and download tracks ...
# 4   Thanks for using Calm! This update contains mu...
# 5                  Introducing the Discover section!
# 6   Get ready for the supersized pack of new featu...
# 7                                                None
# 8   - Medication change indicator - view details o...
# 9             Made some updates and took care of bugs
# 10                                               None
# 11         - New mood and supportive thinking tracker
# 12  - All new candle game: Light up a candle to ig...
# 13  New GG experience with loads more content and ...
# 14  Thanks for using Ginger! This update includes ...
# 15  We’ve added the ability to select different de...
# 16  Happify is now available in Italian! Get activ...
# 17  A few small updates and performance improvemen...
# 18  A steady meditation practice can calm the mind...
# 19              Bug fixes + performance enhancements.
# 20                          Bugfixes and improvements
# 21  Groups are finally here!\r\n\r\nGroups let you...
# 22  We've made a bunch of UI improvements, perform...
# 23  Group Meditation has arrived. Create and join ...
# 24  User experience enhancements and we squashed s...
# 25  In this update, we fixed several bugs and made...
# 26  This update contains improvements and bug fixe...
# 27  Thank you for all your patience and support! W...
# 28  - Easily add entries to your history by duplic...
# 29                 Add user account deletion function
# 30                                               None
# 31                                               None
# 32  3.4.2\r\n* Fixed a bug that affected saving ed...
# 33  New updates, ahoy!\r\n\r\n- Includes improveme...
# 34  Just some minor bug fixes - thank you for your...
# 35  Bug Fixes & Improvements\r\n- fixed an issue f...
# 36  2021 is finally here! And with it, a Rootd rel...
# 37                   Fix for selecting existing photo
# 38  We've noticed crashes among some Android users...
# 39  Trouble sleeping? We got you. In this update: ...
# 40  + Say hello 👋🏽 to our BIGGEST app update EVER!...
# 41  Sober Time 4.0\r\n- Journaling\r\n- Many new d...
# 42                                               None
# 43      +Minor bug fixes and performance improvements
# 44  This release improves performance on certain d...
# 45  Support for our upcoming New Year's Challenge ...
# 46  Introducing Private Communities on The Mighty....
# 47  Fixed notification support. General improvemen...
# 48  To easily review or pick up where you left off...
# 49  Updated 3rd party libraries\r\nRemoved the spl...
# 50                                               None
# 51           - Bug fixes and performance improvements
# 52  - Get to the right ✅ tools and techniques 🛠fas...
#
#                                     recentChangesHTML editorsChoice  \
# 0                                                None         False
# 1   Thank you for using BetterHelp! We are constan...         False
# 2   App has been migrated to our Defense Health Ag...         False
# 3   Create your own playlists and download tracks ...         False
# 4   Thanks for using Calm! This update contains mu...          True
# 5                  Introducing the Discover section!          False
# 6   Get ready for the supersized pack of new featu...          True
# 7                                                None         False
# 8   - Medication change indicator - view details o...         False
# 9             Made some updates and took care of bugs         False
# 10                                               None          True
# 11         - New mood and supportive thinking tracker         False
# 12  - All new candle game: Light up a candle to ig...         False
# 13  New GG experience with loads more content and ...         False
# 14  Thanks for using Ginger! This update includes ...         False
# 15  We’ve added the ability to select different de...         False
# 16  Happify is now available in Italian! Get activ...         False
# 17  A few small updates and performance improvemen...         False
# 18  A steady meditation practice can calm the mind...          True
# 19              Bug fixes + performance enhancements.         False
# 20                          Bugfixes and improvements         False
# 21  Groups are finally here!<br><br>Groups let you...         False
# 22  We&#39;ve made a bunch of UI improvements, per...         False
# 23  Group Meditation has arrived. Create and join ...          True
# 24  User experience enhancements and we squashed s...         False
# 25  In this update, we fixed several bugs and made...          True
# 26  This update contains improvements and bug fixe...         False
# 27  Thank you for all your patience and support! W...         False
# 28  - Easily add entries to your history by duplic...         False
# 29                 Add user account deletion function         False
# 30                                               None          True
# 31                                               None         False
# 32  3.4.2<br>* Fixed a bug that affected saving ed...         False
# 33  New updates, ahoy!<br><br>- Includes improveme...         False
# 34  Just some minor bug fixes - thank you for your...         False
# 35  Bug Fixes &amp; Improvements<br>- fixed an iss...         False
# 36  2021 is finally here! And with it, a Rootd rel...         False
# 37                   Fix for selecting existing photo         False
# 38  We&#39;ve noticed crashes among some Android u...          True
# 39  Trouble sleeping? We got you. In this update: ...         False
# 40  + Say hello 👋🏽 to our BIGGEST app update EVER!...         False
# 41  Sober Time 4.0<br>- Journaling<br>- Many new d...         False
# 42                                               None         False
# 43      +Minor bug fixes and performance improvements         False
# 44  This release improves performance on certain d...         False
# 45  Support for our upcoming New Year&#39;s Challe...         False
# 46  Introducing Private Communities on The Mighty....         False
# 47  Fixed notification support. General improvemen...         False
# 48  To easily review or pick up where you left off...         False
# 49  Updated 3rd party libraries<br>Removed the spl...         False
# 50                                               None         False
# 51           - Bug fixes and performance improvements         False
# 52  - Get to the right ✅ tools and techniques 🛠fas...         False
#
#                                      appId  \
# 0                           com.aurahealth
# 1                           com.betterhelp
# 2               org.t2health.breathe2relax
# 3                       com.Meditation.app
# 4                         com.calm.android
# 5           com.moodtools.cbtassistant.app
# 6                               net.daylio
# 7                       co.swasth.dbtcoach
# 8                               my.tracker
# 9                         com.bitbox.equoo
# 10                      co.thefabulous.app
# 11                  air.com.samuramu.gg.oc
# 12                         com.ggtude.life
# 13                  air.com.samuramu.gg.se
# 14                              com.ginger
# 15           com.habitrpg.android.habitica
# 16                  com.happify.happifyinc
# 17                           com.happyfeed
# 18            com.getsomeheadspace.android
# 19                        com.healthyminds
# 20                              com.hearme
# 21              com.thehungrywasp.iamsober
# 22                    com.theinnerhour.b2b
# 23          com.spotlightsix.zentimerlite2
# 24                      com.incogo.android
# 25                          app.meditasyon
# 26                     de.moodpath.android
# 27                     com.bstro.MindShift
# 28                  com.robleridge.Moodfit
# 29          com.moodmission.moodmissionapp
# 30                org.stopbreathethink.app
# 31                     com.treatmyocd.nocd
# 32                   is.vertical.ptsdcoach
# 33                        com.reflectlyApp
# 34                         com.remente.app
# 35                                 com.rur
# 36                               com.rootd
# 37                      com.recoveryrecord
# 38               com.pacificalabs.pacifica
# 39                     com.shinetext.shine
# 40                     com.smilingmind.app
# 41                 com.sociosoft.sobertime
# 42                    com.superbetter.paid
# 43                    com.bearpty.talklife
# 44              com.talkspace.talkspaceapp
# 45  com.changecollective.tenpercenthappier
# 46                           com.themighty
# 47                              com.t2.vhb
# 48                    org.wakingup.android
# 49          com.jacksontempra.apps.whatsup
# 50                 com.wisdo.android.wisdo
# 51                              com.woebot
# 52                            bot.touchkin
#
#                                                   url
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# 5   https://play.google.com/store/apps/details?id=...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
# 11  https://play.google.com/store/apps/details?id=...
# 12  https://play.google.com/store/apps/details?id=...
# 13  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 15  https://play.google.com/store/apps/details?id=...
# 16  https://play.google.com/store/apps/details?id=...
# 17  https://play.google.com/store/apps/details?id=...
# 18  https://play.google.com/store/apps/details?id=...
# 19  https://play.google.com/store/apps/details?id=...
# 20  https://play.google.com/store/apps/details?id=...
# 21  https://play.google.com/store/apps/details?id=...
# 22  https://play.google.com/store/apps/details?id=...
# 23  https://play.google.com/store/apps/details?id=...
# 24  https://play.google.com/store/apps/details?id=...
# 25  https://play.google.com/store/apps/details?id=...
# 26  https://play.google.com/store/apps/details?id=...
# 27  https://play.google.com/store/apps/details?id=...
# 28  https://play.google.com/store/apps/details?id=...
# 29  https://play.google.com/store/apps/details?id=...
# 30  https://play.google.com/store/apps/details?id=...
# 31  https://play.google.com/store/apps/details?id=...
# 32  https://play.google.com/store/apps/details?id=...
# 33  https://play.google.com/store/apps/details?id=...
# 34  https://play.google.com/store/apps/details?id=...
# 35  https://play.google.com/store/apps/details?id=...
# 36  https://play.google.com/store/apps/details?id=...
# 37  https://play.google.com/store/apps/details?id=...
# 38  https://play.google.com/store/apps/details?id=...
# 39  https://play.google.com/store/apps/details?id=...
# 40  https://play.google.com/store/apps/details?id=...
# 41  https://play.google.com/store/apps/details?id=...
# 42  https://play.google.com/store/apps/details?id=...
# 43  https://play.google.com/store/apps/details?id=...
# 44  https://play.google.com/store/apps/details?id=...
# 45  https://play.google.com/store/apps/details?id=...
# 46  https://play.google.com/store/apps/details?id=...
# 47  https://play.google.com/store/apps/details?id=...
# 48  https://play.google.com/store/apps/details?id=...
# 49  https://play.google.com/store/apps/details?id=...
# 50  https://play.google.com/store/apps/details?id=...
# 51  https://play.google.com/store/apps/details?id=...
# 52  https://play.google.com/store/apps/details?id=...
#
# [53 rows x 50 columns]

# %%
## Also save df to csv
google_play_info_df.to_csv('Data/google_play_info.csv', index=False)

# %%
client.close()

# %%
## Plot distribution of average scores
plt.figure(figsize=(8,6))
g = sns.histplot(data=google_play_info_df, x='score')
g.set_title('Distribution of Average Rating',
            fontdict = {'weight': 'bold', 'size':16})
g.set_xlabel('Average Rating',
            fontdict = {'weight': 'bold', 'size':14})
g.set_xticklabels(g.get_xticks(),
                  fontdict = {'weight': 'bold', 'size':12})
g.set_ylabel('Number of Apps',
            fontdict = {'weight': 'bold', 'size':14})
g.set_yticklabels(g.get_yticks(),
                  fontdict = {'weight': 'bold', 'size':12});
# Out:
# /Users/maxsteele/opt/anaconda3/envs/mha-proj-env/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   if __name__ == '__main__':
# /Users/maxsteele/opt/anaconda3/envs/mha-proj-env/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   del sys.path[0]

# %%
## Plot distribution of installs
plt.figure(figsize=(8,6))
g = sns.histplot(data=google_play_info_df, x='minInstalls');

# %%
## Plot distribution of ratings
plt.figure(figsize=(8,6))
g = sns.histplot(data=google_play_info_df, x='ratings');

# %%
## Plot distribution of reviews
plt.figure(figsize=(8,6))
g = sns.histplot(data=google_play_info_df, x='reviews');
