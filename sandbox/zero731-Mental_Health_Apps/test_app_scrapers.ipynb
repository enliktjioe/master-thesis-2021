# %%
## Import necessary libraries

# retrieves app info from App Store
from itunes_app_scraper.scraper import AppStoreScraper
# retrieves reviews from App Store
from app_store_scraper import AppStore

# retrieves app info AND reviews from Google Play
from google_play_scraper import app, Sort, reviews, reviews_all

# pretty print data structures
from pprint import pprint

import time

import pandas as pd
import datetime as dt

# %%
## Test scraping app details for Happify
scraper = AppStoreScraper()
happify_id = scraper.get_app_ids_for_query('happify-for-stress-worry')
# returns 2 ids, 1st is Happify and the other is something else I don't need
happify_id
# Out:
# ['730601963', '1485409805']

# %%
# Don't use get_app_ids_for_query, just use int ids taken from my MHA proj spreadsheet
happify_id = ['730601963', '730601963']

# %%
happify_details = list(scraper.get_app_details('730601963'))
pprint(happify_details)
# Out:
# https://itunes.apple.com/lookup?id=730601963&country=nl&entity=software
# ['screenshotUrls',
#  'ipadScreenshotUrls',
#  'appletvScreenshotUrls',
#  'artworkUrl60',
#  'artworkUrl512',
#  'artworkUrl100',
#  'artistViewUrl',
#  'supportedDevices',
#  'advisories',
#  'isGameCenterEnabled',
#  'features',
#  'kind',
#  'minimumOsVersion',
#  'trackCensoredName',
#  'languageCodesISO2A',
#  'fileSizeBytes',
#  'sellerUrl',
#  'formattedPrice',
#  'contentAdvisoryRating',
#  'averageUserRatingForCurrentVersion',
#  'userRatingCountForCurrentVersion',
#  'averageUserRating',
#  'trackViewUrl',
#  'trackContentRating',
#  'trackId',
#  'trackName',
#  'releaseDate',
#  'sellerName',
#  'primaryGenreName',
#  'genreIds',
#  'isVppDeviceBasedLicensingEnabled',
#  'currentVersionReleaseDate',
#  'releaseNotes',
#  'primaryGenreId',
#  'currency',
#  'description',
#  'artistId',
#  'artistName',
#  'genres',
#  'price',
#  'bundleId',
#  'version',
#  'wrapperType',
#  'userRatingCount']

# %%
# get_app_details doesn't actually return results (so used the same id twice - see above)
## This won't be a problem when I'm iterating through the full list of app ids,
  ## can just use get_multiple_app_details as intended
happify_info = list(scraper.get_multiple_app_details(happify_id))
pprint(happify_info)
# Out:
# https://itunes.apple.com/lookup?id=730601963&country=nl&entity=software
# https://itunes.apple.com/lookup?id=730601963&country=nl&entity=software
# [{'advisories': '',
#   'appletvScreenshotUrls': '',
#   'artistId': 730601966,
#   'artistName': 'Happify, Inc.',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/happify-inc/id730601966?uo=4',
#   'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/60x60bb.jpg',
#   'averageUserRating': 4.14286,
#   'averageUserRatingForCurrentVersion': 4.14286,
#   'bundleId': 'com.happify.Happify',
#   'contentAdvisoryRating': '4+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2021-02-26T13:09:52Z',
#   'description': "Happify's science-based activities and games can help you "
#                  "overcome negative thoughts, stress, and life's challenges.\n"
#                  '\n'
#                  'Our techniques are developed by leading scientists and '
#                  "experts who've been studying evidence-based interventions in "
#                  'the fields of positive psychology, mindfulness, and '
#                  'cognitive behavioral therapy for decades.\n'
#                  ' \n'
#                  '86% of people who use Happify regularly report feeling '
#                  'better about their lives in 2 months!\n'
#                  '\n'
#                  'JOURNALISTS TRIED IT FOR THEMSELVES, AND HERE’S WHAT THEY '
#                  'SAID:\n'
#                  '\n'
#                  "ABC World News' Mara Schiavocampo\n"
#                  '"I gave it a shot for 5 weeks...it works!"\n'
#                  '\n'
#                  'The New York Times\n'
#                  '"Each track contains bite-size quizzes, games and activities '
#                  'that guide you to seeing more positive aspects of daily '
#                  'life."\n'
#                  '\n'
#                  'The TODAY Show\n'
#                  '"These are things you can do every day -- tasks you can '
#                  'complete and be rewarded for -- to feel better, reduce '
#                  'stress, live a better life, and actually be happy."\n'
#                  '\n'
#                  "WE'RE GRATEFUL TO BE CHANGING LIVES EVERY DAY:\n"
#                  '\n'
#                  '"I absolutely love the Happify app! I’ve been using it for '
#                  'years and it really has transformed my life more than ANY '
#                  'OTHER TOOL I’ve used to grow my positivity! The world would '
#                  'be a much better place if everyone used it...And it’s FUN!" '
#                  '-Ashley S., Tampa, FL\n'
#                  '\n'
#                  '"Happify has helped me develop new skills in a variety of '
#                  'domains such as preventing worry, cultivating my '
#                  'relationships, and setting better sleep habits." - Elaina '
#                  'S., St. Louis, MO\n'
#                  '\n'
#                  '"I have been using the Happify app for a few years. I '
#                  'started using the app when I was going through depression '
#                  'and needed something to distract myself whenever I was '
#                  'dealing with negative thoughts.  Happify has definitely '
#                  'changed my life for the better. I know that whenever I am '
#                  'struggling with negative thoughts, I can use the games and '
#                  'tasks on the Happify app to improve my mood." - Nerina F., '
#                  'Seoul, South Korea\n'
#                  '\n'
#                  '"When I first started, I was skeptical about some of the '
#                  'exercises. However, I was willing to try them...and my '
#                  'skepticism faded when I realized they helped. I have less '
#                  'bad days...and when I have bad days, they disperse more '
#                  "quickly, and they're not as severe as they were before "
#                  'Happify." - Jessica G., West Park, FL\n'
#                  '\n'
#                  'YOU KNOW YOUR GOALS. WE KNOW HOW YOU CAN ACHIEVE THEM.\n'
#                  '\n'
#                  'Choose one track. Choose them all.\n'
#                  '\n'
#                  '* Conquering negative thoughts\n'
#                  '* Coping better with stress\n'
#                  '* Building self-confidence\n'
#                  '* Fueling your career success\n'
#                  '* Achieving mindfulness through meditation\n'
#                  '* …and 65+ more!\n'
#                  '\n'
#                  'Get a taste of what Happify has to offer in the free version '
#                  'of the app. Discover why so many people upgrade to Happify '
#                  'Plus for access to even more, including:\n'
#                  '\n'
#                  '* Unlimited access to 65+ tracks\n'
#                  '* Unlimited access to games and meditations\n'
#                  '* Your 20-page character strength report, offered in '
#                  'partnership with the renowned VIA Institute\n'
#                  '* Track your progress everyday and see how your skills '
#                  'compare\n'
#                  '\n'
#                  'Because we know that everyone has different financial '
#                  'resources, we offer Happify Plus in a variety of plans, for '
#                  'as low as $11.67/month when purchasing a yearly '
#                  'subscription:\n'
#                  '\n'
#                  'Yearly: $139.99 per year ($11.67/month)\n'
#                  'Monthly: $14.99\n'
#                  'Lifetime: $449.99\n'
#                  '\n'
#                  '– Payment will be charged to iTunes Account at confirmation '
#                  'of purchase\n'
#                  '– Subscription automatically renews unless auto-renew is '
#                  'turned off at least 24-hours before the end of the current '
#                  'period\n'
#                  '– Account will be charged for renewal within 24-hours prior '
#                  'to the end of the current period, and identify the cost of '
#                  'the renewal\n'
#                  '– Subscriptions may be managed by the user and auto-renewal '
#                  "may be turned off by going to the user's Account Settings "
#                  'after purchase\n'
#                  '– Any unused portion of a free trial period, if offered, '
#                  'will be forfeited when the user purchases a subscription to '
#                  'that publication, where applicable\n'
#                  '\n'
#                  'Privacy Policy: http://www.happify.com/privacy\n'
#                  'Terms & Conditions: http://www.happify.com/terms\n'
#                  '\n'
#                  'Website: http://www.happify.com\n'
#                  'Help: support@happify.com',
#   'features': '',
#   'fileSizeBytes': '167307264',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6012',
#   'genres': 'Gezondheid en fitness,Lifestyle',
#   'ipadScreenshotUrls': '',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN,FR,DE,IT,JA,PT,ZH,ES',
#   'minimumOsVersion': '9.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2013-11-08T02:38:36Z',
#   'releaseNotes': "Everything's running faster and smoother, thanks to our "
#                   'latest build.\n'
#                   "We love hearing feedback from you! If you're enjoying your "
#                   'Happify experience so far, please consider leaving us a '
#                   'review in the App Store!',
#   'screenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/cd/be/94/cdbe9407-8f99-5e2b-22dc-10643ab41a7b/111e060c-c186-4c3f-b3aa-da849febb1e5_1242x2208bb.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/ba/26/b5/ba26b5e0-0cd3-f74d-752d-69f775db53ea/669e30ae-b1c5-490b-9a0f-cc9843005d16_1242x2208bb-2.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/64/82/df/6482df3c-95ad-321e-85de-c95d6e10f641/4085105b-f679-4f11-939e-0cf556fb2c2a_1242x2208bb-3.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/d8/51/0f/d8510fb4-7188-c806-1b8f-a9598385aaea/71eaffa7-6751-4261-9851-6b5ef782855d_1242x2208bb-4.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/84/50/bd/8450bd06-bd61-c8c0-d2db-5df803de3832/d8773bba-8344-45ce-bacf-a25d4fef17d1_1242x2208bb-5.png/392x696bb.png',
#   'sellerName': 'Happify, Inc.',
#   'sellerUrl': 'http://www.happify.com',
#   'supportedDevices': 'iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-iPhone4S,iPadThirdGen-iPadThirdGen,iPadThirdGen4G-iPadThirdGen4G,iPhone5-iPhone5,iPodTouchFifthGen-iPodTouchFifthGen,iPadFourthGen-iPadFourthGen,iPadFourthGen4G-iPadFourthGen4G,iPadMini-iPadMini,iPadMini4G-iPadMini4G,iPhone5c-iPhone5c,iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#   'trackCensoredName': 'Happify: for Stress & Worry',
#   'trackContentRating': '4+',
#   'trackId': 730601963,
#   'trackName': 'Happify: for Stress & Worry',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/happify-for-stress-worry/id730601963?uo=4',
#   'userRatingCount': 21,
#   'userRatingCountForCurrentVersion': 21,
#   'version': '2.9.34',
#   'wrapperType': 'software'},
#  {'advisories': '',
#   'appletvScreenshotUrls': '',
#   'artistId': 730601966,
#   'artistName': 'Happify, Inc.',
#   'artistViewUrl': 'https://apps.apple.com/nl/developer/happify-inc/id730601966?uo=4',
#   'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/100x100bb.jpg',
#   'artworkUrl512': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/512x512bb.jpg',
#   'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/60x60bb.jpg',
#   'averageUserRating': 4.14286,
#   'averageUserRatingForCurrentVersion': 4.14286,
#   'bundleId': 'com.happify.Happify',
#   'contentAdvisoryRating': '4+',
#   'currency': 'EUR',
#   'currentVersionReleaseDate': '2021-02-26T13:09:52Z',
#   'description': "Happify's science-based activities and games can help you "
#                  "overcome negative thoughts, stress, and life's challenges.\n"
#                  '\n'
#                  'Our techniques are developed by leading scientists and '
#                  "experts who've been studying evidence-based interventions in "
#                  'the fields of positive psychology, mindfulness, and '
#                  'cognitive behavioral therapy for decades.\n'
#                  ' \n'
#                  '86% of people who use Happify regularly report feeling '
#                  'better about their lives in 2 months!\n'
#                  '\n'
#                  'JOURNALISTS TRIED IT FOR THEMSELVES, AND HERE’S WHAT THEY '
#                  'SAID:\n'
#                  '\n'
#                  "ABC World News' Mara Schiavocampo\n"
#                  '"I gave it a shot for 5 weeks...it works!"\n'
#                  '\n'
#                  'The New York Times\n'
#                  '"Each track contains bite-size quizzes, games and activities '
#                  'that guide you to seeing more positive aspects of daily '
#                  'life."\n'
#                  '\n'
#                  'The TODAY Show\n'
#                  '"These are things you can do every day -- tasks you can '
#                  'complete and be rewarded for -- to feel better, reduce '
#                  'stress, live a better life, and actually be happy."\n'
#                  '\n'
#                  "WE'RE GRATEFUL TO BE CHANGING LIVES EVERY DAY:\n"
#                  '\n'
#                  '"I absolutely love the Happify app! I’ve been using it for '
#                  'years and it really has transformed my life more than ANY '
#                  'OTHER TOOL I’ve used to grow my positivity! The world would '
#                  'be a much better place if everyone used it...And it’s FUN!" '
#                  '-Ashley S., Tampa, FL\n'
#                  '\n'
#                  '"Happify has helped me develop new skills in a variety of '
#                  'domains such as preventing worry, cultivating my '
#                  'relationships, and setting better sleep habits." - Elaina '
#                  'S., St. Louis, MO\n'
#                  '\n'
#                  '"I have been using the Happify app for a few years. I '
#                  'started using the app when I was going through depression '
#                  'and needed something to distract myself whenever I was '
#                  'dealing with negative thoughts.  Happify has definitely '
#                  'changed my life for the better. I know that whenever I am '
#                  'struggling with negative thoughts, I can use the games and '
#                  'tasks on the Happify app to improve my mood." - Nerina F., '
#                  'Seoul, South Korea\n'
#                  '\n'
#                  '"When I first started, I was skeptical about some of the '
#                  'exercises. However, I was willing to try them...and my '
#                  'skepticism faded when I realized they helped. I have less '
#                  'bad days...and when I have bad days, they disperse more '
#                  "quickly, and they're not as severe as they were before "
#                  'Happify." - Jessica G., West Park, FL\n'
#                  '\n'
#                  'YOU KNOW YOUR GOALS. WE KNOW HOW YOU CAN ACHIEVE THEM.\n'
#                  '\n'
#                  'Choose one track. Choose them all.\n'
#                  '\n'
#                  '* Conquering negative thoughts\n'
#                  '* Coping better with stress\n'
#                  '* Building self-confidence\n'
#                  '* Fueling your career success\n'
#                  '* Achieving mindfulness through meditation\n'
#                  '* …and 65+ more!\n'
#                  '\n'
#                  'Get a taste of what Happify has to offer in the free version '
#                  'of the app. Discover why so many people upgrade to Happify '
#                  'Plus for access to even more, including:\n'
#                  '\n'
#                  '* Unlimited access to 65+ tracks\n'
#                  '* Unlimited access to games and meditations\n'
#                  '* Your 20-page character strength report, offered in '
#                  'partnership with the renowned VIA Institute\n'
#                  '* Track your progress everyday and see how your skills '
#                  'compare\n'
#                  '\n'
#                  'Because we know that everyone has different financial '
#                  'resources, we offer Happify Plus in a variety of plans, for '
#                  'as low as $11.67/month when purchasing a yearly '
#                  'subscription:\n'
#                  '\n'
#                  'Yearly: $139.99 per year ($11.67/month)\n'
#                  'Monthly: $14.99\n'
#                  'Lifetime: $449.99\n'
#                  '\n'
#                  '– Payment will be charged to iTunes Account at confirmation '
#                  'of purchase\n'
#                  '– Subscription automatically renews unless auto-renew is '
#                  'turned off at least 24-hours before the end of the current '
#                  'period\n'
#                  '– Account will be charged for renewal within 24-hours prior '
#                  'to the end of the current period, and identify the cost of '
#                  'the renewal\n'
#                  '– Subscriptions may be managed by the user and auto-renewal '
#                  "may be turned off by going to the user's Account Settings "
#                  'after purchase\n'
#                  '– Any unused portion of a free trial period, if offered, '
#                  'will be forfeited when the user purchases a subscription to '
#                  'that publication, where applicable\n'
#                  '\n'
#                  'Privacy Policy: http://www.happify.com/privacy\n'
#                  'Terms & Conditions: http://www.happify.com/terms\n'
#                  '\n'
#                  'Website: http://www.happify.com\n'
#                  'Help: support@happify.com',
#   'features': '',
#   'fileSizeBytes': '167307264',
#   'formattedPrice': 'Gratis',
#   'genreIds': '6013,6012',
#   'genres': 'Gezondheid en fitness,Lifestyle',
#   'ipadScreenshotUrls': '',
#   'isGameCenterEnabled': False,
#   'isVppDeviceBasedLicensingEnabled': True,
#   'kind': 'software',
#   'languageCodesISO2A': 'EN,FR,DE,IT,JA,PT,ZH,ES',
#   'minimumOsVersion': '9.0',
#   'price': 0.0,
#   'primaryGenreId': 6013,
#   'primaryGenreName': 'Health & Fitness',
#   'releaseDate': '2013-11-08T02:38:36Z',
#   'releaseNotes': "Everything's running faster and smoother, thanks to our "
#                   'latest build.\n'
#                   "We love hearing feedback from you! If you're enjoying your "
#                   'Happify experience so far, please consider leaving us a '
#                   'review in the App Store!',
#   'screenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/cd/be/94/cdbe9407-8f99-5e2b-22dc-10643ab41a7b/111e060c-c186-4c3f-b3aa-da849febb1e5_1242x2208bb.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/ba/26/b5/ba26b5e0-0cd3-f74d-752d-69f775db53ea/669e30ae-b1c5-490b-9a0f-cc9843005d16_1242x2208bb-2.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/64/82/df/6482df3c-95ad-321e-85de-c95d6e10f641/4085105b-f679-4f11-939e-0cf556fb2c2a_1242x2208bb-3.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/d8/51/0f/d8510fb4-7188-c806-1b8f-a9598385aaea/71eaffa7-6751-4261-9851-6b5ef782855d_1242x2208bb-4.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/84/50/bd/8450bd06-bd61-c8c0-d2db-5df803de3832/d8773bba-8344-45ce-bacf-a25d4fef17d1_1242x2208bb-5.png/392x696bb.png',
#   'sellerName': 'Happify, Inc.',
#   'sellerUrl': 'http://www.happify.com',
#   'supportedDevices': 'iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-iPhone4S,iPadThirdGen-iPadThirdGen,iPadThirdGen4G-iPadThirdGen4G,iPhone5-iPhone5,iPodTouchFifthGen-iPodTouchFifthGen,iPadFourthGen-iPadFourthGen,iPadFourthGen4G-iPadFourthGen4G,iPadMini-iPadMini,iPadMini4G-iPadMini4G,iPhone5c-iPhone5c,iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#   'trackCensoredName': 'Happify: for Stress & Worry',
#   'trackContentRating': '4+',
#   'trackId': 730601963,
#   'trackName': 'Happify: for Stress & Worry',
#   'trackViewUrl': 'https://apps.apple.com/nl/app/happify-for-stress-worry/id730601963?uo=4',
#   'userRatingCount': 21,
#   'userRatingCountForCurrentVersion': 21,
#   'version': '2.9.34',
#   'wrapperType': 'software'}]

# %%
len(happify_info)
# Out:
# 2

# %%
pprint(happify_info[0])
# Out:
# {'advisories': '',
#  'appletvScreenshotUrls': '',
#  'artistId': 730601966,
#  'artistName': 'Happify, Inc.',
#  'artistViewUrl': 'https://apps.apple.com/nl/developer/happify-inc/id730601966?uo=4',
#  'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/100x100bb.jpg',
#  'artworkUrl512': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/512x512bb.jpg',
#  'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Purple124/v4/fd/cf/b8/fdcfb8c9-19c4-f454-b6d9-3204226bda73/source/60x60bb.jpg',
#  'averageUserRating': 4.14286,
#  'averageUserRatingForCurrentVersion': 4.14286,
#  'bundleId': 'com.happify.Happify',
#  'contentAdvisoryRating': '4+',
#  'currency': 'EUR',
#  'currentVersionReleaseDate': '2021-02-26T13:09:52Z',
#  'description': "Happify's science-based activities and games can help you "
#                 "overcome negative thoughts, stress, and life's challenges.\n"
#                 '\n'
#                 'Our techniques are developed by leading scientists and '
#                 "experts who've been studying evidence-based interventions in "
#                 'the fields of positive psychology, mindfulness, and cognitive '
#                 'behavioral therapy for decades.\n'
#                 ' \n'
#                 '86% of people who use Happify regularly report feeling better '
#                 'about their lives in 2 months!\n'
#                 '\n'
#                 'JOURNALISTS TRIED IT FOR THEMSELVES, AND HERE’S WHAT THEY '
#                 'SAID:\n'
#                 '\n'
#                 "ABC World News' Mara Schiavocampo\n"
#                 '"I gave it a shot for 5 weeks...it works!"\n'
#                 '\n'
#                 'The New York Times\n'
#                 '"Each track contains bite-size quizzes, games and activities '
#                 'that guide you to seeing more positive aspects of daily '
#                 'life."\n'
#                 '\n'
#                 'The TODAY Show\n'
#                 '"These are things you can do every day -- tasks you can '
#                 'complete and be rewarded for -- to feel better, reduce '
#                 'stress, live a better life, and actually be happy."\n'
#                 '\n'
#                 "WE'RE GRATEFUL TO BE CHANGING LIVES EVERY DAY:\n"
#                 '\n'
#                 '"I absolutely love the Happify app! I’ve been using it for '
#                 'years and it really has transformed my life more than ANY '
#                 'OTHER TOOL I’ve used to grow my positivity! The world would '
#                 'be a much better place if everyone used it...And it’s FUN!" '
#                 '-Ashley S., Tampa, FL\n'
#                 '\n'
#                 '"Happify has helped me develop new skills in a variety of '
#                 'domains such as preventing worry, cultivating my '
#                 'relationships, and setting better sleep habits." - Elaina S., '
#                 'St. Louis, MO\n'
#                 '\n'
#                 '"I have been using the Happify app for a few years. I started '
#                 'using the app when I was going through depression and needed '
#                 'something to distract myself whenever I was dealing with '
#                 'negative thoughts.  Happify has definitely changed my life '
#                 'for the better. I know that whenever I am struggling with '
#                 'negative thoughts, I can use the games and tasks on the '
#                 'Happify app to improve my mood." - Nerina F., Seoul, South '
#                 'Korea\n'
#                 '\n'
#                 '"When I first started, I was skeptical about some of the '
#                 'exercises. However, I was willing to try them...and my '
#                 'skepticism faded when I realized they helped. I have less bad '
#                 'days...and when I have bad days, they disperse more quickly, '
#                 'and they\'re not as severe as they were before Happify." - '
#                 'Jessica G., West Park, FL\n'
#                 '\n'
#                 'YOU KNOW YOUR GOALS. WE KNOW HOW YOU CAN ACHIEVE THEM.\n'
#                 '\n'
#                 'Choose one track. Choose them all.\n'
#                 '\n'
#                 '* Conquering negative thoughts\n'
#                 '* Coping better with stress\n'
#                 '* Building self-confidence\n'
#                 '* Fueling your career success\n'
#                 '* Achieving mindfulness through meditation\n'
#                 '* …and 65+ more!\n'
#                 '\n'
#                 'Get a taste of what Happify has to offer in the free version '
#                 'of the app. Discover why so many people upgrade to Happify '
#                 'Plus for access to even more, including:\n'
#                 '\n'
#                 '* Unlimited access to 65+ tracks\n'
#                 '* Unlimited access to games and meditations\n'
#                 '* Your 20-page character strength report, offered in '
#                 'partnership with the renowned VIA Institute\n'
#                 '* Track your progress everyday and see how your skills '
#                 'compare\n'
#                 '\n'
#                 'Because we know that everyone has different financial '
#                 'resources, we offer Happify Plus in a variety of plans, for '
#                 'as low as $11.67/month when purchasing a yearly '
#                 'subscription:\n'
#                 '\n'
#                 'Yearly: $139.99 per year ($11.67/month)\n'
#                 'Monthly: $14.99\n'
#                 'Lifetime: $449.99\n'
#                 '\n'
#                 '– Payment will be charged to iTunes Account at confirmation '
#                 'of purchase\n'
#                 '– Subscription automatically renews unless auto-renew is '
#                 'turned off at least 24-hours before the end of the current '
#                 'period\n'
#                 '– Account will be charged for renewal within 24-hours prior '
#                 'to the end of the current period, and identify the cost of '
#                 'the renewal\n'
#                 '– Subscriptions may be managed by the user and auto-renewal '
#                 "may be turned off by going to the user's Account Settings "
#                 'after purchase\n'
#                 '– Any unused portion of a free trial period, if offered, will '
#                 'be forfeited when the user purchases a subscription to that '
#                 'publication, where applicable\n'
#                 '\n'
#                 'Privacy Policy: http://www.happify.com/privacy\n'
#                 'Terms & Conditions: http://www.happify.com/terms\n'
#                 '\n'
#                 'Website: http://www.happify.com\n'
#                 'Help: support@happify.com',
#  'features': '',
#  'fileSizeBytes': '167307264',
#  'formattedPrice': 'Gratis',
#  'genreIds': '6013,6012',
#  'genres': 'Gezondheid en fitness,Lifestyle',
#  'ipadScreenshotUrls': '',
#  'isGameCenterEnabled': False,
#  'isVppDeviceBasedLicensingEnabled': True,
#  'kind': 'software',
#  'languageCodesISO2A': 'EN,FR,DE,IT,JA,PT,ZH,ES',
#  'minimumOsVersion': '9.0',
#  'price': 0.0,
#  'primaryGenreId': 6013,
#  'primaryGenreName': 'Health & Fitness',
#  'releaseDate': '2013-11-08T02:38:36Z',
#  'releaseNotes': "Everything's running faster and smoother, thanks to our "
#                  'latest build.\n'
#                  "We love hearing feedback from you! If you're enjoying your "
#                  'Happify experience so far, please consider leaving us a '
#                  'review in the App Store!',
#  'screenshotUrls': 'https://is2-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/cd/be/94/cdbe9407-8f99-5e2b-22dc-10643ab41a7b/111e060c-c186-4c3f-b3aa-da849febb1e5_1242x2208bb.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/ba/26/b5/ba26b5e0-0cd3-f74d-752d-69f775db53ea/669e30ae-b1c5-490b-9a0f-cc9843005d16_1242x2208bb-2.png/392x696bb.png,https://is2-ssl.mzstatic.com/image/thumb/PurpleSource114/v4/64/82/df/6482df3c-95ad-321e-85de-c95d6e10f641/4085105b-f679-4f11-939e-0cf556fb2c2a_1242x2208bb-3.png/392x696bb.png,https://is1-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/d8/51/0f/d8510fb4-7188-c806-1b8f-a9598385aaea/71eaffa7-6751-4261-9851-6b5ef782855d_1242x2208bb-4.png/392x696bb.png,https://is4-ssl.mzstatic.com/image/thumb/PurpleSource124/v4/84/50/bd/8450bd06-bd61-c8c0-d2db-5df803de3832/d8773bba-8344-45ce-bacf-a25d4fef17d1_1242x2208bb-5.png/392x696bb.png',
#  'sellerName': 'Happify, Inc.',
#  'sellerUrl': 'http://www.happify.com',
#  'supportedDevices': 'iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-iPhone4S,iPadThirdGen-iPadThirdGen,iPadThirdGen4G-iPadThirdGen4G,iPhone5-iPhone5,iPodTouchFifthGen-iPodTouchFifthGen,iPadFourthGen-iPadFourthGen,iPadFourthGen4G-iPadFourthGen4G,iPadMini-iPadMini,iPadMini4G-iPadMini4G,iPhone5c-iPhone5c,iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellular-iPadAirCellular,iPadMiniRetina-iPadMiniRetina,iPadMiniRetinaCellular-iPadMiniRetinaCellular,iPhone6-iPhone6,iPhone6Plus-iPhone6Plus,iPadAir2-iPadAir2,iPadAir2Cellular-iPadAir2Cellular,iPadMini3-iPadMini3,iPadMini3Cellular-iPadMini3Cellular,iPodTouchSixthGen-iPodTouchSixthGen,iPhone6s-iPhone6s,iPhone6sPlus-iPhone6sPlus,iPadMini4-iPadMini4,iPadMini4Cellular-iPadMini4Cellular,iPadPro-iPadPro,iPadProCellular-iPadProCellular,iPadPro97-iPadPro97,iPadPro97Cellular-iPadPro97Cellular,iPhoneSE-iPhoneSE,iPhone7-iPhone7,iPhone7Plus-iPhone7Plus,iPad611-iPad611,iPad612-iPad612,iPad71-iPad71,iPad72-iPad72,iPad73-iPad73,iPad74-iPad74,iPhone8-iPhone8,iPhone8Plus-iPhone8Plus,iPhoneX-iPhoneX,iPad75-iPad75,iPad76-iPad76,iPhoneXS-iPhoneXS,iPhoneXSMax-iPhoneXSMax,iPhoneXR-iPhoneXR,iPad812-iPad812,iPad834-iPad834,iPad856-iPad856,iPad878-iPad878,iPadMini5-iPadMini5,iPadMini5Cellular-iPadMini5Cellular,iPadAir3-iPadAir3,iPadAir3Cellular-iPadAir3Cellular,iPodTouchSeventhGen-iPodTouchSeventhGen,iPhone11-iPhone11,iPhone11Pro-iPhone11Pro,iPadSeventhGen-iPadSeventhGen,iPadSeventhGenCellular-iPadSeventhGenCellular,iPhone11ProMax-iPhone11ProMax,iPhoneSESecondGen-iPhoneSESecondGen,iPadProSecondGen-iPadProSecondGen,iPadProSecondGenCellular-iPadProSecondGenCellular,iPadProFourthGen-iPadProFourthGen,iPadProFourthGenCellular-iPadProFourthGenCellular,iPhone12Mini-iPhone12Mini,iPhone12-iPhone12,iPhone12Pro-iPhone12Pro,iPhone12ProMax-iPhone12ProMax,iPadAir4-iPadAir4,iPadAir4Cellular-iPadAir4Cellular,iPadEighthGen-iPadEighthGen,iPadEighthGenCellular-iPadEighthGenCellular',
#  'trackCensoredName': 'Happify: for Stress & Worry',
#  'trackContentRating': '4+',
#  'trackId': 730601963,
#  'trackName': 'Happify: for Stress & Worry',
#  'trackViewUrl': 'https://apps.apple.com/nl/app/happify-for-stress-worry/id730601963?uo=4',
#  'userRatingCount': 21,
#  'userRatingCountForCurrentVersion': 21,
#  'version': '2.9.34',
#  'wrapperType': 'software'}

# %%
## Test obtaining 20 Happify reviews
happify = AppStore(country='us', app_name='happify-for-stress-worry')
happify.review(how_many=20)

pprint(happify.reviews)
pprint(happify.reviews_count)
# Out:
# 2021-03-24 11:24:31,090 [INFO] Base - Searching for app id
# 2021-03-24 11:24:32,852 [INFO] Base - Initialised: AppStore('us', 'happify-for-stress-worry', 730601963)
# 2021-03-24 11:24:32,852 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/happify-for-stress-worry/id730601963
# 2021-03-24 11:24:33,292 [INFO] Base - [id:730601963] Fetched 20 reviews (20 fetched in total)
# [{'date': datetime.datetime(2017, 10, 25, 16, 0, 21),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I had Happify on my phone for a couple of years before I used it. '
#             'I got it for free when Starbucks gave away apps and music. I '
#             'started a minimalism lifestyle transition earlier this year and '
#             'by summer decided to reduce the number of apps on my phone. I '
#             'decided to open up Happify and see what it was about before I '
#             'deleted it. I did the first track recommend and it was awesome. I '
#             'was going through my annual feeling stuck and hopeless season. I '
#             'felt I needed to do something drastic this time around. I was '
#             'tired of the loop that was my life. I had to break free. \n'
#             '\n'
#             'No drastic actions needed. This app gradually transformed my mind '
#             'state. I am happier now for real. I don’t have to force myself to '
#             'be happy. I have less anxiety about money, my negative mind-state '
#             'is now struggling for survival instead of being dominant. I feel '
#             'freer. I have a refreshing perspective on life-a paradigm '
#             'shift.  \n'
#             '\n'
#             'When the student is ready the Teacher will appear. This app was '
#             'in my life, patiently waiting for me to see it. \n'
#             'Thank you Starbucks. Thank you Happify. Thank you Universe for '
#             'putting tools in place in my life. The Universe puts things and '
#             'people in our lives for a reason. This life-changer was hanging '
#             'out on my phone for years and showed up when I really needed. I '
#             'deleted a lot of apps I got from Starbucks but never this one. 🤔',
#   'title': 'Life Transformation in a app!',
#   'userName': 'Belushus'},
#  {'date': datetime.datetime(2019, 1, 7, 21, 25, 49),
#   'isEdited': False,
#   'rating': 2,
#   'review': 'I had high hopes for Happify, but, so far, it’s stressing me out. '
#             'Imposing deadlines I never meant to put in myself by challenging '
#             'me to do something nice for someone is stressful. The words in '
#             'the “uplift” game that are supposed to be empowering and '
#             'uplifting are sometimes actually unattainable ideals and/or '
#             'things some people don’t aspire to (I don’t want to be “perky,” '
#             'for instance. That’s not my personality. I am happy, and '
#             'pleasant, and even outgoing, but not perky).  Some people reading '
#             'these words won’t feel uplifted so much as invalidated. Words '
#             'like “peace,” “calm” and “uplift” were fine. When the game got '
#             'too cluttered, again, it was just stressful, because I couldn’t '
#             'read anything. The reminders from Happify of what I am supposed '
#             'to be doing on the app, the little icon that shows my mood, and '
#             'tools that measure my progress ~ all of this would be great, if '
#             'it was designed to make sure the user easily maintained upward '
#             'movement, but it’s not. It’s all extremely pressuring and '
#             'stressful, in my opinion. It feels more like a challenge I am '
#             'trying to meet than an app that is supposed to help me feel '
#             'better.',
#   'title': 'Stressing me out',
#   'userName': 'sammykate'},
#  {'date': datetime.datetime(2018, 3, 17, 7, 9, 43),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve tried numerous other like this one but after using them once '
#             'or twice I lost interest. I’m so glad that I found Happify! It '
#             'has been very helpful and I noticed that I’m drawn to it several '
#             'times throughout my day, unusually at a time when I need it '
#             'most. \n'
#             '\n'
#             'To my surprise it actually makes me smile and I look forward to '
#             'the activities instead of that guiltily feeling I have come to '
#             'dread. Other apps felt more like a chore I have to get done or I '
#             'would feel worse over my laziness and since I’ve been using '
#             'Happify it has been the complete opposite, and I couldn’t ask for '
#             'more. \n'
#             '\n'
#             'I high recommend giving it a try, I’m glad I found it before I '
#             'gave up on finding the right one for me.',
#   'title': 'Informational and fun',
#   'userName': 'smerk1303'},
#  {'date': datetime.datetime(2017, 10, 25, 13, 2, 30),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I have used this app for less than two days and already it has '
#             'been more understanding and compassionate about my emotions and '
#             'feelings than all of my family members put together.\n'
#             '\n'
#             'I had a poll about my least favorite chore and that made me feel '
#             'listened to. I was just having an emotional meltdown that peaked '
#             'after three hours and after looking at my phone and seeing a '
#             'notif for a ‘Happiness Check-In’, I had stopped by the time I '
#             'read the first question. It was comforting to be acknowledged and '
#             'cared about individually. \n'
#             '\n'
#             'The games actually are helpful and the ‘Why this Works’ section '
#             'is informative and inspires faith and confidence. I recommend '
#             'this app to my family, friends and anyone who is having it '
#             'rough. \n'
#             '\n'
#             'I have tried a lot of these sort of apps before and this one '
#             'stands out from the rest. One yearly subscription fee ($4.99 a '
#             'month with $60 as full payment for a year) is $20 cheaper than '
#             'two weekly visits to my old therapist under insurance. Please '
#             'give this app a chance. Thank you developers for making such a '
#             'great thing for everyone.\n'
#             '\n'
#             'Edit: Purchased the full version, have a week free trial of '
#             'coaching. 4 days have gone by, no daily advice, questions '
#             'answered, or progress reviews as promised. Trial expires in two '
#             'days and haven’t even gotten to use it. Very upset. Considering a '
#             'full refund.',
#   'title': 'Just wow!',
#   'userName': 'UnwrittenT'},
#  {'date': datetime.datetime(2020, 3, 27, 13, 9, 49),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve had this app since Beta-testing it a few years ago. I don’t '
#             'typically use apps like this because most don’t seem to have real '
#             'direction or a variety that fits. I let this one sit for a bit '
#             'before coming back to it during a stressful period, and I was '
#             'pleasantly surprised! I like that I can extend my tracks now '
#             'considering I don’t come back here everyday, and the '
#             'personalization is dead on for me! It goes hand in hand with '
#             'where I’ve needed to grow yet lacked a clue where to start. My '
#             'therapist very much approved too! I’ve since “graduated” '
#             'trauma-informed therapy, and this app has helped me in moments '
#             'I’ve needed to simply be reminded of my newer mental toolbox. It '
#             'doesn’t overstep any spiritual boundaries for me either (I’m a '
#             'pastor). Thanks!!!',
#   'title': 'Favorite Self-care App',
#   'userName': 'SolitaryBridge'},
#  {'date': datetime.datetime(2018, 2, 10, 20, 11, 35),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app has helped me along with CBT and small lifestyle changes '
#             'to see things in another light. Life isn’t perfect and it’s hard '
#             'for everyone. I feel anxiety and stress everyday. I feels anxious '
#             'around others and certain people and places can make my physical '
#             'anxiety seem like I am going to die. There’s no mineral, vitamin '
#             'or supplement that can change your thought patterns as a response '
#             'from external stimulation. That you have to practice everyday '
#             'along with mastering your tone, facial expressions and body '
#             'language. I find life to be more emotionally rough more so than '
#             'anything else',
#   'title': 'Thanks',
#   'userName': 'MaxMidnight'},
#  {'date': datetime.datetime(2019, 9, 29, 3, 33, 40),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'Had hoped this app would help, but it only made me more stressed '
#             'and upset. Keeping score and subtracting when you miss something? '
#             'Scrambling to keep up and not miss things? Turning happiness into '
#             'a competition? NOT a positive thing! Now I feel like I have to '
#             'measure up and do better and succeed more when that kind of '
#             'stress is part of the problem to begin with. It was also really '
#             'distracting with pop-ups about winning certain perks, not to '
#             'mention confusing as to what they are and do. Honestly, not here '
#             'to try and earn points. I found the overall layout pretty '
#             'confusing as well. The emails that are meant to encourage you to '
#             'do more activities in the app are incredibly annoying. Also '
#             'didn’t like what I read in the legal and privacy policies, and '
#             'feeling forced to share my real data. I’d have paid money for an '
#             'app that was actually relaxing and uplifting while maintaining a '
#             'feeling of anonymity and privacy. This is NOT that.',
#   'title': 'Way Too Stressful and Cluttered',
#   'userName': 'Reiland9'},
#  {'date': datetime.datetime(2017, 12, 27, 15, 36, 39),
#   'isEdited': False,
#   'rating': 2,
#   'review': 'Stuck in an endless loop of repetitive not-fun questions that '
#             'never end. I thought once I completed track 1 I could get into '
#             'some of those happy games. Nope. Pushed into track 2. More survey '
#             'questions—with stock answers that don’t apply. It took me weeks '
#             'to finish track 2, but I finally did...only be told to repeat '
#             'track 2 again. So, I did. And when I completed track 2 again, I '
#             'was told to repeat it one more time. \n'
#             '\n'
#             'When you participate in the study, you can’t change your tracks. '
#             'If you want out of the study, you can’t return to it and lose the '
#             'perk of premium membership for free. For now I’m sticking with it '
#             'and praying that I’ll be let out of the “no-exit “ that is these '
#             'stupid, meaningless survey questions.',
#   'title': 'Don’t do the study',
#   'userName': 'lkremen'},
#  {'date': datetime.datetime(2019, 3, 17, 15, 24, 29),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app is great so far! My problem is forgetting to take the '
#             'time for self-care and reflection so I’m hoping this app will '
#             'help me with that. I haven’t been using it long so I’ll update my '
#             'review if anything changes. The activities are easy, uplifting, '
#             'and don’t take too long to complete. My only critique at the '
#             'moment is the user interface is a little cluttered/clunky on my '
#             'iPhone 7 Plus—would love them to make their dimensions better fit '
#             'bigger phones.',
#   'title': 'Great so far',
#   'userName': 'mjblue7'},
#  {'date': datetime.datetime(2018, 12, 18, 16, 34, 42),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I usually don’t write reviews, but I have become so frustrated at '
#             'the constant up-selling in this app. I suffer from anxiety and '
#             'depression - so I downloaded this to relax me. However, after '
#             'almost EVERY activity I’m bombarded with “you can’t access this '
#             'unless you upgrade,” “you should upgrade to premium,” “UPGRADE.” '
#             'It’s very hard to wind down when after you finish a genuinely '
#             'comforting exercise you have to constantly deny wanting to '
#             'upgrade. This app has made it clear to me that it’s prioritizes '
#             'taking your money instead of helping you become a better you.',
#   'title': 'This app wants your money more than your happiness.',
#   'userName': 'Abigail AKA Two Street'},
#  {'date': datetime.datetime(2018, 10, 16, 2, 37, 34),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'It starts by showing you a very busy screen with all these '
#             'different tracks you can take and some are paid which is '
#             'immediately stressful and feels like they’re going to try to push '
#             'their paid product. Then it goes through all these animations '
#             'that go too fast to read properly selling the app saying x% of '
#             'people are happier after doing our activities. I felt like I '
#             'already got the app why is it trying to convince me of getting '
#             'it. I’m trying to use it. Then I tried one game with balloons '
#             'were you have to focus on positive words on the balloons but the '
#             'UI is janky and it just made me more stressed. As you can see, '
#             'not feeling positive at all after using ‘Happify’.',
#   'title': 'On boarding awful',
#   'userName': 'Elisaj7'},
#  {'date': datetime.datetime(2018, 7, 20, 4, 37, 15),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I found this app, and only used it a bit. And lately been using '
#             'it every day, I can not afford the upgrades at this time. But the '
#             'options that are available are incredibly helpful. I use it when '
#             'I get anxiety, and the readings help, he simple games. And '
#             'people’s daily writings, I’m surprised how much it’s helped me. I '
#             'love the stone throw at any negative emotion we have! Thank you '
#             'Happify and all the people not afraid to post their struggles and '
#             'accomplishments !',
#   'title': 'Happy for  Happify',
#   'userName': 'concettahough'},
#  {'date': datetime.datetime(2018, 5, 24, 6, 35, 19),
#   'developerResponse': {'body': 'Hi there, sorry to hear you did not enjoy '
#                                 'your signup experience. Unfortunately we do '
#                                 'require that users signup for Happify in '
#                                 'order to gain access to our activities and '
#                                 'games. I can assure you Facebook login is not '
#                                 'required to signup. Hopefully you can try '
#                                 'with an alternative email address in the '
#                                 'future!',
#                         'id': 4481345,
#                         'modified': '2018-07-31T19:20:17Z'},
#   'isEdited': False,
#   'rating': 2,
#   'review': 'As soon as an app forces me to SIGN UP with Facebook (I gave up '
#             'Facebook long ago and would never go back) or give my email... '
#             'it’s over. I can kind of understand if I decided to purchase the '
#             'full version, but until I have been able to at least try the '
#             'trial version of an app I am not giving out any personal info. '
#             'Just a warning to those of you who do not care for giving out '
#             'your info to just anyone. Like I don’t get enough spam '
#             'already...sheesh.\n'
#             '(If course I keep extra emails for such situations. I would never '
#             'give my main email address that I use for banking etc to any app '
#             'EVER) \n'
#             'Bye bye\n'
#             '*UNINSTALLED*',
#   'title': 'Lost Me At Hello',
#   'userName': 'nonyanickname'},
#  {'date': datetime.datetime(2018, 9, 6, 1, 3, 5),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I tried he app, it was fine but not for me so I just deleted it.  '
#             'Afterwards I got email after email from happify but when I would '
#             'click on unsubscribe, I would be taken to a window that wanted me '
#             'to install the app. The unsubscribe link wouldn’t let me '
#             'unsubscribe. I thought I could get it with a spam filter but '
#             'eventually I had to reinstall the app so I could go into the '
#             'settings about emails. there was no way to unsubscribe '
#             'otherwise.  It didn’t take a long time, but I shouldn’t have had '
#             'to do it at all. This I give a 1* so the developers can take '
#             'specific note.  And as for the app, it was meh to fine. Sweet '
#             'concept but it’s a kindergarten game.',
#   'title': 'I was provoked into this review',
#   'userName': 'The niha'},
#  {'date': datetime.datetime(2019, 6, 5, 23, 9, 9),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I used to have a stressful life living in fear every day, sad and '
#             'depressed and worrying all the time. With doing the '
#             'thought-provoking exercises, stress-reliever games , the Happify '
#             'community cheering on your successes or helping you see in a '
#             'different perspective if you’re needing guidance, the uplifting '
#             'videos that make your heart smile and you learn something new '
#             'helped me tremendously! Thank you Happify, truly!!! 🤗💝😇🤩 You’ve '
#             'helped me live my best life and be the best version of myself!',
#   'title': 'Happify saved my life!',
#   'userName': 'Nikki Petersen'},
#  {'date': datetime.datetime(2018, 3, 19, 2, 1, 4),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'This app has you do one small insignificant part of a larger task '
#             "and then tells you that you can't do anything else unless you pay "
#             "for a full premium version...isn't the point of getting someone "
#             'to pay for premium that you actually provide a good service and '
#             "convince them it's worth the money?\n"
#             " I have not benefitted in the least and it's making me annoyed to "
#             "start a task, but halfway through it says I can't finish the task "
#             "unless I pay. Based on what I've seen thus far I would never pay "
#             "for it. It's not even high quality or worthwhile. There are "
#             'better freemium apps that actually provide value for free and are '
#             'worth the paid upgrade',
#   'title': 'Ploy to be paid',
#   'userName': 'setisA1'},
#  {'date': datetime.datetime(2017, 7, 28, 5, 21, 56),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I did not expect to like this app so much, but it is amazing. It '
#             'has the perfect balance of a little information accompanying '
#             'activities that actually really do boost my mood. And the '
#             'activities that encourage you to connect with other people make '
#             'it impact my mood and wellbeing past just when I am in the app. '
#             "Give it even just a few minutes and you'll probably love this app "
#             'too!',
#   'title': 'I love this app!!',
#   'userName': 'dasweinz'},
#  {'date': datetime.datetime(2017, 11, 12, 11, 54, 42),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'I really do like the app but hate that the “free program” has to '
#             'be completed by paying for the subscription. That’s a bit '
#             'deceptive. \n'
#             '\n'
#             'I wouldn’t mind paying for the program if they actually charged '
#             'the amount per month like it says. For a full year of the '
#             'program, it cost roughly $4 a month, however they want $60ish up '
#             'front 🙄. I should be able to pay it monthly like any other bill. '
#             'Since, I can’t I won’t bother paying at all.',
#   'title': 'I like the app but. . .',
#   'userName': "Tasha's listening"},
#  {'date': datetime.datetime(2018, 6, 11, 9, 4, 37),
#   'isEdited': False,
#   'rating': 2,
#   'review': 'On a technical side, this app is pretty much garbage. But hey, '
#             'it’s a mindfulness app- it doesn’t have to look amazing. But '
#             'considering that this mindfulness app with terrible graphics and '
#             'copycat games wants to bill your every action with a repeated fee '
#             'for “free” content that’s meant to be helping you, I can’t say '
#             'I’m impressed. Nothing break through, most of this stuff you '
#             'could study for yourself online elsewhere and the “scientifically '
#             'backed games” probably aren’t going to change your life, '
#             'especially since they block you around level two. Also the '
#             'sweepstakes are nothing short of shady.',
#   'title': 'Not amazing',
#   'userName': 'DontAskDontTell'},
#  {'date': datetime.datetime(2018, 2, 26, 17, 44, 38),
#   'isEdited': False,
#   'rating': 2,
#   'review': 'This would app would be great with the tools given with the $60 '
#             'premium subscription. However as a poor depressed college student '
#             "I can barely afford food let alone a 'happy' app. From what I've "
#             "tried it seems to be a great app but without premium you can't do "
#             'much. For example the last 2 days my track has only listed '
#             'premium activities that I cannot unlock. I would be less annoyed '
#             "if it wasn't listed as a free app. Overall if you have $60 you "
#             'will enjoy this app if not I would give it a pass.',
#   'title': 'If Only I Was Rich.....',
#   'userName': 'Krey21'}]
# 20

# %%
happify_20 = happify.reviews
pd.DataFrame(happify_20)
# Out:
#                   date  rating  isEdited  \
# 0  2017-10-25 16:00:21       5     False
# 1  2019-01-07 21:25:49       2     False
# 2  2018-03-17 07:09:43       5     False
# 3  2017-10-25 13:02:30       3     False
# 4  2020-03-27 13:09:49       5     False
# 5  2018-02-10 20:11:35       5     False
# 6  2019-09-29 03:33:40       1     False
# 7  2017-12-27 15:36:39       2     False
# 8  2019-03-17 15:24:29       5     False
# 9  2018-12-18 16:34:42       3     False
# 10 2018-10-16 02:37:34       1     False
# 11 2018-07-20 04:37:15       5     False
# 12 2018-05-24 06:35:19       2     False
# 13 2018-09-06 01:03:05       1     False
# 14 2019-06-05 23:09:09       5     False
# 15 2018-03-19 02:01:04       1     False
# 16 2017-07-28 05:21:56       5     False
# 17 2017-11-12 11:54:42       4     False
# 18 2018-06-11 09:04:37       2     False
# 19 2018-02-26 17:44:38       2     False
#
#                                                 title                userName  \
# 0                       Life Transformation in a app!                Belushus
# 1                                    Stressing me out               sammykate
# 2                               Informational and fun               smerk1303
# 3                                           Just wow!              UnwrittenT
# 4                              Favorite Self-care App          SolitaryBridge
# 5                                              Thanks             MaxMidnight
# 6                     Way Too Stressful and Cluttered                Reiland9
# 7                                  Don’t do the study                 lkremen
# 8                                        Great so far                 mjblue7
# 9   This app wants your money more than your happi...  Abigail AKA Two Street
# 10                                  On boarding awful                 Elisaj7
# 11                                 Happy for  Happify           concettahough
# 12                                   Lost Me At Hello           nonyanickname
# 13                    I was provoked into this review                The niha
# 14                             Happify saved my life!          Nikki Petersen
# 15                                    Ploy to be paid                 setisA1
# 16                                  I love this app!!                dasweinz
# 17                            I like the app but. . .       Tasha's listening
# 18                                        Not amazing         DontAskDontTell
# 19                            If Only I Was Rich.....                  Krey21
#
#                                                review  \
# 0   I had Happify on my phone for a couple of year...
# 1   I had high hopes for Happify, but, so far, it’...
# 2   I’ve tried numerous other like this one but af...
# 3   I have used this app for less than two days an...
# 4   I’ve had this app since Beta-testing it a few ...
# 5   This app has helped me along with CBT and smal...
# 6   Had hoped this app would help, but it only mad...
# 7   Stuck in an endless loop of repetitive not-fun...
# 8   This app is great so far! My problem is forget...
# 9   I usually don’t write reviews, but I have beco...
# 10  It starts by showing you a very busy screen wi...
# 11  I found this app, and only used it a bit. And ...
# 12  As soon as an app forces me to SIGN UP with Fa...
# 13  I tried he app, it was fine but not for me so ...
# 14  I used to have a stressful life living in fear...
# 15  This app has you do one small insignificant pa...
# 16  I did not expect to like this app so much, but...
# 17  I really do like the app but hate that the “fr...
# 18  On a technical side, this app is pretty much g...
# 19  This would app would be great with the tools g...
#
#                                     developerResponse
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'id': 4481345, 'body': 'Hi there, sorry to he...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN

# %%
## Test obtaining 20 Happify reviews
happify = AppStore(country='us', app_name='happify-for-stress-worry')
happify.review(how_many=20, after=dt.datetime(2020, 2, 28))

pprint(happify.reviews)
pprint(happify.reviews_count)
# Out:
# 2021-03-15 14:21:55,413 [INFO] Base - Searching for app id
# 2021-03-15 14:21:57,980 [INFO] Base - Initialised: AppStore('us', 'happify-for-stress-worry', 730601963)
# 2021-03-15 14:21:57,982 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/happify-for-stress-worry/id730601963
# 2021-03-15 14:21:59,207 [INFO] Base - [id:730601963] Fetched 20 reviews (20 fetched in total)
# [{'date': datetime.datetime(2020, 3, 27, 13, 9, 49),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve had this app since Beta-testing it a few years ago. I don’t '
#             'typically use apps like this because most don’t seem to have real '
#             'direction or a variety that fits. I let this one sit for a bit '
#             'before coming back to it during a stressful period, and I was '
#             'pleasantly surprised! I like that I can extend my tracks now '
#             'considering I don’t come back here everyday, and the '
#             'personalization is dead on for me! It goes hand in hand with '
#             'where I’ve needed to grow yet lacked a clue where to start. My '
#             'therapist very much approved too! I’ve since “graduated” '
#             'trauma-informed therapy, and this app has helped me in moments '
#             'I’ve needed to simply be reminded of my newer mental toolbox. It '
#             'doesn’t overstep any spiritual boundaries for me either (I’m a '
#             'pastor). Thanks!!!',
#   'title': 'Favorite Self-care App',
#   'userName': 'SolitaryBridge'},
#  {'date': datetime.datetime(2020, 4, 4, 18, 25, 26),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I don’t have access to mental health treatment/therapy but this '
#             'is a good alternative for now. It helps me practice positive '
#             'thinking and being aware of how my thoughts affect my wellbeing. '
#             'Some of the games seem kind of useless but there are other things '
#             'that have helped me a lot.',
#   'title': 'I highly recommend this ap',
#   'userName': 'shaynemoth'},
#  {'date': datetime.datetime(2020, 5, 9, 2, 10, 18),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'It’s helped me lots so far I am feeling better then before I have '
#             'done only one but it’s helped me I am becoming more happier I was '
#             'depressed but now I feel very good about this and think if I do '
#             'more I will not be depressed anymore. I hope it works out for you '
#             'to.',
#   'title': 'I hope it will be god for you',
#   'userName': 'Muhtasom'},
#  {'date': datetime.datetime(2020, 3, 27, 17, 23, 50),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I love this app bc it helps me feel happy and I get to talk to '
#             'some ppl and share pictures and I think that makes me happy to '
#             'havto have have freinds  on here it makes me feel good about '
#             'myself I really do recommend this app',
#   'title': 'This has really helped me not feel as lonely as I did before',
#   'userName': '#rainbow lover'},
#  {'date': datetime.datetime(2021, 1, 3, 4, 35, 4),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app really changed my life. Ive been struggling with my '
#             'borderline personality disorder and extreme anger. This app has '
#             'shown me how to focus on the positive and push past negative '
#             'moods. I still struggle but my life has improved far more than I '
#             'ever expected. Thank you for making this.',
#   'title': 'Wonderful',
#   'userName': 'Krist0n'},
#  {'date': datetime.datetime(2020, 3, 22, 13, 26, 3),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app isn’t pressuring to me, it tells me that I have to work '
#             'at something to get results which is how good things come in '
#             'life. It has helped me out a lot in times of need. Very '
#             'satisfied. Thank you Happify 😊♥️',
#   'title': 'Happy',
#   'userName': 'PeaceLoveJessica'},
#  {'date': datetime.datetime(2020, 11, 7, 13, 52, 1),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I have been struggling with self esteem and depression. This app '
#             'is AMAZING by giving you the tools to change your mindset to '
#             'being a happier individual and goals to focus on. I’m so thankful '
#             'to have found this app!',
#   'title': 'Life changing',
#   'userName': 'Toyotalove_90'},
#  {'date': datetime.datetime(2021, 2, 20, 22, 6, 57),
#   'developerResponse': {'body': 'Oh no! We sincerely apologize for the '
#                                 "troubles you've had with the app. We'd be "
#                                 'happy to take a look into this for you, '
#                                 'please contact us at support@happify.com. '
#                                 'Thank you.',
#                         'id': 21215857,
#                         'modified': '2021-02-22T14:30:01Z'},
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I haven’t been able to use the app because I can’t rest my '
#             'password. I get the rest password email but it takes me to the '
#             'website where there’s nothing there to help me rest my password. '
#             'I’d rather use the app than the website.',
#   'title': 'Rest Password Doesn’t Work',
#   'userName': 'Jus Sayn'},
#  {'date': datetime.datetime(2020, 6, 9, 18, 27, 2),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I found this app at exactly the right time. The activities have '
#             'given me something positive to focus on through these difficult '
#             'times and I’m so grateful I found it!!',
#   'title': 'Love this app❤️',
#   'userName': 'not that dory'},
#  {'date': datetime.datetime(2020, 7, 6, 3, 33, 21),
#   'developerResponse': {'body': "Thank you so much for the review and we're "
#                                 'glad Happify is helping you along on your '
#                                 'wellness journey! We would love to use your '
#                                 'review as a testimonial on Happify. If we '
#                                 'have your permission, please email us at '
#                                 "support@happify.com and we'll let you know a "
#                                 'few other details we would need from you. ',
#                         'id': 16704017,
#                         'modified': '2020-07-17T15:46:18Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I resisted my husband’s suggestion to try Happify for 6 months. '
#             'I’m kicking myself now. It’s really helping me deal with my '
#             'anxiety in between therapy sessions. I’m actually happy for the '
#             'first time in forever.',
#   'title': 'Game changer',
#   'userName': 'Wernicki'},
#  {'date': datetime.datetime(2020, 9, 2, 2, 20, 45),
#   'developerResponse': {'body': "We're sorry you encountered some issues with "
#                                 'our app. If you email us at '
#                                 'support@happify.com, we would like to look '
#                                 'into this issue further.',
#                         'id': 17827494,
#                         'modified': '2020-09-11T13:30:49Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'The first time is used the app after downloading, everything '
#             'worked great. Now every time I try to open it I get an error '
#             'saying “there was an error processing your request.” Only by '
#             'uninstalling and reinstalling the app am I able to log in, but '
#             'then only once because after the app times out I get the same '
#             'error message.',
#   'title': 'Constant issues logging in',
#   'userName': 'unhappifyapp'},
#  {'date': datetime.datetime(2020, 4, 26, 22, 47, 7),
#   'developerResponse': {'body': 'Please contact support@happify.com. You may '
#                                 'have the wrong version of our app and our '
#                                 'team can send you instructions on how to '
#                                 'download the right one.',
#                         'id': 14973458,
#                         'modified': '2020-04-28T18:03:44Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I need to use this app to earn wellness points for work but the '
#             'app on my IPhone 11 will not let me login and just keeps '
#             'circling. Beyond frustrating.',
#   'title': 'Server errors',
#   'userName': 'Deekem'},
#  {'date': datetime.datetime(2020, 8, 12, 5, 34, 37),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I get they have to make money but I don’t have any at all I’m '
#             'young and my anxiety leaves me shaking and trembling on the '
#             'floor. I need an app that I can just open up and use to calm me '
#             'down. Not one that gives me limited options unless I pay',
#   'title': 'Have to pay?',
#   'userName': 'please be reasonable'},
#  {'date': datetime.datetime(2020, 6, 14, 21, 24, 16),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I am enjoy this so far after a couple of weeks.  I really wish '
#             'you’d create a kids version.  🤞🏼',
#   'title': 'So far so good',
#   'userName': 'AngBtmn'},
#  {'date': datetime.datetime(2021, 2, 4, 3, 8, 37),
#   'developerResponse': {'body': "We're sorry you encountered issues with our "
#                                 'app. You may email us at support@happify.com, '
#                                 'we would like to look into this issue '
#                                 'further.',
#                         'id': 20931234,
#                         'modified': '2021-02-08T14:51:05Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I couldn’t figure out how to get the correct \n'
#             'Information to the coach . Info was limited. They cut you off and '
#             'don’t let you complete your end of the chat.\n'
#             '\n'
#             'My anxiety level is so high and  I just downloaded this app an '
#             'hour ago. But have spent most of the time trying to delete it!!\n'
#             '👎🏻👎🏻👎🏻👎🏻👎🏻',
#   'title': 'The worst.. just got and I’m so stressed out',
#   'userName': 'dancinbecause'},
#  {'date': datetime.datetime(2020, 11, 12, 3, 18, 32),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'It teaches and makes ya laugh.   I’ve tried others with no '
#             'success and now I can’t wait for the next challenge',
#   'title': 'Best APP ever for depression',
#   'userName': 'Ms JoLynn'},
#  {'date': datetime.datetime(2020, 11, 14, 14, 48, 21),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I am enjoying Happify! It is helping me to improve area area of '
#             'my life. I feel happy, healthy and whole.',
#   'title': 'This is great exercise for the mind, body and spirit!',
#   'userName': 'ChinaryK'},
#  {'date': datetime.datetime(2021, 2, 27, 4, 28, 53),
#   'developerResponse': {'body': 'Oh no! We sincerely apologize for the '
#                                 "troubles you've had with the app. We'd be "
#                                 'happy to take a look into this for you, '
#                                 'please contact us at support@happify.com and '
#                                 'provide us the username and email associated '
#                                 'with your account along with the error '
#                                 'message you receive. Thank you!',
#                         'id': 21475917,
#                         'modified': '2021-03-05T16:11:22Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'App will log you out on its own after inactivity, but you can’t '
#             'log back in afterwards. Gives you an error message. Only way to '
#             'log back in is to repeatedly uninstall and reinstall the app. '
#             'What a waste. I was genuinely enjoying the content I’d gotten to '
#             'use so far.',
#   'title': 'No login on app',
#   'userName': 'quack.addict'},
#  {'date': datetime.datetime(2020, 6, 23, 1, 7, 19),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app is a must because anytime you are feeling angry, '
#             'worried, or stressed Happify is there for you!',
#   'title': 'Thank you so much Happify!',
#   'userName': 'balinese kitty'},
#  {'date': datetime.datetime(2020, 5, 8, 16, 52, 14),
#   'developerResponse': {'body': "We're sorry you encountered an issue with the "
#                                 'app. If you email support@happify.com, our '
#                                 'team will assist you in figuring out what the '
#                                 'problem is.',
#                         'id': 15494557,
#                         'modified': '2020-05-22T14:15:35Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I tried it online and enjoyed it, so I downloaded the app. But I '
#             'can’t even get the app to work — hitting any button gives a '
#             'server error, and the one time I managed to get a login screen it '
#             'said my login was incorrect. Useless.',
#   'title': 'Doesn’t work.',
#   'userName': 'AvecGuillotine'}]
# 20

# %%
happify_rvws = happify.reviews
pprint(happify_rvws)
# Out:
# [{'date': datetime.datetime(2020, 3, 27, 13, 9, 49),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve had this app since Beta-testing it a few years ago. I don’t '
#             'typically use apps like this because most don’t seem to have real '
#             'direction or a variety that fits. I let this one sit for a bit '
#             'before coming back to it during a stressful period, and I was '
#             'pleasantly surprised! I like that I can extend my tracks now '
#             'considering I don’t come back here everyday, and the '
#             'personalization is dead on for me! It goes hand in hand with '
#             'where I’ve needed to grow yet lacked a clue where to start. My '
#             'therapist very much approved too! I’ve since “graduated” '
#             'trauma-informed therapy, and this app has helped me in moments '
#             'I’ve needed to simply be reminded of my newer mental toolbox. It '
#             'doesn’t overstep any spiritual boundaries for me either (I’m a '
#             'pastor). Thanks!!!',
#   'title': 'Favorite Self-care App',
#   'userName': 'SolitaryBridge'},
#  {'date': datetime.datetime(2020, 4, 4, 18, 25, 26),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I don’t have access to mental health treatment/therapy but this '
#             'is a good alternative for now. It helps me practice positive '
#             'thinking and being aware of how my thoughts affect my wellbeing. '
#             'Some of the games seem kind of useless but there are other things '
#             'that have helped me a lot.',
#   'title': 'I highly recommend this ap',
#   'userName': 'shaynemoth'},
#  {'date': datetime.datetime(2020, 5, 9, 2, 10, 18),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'It’s helped me lots so far I am feeling better then before I have '
#             'done only one but it’s helped me I am becoming more happier I was '
#             'depressed but now I feel very good about this and think if I do '
#             'more I will not be depressed anymore. I hope it works out for you '
#             'to.',
#   'title': 'I hope it will be god for you',
#   'userName': 'Muhtasom'},
#  {'date': datetime.datetime(2020, 3, 27, 17, 23, 50),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I love this app bc it helps me feel happy and I get to talk to '
#             'some ppl and share pictures and I think that makes me happy to '
#             'havto have have freinds  on here it makes me feel good about '
#             'myself I really do recommend this app',
#   'title': 'This has really helped me not feel as lonely as I did before',
#   'userName': '#rainbow lover'},
#  {'date': datetime.datetime(2021, 1, 3, 4, 35, 4),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app really changed my life. Ive been struggling with my '
#             'borderline personality disorder and extreme anger. This app has '
#             'shown me how to focus on the positive and push past negative '
#             'moods. I still struggle but my life has improved far more than I '
#             'ever expected. Thank you for making this.',
#   'title': 'Wonderful',
#   'userName': 'Krist0n'},
#  {'date': datetime.datetime(2020, 3, 22, 13, 26, 3),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app isn’t pressuring to me, it tells me that I have to work '
#             'at something to get results which is how good things come in '
#             'life. It has helped me out a lot in times of need. Very '
#             'satisfied. Thank you Happify 😊♥️',
#   'title': 'Happy',
#   'userName': 'PeaceLoveJessica'},
#  {'date': datetime.datetime(2020, 11, 7, 13, 52, 1),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I have been struggling with self esteem and depression. This app '
#             'is AMAZING by giving you the tools to change your mindset to '
#             'being a happier individual and goals to focus on. I’m so thankful '
#             'to have found this app!',
#   'title': 'Life changing',
#   'userName': 'Toyotalove_90'},
#  {'date': datetime.datetime(2021, 2, 20, 22, 6, 57),
#   'developerResponse': {'body': 'Oh no! We sincerely apologize for the '
#                                 "troubles you've had with the app. We'd be "
#                                 'happy to take a look into this for you, '
#                                 'please contact us at support@happify.com. '
#                                 'Thank you.',
#                         'id': 21215857,
#                         'modified': '2021-02-22T14:30:01Z'},
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I haven’t been able to use the app because I can’t rest my '
#             'password. I get the rest password email but it takes me to the '
#             'website where there’s nothing there to help me rest my password. '
#             'I’d rather use the app than the website.',
#   'title': 'Rest Password Doesn’t Work',
#   'userName': 'Jus Sayn'},
#  {'date': datetime.datetime(2020, 6, 9, 18, 27, 2),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I found this app at exactly the right time. The activities have '
#             'given me something positive to focus on through these difficult '
#             'times and I’m so grateful I found it!!',
#   'title': 'Love this app❤️',
#   'userName': 'not that dory'},
#  {'date': datetime.datetime(2020, 7, 6, 3, 33, 21),
#   'developerResponse': {'body': "Thank you so much for the review and we're "
#                                 'glad Happify is helping you along on your '
#                                 'wellness journey! We would love to use your '
#                                 'review as a testimonial on Happify. If we '
#                                 'have your permission, please email us at '
#                                 "support@happify.com and we'll let you know a "
#                                 'few other details we would need from you. ',
#                         'id': 16704017,
#                         'modified': '2020-07-17T15:46:18Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I resisted my husband’s suggestion to try Happify for 6 months. '
#             'I’m kicking myself now. It’s really helping me deal with my '
#             'anxiety in between therapy sessions. I’m actually happy for the '
#             'first time in forever.',
#   'title': 'Game changer',
#   'userName': 'Wernicki'},
#  {'date': datetime.datetime(2020, 9, 2, 2, 20, 45),
#   'developerResponse': {'body': "We're sorry you encountered some issues with "
#                                 'our app. If you email us at '
#                                 'support@happify.com, we would like to look '
#                                 'into this issue further.',
#                         'id': 17827494,
#                         'modified': '2020-09-11T13:30:49Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'The first time is used the app after downloading, everything '
#             'worked great. Now every time I try to open it I get an error '
#             'saying “there was an error processing your request.” Only by '
#             'uninstalling and reinstalling the app am I able to log in, but '
#             'then only once because after the app times out I get the same '
#             'error message.',
#   'title': 'Constant issues logging in',
#   'userName': 'unhappifyapp'},
#  {'date': datetime.datetime(2020, 4, 26, 22, 47, 7),
#   'developerResponse': {'body': 'Please contact support@happify.com. You may '
#                                 'have the wrong version of our app and our '
#                                 'team can send you instructions on how to '
#                                 'download the right one.',
#                         'id': 14973458,
#                         'modified': '2020-04-28T18:03:44Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I need to use this app to earn wellness points for work but the '
#             'app on my IPhone 11 will not let me login and just keeps '
#             'circling. Beyond frustrating.',
#   'title': 'Server errors',
#   'userName': 'Deekem'},
#  {'date': datetime.datetime(2020, 8, 12, 5, 34, 37),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I get they have to make money but I don’t have any at all I’m '
#             'young and my anxiety leaves me shaking and trembling on the '
#             'floor. I need an app that I can just open up and use to calm me '
#             'down. Not one that gives me limited options unless I pay',
#   'title': 'Have to pay?',
#   'userName': 'please be reasonable'},
#  {'date': datetime.datetime(2020, 6, 14, 21, 24, 16),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I am enjoy this so far after a couple of weeks.  I really wish '
#             'you’d create a kids version.  🤞🏼',
#   'title': 'So far so good',
#   'userName': 'AngBtmn'},
#  {'date': datetime.datetime(2021, 2, 4, 3, 8, 37),
#   'developerResponse': {'body': "We're sorry you encountered issues with our "
#                                 'app. You may email us at support@happify.com, '
#                                 'we would like to look into this issue '
#                                 'further.',
#                         'id': 20931234,
#                         'modified': '2021-02-08T14:51:05Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I couldn’t figure out how to get the correct \n'
#             'Information to the coach . Info was limited. They cut you off and '
#             'don’t let you complete your end of the chat.\n'
#             '\n'
#             'My anxiety level is so high and  I just downloaded this app an '
#             'hour ago. But have spent most of the time trying to delete it!!\n'
#             '👎🏻👎🏻👎🏻👎🏻👎🏻',
#   'title': 'The worst.. just got and I’m so stressed out',
#   'userName': 'dancinbecause'},
#  {'date': datetime.datetime(2020, 11, 12, 3, 18, 32),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'It teaches and makes ya laugh.   I’ve tried others with no '
#             'success and now I can’t wait for the next challenge',
#   'title': 'Best APP ever for depression',
#   'userName': 'Ms JoLynn'},
#  {'date': datetime.datetime(2020, 11, 14, 14, 48, 21),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I am enjoying Happify! It is helping me to improve area area of '
#             'my life. I feel happy, healthy and whole.',
#   'title': 'This is great exercise for the mind, body and spirit!',
#   'userName': 'ChinaryK'},
#  {'date': datetime.datetime(2021, 2, 27, 4, 28, 53),
#   'developerResponse': {'body': 'Oh no! We sincerely apologize for the '
#                                 "troubles you've had with the app. We'd be "
#                                 'happy to take a look into this for you, '
#                                 'please contact us at support@happify.com and '
#                                 'provide us the username and email associated '
#                                 'with your account along with the error '
#                                 'message you receive. Thank you!',
#                         'id': 21475917,
#                         'modified': '2021-03-05T16:11:22Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'App will log you out on its own after inactivity, but you can’t '
#             'log back in afterwards. Gives you an error message. Only way to '
#             'log back in is to repeatedly uninstall and reinstall the app. '
#             'What a waste. I was genuinely enjoying the content I’d gotten to '
#             'use so far.',
#   'title': 'No login on app',
#   'userName': 'quack.addict'},
#  {'date': datetime.datetime(2020, 6, 23, 1, 7, 19),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app is a must because anytime you are feeling angry, '
#             'worried, or stressed Happify is there for you!',
#   'title': 'Thank you so much Happify!',
#   'userName': 'balinese kitty'},
#  {'date': datetime.datetime(2020, 5, 8, 16, 52, 14),
#   'developerResponse': {'body': "We're sorry you encountered an issue with the "
#                                 'app. If you email support@happify.com, our '
#                                 'team will assist you in figuring out what the '
#                                 'problem is.',
#                         'id': 15494557,
#                         'modified': '2020-05-22T14:15:35Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I tried it online and enjoyed it, so I downloaded the app. But I '
#             'can’t even get the app to work — hitting any button gives a '
#             'server error, and the one time I managed to get a login screen it '
#             'said my login was incorrect. Useless.',
#   'title': 'Doesn’t work.',
#   'userName': 'AvecGuillotine'}]

# %%
for rvw in happify_rvws:
    rvw['app_name'] = 'happify-for-stress-worry'
    rvw['app_id'] = 730601963
    
pprint(happify_rvws)
# Out:
# [{'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 3, 27, 13, 9, 49),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve had this app since Beta-testing it a few years ago. I don’t '
#             'typically use apps like this because most don’t seem to have real '
#             'direction or a variety that fits. I let this one sit for a bit '
#             'before coming back to it during a stressful period, and I was '
#             'pleasantly surprised! I like that I can extend my tracks now '
#             'considering I don’t come back here everyday, and the '
#             'personalization is dead on for me! It goes hand in hand with '
#             'where I’ve needed to grow yet lacked a clue where to start. My '
#             'therapist very much approved too! I’ve since “graduated” '
#             'trauma-informed therapy, and this app has helped me in moments '
#             'I’ve needed to simply be reminded of my newer mental toolbox. It '
#             'doesn’t overstep any spiritual boundaries for me either (I’m a '
#             'pastor). Thanks!!!',
#   'title': 'Favorite Self-care App',
#   'userName': 'SolitaryBridge'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 4, 4, 18, 25, 26),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I don’t have access to mental health treatment/therapy but this '
#             'is a good alternative for now. It helps me practice positive '
#             'thinking and being aware of how my thoughts affect my wellbeing. '
#             'Some of the games seem kind of useless but there are other things '
#             'that have helped me a lot.',
#   'title': 'I highly recommend this ap',
#   'userName': 'shaynemoth'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 5, 9, 2, 10, 18),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'It’s helped me lots so far I am feeling better then before I have '
#             'done only one but it’s helped me I am becoming more happier I was '
#             'depressed but now I feel very good about this and think if I do '
#             'more I will not be depressed anymore. I hope it works out for you '
#             'to.',
#   'title': 'I hope it will be god for you',
#   'userName': 'Muhtasom'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 3, 27, 17, 23, 50),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I love this app bc it helps me feel happy and I get to talk to '
#             'some ppl and share pictures and I think that makes me happy to '
#             'havto have have freinds  on here it makes me feel good about '
#             'myself I really do recommend this app',
#   'title': 'This has really helped me not feel as lonely as I did before',
#   'userName': '#rainbow lover'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2021, 1, 3, 4, 35, 4),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app really changed my life. Ive been struggling with my '
#             'borderline personality disorder and extreme anger. This app has '
#             'shown me how to focus on the positive and push past negative '
#             'moods. I still struggle but my life has improved far more than I '
#             'ever expected. Thank you for making this.',
#   'title': 'Wonderful',
#   'userName': 'Krist0n'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 3, 22, 13, 26, 3),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app isn’t pressuring to me, it tells me that I have to work '
#             'at something to get results which is how good things come in '
#             'life. It has helped me out a lot in times of need. Very '
#             'satisfied. Thank you Happify 😊♥️',
#   'title': 'Happy',
#   'userName': 'PeaceLoveJessica'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 11, 7, 13, 52, 1),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I have been struggling with self esteem and depression. This app '
#             'is AMAZING by giving you the tools to change your mindset to '
#             'being a happier individual and goals to focus on. I’m so thankful '
#             'to have found this app!',
#   'title': 'Life changing',
#   'userName': 'Toyotalove_90'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2021, 2, 20, 22, 6, 57),
#   'developerResponse': {'body': 'Oh no! We sincerely apologize for the '
#                                 "troubles you've had with the app. We'd be "
#                                 'happy to take a look into this for you, '
#                                 'please contact us at support@happify.com. '
#                                 'Thank you.',
#                         'id': 21215857,
#                         'modified': '2021-02-22T14:30:01Z'},
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I haven’t been able to use the app because I can’t rest my '
#             'password. I get the rest password email but it takes me to the '
#             'website where there’s nothing there to help me rest my password. '
#             'I’d rather use the app than the website.',
#   'title': 'Rest Password Doesn’t Work',
#   'userName': 'Jus Sayn'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 6, 9, 18, 27, 2),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I found this app at exactly the right time. The activities have '
#             'given me something positive to focus on through these difficult '
#             'times and I’m so grateful I found it!!',
#   'title': 'Love this app❤️',
#   'userName': 'not that dory'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 7, 6, 3, 33, 21),
#   'developerResponse': {'body': "Thank you so much for the review and we're "
#                                 'glad Happify is helping you along on your '
#                                 'wellness journey! We would love to use your '
#                                 'review as a testimonial on Happify. If we '
#                                 'have your permission, please email us at '
#                                 "support@happify.com and we'll let you know a "
#                                 'few other details we would need from you. ',
#                         'id': 16704017,
#                         'modified': '2020-07-17T15:46:18Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I resisted my husband’s suggestion to try Happify for 6 months. '
#             'I’m kicking myself now. It’s really helping me deal with my '
#             'anxiety in between therapy sessions. I’m actually happy for the '
#             'first time in forever.',
#   'title': 'Game changer',
#   'userName': 'Wernicki'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 9, 2, 2, 20, 45),
#   'developerResponse': {'body': "We're sorry you encountered some issues with "
#                                 'our app. If you email us at '
#                                 'support@happify.com, we would like to look '
#                                 'into this issue further.',
#                         'id': 17827494,
#                         'modified': '2020-09-11T13:30:49Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'The first time is used the app after downloading, everything '
#             'worked great. Now every time I try to open it I get an error '
#             'saying “there was an error processing your request.” Only by '
#             'uninstalling and reinstalling the app am I able to log in, but '
#             'then only once because after the app times out I get the same '
#             'error message.',
#   'title': 'Constant issues logging in',
#   'userName': 'unhappifyapp'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 4, 26, 22, 47, 7),
#   'developerResponse': {'body': 'Please contact support@happify.com. You may '
#                                 'have the wrong version of our app and our '
#                                 'team can send you instructions on how to '
#                                 'download the right one.',
#                         'id': 14973458,
#                         'modified': '2020-04-28T18:03:44Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I need to use this app to earn wellness points for work but the '
#             'app on my IPhone 11 will not let me login and just keeps '
#             'circling. Beyond frustrating.',
#   'title': 'Server errors',
#   'userName': 'Deekem'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 8, 12, 5, 34, 37),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I get they have to make money but I don’t have any at all I’m '
#             'young and my anxiety leaves me shaking and trembling on the '
#             'floor. I need an app that I can just open up and use to calm me '
#             'down. Not one that gives me limited options unless I pay',
#   'title': 'Have to pay?',
#   'userName': 'please be reasonable'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 6, 14, 21, 24, 16),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I am enjoy this so far after a couple of weeks.  I really wish '
#             'you’d create a kids version.  🤞🏼',
#   'title': 'So far so good',
#   'userName': 'AngBtmn'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2021, 2, 4, 3, 8, 37),
#   'developerResponse': {'body': "We're sorry you encountered issues with our "
#                                 'app. You may email us at support@happify.com, '
#                                 'we would like to look into this issue '
#                                 'further.',
#                         'id': 20931234,
#                         'modified': '2021-02-08T14:51:05Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I couldn’t figure out how to get the correct \n'
#             'Information to the coach . Info was limited. They cut you off and '
#             'don’t let you complete your end of the chat.\n'
#             '\n'
#             'My anxiety level is so high and  I just downloaded this app an '
#             'hour ago. But have spent most of the time trying to delete it!!\n'
#             '👎🏻👎🏻👎🏻👎🏻👎🏻',
#   'title': 'The worst.. just got and I’m so stressed out',
#   'userName': 'dancinbecause'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 11, 12, 3, 18, 32),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'It teaches and makes ya laugh.   I’ve tried others with no '
#             'success and now I can’t wait for the next challenge',
#   'title': 'Best APP ever for depression',
#   'userName': 'Ms JoLynn'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 11, 14, 14, 48, 21),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I am enjoying Happify! It is helping me to improve area area of '
#             'my life. I feel happy, healthy and whole.',
#   'title': 'This is great exercise for the mind, body and spirit!',
#   'userName': 'ChinaryK'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2021, 2, 27, 4, 28, 53),
#   'developerResponse': {'body': 'Oh no! We sincerely apologize for the '
#                                 "troubles you've had with the app. We'd be "
#                                 'happy to take a look into this for you, '
#                                 'please contact us at support@happify.com and '
#                                 'provide us the username and email associated '
#                                 'with your account along with the error '
#                                 'message you receive. Thank you!',
#                         'id': 21475917,
#                         'modified': '2021-03-05T16:11:22Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'App will log you out on its own after inactivity, but you can’t '
#             'log back in afterwards. Gives you an error message. Only way to '
#             'log back in is to repeatedly uninstall and reinstall the app. '
#             'What a waste. I was genuinely enjoying the content I’d gotten to '
#             'use so far.',
#   'title': 'No login on app',
#   'userName': 'quack.addict'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 6, 23, 1, 7, 19),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This app is a must because anytime you are feeling angry, '
#             'worried, or stressed Happify is there for you!',
#   'title': 'Thank you so much Happify!',
#   'userName': 'balinese kitty'},
#  {'app_id': 730601963,
#   'app_name': 'happify-for-stress-worry',
#   'date': datetime.datetime(2020, 5, 8, 16, 52, 14),
#   'developerResponse': {'body': "We're sorry you encountered an issue with the "
#                                 'app. If you email support@happify.com, our '
#                                 'team will assist you in figuring out what the '
#                                 'problem is.',
#                         'id': 15494557,
#                         'modified': '2020-05-22T14:15:35Z'},
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I tried it online and enjoyed it, so I downloaded the app. But I '
#             'can’t even get the app to work — hitting any button gives a '
#             'server error, and the one time I managed to get a login screen it '
#             'said my login was incorrect. Useless.',
#   'title': 'Doesn’t work.',
#   'userName': 'AvecGuillotine'}]

# %%
happify
# Out:
# AppStore(country='us', app_name='happify-for-stress-worry', app_id=730601963)

# %%
happify.app_id
# Out:
# 730601963

# %%
happify.app_name
# Out:
# 'happify-for-stress-worry'

# %%
happify.review
# Out:
# <bound method Base.review of AppStore(country='us', app_name='happify-for-stress-worry', app_id=730601963)>

# %%
happify.url
# Out:
# 'https://apps.apple.com/us/app/happify-for-stress-worry/id730601963'

# %%
## Test obtaining all Aloe Bud reviews
aloe_bud = AppStore(country='us', app_name='aloe-bud')
aloe_bud.review(after=dt.datetime(2020, 2, 28))

# pprint(aloe_bud.reviews)
pprint(aloe_bud.reviews_count)
# Out:
# 2021-03-15 13:36:42,259 [INFO] Base - Searching for app id
# 2021-03-15 13:36:44,290 [INFO] Base - Initialised: AppStore('us', 'aloe-bud', 1318382054)
# 2021-03-15 13:36:44,291 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/aloe-bud/id1318382054
# 2021-03-15 13:37:19,716 [INFO] Base - [id:1318382054] Fetched 20 reviews (20 fetched in total)
# 2021-03-15 13:37:21,524 [INFO] Base - [id:1318382054] Fetched 73 reviews (73 fetched in total)
# 73

# %%
## Test obtaining all Aloe Bud reviews
aloe_bud = AppStore(country='us', app_name='aloe-bud')
aloe_bud.review(how_many=20000, after=dt.datetime(2020, 2, 28))

# pprint(aloe_bud.reviews)
pprint(aloe_bud.reviews_count)
# Out:
# 2021-03-15 14:06:42,008 [INFO] Base - Searching for app id
# 2021-03-15 14:06:44,069 [INFO] Base - Initialised: AppStore('us', 'aloe-bud', 1318382054)
# 2021-03-15 14:06:44,070 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/aloe-bud/id1318382054
# 2021-03-15 14:06:45,940 [INFO] Base - [id:1318382054] Fetched 73 reviews (73 fetched in total)
# 73

# %%
## Test obtaining all MindDoc reviews
minddoc = AppStore(country='us', app_name='moodpath-depression-anxiety')
minddoc.review(after=dt.datetime(2020, 2, 28))

pprint(minddoc.reviews_count)
# Out:
# 2021-03-15 15:11:30,833 [INFO] Base - Searching for app id
# 2021-03-15 15:11:35,574 [INFO] Base - Initialised: AppStore('us', 'moodpath-depression-anxiety', 1052216403)
# 2021-03-15 15:11:35,576 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/moodpath-depression-anxiety/id1052216403
# 2021-03-15 15:11:54,271 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/us/apps/1052216403/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2021-03-15 15:11:54,277 [INFO] Base - [id:1052216403] Fetched 0 reviews (0 fetched in total)
# 0

# %%
pprint(minddoc.reviews[:5])
# Out:
# [{'date': datetime.datetime(2020, 9, 22, 20, 27, 42),
#   'isEdited': False,
#   'rating': 4,
#   'review': '4.3\n'
#             'This app has a lot of useful information to help people '
#             'understand the thoughts in their head. With great information on '
#             'what depression is, the symptoms, and the treatment that all are '
#             'based on factual information that I have learned in my college '
#             'psychology classes. This app, developed by a group of experts in '
#             'psychology can be used for many different things like keeping '
#             'track of how you felt on a certain day as it gives you reminders '
#             'to get into the app and let them know how you feel every morning, '
#             'evening and night. You also will receive and assessment every 14 '
#             'days of your emotional health that is based off your daily '
#             'journal. This process repeats itself so you are able to track '
#             'your progress. I am a big fan of the different “courses” that you '
#             'can take and learn about that also give you exercises to help '
#             'with what you learned in that course. There is a lot of upside to '
#             'this app and it can feel like and easier route then actually '
#             'seeing a psychologist especially with the scientific accuracy and '
#             'detail this app can give. But, I wouldn’t substitute it for a '
#             'real psychologist especially if you are experiencing severe '
#             'symptoms. But overall this is a great app to help you log how you '
#             'feel and learn information about depression that you would be '
#             'able to learn in a psychology class.',
#   'title': 'Solid app with very helpful information',
#   'userName': 'C,Isaac'},
#  {'date': datetime.datetime(2020, 3, 12, 21, 0, 9),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I really value this app for requiring me to check in with myself '
#             'and recognize how I’m feeling. It has been invaluable for that, '
#             'because otherwise I just won’t and then wonder why I’m suddenly '
#             'spiraling into depression. \n'
#             'That said, I wish this app saved data to my phone. If I’m not on '
#             'WiFi and have to use my subpar carrier’s data instead, I have a '
#             'mini-panic when I open the app and don’t see the months of mood '
#             'logging I’ve done, because it apparently isn’t stored on my '
#             'phone, but (I’m guessing) on their servers or cloud or whatever. '
#             'Along the same line, if I have to connect over my carrier’s data '
#             'instead of WiFi, it will take FOREVER to load. I’ll get the '
#             'notification that it’s time to answer questions, but then the '
#             'questions will take a few minutes because they aren’t already on '
#             'my phone. \n'
#             'There are sometimes other issues where if I decide to answer '
#             'questions a little bit before the time I’m supposed to, it '
#             'doesn’t save my responses and instead, asks me again. These '
#             'issues seem tied to just having that information stored in the '
#             'app but on the phone, but I’m no engineer. All I know is I like '
#             'this app but I wish there were other features or storage options '
#             'that wouldn’t give me a panic or make me agitated when I’m in an '
#             'otherwise good mood.',
#   'title': 'Needs Some Features',
#   'userName': 'Arielle_E_'},
#  {'date': datetime.datetime(2020, 9, 17, 3, 57, 51),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'I was really excited about this app at first, but after two '
#             'months, it became just an annoyance. It asks about 3 questions '
#             "from a small set of questions every day. It doesn't ask any "
#             'questions to determine if the way you are feeling is due to '
#             "stress. It doesn't address anxiety (even though it says it does "
#             'in the description). The "how are you feeling" section at the end '
#             "of the questions is arbitrary, doesn't get monitored or "
#             "considered in your report at all. The insights it gives aren't "
#             'helpful. When you are "having a mild depressive episode" it '
#             'basically just tells you to just be happy.....I am giving it 3 '
#             'stars because the way the app is set up has lots of potential to '
#             'be so thing good. But for the amount of time you give it each '
#             "day, you don't get much useful out of it. But is free and you get "
#             'what you pay for.\n'
#             'I would be willing to pay a monthly subscription to this app if '
#             'they expanded their data collections and analyzing, even if they '
#             'didn\'t give a "fix it" insight, though I\'d be willing to pay '
#             'more if it had actually helpful tips to overcoming the problems '
#             "it finds.....so it's not bad, but it's still in the baby phases "
#             'of a becoming a great app. I deleted it for now. I may revisit it '
#             'next year to see if things have improved.',
#   'title': 'It leaves a lot to be desired',
#   'userName': 'True Critic Reviews'},
#  {'date': datetime.datetime(2021, 2, 1, 19, 41, 43),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'According to Moretti and Peled, depression is one of the most '
#             'common issues of adolescence (2004). Adults experience a clarity '
#             'of adolescent memories referred to as the reminiscence bump, '
#             'likely the result of many firsts during this developmental stage '
#             '(Steinberg, 2014); journaling and clarifying thoughts and '
#             'emotions on these firsts can help in reflection and '
#             'self-assurance. Additionally, Steinberg addresses the three R’s '
#             'of adolescent brain development: reward, relationships, and '
#             'regulation (2014). MindDoc would be helpful while the adolescent '
#             'brain is in this stage of neuroplasticity; its design initiates '
#             'reward-seeking behavior of completing tasks, and the '
#             'acknowledgement of positive and negative emotions can help a teen '
#             'learn to self-regulate. If a teen can recognize a pattern in '
#             'their manic or depressive symptoms, they should be able to '
#             'project that interpretation into their future and hopefully avoid '
#             'or at least curb any risky behavior. While this app states that '
#             'it is appropriate for ages twelve and above, it may be best for '
#             'adolescents sixteen and older, during the time that their brains '
#             'are better attuned to problem solving and abstract thought '
#             '(Moretti & Peled, 2004).',
#   'title': 'Great for teens and young adults',
#   'userName': 'ShelbyinSOWK615'},
#  {'date': datetime.datetime(2020, 7, 25, 18, 8, 58),
#   'developerResponse': {'body': 'We really appreciate your comment, because '
#                                 'feedback like yours helps us to improve '
#                                 'Moodpath. It is a good thing that you trust '
#                                 'your own instincts when you know that the '
#                                 "result doesn't reflect your full story. "
#                                 'Having said that, we are concerned about you '
#                                 'and would like to offer you getting in touch '
#                                 'with us at\xa0info@moodpath.de. The National '
#                                 'Suicide Prevention Lifeline also offers great '
#                                 'support in times of crisis: +18002738255.  It '
#                                 'does help reaching out and speaking to '
#                                 'someone you trust. Please do so and take '
#                                 'care. You deserve support.\n'
#                                 '\n'
#                                 'Update: We do believe that you deserve our '
#                                 'support and would like to emphasise that the '
#                                 'offer still stands. We really hope you '
#                                 'consider reaching out to us in case you feel '
#                                 'the mood building up again. ',
#                         'id': 16896434,
#                         'modified': '2020-07-27T10:30:41Z'},
#   'isEdited': False,
#   'rating': 4,
#   'review': 'My first insight gave me a severe depressive episode. My second '
#             'insight gave me a moderate depressive episode. The last two weeks '
#             'were significantly worse for me than the previous two weeks, so '
#             'I’ve been using vodka to numb my emotions. I tried to end my life '
#             'because I feel so much worse, but apparently my depressive '
#             'episode was better based on their questions. I think the moods '
#             'should be taken into consideration better.  Just because I use '
#             'alcohol to soften my depressive symptoms doesn’t mean I’m getting '
#             'better. Either way, this app is a great way to track moods. I '
#             'really like it for that, but I think more questions should be '
#             'asked in a day. I answered no for crying more often, no for '
#             'having slowed movements, but I did try to hang myself that night '
#             'because I felt so depressed. It didn’t take that into '
#             'consideration. \n'
#             'Update: I don’t need to get in touch with anyone. I don’t deserve '
#             'help. Thanks to this app I know I’ll do something dangerous after '
#             'multiple days of answering with a very bad mood only.',
#   'title': 'Not accurate if you use alcohol to alter your mood',
#   'userName': 'Regalbeanie'}]

# %%
app_df = pd.read_csv('Data/mha_app_info.csv')
app_df.head()
# Out:
#         app_name  iOS  iOS_revs                  iOS_app_name  iOS_app_id  \
# 0       Aloe Bud    1      3000                      aloe-bud  1318382054
# 1           Aura    1     22100         aura-meditation-sleep  1114223104
# 2     BetterHelp    1     32400  betterhelp-online-counseling   995252384
# 3  Breathe2Relax    1       200                 breathe2relax   425720246
# 4           Calm    1   1200000                          calm   571800810
#
#    android  android_revs               android_appID
# 0        0             0                         NaN
# 1        1         10400              com.aurahealth
# 2        1         15300              com.betterhelp
# 3        1          1100  org.t2health.breathe2relax
# 4        1        352500            com.calm.android

# %%
## Store list of app ids to loop through for google play
google_play_apps = app_df.copy()
google_play_apps = google_play_apps.loc[google_play_apps['android']==1]

google_play_names = list(google_play_apps['app_name'])
google_play_ids = list(google_play_apps['android_appID'])

# %%
google_play_names
# Out:
# ['Aura',
#  'BetterHelp',
#  'Breathe2Relax',
#  'Calm',
#  'CBT Thought Diary',
#  'DBT Coach',
#  'eMoods',
#  'eQuoo: Emotional Fitness Game',
#  'Fabulous',
#  'GG OCD',
#  'GG Self Care',
#  'GG Self Esteem',
#  'Ginger',
#  'Habitica',
#  'Happify',
#  'Happyfeed',
#  'Headspace',
#  'Healthy Minds Program',
#  'HearMe',
#  'I Am Sober',
#  'Insight Timer',
#  'Lyf',
#  'MindDoc',
#  'MindShift CBT',
#  'Moodfit',
#  'MoodMission',
#  'MyLife Meditation',
#  'NOCD',
#  'PTSD Coach',
#  'Reflectly',
#  'Remente',
#  'Rise Up + Recover',
#  'Rootd',
#  'RR Eating Disorder Management',
#  'Sanvello',
#  'Shine',
#  'Smiling Mind',
#  'SuperBetter',
#  'Talk Life',
#  'Talkspace',
#  'Ten Percent Happier',
#  'The Mighty',
#  'Virtual Hope Box',
#  "What's Up?",
#  'Wisdo',
#  'Woebot',
#  'Wysa']

# %%
google_play_ids
# Out:
# ['com.aurahealth',
#  'com.betterhelp',
#  'org.t2health.breathe2relax',
#  'com.calm.android',
#  'com.moodtools.cbtassistant.app',
#  'co.swasth.dbtcoach',
#  'my.tracker',
#  'com.bitbox.equoo',
#  'co.thefabulous.app',
#  'air.com.samuramu.gg.oc',
#  'com.ggtude.life',
#  'air.com.samuramu.gg.se',
#  'com.ginger',
#  'com.habitrpg.android.habitica',
#  'com.happify.happifyinc',
#  'com.happyfeed',
#  'com.getsomeheadspace.android',
#  'com.healthyminds',
#  'com.hearme',
#  'com.thehungrywasp.iamsober',
#  'com.spotlightsix.zentimerlite2',
#  'com.incogo.android',
#  'de.moodpath.android',
#  'com.bstro.MindShift',
#  'com.robleridge.Moodfit',
#  'com.moodmission.moodmissionapp',
#  'org.stopbreathethink.app',
#  'com.treatmyocd.nocd',
#  'is.vertical.ptsdcoach',
#  'com.reflectlyApp',
#  'com.remente.app',
#  'com.rur',
#  'com.rootd',
#  'com.recoveryrecord',
#  'com.pacificalabs.pacifica',
#  'com.shinetext.shine',
#  'com.smilingmind.app',
#  'com.superbetter.paid',
#  'com.bearpty.talklife',
#  'com.talkspace.talkspaceapp',
#  'com.changecollective.tenpercenthappier',
#  'com.themighty',
#  'com.t2.vhb',
#  'com.jacksontempra.apps.whatsup',
#  'com.wisdo.android.wisdo',
#  'com.woebot',
#  'bot.touchkin']

# %%
google_play_reviews = []

for app_name, app_id in zip(google_play_names, google_play_ids):
    print(f'Scraping {app_name}')
    rvws, _ = reviews(
        app_id,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
    )
    for r in rvws:
        r['app_name'] = app_name
        r['app_id'] = app_id
    google_play_reviews.extend(rvws)
# Out:
# Scraping Aura
# Scraping BetterHelp
# Scraping Breathe2Relax
# Scraping Calm
# Scraping CBT Thought Diary
# Scraping DBT Coach
# Scraping eMoods
# Scraping eQuoo: Emotional Fitness Game
# Scraping Fabulous
# Scraping GG OCD
# Scraping GG Self Care
# Scraping GG Self Esteem
# Scraping Ginger
# Scraping Habitica
# Scraping Happify
# Scraping Happyfeed
# Scraping Headspace
# Scraping Healthy Minds Program
# Scraping HearMe
# Scraping I Am Sober
# Scraping Insight Timer
# Scraping Lyf
# Scraping MindDoc
# Scraping MindShift CBT
# Scraping Moodfit
# Scraping MoodMission
# Scraping MyLife Meditation
# Scraping NOCD
# Scraping PTSD Coach
# Scraping Reflectly
# Scraping Remente
# Scraping Rise Up + Recover
# Scraping Rootd
# Scraping RR Eating Disorder Management
# Scraping Sanvello
# Scraping Shine
# Scraping Smiling Mind
# Scraping SuperBetter
# Scraping Talk Life
# Scraping Talkspace
# Scraping Ten Percent Happier
# Scraping The Mighty
# Scraping Virtual Hope Box
# Scraping What's Up?
# Scraping Wisdo
# Scraping Woebot
# Scraping Wysa

# %%
google_play_reviews
# Out:
# [{'reviewId': 'gp:AOqpTOFEiK76RQn3IT_l33057YhZTiJG5-2CHqSjhauOejF0A4xhQaXgsTB7y7fJ-5cTHU6AGAILiH9RhMRj-A',
#   'userName': 'Brieanna Leader',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhHzKkmb3aS4KAb3KXHZgGzCeYwODM6W9Tnc4OF',
#   'content': 'This app is a great way to express your thoughts and helps you release tension',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 15, 12, 57, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGvtXXTIO5iLmumGGEWYEoSHsf9bnR9CIqVeVLv44VPx4rCzC_GVTRzVDtBGZU_sikVfAGVYLhcIOajYQ',
#   'userName': 'Raelene Bennett',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi_cpxVv0tzDVfPXMIBkRcFPOWGcRiyDJTSuhJf',
#   'content': 'Easy to use short and practical',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 14, 14, 19, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEsycUO6F1EtiLx-Lc4JQYizxEEVfQz3DeVScNYHbclN8g_9rKfaUtV6kJDmOfOTHLcz-Mmn9ihPO-jww',
#   'userName': 'adam rivera',
#   'userImage': 'https://play-lh.googleusercontent.com/-_etwUFTXXPU/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckmvrohdE2ZVtJbiilZkFVqCpKLmA/photo.jpg',
#   'content': 'The greatest! Feeling',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 13, 19, 57, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOG82BmVA1oTLV3Hjjhol7CfnTD6Uq-KTlWVaYwydS0eVOyik4a54stfQg2_9ip1Usazci2aQ93C9TJF4w',
#   'userName': 'Jeanne Macdonald',
#   'userImage': 'https://play-lh.googleusercontent.com/-M5HNH1cmtY4/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclKvFsEMeq-pcebJCZ3RKqdX0HRdw/photo.jpg',
#   'content': 'It has a beautiful flowing qualify.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 13, 16, 30, 24),
#   'replyContent': 'Thank you very much for your 5-star review!!! Have a great day :)',
#   'repliedAt': datetime.datetime(2021, 3, 9, 18, 47, 18),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFN12XjpLAb9-RRn516nLYqnT2RPdh06u774Xn1vGsM4_iCZo4AtaRiIdT--REKB6Ylt1ShExZ_KaM6FA',
#   'userName': 'Christina Reeves',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgTlXr7zd30gkC5L6FMJ-fUietzmvEeWbhmbB5F_w',
#   'content': '👍👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 13, 13, 46, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHPJBUR3Cv4Cxk44mxaysR_XEJegkY5X27QJOUJbnFTfhP-qbqpggCb5jvoMe-306jPGCa2Q_xNEx6Qfg',
#   'userName': 'Franklin cruz',
#   'userImage': 'https://play-lh.googleusercontent.com/-FpvcB0YSS90/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckMnJlnfoJA-sshOMrbIPt3JTTaFA/photo.jpg',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 13, 8, 11, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHk2pycI8_boZYhRM5H8EhbVSPNbmCggT02TliKzjEJSk52IstI2EJ_66O0fvr8BpPODjpd05XrWB_MBQ',
#   'userName': 'Buy indian hair Wholesale Hair extensions',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghn1wIBg8MwUtwnjxazmtnqtggT7NZyihOi4Jk-fw',
#   'content': 'Great calm',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 12, 18, 9, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOG-DjZHo5hyR8BZMTQIjIcIhM2H4ZQqUod_T2oJVnDjhz_cPPbc2JAORNyyk9TZj377xdRNsTEuDTZabg',
#   'userName': 'Sometimes Always',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhRdowiLXDfASv5M4gVijcxmSHrusEt9Jr2_6b8ww',
#   'content': 'I\'ve tried several mindfulness apps, all the bug ones, but I think this is the most comprehensive for my needs. I highly recommend for mom\'s on-the-go (once we\'re back from Covid). So glad to have this in my positive habit arsenal before the transition "back to normal".',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 9, 9, 23, 5),
#   'replyContent': "Hi! Thank you for the 5-star rating and wonderful review. We're so glad Aura has been a great fit for your needs. We get us every day because of awesome people like you. If you have suggestions or other feedback, don't hesitate to email us at hello@aurahealth.io. Take care! :)",
#   'repliedAt': datetime.datetime(2021, 3, 9, 18, 38, 11),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOH_El3BRtKopDwKD60JCoVwHmjKvpRt5JHhLd_nhOv6SGh9tsCLfFrHF1TiDIw9GYUFF75VSJB8xtzlKA',
#   'userName': 'Howard Bradford',
#   'userImage': 'https://play-lh.googleusercontent.com/-K1bPUGR9lrQ/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclCTi9TIJJ5-YKN-_ixy-Ori1TdGg/photo.jpg',
#   'content': 'Great for mindfulness',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 6, 11, 27, 32),
#   'replyContent': 'Hi Howard! Thanks for the 5-star rating. If there is anything we can do for you, just let us know at hello@aurahealth.io!\nHave a wonderful day!',
#   'repliedAt': datetime.datetime(2021, 3, 9, 18, 48, 6),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE0IDltJ8XM5EMh0DfSaS62TDUnE5DiAeNZKP3swVuSVrNXDSqbIsgxX18rUGwBpWPmnInGsW5KZT29og',
#   'userName': 'Karen Leftige',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GihkcnmLbDARxeDuHMD2vdHuS0NSYMdNFWz4QYKzPg',
#   'content': 'Brand new, but I am enjoying the choices.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 5, 13, 40, 10),
#   'replyContent': "Hi Karen! Thank you for your feedback. So glad you are enjoying Aura's content. If you need any help, please don't hesitate to email us at hello@aurahealth.io. Take care! :)",
#   'repliedAt': datetime.datetime(2021, 3, 9, 18, 51, 11),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEkIKCBkwdnMVIAuogR2t1CNTzcKgJp3_gftDkYC-RrDLkbsJe0s7iE-5VUbjdgoNv2u5rTXC2ZSQKz3w',
#   'userName': 'Erika Knapp',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh0cGcd4FADmLntpl9-YjVrrBYE8H_aTAy_tQyWUw',
#   'content': 'Cancelled same day free trial started and they decided to randomly charge my card for a year subscription when the app isnt even on my phone anymore',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 3, 5, 1, 10, 46),
#   'replyContent': "Hi Erika! You shouldn't be charged onset. It might have been a test charge or temporary hold. If you were able to cancel the subscription, it should be removed from your pending charges after a few days. Please don't hesitate to email us at hello@aurahealth.io if you have questions or if you need assitance. We'll be glad to help. Thank you!",
#   'repliedAt': datetime.datetime(2021, 3, 9, 18, 28, 20),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGL_ZgrDcjtme1rDRyHvSHL4msIpQgmlhuwliGt769wRYoeNAD50D-g2Dii7CTx9QrHZx7SIN-phTJBxA',
#   'userName': 'Jennifer Dryden',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghq3o53v2M9fCYKkxh_q-L4008Z3BrQiI1uPyfG',
#   'content': 'Love it!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 3, 9, 47, 5),
#   'replyContent': 'Thank you so much, Jennifer. Glad you love it! :)',
#   'repliedAt': datetime.datetime(2021, 3, 9, 18, 52, 14),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOECXvRztecWAAdPXJy9uTWbJWVkzAgejLFyfXtcPKS1iAKCV-JExamrYuNhJOLP2zSJAOAuR43JYsws4w',
#   'userName': 'Lucy Moorhead',
#   'userImage': 'https://play-lh.googleusercontent.com/-3QjAMqBL_C0/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckAKqL2zXHo-8ujR1wZkfNvTGrgrg/photo.jpg',
#   'content': 'Fantastic app. It reminds me to check in and be happy and calm. Helping me on my road to recovery. Thanks Aura for having my back x',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 3, 9, 2, 39),
#   'replyContent': "Hi Lucy! Thanks for your 5-star review. We're glad Aura is having such a positive impact. We get up every day because of awesome people like you! If you any other feedback or suggestions in the future, please let us know at hello@aurahealth.io. Thank you!",
#   'repliedAt': datetime.datetime(2021, 3, 10, 17, 51, 49),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHWvSfQUT7yW9PTOIdnc3VglLiSrE9Qc92w8UkRLCqoZ63rA2YegpD1P-gNg6Vi5_8h1ZTSgoFp9Zs6Xg',
#   'userName': 'Ajay Pranav',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggl1mAcpUnXc5r2Wx7UYtx5cXGAv7dVIFxs6lzPiA',
#   'content': 'Starting the meditation bit by bit',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 1, 4, 51, 10),
#   'replyContent': 'Thank you, Ajay! :) If you have any suggestions, please let us know at hello@aurahealth.io. It would help us to continue improving Aura.',
#   'repliedAt': datetime.datetime(2021, 3, 3, 22, 24, 34),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEbPToPY_xLjEykldw6sGshkSnX9yQB2LJteD2A59hY-tGXbg5s-d9qyjIodUNt11oM9Xe6LZO7pgYgOA',
#   'userName': 'Stephanie A Geyer',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhcBigNO97KapKA3pzWW6VVmaojcNfV5LRMUp_a',
#   'content': 'I just installed and am not impressed. Extremely limited for first time users. Going to uninstall and switch back to the app I used before because they have more to offer for free.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 3, 1, 2, 55, 9),
#   'replyContent': "Sorry to hear you are unsatisfied with the app, but thank you for the feedback. We want to assure you that we are working daily on improving Aura and that includes the free version. Please don't hesitate to contact us at hello@aurahealth.io if you need any help. We hope you can enjoy our app again in the future.",
#   'repliedAt': datetime.datetime(2021, 3, 3, 22, 21, 13),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOH7OYRZgf3eaW8RijK6zdMRIekPvT1KAhUGRjWxhRiYZpuiZlhd5Ll3xuIKFvwVwG2ySPEkx7BSKvlM1g',
#   'userName': 'Ruby Elmore',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GizWdqQDEyjai-Znuqf1vQhvNWDGEcIie8qTsyndw',
#   'content': 'Relaxing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 28, 0, 4, 47),
#   'replyContent': 'Thank you very much for your 5-star review! :)',
#   'repliedAt': datetime.datetime(2021, 3, 10, 17, 52, 6),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHma32o-gCJ1KRdHRYndgafq0xO0EqPgeUurEcyoPmUnGft5bHvI49zbXEe6hqWp-6VsN56VAe3oPCttQ',
#   'userName': 'Darlene Herrington',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiPIzVFbMitZZPqLYWe0NNazPYMD9OK2YJsy8ZN',
#   'content': 'I like the Aura:Meditatons,Sleep &Mindfulness',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 2, 25, 17, 57, 12),
#   'replyContent': 'Glad you like it, Darlene! :) Shoot us an email at hello@aurahealth.io if you have other feedback or suggestions. Thank you!',
#   'repliedAt': datetime.datetime(2021, 3, 10, 18, 3, 58),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHmk8D4zc4hcc2LcfWxLjwONFrNvOgvnxvVeTFzRJHbH1JPv22ZbwhWUtdb4DQLK3NR9uTkFs0C419iIw',
#   'userName': 'Kathryn Weilert',
#   'userImage': 'https://play-lh.googleusercontent.com/-znhs3Fvhjcg/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclojjH3ISSinzgM6nEjF80Ir2Qipg/photo.jpg',
#   'content': 'I have used this app about 6 months no and find it very helpful. I most love the sleep meditations, calming soundtracks, and breathing exercises. Worth the money in my honest opinion',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 25, 15, 20, 38),
#   'replyContent': 'Hi Kathryn! Thanks for the wonderful review. Glad Aura has been helping you every day! We get up every day because of awesome people like you. If you have other feedback or suggestions in the future, please send us an email at hello@aurahealth.io. Thank you!',
#   'repliedAt': datetime.datetime(2021, 3, 10, 18, 15, 24),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGd_q4u0kLPxOWftT0ECbJ_CdBxAwlGF2NxhlvnUGS0-a9Dkg5l2iajdgAjBqWGDsTR2OdvsV5zVEie8Q',
#   'userName': 'Timothy Okafor',
#   'userImage': 'https://play-lh.googleusercontent.com/-3v00KxJYtys/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckTD842-CA9LzVFs6yjjSfn8cLX_g/photo.jpg',
#   'content': 'Good for mankind',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 25, 4, 30, 58),
#   'replyContent': "Thanks a lot! If you'd like to suggest a feature or an improvement to the app, please write in to us at hello@aurahealth.io. We'll do our best to incorporate the same and earn a five star rating from you.",
#   'repliedAt': datetime.datetime(2021, 2, 26, 21, 27, 26),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOECYq0GpnNK2VKQyXAstueegBw_WEjv1GmlfVYTmH2Ah470AQuMSCo_Q8xQeeSf3OZk_CJO5O9BKqCbog',
#   'userName': 'Sarah Oehring/staton',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj0SJTW5JkGLIR2w3DmLIkrGZdl3bhRuFSDqsGd',
#   'content': 'Omg love this',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 22, 21, 51, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFZyVyGc6Hb3D75wvx9Htjv272v25AW4StzPqs-sBuRKz46SlmdwmkOD7rWqsluHl45n4nty-G9TeGeZA',
#   'userName': 'Tabitha Monsalud',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiYGFAjMH2YnWC6BM2Vx8q5xOFJ3EdEKJlc3dJkLA',
#   'content': 'Easy to use and has variety.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 22, 19, 0, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGSMDdtACmS97LPa3S7Xe2ZNPg_dfXVrEBZvYQ3t7Dus0-ARma4tJQGMlg9sSnHxLbk6ipUNG-6h0gDEg',
#   'userName': 'Frank Manda',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgWzWNzHB6_8JD7FcioeRiAy6aSjwcBNL0ojQftDA',
#   'content': 'This is truly beautiful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 22, 18, 10, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGQ5GkJsu6UkzITYikeXzEnZ2RoX6mcz6m0SYegSI8xG9Go5bSR-1x45YmslZv8d7h88R8wi7H7x2v4vw',
#   'userName': 'Jax Martin',
#   'userImage': 'https://play-lh.googleusercontent.com/-sQXzwPOw7IU/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucms3yd07ckQnetJehj_TszTvNHh9A/photo.jpg',
#   'content': 'Got charged after canceling. Will never sub again.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 2, 22, 10, 46, 36),
#   'replyContent': "Hi Jax! Sorry that it didn't work out for you. It should not charge you if you have cancelled before your free trial expired. Please email us at hello@aurahealth.io with your details and we'd be happy to take a look into this for you. Thank you!",
#   'repliedAt': datetime.datetime(2021, 2, 24, 18, 51, 5),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEvG6db02qfMVVeYF-9t1CCGs5CV6PrJlAjVUxgryIU-N4ZsWmPv0OErBQpSvDX8rf1qOurVtrJjCOc0g',
#   'userName': 'Sue Stewart',
#   'userImage': 'https://play-lh.googleusercontent.com/-DMXU3C-CgvE/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucm9njWogDgAladl58lHCapH0uDjEw/photo.jpg',
#   'content': 'Eye opening!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 21, 8, 47, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE4Snua7qp8zSTprSPTghMQZsX97Ts9mYa75JMHRoo_KE2itGIfkZM3_BIRGNOaZewgiowuaLegEjY1DA',
#   'userName': 'Gerardo garcia',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GihE9spDL98EUfvpL9eM5nuJEVIJFg3mLkylaG7',
#   'content': "It's a wonderful app. Gives u short bursts of calming and other meditations to help u in your daily life depending on the situations. Have just added it to my daily schedule.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 20, 14, 53, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGyhgHeRTzL_ziwuZM4stxi27Z2N8q61WHJmsXJtWTYLyoEXN_yXQ7f-1HesdmHVGoweo1HomeVaK3uTg',
#   'userName': 'Ramona Badescu',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhflJz5lEeJa0qb829RJeESiXLckdlCc3LvhqfGkWU',
#   'content': 'Very helpful',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 19, 7, 21, 28),
#   'replyContent': "Thanks for your feedback, Ramona! Hope you are enjoying Aura! If there's anything we can do for you, please write in to us at hello@aurahealth.io. Thank you and take care!",
#   'repliedAt': datetime.datetime(2021, 2, 24, 19, 11, 20),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE4giw2nKDe24C2L5bGs2oOaCqlj51pGvn7iiwJBN0s0fqrerqpJWE8T7lCSwU56T6pGt6y8Ne5E1IpKQ',
#   'userName': 'Betty Collins',
#   'userImage': 'https://play-lh.googleusercontent.com/-70fIadzDDkE/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnHBtG1b6O1CaNhJbCpD2XNq05fSw/photo.jpg',
#   'content': 'Horrible!!! Do NOT fall for the free trial...if you think you will be charged month if you miss the deadline..nope!!! $80!!!!! Horrible app..hard to navigate. Terrible terrible meditations...calmness with talk of destruction war and impoverishment..geez. do not buy',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 18, 11, 13),
#   'replyContent': "Hi Betty! So sorry for the unpleasant experience you had with our app, but thank you for the feedback. We do offer a monthly plan and it is available when you subscribe to Premium. If you need further assistance on this, please email us at hello@aurahealth.io and we'd like to help the best way we can. Thank you and hope you enjoy your week!",
#   'repliedAt': datetime.datetime(2021, 2, 24, 18, 54, 17),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOF9VsdeswXg_wuwuPvJmzo4P0gubg2Au9mXdhZdSqsNZtNm3OA84YBtS6S1crRp8y_vYgyOKi_ZZz_ZJg',
#   'userName': 'Merr Johnson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GivTGBjZKQ4g3Ib2nlp9Kqb13ez1GkjfmO3icl0Og',
#   'content': "There's no way to say if I like the app or not; the trial was so limited. After taking a short profile quiz to let the app know what you're looking for, it gives you a short meditation with no ability to 'skip' or select your own content to view. I didn't want to listen to guided meditation, yet my daily sample was spent on it. Ah, well. Back to YouTube for nature sounds!",
#   'score': 2,
#   'thumbsUpCount': 19,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 18, 7, 1, 28),
#   'replyContent': "Hi Merr! Thank you for the feedback. We're sorry to hear about your experience with the app. We want to assure you that we are working daily on improving Aura and that includes the free version. Please send us an email at hello@aurahealth.io and we can provide you steps on how to utilize it. Thank you and take care!",
#   'repliedAt': datetime.datetime(2021, 2, 24, 19, 7, 38),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEAkkcn45Q7RMp-9dcME8sqlXj3EiwzzlQlgV3mY8EL-gYtF9bz_CL8m0LMCKXx-vsSqDM3XPVhCfcJMg',
#   'userName': 'Amber Rose',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhW8GoCenBTtiG2vniBhGXIw0TV8hKDriWJX5_KpQ',
#   'content': 'Really enjoying this app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 18, 3, 7, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGgzwzHBntd7-4CPF1jXxG81dxShxQRdBUPvPLD25Faqu2RyBnlhb5qJzKOT6oQ8fwtT0jpQavog3p7GQ',
#   'userName': 'Tiffany French',
#   'userImage': 'https://play-lh.googleusercontent.com/-IdXo2RQGW7I/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucm1tBzF8cMapuyC33SpL0OgsGPJLQ/photo.jpg',
#   'content': 'Simple way to feel much better in minutes. Great ambient sounds',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 17, 11, 4, 40),
#   'replyContent': 'Thank you so much for your review. Glad you like it! :) If there is anything we can do for you, just let us know at hello@aurahealth.io! Have a wonderful day!',
#   'repliedAt': datetime.datetime(2021, 2, 17, 20, 10, 33),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEiTag4gdZxYWXXiAdD_28r_F7hQs7VWBmIzCmL0Jv39ecvs8zzo75OYki5YMj7GCFE7XN_tfVm-xmbXg',
#   'userName': 'Amber Malone',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjjNVDfn9WSv9Okze9oGyeQEE6RB5CVBbV_jDhM',
#   'content': "I particularly enjoy Deanna Burkette's content. Her instructions are very helpful to the whole process.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 15, 16, 28, 52),
#   'replyContent': 'We are pleased that you enjoyed the app. If there is anything we can do for you, just let us know at hello@aurahealth.io!\nHave a wonderful day!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 42, 45),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEkADFSuJMTWVbZPLE1ozaKalVkKYR4xV1k7y6817YXI6c3bUHg6kMKYXaDdqltCYYsAnXy71VRaL2F3g',
#   'userName': 'Claudia Ivette Moreno',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh091lX7Ku0qTraz3PnOYnUa_bNeHF8L1LropCB7Q',
#   'content': 'VERY HELPFUL IN ALL WAYS',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 15, 8, 29, 45),
#   'replyContent': 'Thank you for your review. Enjoy using the app & keep supporting us :)\nIf you have any feedback or suggestion, you could write to us at hello@aurahealth.io. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2021, 2, 17, 20, 7, 24),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGhDYOEzgEVf_rfyICLMNtl-aY8QMi54x-maNsvgdjds_H0AeMve727fxHptbtKgLDpa5TfXurJzUa2sQ',
#   'userName': 'Rupam Chakma',
#   'userImage': 'https://play-lh.googleusercontent.com/-kaGNtPiGel4/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmourrZZ81ESN_MIY_0al9SabRkog/photo.jpg',
#   'content': 'Good for meditation purpose',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 2, 13, 1, 41, 19),
#   'replyContent': 'Thank you for your review. If you have any feedback or suggestion, you could write to us at hello@aurahealth.io. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 42, 8),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEh8AJL4Np6gQ9IwmjfKVeQf6w4aU0bEr4sBHqI2KJ4lxndNdsZGjDs-LtUrua5Gp8WRftTnj0mhjciXQ',
#   'userName': 'Danielle Dalton',
#   'userImage': 'https://play-lh.googleusercontent.com/-cpYiGxnG8LM/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucn8IDbj0cPZU2zhC-esBg3jlMuGbw/photo.jpg',
#   'content': 'It is very, very relaxing!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 11, 5, 58, 9),
#   'replyContent': 'Thank you so much for your review!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 42, 29),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGwuxd7hX3iI5fxAIgcVWfS3hmupe1WoJt3B1XNIsmA7X1KluyhqwC2dWyuKYLxP5dyYbTQ3sC6EtKpqg',
#   'userName': 'Lidia Walters',
#   'userImage': 'https://play-lh.googleusercontent.com/-Zq1uCDfxtrU/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckY-AMPNo-kvlCy-Dg_Xl6DScgdgg/photo.jpg',
#   'content': 'I love how its interactive with me. It prompts suggestions and asks meaningful questions.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 9, 23, 20, 23),
#   'replyContent': 'We are pleased that you enjoyed the app. If there is anything we can do for you, just let us know at hello@aurahealth.io!\nHave a wonderful day!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 41, 19),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFCCgO8hOMWPwyDaVc3rN0iQujVOrFZrc4UL3ANajSgozrohrA5mcfWW-upWeeZh-1kRy99OQGHtjN8KA',
#   'userName': 'dave singh',
#   'userImage': 'https://play-lh.googleusercontent.com/-bxvhi9A38H4/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckjKxOS40PaKKe_DzJgzjPnxn-4bg/photo.jpg',
#   'content': 'Just Trying',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 6, 19, 30, 35),
#   'replyContent': 'Thanks for trying Aura If you have any suggestions or if you are facing any problems, please contact us at hello@aurahealth.io. We will try our best to help you out.',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 41, 1),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE4cs7iuPRXfvcgHE89qToU3ArWp-xmQySXzfKWOyvM4v7XUDnJnsewNfQRR1cuI1FYRsGvq2iEWAjclQ',
#   'userName': 'Shammi Turna',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg5VoAwPYmvCv-DZj2EXArWfsLa2zBS7clBDsVYYnE',
#   'content': 'Not everything is free. But the free content they do have is pretty relaxing.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 6, 17, 24, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEnrgPizOxaS7_nZGYqGzMKbCq_zZmSdB3xAF1QpjziuwMyAepbn3KZuTFqteTyWwxBa7cCXAAL8rvgLA',
#   'userName': 'Matias Antonio',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhRwlZKQQ0aai7PQlcuvPx72x_Y1cX4DOM1WC6DtQ',
#   'content': 'Tranquility at its best',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 5, 21, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFqcLRLVQwfD-pIvCdEmZVbw2OGk_8HQbFf5dPpFXloNYdM50zbTSbiXv_THNciyQdrOXVUIAcyourRfw',
#   'userName': 'LJC',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhNqN2XrVmCSmCAr_IFYC06F5e-CPzecYiG8-TG5g',
#   'content': "High Hopes! All the pop- ups were frustraing and then having to constantly close them to continue where I was only to find out you have to buy a subscription; or all the helpful options were locked without premium purchase. I am pretty disappointed that I could not really give this app a stress free try without having to give my credit card in order to get the 7 day free trial. I finally found out the free version only offers one free meditation a day after reading reviews. That's all.",
#   'score': 2,
#   'thumbsUpCount': 36,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 5, 8, 5, 5),
#   'replyContent': 'Hi! Thanks for the feedback. We’re always pushing ourselves to decrease the price; much of the fee goes directly to therapists & coaches who are creating contents. We appreciate you taking the time to try Aura and we hope you enjoy the rest of the week!',
#   'repliedAt': datetime.datetime(2021, 2, 10, 21, 28, 52),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHuAzMAIlzhH66Eck45T3qNoIAL643PJrWZfA74RrmQtBW7MFgbcZv25_SrKHF7lG7Id6Gv76dviKvHkg',
#   'userName': 'Gabbydagabster M',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjoGluVQ5KBTpYBM72QX2aDZER8t4V9VvowevsJ_1M',
#   'content': 'Really helps with my sleep thank you thee sounds are exactly what one been looking for and the quotes i enjoy everyday',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 4, 5, 16, 5),
#   'replyContent': 'We are pleased that you enjoyed the app. If there is anything we can do for you, just let us know at hello@aurahealth.io!\nHave a wonderful day!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 40, 38),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFkxJkSXj9rF0QfRjIcZ6NY-Hz7tvpUzLzkcnRrfQQ4aFZ5OO7J24G7ik9yJ_ZPYXmO6eSfGv3oUyr71w',
#   'userName': 'Wendy Goldberg',
#   'userImage': 'https://play-lh.googleusercontent.com/-bJIREoyhMbU/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmHcRO_J4xwIgk0cRnRtc1-cA4Sgg/photo.jpg',
#   'content': 'My issue with redeeming my gift card was resolved very quickly and efficiently thank you for your amazing customer service and app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 3, 7, 38, 14),
#   'replyContent': "Great! Thanks for updating your feedback, Wendy. We're just an email away if you have feedback or questions in the future. Take care! :)",
#   'repliedAt': datetime.datetime(2021, 2, 3, 18, 2, 55),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE1izpHlc1Hafn3N66yHpWUkGXR1-U6z7WWJFkTZJdKkwWleWJGDWOSPOU9P0y-Dx2UHhSmAgpFjYeYHg',
#   'userName': 'Taiwo Chidinma Ogunyale',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjHsnyVxcLLsZYfyVYECL3_u1O-thWWBfZSHJnC5Sc',
#   'content': 'Awesome',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 3, 5, 46, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOF7I1S1mLiS2d8oyX4Smw_Dal5kc76SEGKLiY1PP8Lpsi6rOV5Ue9poHirrjwHT2Q9xkMgByQf7NP9zaA',
#   'userName': 'Kaylee Delorey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggz9f-93q4j-m1nhJ5qoZEgwbypgY0Rh6AvyClzvgU',
#   'content': 'So nice to be able to choose just tiny bits of time to ground yourself.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 2, 15, 55, 33),
#   'replyContent': 'Thank you so much for your review!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 40, 19),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEvkN_ueJn-v85sk58bo5pZR_VGfiJOHzK28_6SmjtbDcGh54Bbw2_IdeXvrkKTgqe7PbrfgT3Q9W69WQ',
#   'userName': 'Joel Karr',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg6UeBkxcgB9CvCnfq6YQVFG6saO4ujYwVKwuHk',
#   'content': 'And free',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 2, 1, 9, 12, 13),
#   'replyContent': 'Hi Joel! Thanks for your feedback. Please send us an email at hello@aurahealth.io if you have questions or feedback in the future. :) Take care!',
#   'repliedAt': datetime.datetime(2021, 2, 3, 18, 21, 26),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFOUUb0zjzx93JoZta4i6G8uAOLR1sx08BOdLPZIbhR71iszhQl15wWA_KwEyJ-eH-CkAZkKleyK4YxuA',
#   'userName': 'Mounia Ouchan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiGdOVvTUjTBHebrWI1Z6R8nTW2_xupZ9fPUJID',
#   'content': 'Wonderful 👏',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 31, 9, 23, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHBDqeD59sGJDFCaVe03c5s6pTDSDS0Ff_M4bZPY4Vv1aO9PS74r9joeI-9zJguzVy8nekGHvaWVWXevw',
#   'userName': 'Punk Rock',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgS5sSasUNW_POMgkLzcbFQrJ6KLBlOM72AzGaHmw',
#   'content': "Its everyone I failed lol for sure not cool I'm OCD ya digimon sorry mained meditation and sleep love all I broke me hopefully alliya wilford givvenna mifor thscros I cnttypa whtameed tasai",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 29, 21, 39, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEy0VA08Eh-QleKw92qq01-TwoKF88vdxi0haTzZafZWneL_SakbSy9dMj06M7OCHWwjlTy46jwrpB6ZA',
#   'userName': '•StraberryMochi•',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghmjc59t6RHYx_FtrAn08MBPlTdp2TfZ_DNHhA',
#   'content': "I think this is a good app but if you dont like paying for things this isnt it it asks you to pay AFTER you put in your email and get started with everything I dont know why they couldn't of had you pay for it before you done everything of when you putted your name......",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 1, 28, 18, 31, 54),
#   'replyContent': "Thanks for your feedback! There might be a slight misunderstanding, Aura is free, one new 3-minute session every two hours daily is on us. You might get a prompt about upgrading to premium but you can alway close that to go with the free version. If you want to know more on how to get started, email us at hello@aurahealth.io and we'll assist you.",
#   'repliedAt': datetime.datetime(2021, 2, 3, 11, 21, 13),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEaScLxi4Xlv4-1xoOm9o2WJblZIqeKfgN4HZIIxz_I_Gqhir9algReYfit-7jwEMvMzsipJLNIad3o9w',
#   'userName': 'Kathleen Butler',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjqGap2e3BMZxg6BlNbuYBpFiXJWLAt1bdjuPxrIA',
#   'content': 'I love the stories!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 26, 20, 59, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHRyoIgvUT8MjLtGmRh6IVUDWswEGXBGKgFt5LF-XyKekWpN0ml7_rZZ-ZfFGDPxkNcFlpfkUtPgtypfQ',
#   'userName': 'Lesley Frances',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghc9qB7Jr670IrXFdGqTrYnbn806GUGOb7C-oL8KA',
#   'content': 'Beautiful app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 26, 9, 18, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEcnVP2mC_dP_L6L5ApRVHn394CMv7vj16xpkqTqJBZviSV61vhrfSxy4P3UfbYWkDzoIlGFtEWMLVr2g',
#   'userName': 'aura de cuba',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi1xMnl9_cT-Hp2VPVbyEpkO2Yfmt6dUmmKch16Lw',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 26, 8, 19, 32),
#   'replyContent': 'Thanks for your love. If you have any questions, please contact us at hello@aurahealth.io.',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 39, 27),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFBD2-E67g4Sj39ns_JGSWcrX1woAmxqpH8FFrWA8BdxkhSU2fNj46x8auuJx7ZkRYFTa947a1F904Rug',
#   'userName': 'April Russell',
#   'userImage': 'https://play-lh.googleusercontent.com/-2tmJY1j5eB0/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclr5qUsctOCAUBhpLYU1VLug1fzPw/photo.jpg',
#   'content': 'Helps me fall asleep 🧡 bedtime stories',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 25, 22, 38, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFb_O0Wj3akdoqNAF4t0L8LBK0Ub8l-pGPkA4Gdg60JyI1hTdpkAG8wMdIFAiE02HnKH1MiEy470jwfcg',
#   'userName': 'Allen P',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiBZdpuKCE_EuovaX85swGTqe9949F6l2fS__7R6Q',
#   'content': 'Probably a good app. But after entering personal information it wanted me to prepay for a year and I can stop after 7 days of free time. They need to tell you that up front before you start putting in data',
#   'score': 3,
#   'thumbsUpCount': 20,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 25, 20, 52, 54),
#   'replyContent': "Thanks for your feedback, Allen! There might be a slight misunderstanding. Aura is free, one new 3-minute session every two hours daily is on us. You might get a prompt about upgrading to premium but you can alway close it to go with the free version. If you want to know more on how to get started, email us at hello@aurahealth.io & we'll assist you",
#   'repliedAt': datetime.datetime(2021, 2, 3, 11, 45, 10),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE9iXiNOBo-ukIaLkcj08nnuK2b23MDZplaM3S5gPrHHl-9gM5oVX2xYPI3tWj9lGeftpDeOv5C3G-A2g',
#   'userName': 'Liz Lynn',
#   'userImage': 'https://play-lh.googleusercontent.com/-jCvxFEbz8zA/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclGKbcKUFeEwi6XbV0Ha2BGr4b9SA/photo.jpg',
#   'content': 'Very useful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 25, 1, 13, 8),
#   'replyContent': 'Dear User, we are happy to know that you found our app useful. Please help us by spreading the word amongst your friends. If you have any feedback or suggestions, please write to us at hello@aurahealth.io. We would love to hear from you!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 39, 55),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGLCRMEfYG14_mU__VjCtJ5ttVv-U3PoCKYHvT9Kr641zq4OQyPtRZkTPJXvVXEz-R4V1xiKSNmUkOmtA',
#   'userName': 'Jessica Chapman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgS6yO7s4AHowaNqP9p8QRb02YJQLVf1Rg9zJluGg',
#   'content': 'Greatly enjoy the music and story options available for meditation practices or to prep for sleep!',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 24, 17, 22, 35),
#   'replyContent': 'Thank you so much for your review!',
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 39, 1),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOE1KUcArBmxnX64tvh72od0l_TXvxtSu8upny01930qvRGjuY3KCmswP4p_iuGNRAjjj-8MllhAA22aXg',
#   'userName': 'James Wirth',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GinVU0m5CTIkupS83IMEr1VehNJAffFAv2rmEsjGQ',
#   'content': "Great place to go to sleep and enjoy the sounds of the way that you have a chance to get to see what happens next few months and you'll see what the best results from opening the door to aura and the way that they have set up their system to make the world really relax and enjoy their own lives for once and for all of the bad things going on in the world is not going to be here forever and I am very grateful to be able to make a difference in my experience with the new mindset that I'm going tow",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 23, 18, 16, 37),
#   'replyContent': "Thank you for your feedback. We're pleased that you enjoyed the app. If you have any questions, please contact us at hello@aurahealth.io.",
#   'repliedAt': datetime.datetime(2021, 2, 15, 18, 38, 37),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFeUrHhZAeTo3E94CFA6prZhEko5gycwwX00ntv3du07GWJf3bWP-VfqnJD1ku1KF_3xFsAmhRTLYviPw',
#   'userName': 'Sarah Denney',
#   'userImage': 'https://play-lh.googleusercontent.com/-jEaTKIXHPJc/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnQCMEepzR15mEfunkNl1VA2HkDjw/photo.jpg',
#   'content': 'This is amazing...',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 21, 20, 45, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOF3xYbU83l4k20tlnyVPIg9NcTFr3SCQ9rdBgv8we33ukOP4dM_l4NSK7QbcJrfP-hOEtaO0MkYouP7_A',
#   'userName': 'Jordan Cobb',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiYc1_EPUKLVrMmbrx11kCc6RnDRG7YQbbjy2_P',
#   'content': 'Loving this already.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 21, 11, 5, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEczcVeRl6wVk0MAtmxZaXcDY1tpa-IugJsRQUpImGlDgNsLmsgWhGPVN813u6MWslGZkR7vAT7DIFFdA',
#   'userName': 'Aubrie Neil',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjKE6TtSrz2BldggZq7jkE9slRsKYq8cBAql4D2Hw',
#   'content': 'Love this! Such great content.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 20, 19, 51, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGBbvKuEAC-5RpZFUF-2BtRC1b7nWYCfWwc6zRzy643G8rF5FwBj9VHWjt1q4fG-omfjQ7CxTji-fbLSw',
#   'userName': 'Louise',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhtCMPD1Gfh9qA19RhRp2ktoz-mznzPJDycwRW8IA',
#   'content': 'Great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 18, 6, 0, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEd7JN0cU2lGZHar8hg5MUbRGW0JpoA7vQlJYvb92RC6QQil8_IRUMGFqo-0ga27uL-qFPHh_QPZ2A5Pg',
#   'userName': 'Melody Chidha',
#   'userImage': 'https://play-lh.googleusercontent.com/-ML-SQjXeNZA/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnEjVhCjt5fygHwdI_Skj56T8jLyw/photo.jpg',
#   'content': 'Extra ordinary',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 1, 13, 14, 17, 50),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOF4JWlg9kQLfRHO9m-owbzSmmZ9R280TjzvoakiO0dLyQn1HoqYC3O34aeHYZd8OJVeHrQ1Vv5ytOv0cw',
#   'userName': 'Angela Agati',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gin_kGMHadI1OFxe4S7Q7kaIXiFVJZM5_lQ01N3',
#   'content': 'Delightful guided meditation app.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 13, 11, 58, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHyEnfshNaMpQKQWUaSei5cx2VC-LgLdil6ddqcQKqb5HkdwPwD6ZboHlsZKvaVhIIes8GdVWogVASwIA',
#   'userName': 'Boatagne Daniel',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gib-y-C6m9MZIrBn4sK4F_VChEuswG6f9fCgB7Z_Q',
#   'content': 'I wish it was totally free.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 13, 9, 51, 41),
#   'replyContent': "Hi! Thanks for the feedback. We want to assure you that we are always pushing ourselves to decrease the price; and much of the fee goes directly to therapists & coaches who are creating content for people on Aura. We'd like to help, please send us an email at hello@aurahealth.io. Thank you!",
#   'repliedAt': datetime.datetime(2021, 1, 15, 17, 54, 25),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOHAVldy1e6YLZ4xqoI2nEa9a8Bxk27APQgpGfFYLev47silzXLMul7iByckMZRcUsZKcXuPvHHWV5KP4w',
#   'userName': 'Tina Walsh',
#   'userImage': 'https://play-lh.googleusercontent.com/-o3ceAiN_658/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucllCLmnedJTDpIrYsZZhDPan4Y_2g/photo.jpg',
#   'content': 'Relaxing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 11, 19, 44, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOFvkE7CW9YtqEG7YDA2Yvn7fwm-umucylVg5fVmvLIEy45AfkVm9YmIzn9H7KBfpDuFNZpGDNg_MswJEQ',
#   'userName': 'Anna Marcotulli',
#   'userImage': 'https://play-lh.googleusercontent.com/-kBkY_EiOoog/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnPR9UfyN3mWVqYnMwbvJiwp9Xpcw/photo.jpg',
#   'content': 'Relaxing,Breath of peace.love this',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 9, 3, 16, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGLeVusZTRdjFsaymMpv1yspb6q5bL6MVlcAqOf40pv-k_EeaRVYAIDEqyX3b52iXw2ciVq_jPOXSbIfQ',
#   'userName': 'Olivia Plump',
#   'userImage': 'https://play-lh.googleusercontent.com/-7M5EnrO8oEU/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucm0URr62jmdnVZpYD2kuEAbWUefgQ/photo.jpg',
#   'content': 'Peaceful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.4',
#   'at': datetime.datetime(2021, 1, 7, 11, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEfcnMZXW_Y3FpDhBQl0s1Z0jDbjN9ZxG4I3Ogq3USdJqiGBGCux-6EfZTRF5kuMgCzz7D0zIRCgS0YWQ',
#   'userName': 'sherri snow',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg7tToStEvDdWrp39bj2ewulSJ10g5Kgc5jIMGHLdM',
#   'content': "It's really helped me emotionally heal",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 7, 0, 30, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOGP-xCYETVZzARtlUFiPAgbQfuDg0yqsANbrXcEUwveB9Baas_hrSzuuqOeWaaRSUacybOPgHKrabsBuw',
#   'userName': 'Barbara Lane',
#   'userImage': 'https://play-lh.googleusercontent.com/-MaxYvGuk2oI/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckUbual8WmCNORvVagb7qKxbRQukw/photo.jpg',
#   'content': 'Very calming and relaxing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 5, 17, 20, 38),
#   'replyContent': 'Thank you so much for your review!',
#   'repliedAt': datetime.datetime(2021, 1, 6, 18, 56, 35),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEUTA_cDOVc4B61VdyAzZG1wethn2Sa1FyJ4K8vj1DeCIteUQ1wxCWSiuebpjqZ6I1Hr274b0ugjrJlxQ',
#   'userName': 'Roger Valle',
#   'userImage': 'https://play-lh.googleusercontent.com/-1LTIRzL8ru0/AAAAAAAAAAI/AAAAAAAAHW4/AMZuuckoyI5m2gFbegNlFvojrYKU9Yg_rw/photo.jpg',
#   'content': 'A lovely experience as a free user shame about the 2 hour wait time for different content.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 1, 4, 14, 56, 26),
#   'replyContent': "Thank you for providing your valuable feedback, Roger. We try our best to improve daily on our free version. Please reach out to us at hello@aurahealth.io if there's anything we can do for you. Have a wonderful day!",
#   'repliedAt': datetime.datetime(2021, 1, 6, 19, 2, 16),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOETd9VBKman5uD8Zx4w7MI0KEVH3gGloF2PgV7ke-QTRhHfwpqgesMI-v64MT_8pSj3EX0A8z9oDsf7wg',
#   'userName': 'Jaylee Scepanski',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj582HRDJmQFOVPebuf5x2SiXBXQxPL05Eswfn_wQ',
#   'content': 'Just started and liking what i see. More and likely will subscribe!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
#   'at': datetime.datetime(2021, 1, 4, 4, 43, 12),
#   'replyContent': 'Thanks for your love, Jaylee. If you have any questions, please contact us at hello@aurahealth.io.',
#   'repliedAt': datetime.datetime(2021, 1, 6, 19, 2, 53),
#   'app_name': 'Aura',
#   'app_id': 'com.aurahealth'},
#  {'reviewId': 'gp:AOqpTOEm9sEGq24b_XQ8YzEfkpeFk-aYOp6i2IZQ4ScuVDxgwGLhaBRE984UOx73y4atzq5cW5c9mKor8v0V7g',
#   'userName': 'Selasi Kwaku',
#   'userImage': 'https://play-lh.googleusercontent.com/-lNmClNuDbgo/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclmjSxwS4D4CxPCDqihMjDgV1rQgA/photo.jpg',
#   'content': 'Good',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.4.2',
# ...
#   'userName': 'Gareth Holland',
#   'userImage': 'https://play-lh.googleusercontent.com/-RVWcN5xD1pM/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckk5yJHNTDWXx55RGQoBx3gzMde-Q/photo.jpg',
#   'content': 'I have found this app easy to use and helpful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 3, 12, 28, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOFnXrQDZOo7Rf946tfTZ7H9hZq5FV6jgIfPeLfZ37PGoOUcNFoxwftL0UMPeQ32vsk-op-LVgMoJ0X1nZY',
#   'userName': 'B H',
#   'userImage': 'https://play-lh.googleusercontent.com/-4gSb-JEs658/AAAAAAAAAAI/AAAAAAAAhVc/AMZuucmH2PmJffvWZHtl2lTfzpV6EL48aw/photo.jpg',
#   'content': 'Really needed this at this stage of my life',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 3, 7, 8, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOE9LWeokIHkicRjoivAIQqb_VwwS19Ijd3KLRDtWDTYrL-nYZF8yvT1xCmj8INdi08C0ad5hS0A00qJk70',
#   'userName': 'bla bla',
#   'userImage': 'https://play-lh.googleusercontent.com/-GJQo1FUOEY4/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckW76NOprjlMAA4Q6oqMwbGEhV46g/photo.jpg',
#   'content': 'Very nice and useful, still need to get used to it but I like it, finding it helpful so far',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 3, 5, 11, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOFI0XwO23gNbefU6h5AORFHtl0p80BZ0ndhwEJ7WLjbvZvnhn2Hrc6wReHj-8RO9SpDSQZplRyNgAUj4s8',
#   'userName': 'Andy Stewart',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh49Z7HeYPxOFFfqeytenX8ux7Hj4RM2YCfq1PM4w',
#   'content': 'I have just started but I already highly recommend',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 3, 4, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOGME_dcKuw1vXWEUdBBPuH6a2vP8VdNeuTXA-39PLuPy-rJPIpJVoHENUh3Qe3x_QzOrOiCWyOaNtQ9Yp0',
#   'userName': 'SAKSHI CHAUBE',
#   'userImage': 'https://play-lh.googleusercontent.com/-ZpPrVDUinQ8/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmkrQc7KoB5LMUxxrgXIAFAJcvmxw/photo.jpg',
#   'content': 'This app helps me think rationally and lessens my worry.',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 3, 3, 28, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOF1cZ2zkNVzW2PaTnAf8ESDIIWbG-zzqjmB_g1-Ho2mVfKvx2orn5BK5PC1bTwpg9eN1_CLmJd3_IZ-Xg8',
#   'userName': 'Sandra Cook',
#   'userImage': 'https://play-lh.googleusercontent.com/-FTNpuLAD-nc/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnaYVKoKUY8bJ8CF4Uem4r68UD4UQ/photo.jpg',
#   'content': 'This app really helps me work thru my thoughts and feelings.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 2, 18, 19, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOEqRozBDg8S8do7_5wyK57KQnTaV8CxjT-5xyXHWlNkXWR1lTVBZJ6neAX7olnPEQ8CbqTCfowVUOisPSs',
#   'userName': 'Arya Sivadasan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgoOct85Fs2cCvL6BH69J4KAg1wVWN7GTBA-yHhmw',
#   'content': 'A very nice app. Really helpful. I have one suggestion. Could you please add an option to slide through the diary pages. Now every time we need to press back button and have to choose the enty. It will be great if you provide this feature too.',
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 8, 2, 12, 1, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOFeJuhskdsE255fH4bqruEKp9ssnaiMjJ5ECgu8I3CConmMpU57nLBcTRBC5VeUqmrFLDZVHbTmgSyrevM',
#   'userName': 'Rafael Castiblanco',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgXL5_eDMpYDgg0-qSqCB9e25FDNNMaRMtYB9z7T3o',
#   'content': 'Great app to keep a diary',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 31, 0, 19, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOEKX9Pqt5XevR4FcnPqN5VGv-TWTZdvAR10h3ptCQPXgG11KteXGTXbKCamMK-21V7MvEFieYsqjCxtsIU',
#   'userName': 'Cassie Baker',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg7ToiHVHfnJQrlJsAXa2E2wvf4XPbxdrGIvGHMjg',
#   'content': 'Decent app for thought tracking, easier than writing it down.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 7, 30, 20, 41, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOFjpMNkD6MNumX5gE1sj6tPHeok3LhJhpazEHA1ryIL-KTECdSoVe2dIIlKjUeAGQAPHeFUwLEJvRjUlGY',
#   'userName': 'Lauren Hinson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgRQQiGo2_sGhrqHg8o5btst5u7Pns-BOo1TTAeyQ',
#   'content': 'Love it!!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 7, 30, 20, 33, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOFG0Lz7Jbi79WiBjE6FpBIyBooGnEwLqtkd8tvMqF4G1m6-aKuwB3sSdjPAJFCuyVVZoi8mUmQzxdAKj8k',
#   'userName': 'Zoe Zengel',
#   'userImage': 'https://play-lh.googleusercontent.com/-7em_x6HUPNs/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckShAD89j97kQOSyIzDAJybTgiQLQ/photo.jpg',
#   'content': 'Really helps calm my overthinking',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 7, 29, 20, 33, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOG5A3TpCYol5vNfG9pTgQbdze2chzo4JTaedOD3Bw6kw7vx-LUamMepdu5AWQIRI4_8X1YUTdLHIPR9uq8',
#   'userName': 'palak arora',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh6NRj537_qdSiKewcKvRIiRLikQGjQF3F9wC3CzQ',
#   'content': 'Love the app. Always makes me feel better and bring clarity in the moment when I am too fogged to tune into the reality!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 7, 29, 14, 54, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOFVfTqlJzXv3E60w9yW-7wUgPBrpmkeVYyadbVnI-BFK7dshVZhNxqatjNAh9WQCWzPijCZHSayKFnRqu8',
#   'userName': 'Andy Vale',
#   'userImage': 'https://play-lh.googleusercontent.com/-Wo_WI_SlShw/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclcFiug936MRXAYekHaD7X_o5jEFA/photo.jpg',
#   'content': 'A great way to get thoughts out of your head and onto paper. I tend to then park the thoughts and revisit them at the same time everyday. Often gives me a different perspective or the emotions involved have lessened.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.6',
#   'at': datetime.datetime(2020, 7, 29, 6, 10, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOELUFKIcL4IGL4iOvTUK1ygNHd6QcuiNK09pdukAsVnY4j_Hv0TR6Pi4amntp4MCN1thB-0_TnMqHEDImg',
#   'userName': 'Darah Hudson',
#   'userImage': 'https://play-lh.googleusercontent.com/-MfOmT31ld94/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckzjNqz0zig6bEuOsqZdNkyZeyK7A/photo.jpg',
#   'content': 'Really helps me check myself and puts a stop to most of my self sabatoging behaviors.',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 28, 20, 14, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOEf06Dz-vhw6Et90AgtPeCgIoHmExXU-C7YKVdJA7HNtEoTAsxkEj-6TO3CHZ-tacOjrvJOgApVh0kI6gU',
#   'userName': 'Michael Harrison',
#   'userImage': 'https://play-lh.googleusercontent.com/-IEweBiHWX8A/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckMIjNiq49K3f0iNHL-nKkON5iqKA/photo.jpg',
#   'content': "This is a great app. It already helps to align my heart with my boyfriend. And I haven't even upgraded it to pro yet!",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 28, 8, 54, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOHqmmB3t4zMh0WtyH4wTfz90vzD7c56vg9zPBCUcKxuUxSaXeYMwKrE-OI9rqJYJ9Sy26l2kBjE0G0qFso',
#   'userName': 'Onerow Hohner',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjVPQTFyVfMLFqGH8aZiir3F8fb7Zrw378AHK71',
#   'content': 'simple snd easy to use. nice interface',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 28, 6, 32, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOESGDeQ1HZDtyqeBB4I0lB6x4p-4iR6RavNfMGUF6vFDk-606hiYyh4M1gOBFaDx_QCCwYV1Be7Hx1SPdc',
#   'userName': 'Henriette Pilkes',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhFrsk4xI2FzrZ_D8Smh3IfQz2lvFeqcUKbSfAAsw',
#   'content': 'The free version is also very useful. Love this app.',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 27, 20, 0, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOEs1MctowRnUxMq8KQID0FUvppkYX3zPdZIb1fx4xKqBvfdaNdyDCJuu19M0kNdJX2HqvapJmJBC0AwpWM',
#   'userName': 'Om Talreja',
#   'userImage': 'https://play-lh.googleusercontent.com/-4kN0T5FxMuQ/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmhaGwjqs7AaFUtyhovE6yqZLhbsw/photo.jpg',
#   'content': 'Just starting out... Looks good',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 27, 10, 39, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOGLogiUzYOWl2SRkD3117qhsuhyX82P_3Rx3970-8B57mky_DkxFo3wHkQhJV66JBtt-l8ah2961oCdRMY',
#   'userName': 'DJ Starr Junkie',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhCp93rmNwadAQSBDwOdydBPz0wQIOyBGntNfXg8A',
#   'content': 'I just finished a 10 week CBT course for chronic pain. I\'m learning to retrain my thinking and it\'s easier said than done because there is so much learning. Although I\'ve only been using this app a few times since downloading yesterday, I truly appreciate the fact this app has a reminder "to check how I\'m doing." It\'s VERY easy to NOT WANT to put in the work, however, the simple fact is we cannot grow if we don\'t dig in and change how we think. Thank you 😊',
#   'score': 5,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 27, 10, 36, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOEhG6eYkm-O2vuWgWQomoOKjrHRJqkwgCvYXTvWqNwbNncZTiOu_hUHZuqYNTLog7g58STHF45PrGTaBes',
#   'userName': 'Tionne Cherae',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhVqJXmNHDlONNnlNx2KGJ9gPl0d2l_bMOoc7Qw3zs',
#   'content': 'I have BPD, everytime I have a episode I write ot here and it helps me to see them differently. Its helpful so thank you.',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 27, 4, 51, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOHpl-IT15xvHFrcH0MtiFgOWOynnRGzVHNEu2mB6U-MWyrhMokEdvSDXBzLo8ntls0QEzisTVbp2qrLPiU',
#   'userName': 'katie kohler',
#   'userImage': 'https://play-lh.googleusercontent.com/-JL3vod1Igh0/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmCe3B2_FE3v5IKpdNlaWx0sPbnPQ/photo.jpg',
#   'content': "I've gotten a lot of value out of this app. It's very a very simple tool that just walks me through my thoughts and channels them into a more positive direction. Each time I've used it, I've felt immensely better afterward.",
#   'score': 4,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 26, 20, 47, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOHvrDuPlgW0HwCMuI85jrtiEola7Gud61r42JBDXxxyGPHZYtZOd-BNy475DkObzk8MznRFb40o9_ZClCY',
#   'userName': 'Sophie Kennish',
#   'userImage': 'https://play-lh.googleusercontent.com/-2pcXR_bfHnQ/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucm5149eAzvg-_d_FDd-D02o7E6oXg/photo.jpg',
#   'content': 'Really good for people interested in cognitive restructuring. As a therapist this is the app I recommend to my patients',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 26, 17, 54, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOH_6l-39PtWqux8LMeHd9mYqXNl5vnoxXsGzveR_WWH7nJq4WOfItAsbNMUttvDpgtZfAbnRXWyGCNCy-I',
#   'userName': 'zombabe Therese',
#   'userImage': 'https://play-lh.googleusercontent.com/-KSPkq8NQsYQ/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclVP8f-z30fowqZMQkyUY8-9WikxA/photo.jpg',
#   'content': "Good app, I like the simplicity of it because it makes it easy to use but many of the features in this app require premium so that's why it's only three stars as I didn't get to use most of this app without paying.",
#   'score': 3,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 26, 15, 12, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOHO7E1xO21mFHVn5-aYQrm-kWI5Jcs41cHK9ICVZUpdvjf3oQ76qusMNOU5S1gmEVq6LAylxmAyd1DBHvI',
#   'userName': 'David Rovere',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjU4CwE-WUO7OS3jEqxXI4SLpy9KKLn88UzPZ-FOw',
#   'content': 'This is the best application I found to keep track on my cbt-i I program',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 25, 23, 9, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  {'reviewId': 'gp:AOqpTOGWQYH_R3St6Lhq2wpnPJRspXWr-47ISiAybv6HNWVWt4mJmypSw1hm1s-gY3tn4zrX1MhYTHrCS5F9k4E',
#   'userName': 'joanne breen',
#   'userImage': 'https://play-lh.googleusercontent.com/-OsYVIKw-tf4/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnN66B6i4F9rXnn22uvioUDNPV5tA/photo.jpg',
#   'content': "It is a really good app it has helped with my problems that I won't tell about to anyone. I have never really told anyone who I feel. It feels good to get that weight off me. I recommend it for people who never talk about their feelings",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.1.5',
#   'at': datetime.datetime(2020, 7, 25, 17, 54, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'app_name': 'CBT Thought Diary',
#   'app_id': 'com.moodtools.cbtassistant.app'},
#  ...]

# %%
len(google_play_reviews)
# Out:
# 8703

# %%
gp_rvw_df = pd.DataFrame(google_play_reviews)
gp_rvw_df.head()
# Out:
#                                             reviewId          userName  \
# 0  gp:AOqpTOFEiK76RQn3IT_l33057YhZTiJG5-2CHqSjhau...   Brieanna Leader
# 1  gp:AOqpTOGvtXXTIO5iLmumGGEWYEoSHsf9bnR9CIqVeVL...   Raelene Bennett
# 2  gp:AOqpTOEsycUO6F1EtiLx-Lc4JQYizxEEVfQz3DeVScN...       adam rivera
# 3  gp:AOqpTOG82BmVA1oTLV3Hjjhol7CfnTD6Uq-KTlWVaYw...  Jeanne Macdonald
# 4  gp:AOqpTOFN12XjpLAb9-RRn516nLYqnT2RPdh06u774Xn...  Christina Reeves
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/-_etwUFT...
# 3  https://play-lh.googleusercontent.com/-M5HNH1c...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  This app is a great way to express your though...      5              0
# 1                    Easy to use short and practical      5              0
# 2                              The greatest! Feeling      5              0
# 3                It has a beautiful flowing qualify.      5              0
# 4                                                 👍👍      5              0
#
#   reviewCreatedVersion                  at  \
# 0                2.4.2 2021-03-15 12:57:44
# 1                2.4.2 2021-03-14 14:19:41
# 2                2.4.2 2021-03-13 19:57:50
# 3                2.4.2 2021-03-13 16:30:24
# 4                2.4.2 2021-03-13 13:46:47
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3  Thank you very much for your 5-star review!!! ... 2021-03-09 18:47:18
# 4                                               None                 NaT
#
#   app_name          app_id
# 0     Aura  com.aurahealth
# 1     Aura  com.aurahealth
# 2     Aura  com.aurahealth
# 3     Aura  com.aurahealth
# 4     Aura  com.aurahealth

# %%
gp_rvw_df['app_name'].value_counts()
# Out:
# Headspace                        200
# Wisdo                            200
# RR Eating Disorder Management    200
# eQuoo: Emotional Fitness Game    200
# Reflectly                        200
# Wysa                             200
# Virtual Hope Box                 200
# Talk Life                        200
# Habitica                         200
# Breathe2Relax                    200
# Sanvello                         200
# SuperBetter                      200
# Aura                             200
# Shine                            200
# Rootd                            200
# MyLife Meditation                200
# eMoods                           200
# PTSD Coach                       200
# Talkspace                        200
# I Am Sober                       200
# Woebot                           200
# MindShift CBT                    200
# Smiling Mind                     200
# Happify                          200
# MindDoc                          200
# DBT Coach                        200
# Remente                          200
# Ten Percent Happier              200
# Insight Timer                    200
# Lyf                              200
# HearMe                           200
# Fabulous                         200
# Ginger                           200
# Calm                             200
# Moodfit                          200
# CBT Thought Diary                200
# The Mighty                       200
# What's Up?                       200
# BetterHelp                       200
# Healthy Minds Program            173
# Rise Up + Recover                162
# NOCD                             146
# GG Self Esteem                   140
# Happyfeed                        118
# GG OCD                            81
# MoodMission                       67
# GG Self Care                      16
# Name: app_name, dtype: int64

# %%
test_2_apps = [('Breathe2Relax', 'org.t2health.breathe2relax'),
               ('CBT Thought Diary', 'com.moodtools.cbtassistant.app')]

# %%
test_2_reviews = []

for app_name, app_id in [('Breathe2Relax', 'org.t2health.breathe2relax'),
                         ('CBT Thought Diary', 'com.moodtools.cbtassistant.app')]:
    print(f'Scraping {app_name}')
    
    count = 200
    batch_num = 0
    
    if batch_num ==0:
        rvws, token = reviews(
            app_id,
            lang='en',
            country='us',
            sort=Sort.NEWEST,
            count=count
        )
        for r in rvws:
            r['app_name'] = app_name
            r['app_id'] = app_id
            
        test_2_reviews.extend(rvws)
        
        batch_num +=1 
        print(f'Batch {batch_num} completed.')
    
    else:
        rvws, token = reviews(
            app_id,
            lang='en',
            country='us',
            sort=Sort.NEWEST,
            count=count,
            continuation_token=token.token
        )
        for r in rvws:
            r['app_name'] = app_name
            r['app_id'] = app_id
            
        test_2_reviews.extend(rvws)
        
        batch_num +=1 
        print(f'Batch {batch_num} completed.')
# Out:
# Scraping Breathe2Relax
# Batch 1 completed.
# Scraping CBT Thought Diary
# Batch 1 completed.

# %%
len(test_2_reviews)
# Out:
# 400

# %%
test_2_reviews = []

for app_name, app_id in [('Breathe2Relax', 'org.t2health.breathe2relax'),
                         ('CBT Thought Diary', 'com.moodtools.cbtassistant.app')]:
    print(f'Scraping {app_name}')
    
    count = 200
    batch_num = 0
    
    rvws, token = reviews(
        app_id,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=count
    )
    for r in rvws:
        r['app_name'] = app_name
        r['app_id'] = app_id
        
    test_2_reviews.extend(rvws)
    
    time.sleep(random.randint(10,20))
    
    batch_num +=1 
    print(f'Batch {batch_num} completed.')
    
    for batch in range(49):
        rvws, token = reviews(
            app_id,
            lang='en',
            country='us',
            sort=Sort.NEWEST,
            count=count,
            continuation_token=token
        )
        for r in rvws:
            r['app_name'] = app_name
            r['app_id'] = app_id
            
#         if len(rvws) ==0:
#             print(f'No reviews left to scrape. Completed {batch_num} batches.')
#             break
            
        test_2_reviews.extend(rvws)
        
        batch_num +=1
        if batch_num%10==0:
            print(f'Batch {batch_num} completed.')
        
        time.sleep(random.randint(30,45))
# Out:
# Scraping Breathe2Relax
# Batch 1 completed.
# Batch 10 completed.
# Batch 20 completed.
# Batch 30 completed.
# Batch 40 completed.
# Batch 50 completed.
# Scraping CBT Thought Diary
# Batch 1 completed.
# Batch 10 completed.
# Batch 20 completed.
# Batch 30 completed.
# Batch 40 completed.
# Batch 50 completed.

# %%
len(test_2_reviews)
# Out:
# 17072

# %%
test_2_df = pd.DataFrame(test_2_reviews)
test_2_df.head()
# Out:
#                                             reviewId          userName  \
# 0  gp:AOqpTOFds8u_L07dpTGzHATsL1r1wbbJFgLA5QEj41E...        Steve Loos
# 1  gp:AOqpTOE0YbG3Dw13KBulI0JR0-ANk9WzpnLY3Xv2DWQ...   Poisson Bracket
# 2  gp:AOqpTOFj1Ug1Vw9XPFu32QcX17GAWxCK-tATBn3hequ...  Rosie Tobin-Moss
# 3  gp:AOqpTOGEj9oOjM64vm0WPjU2NX_1LPgsZVI5ZhxaoeZ...     Sheila Carter
# 4  gp:AOqpTOG7-iOrhiD793F1oB-i031j7n6juSk3QYGbQI4...        J. Mathews
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/-Lbc5PXq...
# 2  https://play-lh.googleusercontent.com/-poZvI7I...
# 3  https://play-lh.googleusercontent.com/-ssI23W1...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  Why should I have to log in with a password to...      1              0
# 1  So simple to use. Anything overly complicated ...      5              4
# 2  Can't even set the app up because the save but...      1              0
# 3  I can't get past the 2nd security question to ...      1              7
# 4  I can't even start an account because the app ...      1             10
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0                 None 2021-03-15 15:02:24         None       NaT
# 1       3.5.1.20200304 2021-01-07 05:48:39         None       NaT
# 2       3.5.1.20200304 2020-10-16 05:45:05         None       NaT
# 3       3.5.1.20200304 2020-10-14 05:35:04         None       NaT
# 4       3.5.1.20200304 2020-10-09 16:23:21         None       NaT
#
#         app_name                      app_id
# 0  Breathe2Relax  org.t2health.breathe2relax
# 1  Breathe2Relax  org.t2health.breathe2relax
# 2  Breathe2Relax  org.t2health.breathe2relax
# 3  Breathe2Relax  org.t2health.breathe2relax
# 4  Breathe2Relax  org.t2health.breathe2relax

# %%
test_2_df['app_name'].value_counts()
# Out:
# CBT Thought Diary    9472
# Breathe2Relax        7600
# Name: app_name, dtype: int64

# %%
test_2_df['reviewId'].nunique()
# Out:
# 1060

# %%
test_2_df['content'].nunique()
# Out:
# 1031

# %%
test_2_df['content'].value_counts().to_frame()
# Out:
#                                                     content
# Great app                                               114
# Awesome                                                 112
# Good                                                     62
# Very useful                                              51
# Very good                                                51
# ...                                                     ...
# well done app                                            12
# Strongly biased towards negative emotions. Can'...       12
# I came looking for an app implementation of the...       12
# This is one of the most useful apps out there. ...       12
# I recommend this app to my patients and they ha...       12
#
# [1031 rows x 1 columns]

# %%
b2r_test_slice = test_2_df.copy()
b2r_test_slice = b2r_test_slice.groupby('app_name').get_group('Breathe2Relax')
b2r_test_slice
# Out:
#                                                reviewId          userName  \
# 0     gp:AOqpTOFds8u_L07dpTGzHATsL1r1wbbJFgLA5QEj41E...        Steve Loos
# 1     gp:AOqpTOE0YbG3Dw13KBulI0JR0-ANk9WzpnLY3Xv2DWQ...   Poisson Bracket
# 2     gp:AOqpTOFj1Ug1Vw9XPFu32QcX17GAWxCK-tATBn3hequ...  Rosie Tobin-Moss
# 3     gp:AOqpTOGEj9oOjM64vm0WPjU2NX_1LPgsZVI5ZhxaoeZ...     Sheila Carter
# 4     gp:AOqpTOG7-iOrhiD793F1oB-i031j7n6juSk3QYGbQI4...        J. Mathews
# ...                                                 ...               ...
# 7595  lg:AOqpTOFqN9_9ZlwPo2NW1o_IEzg_lvsArBhi2xk39r1...     A Google user
# 7596  lg:AOqpTOHOE1l2aMiW-NCRGXXM110XEgvws9Y6B1mzkCu...     A Google user
# 7597  lg:AOqpTOG_JR_3Rp3s2Tfzo_sJ6olddS0gdvnzxnUyfKi...     A Google user
# 7598  lg:AOqpTOHa8r_WJSZw0H9_dSsAeE1RI_z10lLUdmTsFGT...     A Google user
# 7599  lg:AOqpTOHGixpjtyn7ALkGvoqgIjjWTZZGKlWHTUiQCXe...     A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/AOh14...
# 1     https://play-lh.googleusercontent.com/-Lbc5PXq...
# 2     https://play-lh.googleusercontent.com/-poZvI7I...
# 3     https://play-lh.googleusercontent.com/-ssI23W1...
# 4     https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                 ...
# 7595  https://play-lh.googleusercontent.com/EGemoI2N...
# 7596  https://play-lh.googleusercontent.com/EGemoI2N...
# 7597  https://play-lh.googleusercontent.com/EGemoI2N...
# 7598  https://play-lh.googleusercontent.com/EGemoI2N...
# 7599  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0     Why should I have to log in with a password to...      1              0
# 1     So simple to use. Anything overly complicated ...      5              4
# 2     Can't even set the app up because the save but...      1              0
# 3     I can't get past the 2nd security question to ...      1              7
# 4     I can't even start an account because the app ...      1             10
# ...                                                 ...    ...            ...
# 7595  If you could give the option of retain the bre...      4              1
# 7596  Why does this app needs to know where i am? Wa...      1              1
# 7597  Amazing, works every time. I highly recommend ...      5              0
# 7598  Great in assisting me when I have a panic atta...      5             19
# 7599  Perfect app for relaxing. It also help you go ...      5              5
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                    None 2021-03-15 15:02:24         None       NaT
# 1          3.5.1.20200304 2021-01-07 05:48:39         None       NaT
# 2          3.5.1.20200304 2020-10-16 05:45:05         None       NaT
# 3          3.5.1.20200304 2020-10-14 05:35:04         None       NaT
# 4          3.5.1.20200304 2020-10-09 16:23:21         None       NaT
# ...                   ...                 ...          ...       ...
# 7595                2.4.2 2012-01-09 02:40:53         None       NaT
# 7596                 None 2011-12-31 09:54:17         None       NaT
# 7597                2.4.2 2011-12-30 04:53:38         None       NaT
# 7598                2.4.2 2011-12-29 02:35:27         None       NaT
# 7599                2.4.2 2011-12-23 15:20:52         None       NaT
#
#            app_name                      app_id
# 0     Breathe2Relax  org.t2health.breathe2relax
# 1     Breathe2Relax  org.t2health.breathe2relax
# 2     Breathe2Relax  org.t2health.breathe2relax
# 3     Breathe2Relax  org.t2health.breathe2relax
# 4     Breathe2Relax  org.t2health.breathe2relax
# ...             ...                         ...
# 7595  Breathe2Relax  org.t2health.breathe2relax
# 7596  Breathe2Relax  org.t2health.breathe2relax
# 7597  Breathe2Relax  org.t2health.breathe2relax
# 7598  Breathe2Relax  org.t2health.breathe2relax
# 7599  Breathe2Relax  org.t2health.breathe2relax
#
# [7600 rows x 12 columns]

# %%
b2r_test_slice['reviewId'].nunique()
# Out:
# 304

# %%
cbt_test_slice = test_2_df.copy()
cbt_test_slice = cbt_test_slice.groupby('app_name').get_group('CBT Thought Diary')
cbt_test_slice
# Out:
#                                                 reviewId          userName  \
# 7600   gp:AOqpTOFX6dBhNEh50UAUgG9z1-lAL0OtNW99hUi3Fpz...      Sana Qureshi
# 7601   gp:AOqpTOF_uUezDUJXhzg8ey718KO0rtvm8m64PMiPkPk...          cleojaye
# 7602   gp:AOqpTOFIRJKayMPC_NkS12YMrF4Z6hhMM5Ky7kpPXBB...           Cory Ag
# 7603   gp:AOqpTOEMATZSQaoS36SiACJ2CwQZKNJGAlMYF50iWcO...       Zahir Butta
# 7604   gp:AOqpTOFzoeR5ceka-pu_4l_QhtfRE7B1mgWjzaC-9R-...      Jamie Barber
# ...                                                  ...               ...
# 17067  gp:AOqpTOFUWs0HDLe8umwT5uHyTLj-t1GZLZr0Ru4PVtx...     Amanda Norris
# 17068  gp:AOqpTOFBn-O7qT0StytRbhHD0qxBaQAMbpGXWmKEQkn...   Hannah Sweetman
# 17069  gp:AOqpTOH_P4-HI1u4dhujH1iTe0DY5B5F-4Vp5wMfgJC...  Shandi Pitchford
# 17070  gp:AOqpTOEuW2Yqyq99GFLMWlA56nLbym4SI72j-Zvpova...        Izaac Cole
# 17071  gp:AOqpTOEZp0UUUv0WzpUnbf6V6nZrEvQ-RnzesezTtfx...  audrey arsenault
#
#                                                userImage  \
# 7600   https://play-lh.googleusercontent.com/a-/AOh14...
# 7601   https://play-lh.googleusercontent.com/-B9MbtTH...
# 7602   https://play-lh.googleusercontent.com/a-/AOh14...
# 7603   https://play-lh.googleusercontent.com/-PfD5DM7...
# 7604   https://play-lh.googleusercontent.com/-eif6lrp...
# ...                                                  ...
# 17067  https://play-lh.googleusercontent.com/-HzpftE9...
# 17068  https://play-lh.googleusercontent.com/a-/AOh14...
# 17069  https://play-lh.googleusercontent.com/a-/AOh14...
# 17070  https://play-lh.googleusercontent.com/a-/AOh14...
# 17071  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                  content  score  \
# 7600   I love the fact that this app doesn't just tel...      5
# 7601   I'm so grateful that this app was made. I had ...      5
# 7602   good stuff. I feel like they've put a good chu...      4
# 7603                     Excellent tool to help you cope      5
# 7604   I haven't used the app much but I received ver...      5
# ...                                                  ...    ...
# 17067  I love how it breaks everything down so I dont...      5
# 17068                          Finding this very helpful      5
# 17069                                          Love it!!      5
# 17070  So useful for analysing your thoughts and a gr...      5
# 17071  Easy to navigate through and follow along espe...      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 7600               0               4.1.11 2021-03-15 10:04:23         None
# 7601               0               4.1.11 2021-03-14 04:09:45         None
# 7602               0               4.1.11 2021-03-12 17:20:24         None
# 7603               0               4.1.11 2021-03-10 11:49:50         None
# 7604               0               4.1.11 2021-03-07 04:08:48         None
# ...              ...                  ...                 ...          ...
# 17067              0                  3.2 2020-04-09 11:31:52         None
# 17068              0                  3.2 2020-04-08 16:25:22         None
# 17069              0                  3.2 2020-04-08 12:42:53         None
# 17070              0                  3.2 2020-04-08 05:25:54         None
# 17071              0                  3.2 2020-04-07 21:48:01         None
#
#       repliedAt           app_name                          app_id
# 7600        NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 7601        NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 7602        NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 7603        NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 7604        NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# ...         ...                ...                             ...
# 17067       NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 17068       NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 17069       NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 17070       NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
# 17071       NaT  CBT Thought Diary  com.moodtools.cbtassistant.app
#
# [9472 rows x 12 columns]

# %%
cbt_test_slice['reviewId'].nunique()
# Out:
# 756

# %%
gg_ocd_all = reviews_all(
    'air.com.samuramu.gg.oc',
    sleep_milliseconds=random.randint(10**3, 10**6),
    lang='en',
    country='us',
    sort=Sort.NEWEST
)

# %%
len(gg_ocd_all)
# Out:
# 81

# %%
b2r_all = reviews_all(
    'org.t2health.breathe2relax',
    sleep_milliseconds=random.randint(10*2, 10**4),
    lang='en',
    country='us',
    sort=Sort.NEWEST
)

# %%
len(b2r_all)
# Out:
# 304

# %%
test_2_reviews_2 = []

for app_name, app_id in [('Breathe2Relax', 'org.t2health.breathe2relax'),
                         ('CBT Thought Diary', 'com.moodtools.cbtassistant.app')]:
    print(f'Scraping {app_name}')
    
    count = 200
    batch_num = 0
    
    rvws, token = reviews(
        app_id,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=count
    )
    for r in rvws:
        r['app_name'] = app_name
        r['app_id'] = app_id
        
    test_2_reviews_2.extend(rvws)
    
    time.sleep(random.randint(10,20))
    
    batch_num +=1 
    print(f'Batch {batch_num} completed.')
    
    
    
    pre_review_ids = []
    for rvw in test_2_reviews_2:
        pre_review_ids.append(rvw['reviewId'])
    

    for batch in range(49):
        rvws, token = reviews(
            app_id,
            lang='en',
            country='us',
            sort=Sort.NEWEST,
            count=count,
            continuation_token=token
        )
        
        
        new_review_ids = []
        for r in rvws:
            new_review_ids.append(r['reviewId'])
            r['app_name'] = app_name
            r['app_id'] = app_id
     
        test_2_reviews_2.extend(rvws)
        
        batch_num +=1
        
        all_review_ids = pre_review_ids + new_review_ids
        if len(set(pre_review_ids)) == len(set(all_review_ids)):
            print(f'No reviews left to scrape. Completed {batch_num} batches.')
            break
        
        pre_review_ids = all_review_ids
        
        
        if batch_num%10==0:
            print(f'Batch {batch_num} completed.')
        
        time.sleep(random.randint(30,45))
# Out:
# Scraping Breathe2Relax
# Batch 1 completed.
# No reviews left to scrape. Completed 3 batches.
# Scraping CBT Thought Diary
# Batch 1 completed.
# No reviews left to scrape. Completed 5 batches.

# %%
test_2_df_2 = pd.DataFrame(test_2_reviews_2)
test_2_df_2.head()
# Out:
#                                             reviewId          userName  \
# 0  gp:AOqpTOFds8u_L07dpTGzHATsL1r1wbbJFgLA5QEj41E...        Steve Loos
# 1  gp:AOqpTOE0YbG3Dw13KBulI0JR0-ANk9WzpnLY3Xv2DWQ...   Poisson Bracket
# 2  gp:AOqpTOFj1Ug1Vw9XPFu32QcX17GAWxCK-tATBn3hequ...  Rosie Tobin-Moss
# 3  gp:AOqpTOGEj9oOjM64vm0WPjU2NX_1LPgsZVI5ZhxaoeZ...     Sheila Carter
# 4  gp:AOqpTOG7-iOrhiD793F1oB-i031j7n6juSk3QYGbQI4...        J. Mathews
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/-Lbc5PXq...
# 2  https://play-lh.googleusercontent.com/-poZvI7I...
# 3  https://play-lh.googleusercontent.com/-ssI23W1...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  Why should I have to log in with a password to...      1              0
# 1  So simple to use. Anything overly complicated ...      5              4
# 2  Can't even set the app up because the save but...      1              0
# 3  I can't get past the 2nd security question to ...      1              7
# 4  I can't even start an account because the app ...      1             10
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0                 None 2021-03-15 15:02:24         None       NaT
# 1       3.5.1.20200304 2021-01-07 05:48:39         None       NaT
# 2       3.5.1.20200304 2020-10-16 05:45:05         None       NaT
# 3       3.5.1.20200304 2020-10-14 05:35:04         None       NaT
# 4       3.5.1.20200304 2020-10-09 16:23:21         None       NaT
#
#         app_name                      app_id
# 0  Breathe2Relax  org.t2health.breathe2relax
# 1  Breathe2Relax  org.t2health.breathe2relax
# 2  Breathe2Relax  org.t2health.breathe2relax
# 3  Breathe2Relax  org.t2health.breathe2relax
# 4  Breathe2Relax  org.t2health.breathe2relax

# %%
b2r_test_slice_2 = test_2_df_2.copy()
b2r_test_slice_2 = b2r_test_slice_2.groupby('app_name').get_group('Breathe2Relax')
b2r_test_slice_2['reviewId'].nunique()
# Out:
# 304

# %%
cbt_test_slice_2 = test_2_df_2.copy()
cbt_test_slice_2 = cbt_test_slice_2.groupby('app_name').get_group('CBT Thought Diary')
cbt_test_slice_2['reviewId'].nunique()
# Out:
# 757

# %%
cbt_all = reviews_all(
    'com.moodtools.cbtassistant.app',
    sleep_milliseconds=random.randint(10*2, 10**4),
    lang='en',
    country='us',
    sort=Sort.NEWEST
)

# %%
len(cbt_all)
# Out:
# 757

# %%
min(cbt_test_slice_2['at'])
# Out:
# Timestamp('2014-07-08 08:59:50')

# %%
max(cbt_test_slice_2['at'])
# Out:
# Timestamp('2021-03-16 04:03:16')

# %%
min(b2r_test_slice_2['at'])
# Out:
# Timestamp('2011-12-23 15:20:52')

# %%
max(b2r_test_slice_2['at'])
# Out:
# Timestamp('2021-03-15 15:02:24')

# %%
app_df = pd.read_csv('Data/mha_app_info.csv', usecols=['app_name', 'iOS_app_name', 'iOS_app_id'])
app_df.head()
# Out:
#                          app_name                  iOS_app_name  iOS_app_id
# 0                        Aloe Bud                      aloe-bud  1318382054
# 1                            Aura         aura-meditation-sleep  1114223104
# 2                      BetterHelp  betterhelp-online-counseling   995252384
# 3                   Breathe2Relax                 breathe2relax   425720246
# 4  Breathwrk: Breathing Exercises                     breathwrk  1481804500

# %%
## Store list of app ids and app names to loop through for App Store
app_store_ids = list(app_df['iOS_app_id'])
app_store_names = list(app_df['iOS_app_name'])

# %%
app_store_names[:2]
# Out:
# ['aloe-bud', 'aura-meditation-sleep']

# %%
# ## Instantiate AppStore class for desired app
# my_app = AppStore(
#   country='us',        # required, 2-letter code
#   app_name='aloe-bud', # required, found in app's url
#   app_id=1318382054    # technically not required, found in app's url
# ) 
    
# # Use review method to scrape reviews from App Store
# my_app.review(
#   how_many=100, # if not provided, defaults to scraping all
#   after,        # optional, datetime object, filter old reviews
#   sleep         # optional, int, seconds between each call
# )

# %%
import datetime as dt
from tzlocal import get_localzone

import random
import time

import pandas as pd
import numpy as np

# %%
## Set up loop to go through first 2 apps
for app_name, app_id in zip(app_store_names[:2], app_store_ids[:2]):
    
    start = dt.datetime.now(tz=get_localzone())
    fmt= "%m/%d/%y - %T %p"
    
    print('---'*20)
    print('---'*20)    
    print(f'***** {app_name} started at {start.strftime(fmt)}')
    print()
    
    # instantiate AppStore for app
    app_ = AppStore(country='us', app_name=app_name, app_id=app_id)
    
    # grab reviews posted since February 28, 2020 and limit to 10,000 reviews
    app_.review(how_many=10000,
                after=dt.datetime(2020, 2, 28),
                sleep=random.randint(20,25))
    
    reviews = app_.reviews
    
    # add keys to store information about which app each review is for
    for rvw in reviews:
        rvw['app_name'] = app_name
        rvw['app_id'] = app_id
    
    
    print(f"""Done scraping {app_name}. 
    Scraped a total of {app_.reviews_count} reviews.\n""")
    
    # convert list of dicts to Pandas DataFrame
    review_df = pd.DataFrame(reviews)
    review_df.to_csv('Data/' + app_name + '.csv', index=False)
    
    end = dt.datetime.now(tz=get_localzone())
    
    print(f"""Successfully wrote {app_name} reviews to csv
    at {end.strftime(fmt)}.\n""")
    print(f'Time elapsed for {app_name}: {end-start}')
    print('---'*20)
    print('---'*20)
    print('\n')
    
    time.sleep(random.randint(5,10))
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** aloe-bud started at 03/24/21 - 13:32:37 PM
# 2021-03-24 13:32:38,177 [INFO] Base - Initialised: AppStore('us', 'aloe-bud', 1318382054)
# 2021-03-24 13:32:38,178 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/aloe-bud/id1318382054
# 2021-03-24 13:33:03,290 [INFO] Base - [id:1318382054] Fetched 20 reviews (20 fetched in total)
# 2021-03-24 13:33:53,562 [INFO] Base - [id:1318382054] Fetched 60 reviews (60 fetched in total)
# 2021-03-24 13:34:43,871 [INFO] Base - [id:1318382054] Fetched 67 reviews (67 fetched in total)
# 2021-03-24 13:35:34,281 [INFO] Base - [id:1318382054] Fetched 69 reviews (69 fetched in total)
# 2021-03-24 13:36:24,674 [INFO] Base - [id:1318382054] Fetched 70 reviews (70 fetched in total)
# 2021-03-24 13:36:50,153 [INFO] Base - [id:1318382054] Fetched 73 reviews (73 fetched in total)
# Done scraping aloe-bud.
#     Scraped a total of 73 reviews.
#
# Successfully wrote aloe-bud reviews to csv
#     at 03/24/21 - 13:36:50 PM.
#
# Time elapsed for aloe-bud: 0:04:12.205773
# ------------------------------------------------------------
# ------------------------------------------------------------
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** aura-meditation-sleep started at 03/24/21 - 13:37:00 PM
# 2021-03-24 13:37:01,171 [INFO] Base - Initialised: AppStore('us', 'aura-meditation-sleep', 1114223104)
# 2021-03-24 13:37:01,172 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/aura-meditation-sleep/id1114223104
# 2021-03-24 13:37:21,321 [INFO] Base - [id:1114223104] Fetched 6 reviews (6 fetched in total)
# 2021-03-24 13:38:01,855 [INFO] Base - [id:1114223104] Fetched 19 reviews (19 fetched in total)
# 2021-03-24 13:38:42,887 [INFO] Base - [id:1114223104] Fetched 30 reviews (30 fetched in total)
# 2021-03-24 13:39:23,449 [INFO] Base - [id:1114223104] Fetched 41 reviews (41 fetched in total)
# 2021-03-24 13:39:33,233 [ERROR] Base - Keyboard interrupted
# 2021-03-24 13:39:33,234 [INFO] Base - [id:1114223104] Fetched 44 reviews (44 fetched in total)
# Done scraping aura-meditation-sleep.
#     Scraped a total of 44 reviews.
#
# Successfully wrote aura-meditation-sleep reviews to csv
#     at 03/24/21 - 13:39:33 PM.
#
# Time elapsed for aura-meditation-sleep: 0:02:33.074484
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
aloe_bud_df = pd.read_csv('Data/aloe-bud.csv')
aloe_bud_df.head()
# Out:
#                   date          userName  isEdited  rating  \
# 0  2020-10-09 12:19:21            knsky8     False       5
# 1  2021-03-01 03:51:42  Candycrushgirl60     False       5
# 2  2021-03-13 01:16:42   hhhhhjghjhhnjgh     False       5
# 3  2020-06-29 12:20:49           ekg2005     False       5
# 4  2020-06-26 21:38:49   Shoshana Lipson     False       5
#
#                                 title  \
# 0  Simple gentle ways to a better you
# 1           This app changed my life!
# 2          Love this app! - MOST READ
# 3           Such a cute, helpful app!
# 4                        So Amazing!!
#
#                                               review  app_name      app_id
# 0  I really am enjoying this app and once I start...  aloe-bud  1318382054
# 1  I have tried a lot of apps that said they woul...  aloe-bud  1318382054
# 2  IT JUST CAN'T GET MUCH BETTER! it really helps...  aloe-bud  1318382054
# 3  I don’t usually write reviews for apps, but I ...  aloe-bud  1318382054
# 4  Where to begin before I started using aloe bud...  aloe-bud  1318382054
