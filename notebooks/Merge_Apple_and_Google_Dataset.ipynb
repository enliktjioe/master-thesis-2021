# %% [markdown]
# # Libraries

# %%
from utils import *
import pandas as pd

import pickle

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

config = get_config('config.yaml')

# %% [markdown]
# # Merge Apple and Google

# %% [markdown]
# ## Bolt

# %%
apple = pd.read_csv(config['csv_input_local']['bolt_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
apple
# Out:
# Total Apple reviews: 3154
#            userName                                             review  \
# 0     Tkay_Browning  I love bolt. I don’t use uber often because on...
# 1         Livvii_xo  So annoyed with this app!! Definitely the wors...
# 2      Kazem Sharan  I’ve been using bolt for a month now. I had a ...
# 3     Doctor A Theo  To make things clear, I am not a regular revie...
# 4       Maria348794  I have used the app 3 or 4 times and I thought...
# ...             ...                                                ...
# 3149    -Randycool-  Зачем регестрироваться? Я просто хочу посмотре...
# 3150      Jaak Sarv                                                 :)
# 3151      AlexEesti  Слишком мало машин, иногда нет вообще, часто п...
# 3152           Xfrz  1. samm: positsioneerime telefoni\n2. samm: "V...
# 3153       dhanenko  Taxify's purpose was that you can CHOOSE your ...
#
#       rating                 date
# 0          5  2019-07-20 11:51:59
# ...

# %%
google = pd.read_csv(config['csv_input_local']['bolt_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
google
# Out:
# Total Google reviews: 51907
#               userName                                             review  \
# 0          davide masi  The first thing I noticed is that you can't pr...
# 1        Mymoena Saban  Your GPS setting around Cape Town Internationa...
# 2             hello 87  I was invited by my friend and was given a £10...
# 3         Hilary Meyer  Your drivers are great BUT your support is no ...
# 4            Kenneth B  Loving the app, but can only give it a medium ...
# ...                ...                                                ...
# 51902  jackline munyao       l gzc😤😣😬😠😬😕😉😣😣😣😈😕😯😄😤😯😈😯😥😯😨😲😥😤😡😨😨😤😬😣😣😤😥😣😨😲; "
# 51903   shahid charles        📹📼📼🎈📼📼📼📼📼💻📼⏰⏰🔐🔔🔔🔔🔔🐣😞😒😒😛🐱📱🐚🐚🐚🐚🐚🐚🐚🐚🐚🐚⛺🌅🌅🐣🐣🐣🐜🐟
# 51904    A Google user                                                NaN
# 51905            Mar V                                                NaN
# 51906    A Google user                                                NaN
#
#        rating                 date
# ...

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 55061
#             userName                                             review  \
# 0        davide masi  The first thing I noticed is that you can't pr...
# 1      Mymoena Saban  Your GPS setting around Cape Town Internationa...
# 2           hello 87  I was invited by my friend and was given a £10...
# 3       Hilary Meyer  Your drivers are great BUT your support is no ...
# 4          Kenneth B  Loving the app, but can only give it a medium ...
# ...              ...                                                ...
# 55056    -Randycool-  Зачем регестрироваться? Я просто хочу посмотре...
# 55057      Jaak Sarv                                                 :)
# 55058      AlexEesti  Слишком мало машин, иногда нет вообще, часто п...
# 55059           Xfrz  1. samm: positsioneerime telefoni\n2. samm: "V...
# 55060       dhanenko  Taxify's purpose was that you can CHOOSE your ...
#
#        rating                 date
# 0           1  2020-12-20 01:51:18
# ...

# %%
df_merged.to_csv(config['csv_input_local']['bolt_apple_google'])

# %% [markdown]
# ## Uber

# %%
apple = pd.read_csv(config['csv_input_local']['uber_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 10342

# %%
google = pd.read_csv(config['csv_input_local']['uber_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 10000

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 20342
#                   userName                                             review  \
# 0         Cassandra Winton  Amazing just absolutely love the cheap fares a...
# 1              Vivek Singh  Superb services with Uber cab..I loving it.Tha...
# 2      Bernardino Espinoza  Always on time. Courteous drivers... Highly re...
# 3         Lavenia Mitchell  I had to use Lyft the last 2 days because Uber...
# 4              hassan ijaz  Terrible.. Drivers are rude and Uber don't eve...
# ...                    ...                                                ...
# 20337               TPSLBB  Fantastic Service - Great App - though it coul...
# 20338                Kpila  Good service but no promotion at all to client...
# 20339         Vinnybelfast  Rising Price. They chargede x3.25 the normal f...
# 20340          avinash2904  The app is stuck on the login screen after the...
# 20341                jw548  I use Uber regularly. Today I ordered a car fr...
#
# ...

# %%
df_merged.to_csv(config['csv_input_local']['uber_apple_google'])

# %% [markdown]
# ## Blablacar

# %%
apple = pd.read_csv(config['csv_input_local']['blablacar_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 23308

# %%
google = pd.read_csv(config['csv_input_local']['blablacar_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 21172

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 44480
#                             userName  \
# 0                      sachin sharma
# 1                   Nagesh Choudhary
# 2                         AJAY KUMAR
# 3                      suresh tapila
# 4                     Rajendra Gupta
# ...                              ...
# 44475                      changeale
# 44476                 TantonioII1234
# 44477                         dichas
# 44478            All travelling ways
# 44479  This is my unique username123
#
#                                                   review  rating  \
# 0      If someone use this app for providing a cab se...       5
# 1      It's best facility for both us (car owner & co...       5
# 2      Such a good app. Gives quick and comfy Travel ...       5
# 3      nice.please look into the option of sharing li...       5
# 4      Very good app. Used it multiple times and shar...       4
# ...                                                  ...     ...
# ...

# %%
df_merged.to_csv(config['csv_input_local']['blablacar_apple_google'])

# %% [markdown]
# ## Cabify

# %%
apple = pd.read_csv(config['csv_input_local']['cabify_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 7384

# %%
google = pd.read_csv(config['csv_input_local']['cabify_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 3261

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 10645
#                        userName  \
# 0                   Zonghao Pan
# 1                   Danny Storm
# 2                Francesco Piai
# 3              Candice Williams
# 4                Youngsook Love
# ...                         ...
# 10640                Tin tin 14
# 10641                    magobe
# 10642              l3gendario87
# 10643                ainhoamont
# 10644  nada contento con cabify
#
#                                                   review  rating  \
# 0      my uber had something wrong and didn't work. T...       1
# 1      Horrible Service, my account has been blocked ...       1
# 2      Referencia #27639559 I am not able to call or ...       1
# 3      Whats the point of reserving a cabify several ...       1
# 4      I use Cabify since 2016. I had issue with the ...       1
# ...                                                  ...     ...
# 10640  Gracias a cabify ahora puedo disfrutar de mis ...       5
# ...

# %%
df_merged.to_csv(config['csv_input_local']['cabify_apple_google'])

# %% [markdown]
# ## Via

# %%
apple = pd.read_csv(config['csv_input_local']['via_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 2392

# %%
google = pd.read_csv(config['csv_input_local']['via_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 1873

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 4265
#                  userName                                             review  \
# 0             S.D. Nelson  I enjoy this app a lot, the only thing that I ...
# 1            Joshua Clark  I don't know what kind of GPS Via uses but it ...
# 2       Cynthia Parkhouse  This app is getting worse and worse. Today I r...
# 3                Angeal M  App is super glitchy, won't accept payment fro...
# 4         Michael Andrade  Very reliable, relaxing and safe.. Get to go w...
# ...                   ...                                                ...
# 4260         Funnyscreens  Use my code, jat6s9, to get $20 of free credit...
# 4261             Eric1901  This app and service is UNBELIEVABLE. Has comp...
# 4262             Ab111186  This is a great service, use it daily. Always ...
# 4263            Jackie7i4  As a newly made gimp from a running stress fra...
# 4264  Blahwjfjdpcnsjfjfid  Stupid app doesn't let me enter my credit card...
#
# ...

# %%
df_merged.to_csv(config['csv_input_local']['via_apple_google'])

# %% [markdown]
# ## Getaround

# %%
apple = pd.read_csv(config['csv_input_local']['getaround_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 2488

# %%
google = pd.read_csv(config['csv_input_local']['getaround_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 731

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 3219
#                userName                                             review  \
# 0             Stefan B.  The idea is top, the app is good. There could ...
# 1       Michael Wandera  AVOID! Poorly Vetted Drivers! I used this app ...
# 2          Adrien Bacle  Getaround took more than 12 hours to validate ...
# 3       Julia Christian  The way of advertising prices is very misleadi...
# 4        Brian Giannini  The explanations for ending the rental are unc...
# ...                 ...                                                ...
# 3214          Javivi001  Necesitas un coche? Quieres alguilar un coche ...
# 3215         Monobot123  Perfecta para el alquiler de coches entre part...
# 3216   David de Vicente  Es una gran aplicacion, facil de utilizar, int...
# 3217        Recreativos  Esta app funciona perfectamente para realizar ...
# 3218  Joaksssssssssssss  La idea es buena, pero solo aparecen coches en...
#
#       rating                 date
# ...

# %%
df_merged.to_csv(config['csv_input_local']['getaround_apple_google'])

# %% [markdown]
# ## Ola Cabs

# %%
apple = pd.read_csv(config['csv_input_local']['olacabs_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 922

# %%
google = pd.read_csv(config['csv_input_local']['olacabs_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 10000

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 10922
#                    userName  \
# 0      AMIT KUMAR CHAUDHARY
# 1             ritesh pilare
# 2               Shana Aysha
# 3        Kshitij Khandelwal
# 4             Swaronika Kar
# ...                     ...
# 10917               mmari88
# 10918            osian ryan
# 10919            smishinker
# 10920              Superzor
# 10921          Katiebelissi
#
#                                                   review  rating  \
# 0      Its a bad experience as i have not abke to log...       2
# 1      This app sucks!!! Don't use Ola, go and use Ub...       1
# 2      I was charged 381 when the estimated cost was ...       1
# 3      Whenever i try to book one ride, my ride disap...       1
# 4      They should understand, when people in very ne...       1
# ...                                                  ...     ...
# 10917  I gave twice my refer and earn code to differe...       1
# ...

# %%
df_merged.to_csv(config['csv_input_local']['olacabs_apple_google'])

# %% [markdown]
# ## Taxi.eu

# %%
apple = pd.read_csv(config['csv_input_local']['taxieu_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 564

# %%
google = pd.read_csv(config['csv_input_local']['taxieu_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 211

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 775
#                   userName                                             review  \
# 0           Nikolay Demich  Why the payment with card does not work? Why t...
# 1             Greg Sigalov  I've used 4 other taxi apps in other countries...
# 2    Louis-philippe Marier  The worst app i ever saw. Seriously, between, ...
# 3            Michael Booth  i tried this in antwerp. The arrival time said...
# 4           Jeroen De Dauw  11%. That is how much battery this app uses pe...
# ..                     ...                                                ...
# 770                 fricus  Der Rezensent Taxiiimmm verteilt seinen einzig...
# 771       Milena_mäusschen  Hab die Taxi App runtergeladen und getestet, m...
# 772           Krzysztof007  Funktioniert super schnell und zuverlässig. We...
# 773             bhoernchen  Laut Beschreibung über 40.000 Taxis und das in...
# 774     Usedforthelasttime       Not reliable service. Use some other company
#
# ...

# %%
df_merged.to_csv(config['csv_input_local']['taxieu_apple_google'])

# %% [markdown]
# ## Free Now

# %%
apple = pd.read_csv(config['csv_input_local']['freenow_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 14350

# %%
google = pd.read_csv(config['csv_input_local']['freenow_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 11078

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 25428
#                userName                                             review  \
# 0             Danissima  Awful experience... I don't know if there were...
# 1       Mahmudur Rahman  I find it hard to rate a cab firm this low but...
# 2      Yasmeen Kerflani  Absolute joke of this app. Prebooked taxi yest...
# 3          Caoimhe Cray  This app is awful. It won't open on my phone a...
# 4       Darrell Elliott  Updated my review to 1 from 3 stars because it...
# ...                 ...                                                ...
# 25423           VMarzal                                                  .
# 25424            Nuflis                                                  .
# 25425          VModulor                                                 5*
# 25426      Dani Alcalde  Sólo funciona en Madrid y Barcelona. En el res...
# 25427              zeme                                                  .
#
#        rating                 date
# ...

# %%
df_merged.to_csv(config['csv_input_local']['freenow_apple_google'])

# %% [markdown]
# ## Yandex Go

# %%
apple = pd.read_csv(config['csv_input_local']['yandexgo_apple'],
                    usecols = ['userName','review','rating','date'])
apple = apple.reset_index(drop=True)
total_reviews = len(apple)

print(f'Total Apple reviews: {total_reviews} \n')
# Out:
# Total Apple reviews: 171

# %%
google = pd.read_csv(config['csv_input_local']['yandexgo_google'],
                     usecols = ['userName','content','score','at'])
google = google.rename(columns={'content': 'review','score': 'rating', 'at':'date'})

google = google.reset_index(drop=True)
total_reviews = len(google)

print(f'Total Google reviews: {total_reviews} \n')
# Out:
# Total Google reviews: 7053

# %%
# merge both apple and google
df_merged = google.append(apple, ignore_index=True)
total_reviews = len(df_merged)

print(f'Total merged reviews: {total_reviews} \n')
df_merged
# Out:
# Total merged reviews: 7224
#                   userName                                             review  \
# 0     Eugen-Andrei Coliban  In general, the app is awesome, but there are ...
# 1                      A B  Bad expirience in Chisinau. Price at the end o...
# 2            Saba Tsibadze  This is the worst experience one can have with...
# 3               Dumb Phone  OK in the beginning but now gets worse with ev...
# 4                   Nikita  Impossible to rate a driver if you dismissed a...
# ...                    ...                                                ...
# 7219                 Dtert              Не смогла активировать номер телефона
# 7220              marryost  Очень приятный мужчина!!!!! Успехов!\nВсем вод...
# 7221          NightKrauler  Сложно вызвать такси в любое время , а так цен...
# 7222          Milana536747  That had promotion -50% with credit card, i or...
# 7223                 vuhva  Phone number isn’t allowed. Seems developer do...
#
# ...

# %%
df_merged.to_csv(config['csv_input_local']['yandexgo_apple_google'])

# %% [markdown]
# # Merge all 10 Apps Review

# %%
bolt = pd.read_csv(config['csv_input_local']['bolt_apple_google'], index_col=0)
uber = pd.read_csv(config['csv_input_local']['uber_apple_google'], index_col=0)
blablacar = pd.read_csv(config['csv_input_local']['blablacar_apple_google'], index_col=0)
cabify = pd.read_csv(config['csv_input_local']['cabify_apple_google'], index_col=0)
via = pd.read_csv(config['csv_input_local']['via_apple_google'], index_col=0)
getaround = pd.read_csv(config['csv_input_local']['getaround_apple_google'], index_col=0)
olacabs = pd.read_csv(config['csv_input_local']['olacabs_apple_google'], index_col=0)
taxieu = pd.read_csv(config['csv_input_local']['taxieu_apple_google'], index_col=0)
freenow = pd.read_csv(config['csv_input_local']['freenow_apple_google'], index_col=0)
yandexgo = pd.read_csv(config['csv_input_local']['yandexgo_apple_google'], index_col=0)

# %%
list_df = [bolt, uber, blablacar, cabify, via,
           getaround, olacabs, taxieu, freenow, yandexgo]
df_all = pd.concat(list_df)
df_all
# Out:
#            userName                                             review  \
# 0       davide masi  The first thing I noticed is that you can't pr...
# 1     Mymoena Saban  Your GPS setting around Cape Town Internationa...
# 2          hello 87  I was invited by my friend and was given a £10...
# 3      Hilary Meyer  Your drivers are great BUT your support is no ...
# 4         Kenneth B  Loving the app, but can only give it a medium ...
# ...             ...                                                ...
# 7219          Dtert              Не смогла активировать номер телефона
# 7220       marryost  Очень приятный мужчина!!!!! Успехов!\nВсем вод...
# 7221   NightKrauler  Сложно вызвать такси в любое время , а так цен...
# 7222   Milana536747  That had promotion -50% with credit card, i or...
# 7223          vuhva  Phone number isn’t allowed. Seems developer do...
#
#       rating                 date
# 0          1  2020-12-20 01:51:18
# 1          4  2020-12-09 17:45:31
# ...

# %%
df_all.to_csv(config['csv_input_local']['all_reviews'])
