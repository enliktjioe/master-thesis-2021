# %%
import pandas as pd
import re

# %%
def get_df_and_length(csvInput, columnToUsed):
    url='https://drive.google.com/uc?id=' + csvInput.split('/')[-2]
    df = pd.read_csv(url, usecols=columnToUsed)

    # preprocessing csv input 


    # decode all emoji characters
    # https://stackoverflow.com/a/57514515/2670476
    df = df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

    # Replace all non-letters with space
    df.content = df.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.content).split()), 1)

    # remove all review with total characters less than 20 (such as only emoji)
    df = df[df.content.str.len()>=20]

#     df = df[0:200]

    length = len(df)
    return df, length

# %%
CSV_INPUT = 'https://drive.google.com/file/d/1qWuyf3UrpaU5xnxLmO3GMFa6zybSFYQh/view?usp=sharing'
USE_COLS = ['userName', 'content', 'score']
df, length = get_df_and_length(csvInput = CSV_INPUT, columnToUsed = USE_COLS)
print('length = ' + str(length))
print('\n')
# Out:
# length = 30099

# %%
df
# Out:
#             userName                                            content score
# 0        davide masi  The first thing I noticed is that you can t pr...     1
# 1      Mymoena Saban  Your GPS setting around Cape Town Internationa...     4
# 2           hello 87  I was invited by my friend and was given a fre...     1
# 3       Hilary Meyer  Your drivers are great BUT your support is no ...     3
# 4          Kenneth B  Loving the app but can only give it a medium r...     3
# ...              ...                                                ...   ...
# 48593  A Google user                             Absolutely outstanding     5
# 48612      Klenam TV                             Exceptional experience     5
# 48694  George Acquah                               Wonderful experience     5
# 48705  Sylvia Nortey                               Exceptional services     5
# 48818  A Google user                         It is the best of the best     5
#
# [30099 rows x 3 columns]

# %%
df['score'] = df['score'].astype(int)

# %%
df_agg = df['score'].mean()
df_agg
# Out:
# 3.5117445762317683

# %%
df_agg = df.groupby(['userName']).size().reset_index(name='counts')
df_agg
# Out:
#                   userName  counts
# 0                                2
# 1                               56
# 2                                1
# 3                       27       1
# 4                       '        1
# ...                    ...     ...
# 28078               zuby u       1
# 28079         zunaid moosa       1
# 28080      zura ghonghadze       1
# 28081        zwa Venda Dee       1
# 28082  zwelandile saliwane       1
#
# [28083 rows x 2 columns]

# %%
df_agg[df_agg['counts']>2]
# Out:
#            userName  counts
# 1                        56
# 36    A Google user    1865
# 988            Alex       5
# 4790            Dan       3
# 8257   Gugu Mthembu       3

# %%
df_agg['userName'].to_list()
# Out:
# ['',
#  ' ',
#  '  ',
#  ' 27',
#  "' ",
#  "'Mipe Tuakli-Lawson",
#  '- AfandiyevC',
#  '- Raes -',
#  '.',
#  '0264871127 arthur kane',
#  '031papi',
#  '090 Malys',
#  '0mphemetse Maria',
#  '174Anthony',
#  '1D34 Blu',
#  '256STUNNERS Ugandas finest',
#  '2GUDMUSIC',
#  '360 Designs',
#  '360 Fashion Hub',
#  '372',
#  '3MINUTES CREATIVE',
#  '49Singmetosleep',
#  '4Strate',
#  '512 108',
#  '8 LEGGED DESIGNS',
#  '80s retro',
#  '? Valerie ?Basson',
#  '???????????',
#  'A',
#  'A 2S',
#  'A A',
#  'A A Gupta',
#  'A ADRIANSYAH',
#  'A Bernette',
#  'A Better Place',
#  'A Curvy Chic',
#  'A Google user',
#  'A I',
#  'A I Raisi',
#  'A J',
#  'A K',
#  'A Marrone',
#  'A P',
#  'A Person',
#  'A R',
#  'A- bee',
#  'A. M.',
#  'A. Rahman',
#  'AA Abdulkareem',
#  'ABDIRIZAK NUUR',
#  'ABDULLAHI MUHAMMAD EL-NAFATY',
#  'ABEL SEBIK',
#  'ABIGAIL BOATENG',
#  'ABIGAIL OKAI',
#  'ABIGAIL OKWUDIKE',
#  'ABIOLA AFOLARIN',
#  'ABIOYE OLADIPUPO JIMOH',
#  'ABIRI REKHIA KATE',
#  'ABOLAJI OGUNDARE',
#  'ABOSEDE OLUGBEMIGA',
#  'ABRAHAM OWUSU',
#  'ABUBAKAR ZUBEIR',
#  'ACE Kumalo',
#  'ADAM KIBWANA',
#  'ADEBAYO SMILES',
#  'ADEDAYO ALAO',
#  'ADEGELU ADEBUSOLA',
#  'ADEOLA PRECIOUS',
#  'ADESINA ABOLORE ABDULRAHEEM',
#  'ADEYEMI David Mayowa',
#  'ADEYEMI OLABISI OMOLARA',
#  'ADONAI Visuals',
#  'ADRIAN STYLES',
#  'ADVISER ADVISERS',
#  'ADWAA ALKHALIL DEVELOPMENT',
#  'ADX DLAMUKA',
#  'AFIA BOAHENMAA',
#  'AFRICA UNITE',
#  'AFRIKEN CHALD',
#  'AGLEAN CHELIMO',
#  'AIDAH Nakibuule',
#  'AISHA USMAN',
#  'AIT Consults',
#  'AITO',
#  'AJ',
#  'AJ Aulsberry',
#  'AJ B',
#  'AJ Lugov',
#  'AJIBOLA ONIGEMO',
#  'AJIBOYE ABAYOMI',
#  'AJILEYE ISRAEL',
#  'AKERELE SEUN',
#  'AKHONA HESEWU',
#  'AKHONA MTUKUSHE',
#  'AKUCHUKWU FRANKLYN',
#  'ALECK TAMANIKWA',
#  'ALEXANDRA LAWSON',
#  'ALEXIS PETRIDES',
#  'ALFAYO OMARE',
#  'ALFRED WAWERU',
#  'ALICE JANSEN',
#  'ALIFZA DEFENCE & SECURITY',
#  'ALITA MUDENGE',
#  'ALLINAH MHLAHLO',
#  'ALPHA MANOTA',
#  'ALPHONSE SENYO',
#  'AM F',
#  'AMAMILO EBUBE',
#  'AMANA ILLAH',
#  'AMANDA MKHIZE',
#  'AMAZINGLLOYD DANCE CHOREOGRAPHY',
#  'ANDILE NGWENYA',
#  'ANDREW BRIAN MUTIBA',
#  'ANDREWS APPIAH Kubi',
#  'ANDY NICLAUDE MATASA',
#  'ANELE MBHELE',
#  'ANGELINA MENSAH',
#  'ANM 11',
#  'ANN KARIUKI',
#  'ANORUE KELECHI',
#  'ANTHONY COOKEY IROEGBU',
#  'ANTHONY UWABUNKEONYE',
#  'APHIWE ZINYUSILE',
#  'APOSTLE Dr. Chris',
#  'AR B',
#  'ASANDA MABUYA',
#  'ASANDA MAGELE',
#  'ASMA COOPERATIONTZ',
#  'ASSIDUO Network',
#  'ASUELIMEN PETER',
#  'ASharif Zainul Abedean',
#  'ATAMIA MUZIK',
#  'ATCHOU ELONM',
#  'AUDREY-CARTEY MUSIC',
#  'AUGUSTINE OFORI',
#  'AWAKE MEDA PRO',
#  'AWANOVWE GILBERT LUCKY',
#  'AYIBO ROBERTS',
#  'AYOBAMI ADEYEMI',
#  'AYODELE OLUWABUNMI',
#  'Aaa Aaaa',
#  'Aadarsh Thakur',
#  'Aadil Wardy',
#  'Aaliyah Alexader',
#  'Aaliyah Maart',
#  'Aaliyah Rose',
#  'Aameena Hoosen',
#  'Aaminah Sha',
#  'Aamir Ajaz',
#  'Aanuoluwapo Famoofo',
#  'Aarif Maymood',
#  'Aaron Amponsah',
#  'Aaron Chidozie',
#  'Aaron Kandia',
#  'Aaron Pursell',
#  'Aaron Thompson',
#  'Aaron W',
#  'Aashish Vishwakarma',
#  'Aayy KKyy',
#  'Aba Osam',
#  'Aba Quist',
#  'Aba Walters',
#  'Abayomi Adeyemi',
#  'Abayomi Afanu',
#  'Abayomi Dada',
#  'Abayomi Olajuwon',
#  'Abayomi Oyinloye',
#  'Abayomi Utsheoritshelaju',
#  'Abba Paul Ejembi',
#  'Abbas Idiong',
#  'Abbas Jwali',
#  'Abbas Malungo',
#  'Abbas Nassib Mwaruka',
#  'Abbey Buckland',
#  'Abby Henry',
#  'Abby J',
#  'Abby Karonga',
#  'Abby Katia',
#  'Abced6690@gmail.com Abced6690@gmail.com',
#  'Abd Al Jabbar Hamid',
#  'Abdalla Nizar',
#  'Abdalla OM',
#  'Abdecate Masiye',
#  'Abdelhalim Khalifa',
#  'Abdella Quartey',
#  'AbdiRisak Ahmed',
#  'Abdiaziz Aden',
#  'Abdifatah Samatar',
#  'Abdikadia Ahmed',
#  'Abdikhaliq M',
#  'Abdiladif kunaye',
#  'Abdillahi Kiambuthi',
#  'Abdimalik Hassan',
#  'Abdiwaxid Maxamud',
#  'Abdu Hali',
#  'Abdud-Dayaan Anthony',
#  'Abdul Ahad',
#  'Abdul Alladin',
#  'Abdul Baasit Ismail',
#  'Abdul Bashiru',
#  'Abdul Latif',
#  'Abdul Likonda',
#  'Abdul Mansour',
#  'Abdul Shabani',
#  'Abdul Usman',
#  'Abdul-Nadeem Mansoori',
#  'Abdul-baqi Sintuo Alhassan',
#  'Abdul-karim Larry',
#  'Abdul-rahamani Buhari',
#  'AbdulRahman Adamu',
#  'Abdulahi Mohamed',
#  'Abdulahi Mohammed',
#  'Abdulazeez Mohammed',
#  'Abdulazeez Momoh',
#  'Abdulaziz Gossage',
#  'Abdulaziz O. Aliu',
#  'Abdulghaffar WARDHERE',
#  'Abdulhadi Malik',
#  'Abdulhakeem Mustapha',
#  'Abdulkareem Alghulaigah  ',
#  'Abdulkareem Ibrahim',
#  'Abdulkareem Lateefah',
#  'Abdulkarim Faridat',
#  'Abdulkhaliq Ismael',
#  'Abdullah Ibrahim',
#  'Abdullah Peters',
#  'Abdullahi A Bello',
#  'Abdullahi Abas',
#  'Abdullahi Bukola',
#  'Abdullahi Ganiyu',
#  'Abdullahi Hassan',
#  'Abdullahi Issa',
#  'Abdullahi Saidu',
#  'Abdullateef Ibrahim',
#  'Abdulmojeed Olasunkanmi',
#  'Abdulmutalib Ibrahim',
#  'Abdulrahman Alkhinjari',
#  'Abdulrahman Fowz',
#  'Abdulrahman Isa Yusuf',
#  'Abdulrasheed Abeeb Abiola',
#  'Abdulrasheed Badamasi',
#  'Abdulrazack Seidu',
#  'Abdulrazaq Suleiman',
#  'Abdulsalam Olalekan',
#  'Abdulsalam Olamide',
#  'Abdulsamii Ajala',
#  'Abdulwahab Olflbm Sanuth',
#  'Abdulwaheed Yusuf',
#  'Abdur Makuyi',
#  'Abdur Sohel',
#  'Abduragmaan Jacobs',
#  'Abdurahman Abdiaziz',
#  'Abdurahman Bareh',
#  'Abdurehim Hudulov',
#  'Abdurrahman Ahmad',
#  'Abdurrahman Armani',
#  'Abdussalam Adepoju',
#  'Abe Moses',
#  'Abel Echono',
#  'Abel Iglesias',
#  'Abel Nson',
#  'Abella Queen',
#  'Abena Adutwumwaa M A',
#  'Abena Dorcas',
#  'Abena Kissiedu',
#  'Abhi D',
#  'Abhijeet Naique',
#  'Abhijit Gill',
#  'Abhijot singh Chahal',
#  'Abi Dumson',
#  'Abi Gavin',
#  'Abi-wealth Bello',
#  'Abibat Bello',
#  'Abibata Suwnomah',
#  'Abida Ayub',
#  'Abidemi Uyigue',
#  'Abidoye Adekunle',
#  'Abigail Abbey',
#  'Abigail Acquaye',
#  'Abigail Addo',
#  'Abigail Agbah',
#  'Abigail Agyemang',
#  'Abigail Amaadi',
#  'Abigail Anani',
#  'Abigail Angel',
#  'Abigail Ansah',
#  'Abigail Appiah',
#  'Abigail Chisanga',
#  'Abigail Denise',
#  'Abigail Dusey',
#  'Abigail Gomez',
#  'Abigail Hamba',
#  'Abigail Kemi',
#  'Abigail Ocran',
#  'Abigail Offeibea Abankwa',
#  'Abigail Okyere',
#  'Abigail Serwaa Afriyie',
#  'Abigail Tetteh',
#  'Abili Soki',
#  'Abilo bright Ayefiniwei',
#  'Abimbola Adeniyi',
#  'Abimbola Ajayi',
#  'Abimbola Ayobami',
#  'Abimbola Dara',
#  'Abimbola Emmanuel',
#  'Abimbola Shakira',
#  'Abimbola Sotunde',
#  'Abimbolu Okunowo',
#  'Abiodun Adefusi',
#  'Abiodun Adeoba',
#  'Abiodun Dasofunjo',
#  'Abiodun Fagbemi',
#  'Abiodun Mogaji',
#  'Abiodun Olatunbosun',
#  'Abiodun salau',
#  'Abiola Audifferen',
#  'Abiola Daramola',
#  'Abiola Dirisu',
#  'Abiola Fola-Alao',
#  'Abiola Ola',
#  'Abiola Wasiu',
#  'Abir Banerjee',
#  'Abisogun Ganiu',
#  'Abisola Okiei',
#  'Abisoye Agbaje',
#  'Abiud Ekidon',
#  'Abodunde Kajopelaye-ola',
#  'Abodunrin Rasheed',
#  'Abokobi Presby',
#  'Abolade Ishola',
#  'Abongile Mabona',
#  'Abongile Makaula',
#  'Abongile Mgogodlana',
#  'Abongile Mshumpela',
#  'Abongile Pakathi',
#  'Abongile Papa',
#  'Abordo Hawa',
#  'Abosede Oludaye',
#  'Abraham Atalifo',
#  'Abraham Badu-Shayar',
#  'Abraham Cudjoe Alode',
#  'Abraham Dampson',
#  'Abraham Joshua',
#  'Abraham Ndossy',
#  'Abraham Oluwatimilehin',
#  'Abraham Pascua',
#  'Absalom Alila',
#  'Absalom Jimba',
#  'Abu Rahman',
#  'Abu Sulaiman',
#  'Abubakar Aliyu Ibrahim',
#  'Abubakar Hassan',
#  'Abubakar Jabbo',
#  'Abubakar Mubarak',
#  'Abubakar Sadiq',
#  'Abubakar Said',
#  'Abubakar Shaibu Fonfana',
#  'Abubakar Shehu',
#  'Abubakar mfaume',
#  'Abubakar sadeeq',
#  'Abubakarr Tarawally',
#  'Abubakr',
#  'Abuholy Gerard',
#  'Abuja Oluwaseun',
#  'Abynaarh Gyan',
#  'Abz',
#  'Accra Dog Show',
#  'Ace Esc',
#  'Acheampong Matthew',
#  'Achidi Ngu ElRoy',
#  'Achigbe Abraham',
#  'Achike Azokwu',
#  'Achomhi Bukky',
#  'Achsah Fedha',
#  'Achyuta Keshava das',
#  'Acquah David Kingsley',
#  'Acquilla Velaphi',
#  'Acy Mash',
#  'Ada Amaechi',
#  'Ada Kameli',
#  'Ada Okoro',
#  'Ada Uka',
#  'Ada Uloko',
#  'Adabrah Dominic',
#  'Adam',
#  'Adam A',
#  'Adam Asghar',
#  'Adam Balawender',
#  'Adam Branch',
#  'Adam Dhibette',
#  'Adam Green',
#  'Adam Harton',
#  'Adam Kb',
#  'Adam Lateef',
#  'Adam Musa',
#  'Adam Nasango',
#  'Adam Oros',
#  'Adam Pawlowski',
#  'Adam S.',
#  'Adam Sabbah',
#  'Adam Sagai',
#  'Adam Samari',
#  'Adam Snow',
#  'Adam Takacs',
#  'Adam Touqan',
#  'Adam Ward',
#  'Adams Kelvin',
#  'Adams Lawrence',
#  'Adams Rita',
#  'Adams Sadat',
#  'Adamu Abdul-Razak',
#  'Adamu Adamu',
#  'Adamyepa Billy',
#  'Adan Osman',
#  'Adan Shibia',
#  'Adani Best',
#  'Adanma George',
#  'Adanma Gideon',
#  'Adanna Anyanwu',
#  'Adanna Williams',
#  'Adaobi Umeji',
#  'Adaora Igweagu',
#  'Adaora Nwankwo',
#  'Adaora Nwanyah',
#  'Adaora Onyema',
#  'Adashia Naidoo',
#  'Addae Isaac',
#  'Addae Ronnie',
#  'Addai Gilbert',
#  'Addo Kofi',
#  'Addy Adande',
#  'Ade Adeleye',
#  'Ade Haastrup',
#  'Ade23514',
#  'Adebanjo Akintimehin',
#  'Adebayo Gbenga',
#  'Adebayo Ige Toyosi',
#  'Adebayo Itunu',
#  'Adebayo Jenie',
#  'Adebayo Kazeem',
#  'Adebayo Odukoya',
#  'Adebayo Philnet',
#  'Adebimpe Mosanya',
#  'Adebisi Sonia',
#  'Adebola Oludare',
#  'Adebowale Abiodun',
#  'Adebowale Oyinleye',
#  'Adebowale Tola',
#  'Adebukola Adelana',
#  'Adebukunola Soile-Balogun',
#  'Adedamola Awonusi',
#  'Adedamola Daramola',
#  'Adedamola Onigbinde',
#  'Adedayo Adesugba',
#  'Adedayo Funmilayo',
#  'Adedayo Steven Sanni',
#  'Adedeji Salau',
#  'Adedini Mary',
#  'Adediran John Fashina',
#  'Adedolapo Abiodun',
#  'Adedolapo Adedayo',
#  'Adedotun Popoola',
#  'Adedoyin Sowemimo',
#  'Adeel Khan',
#  'Adeel Malik',
#  'Adegboye Isaac',
#  'Adegboyega Adesida',
#  'Adegeye Monica',
#  'Adegoke Adenike',
#  'Adeiza Isah',
#  'Adejoh Faith',
#  'Adejoke Lasisi',
#  'Adejoke ayeni',
#  'Adejugbe Mike',
#  'Adek Fola',
#  'Adekemi Agboola',
#  'Adekunle Adafin',
#  'Adekunle Ojo',
#  'Adekunle Opeloyeru',
#  'Adel Khorramian',
#  'Adel Lechakane',
#  'Adela Prisacaru',
#  'Adelaide Abongile',
#  'Adelaide Favoured',
#  'Adelaide Malgas',
#  'Adelaja Kayode',
#  'Adelakun Afonja',
#  'Adele',
#  'Adele Botes',
#  'Adele M-va',
#  'Adele Ross',
#  'Adele Segundo',
#  'Adele Smith',
#  'Adele Steenkamp',
#  'Adeleke elizabeth',
#  'Adelina Laice',
#  'Adeline Richards',
#  'Adelu Niculae',
#  'Adelugba Adelani',
#  'Ademide Latona',
#  'Ademidun Adeyeye',
#  'Ademola Adegoke',
#  'Ademola Alade',
#  'Ademola Allen',
#  'Ademola Buhari',
#  'Adeniji Monday',
#  'Adenike Bajo',
#  'Adenike Hannah',
#  'Adeniyi Adeyoyin',
#  'Adeniyi Constant Labintan',
#  'Adeniyi Ishola',
#  'Adeola Adebola',
#  'Adeola Ademokoya',
#  'Adeola Akinreti',
#  'Adeola Ibironke',
#  'Adeola John',
#  'Adeola Joseph',
#  'Adeola Obadan Rosemary',
#  'Adeola Okikiola',
#  'Adeolu Adegoke',
#  'Adeoye Abiona',
#  'Adepoju Joseph',
#  'Aderemi Aderemi',
#  'Aderolake Akinpelu',
#  'Aderonke Ajayi',
#  'Aderonke I',
#  'Adesanya Aderemi',
#  'Adesayo Feyisara',
#  'Adesegun Johnson-Agiri',
#  'Adesewa Adejoju',
#  'Adeshina Issa',
#  'Adesida Damilola',
#  'Adesina Oluwadamilare',
#  'Adesokan Oluwatosin sinatalia',
#  'Adesola Mofikoya',
#  'Adesua Ohi',
#  'Adesua Olatunde',
#  'Adetoun Emede',
#  'Adetoun Ilumoka',
#  'Adetunji Adebayo',
#  'Adetutu Damisa',
#  'Adetutu Oluwafemi',
#  'Adewale Irefin',
#  'Adewale Oladimeji',
#  'Adewale Omowumi',
#  'Adewale Taiwo',
#  'Adewunmi Odufalu',
#  'Adex Obe',
#  'Adeyanju Kofoworola',
#  'Adeyemi Adesumbo',
#  'Adeyemi Damilola',
#  'Adeyemi Esther',
#  'Adeyemi Ifeoluwa',
#  'Adeyemi Oluwagbenga',
#  'Adeyemo Adeshina',
#  'Adeyemo Kehinde',
#  'Adeyinka Adeniran',
#  'Adeyinka Ajayi',
#  'Adeyinka Odumade',
#  'Adeyinka Showcase',
#  'Adeyosola Zheeynarb Bint Odumbo',
#  'Adheel Maikoo',
#  'Adi D',
#  'Adi O',
#  'Adibe Samuel',
#  'Adiela Marin',
#  'Adielah Petersen',
#  'Adiku Bismark',
#  'Adil Pjay',
#  'Adila Sblog',
#  'Adina M',
#  'Adina Margit',
#  'Adjei Anum',
#  'Adjei Michael',
#  'Adjei Shalin',
#  'Adle Lefebvre',
#  'Adline Okere',
#  'Adnaanzi Adow Mohamed',
#  'Adney Decide Dilebo',
#  'Ado mulambu',
#  'Adobea Eshun',
#  'Adobi Ilevbare',
#  'Adolf Larson',
#  'Adolph Thema',
#  'Adolphine Korba',
#  'Adomaa beatrice',
#  'Adomah Cakes',
#  'Adomas Dulskis',
#  'Adongo Williams Anaba',
#  'Adonty Clifford',
#  'Adorable Ada',
#  'Adrean Frances Mpofu',
#  'Adri Du Preez',
#  'Adri Roux',
#  'Adrian Bartos',
#  'Adrian Bosilca',
#  'Adrian Cazacu',
#  'Adrian Froyo',
#  'Adrian Ghita',
#  'Adrian Glvan',
#  'Adrian Grigore',
#  'Adrian Horga',
#  'Adrian Jimenez',
#  'Adrian Mesfin',
#  'Adrian Muse',
#  'Adrian Nimara',
#  'Adrian Nsokwa',
#  'Adrian Pop',
#  'Adrian Prinsloo',
#  'Adrian Speteanu',
#  'Adrian Taxi',
#  'Adrian Vargas',
#  'Adriana Gouveia',
#  'Adriana Lazar',
#  'Adriana Marcu',
#  'Adriana Olaru',
#  'Adrienne Fredericks',
#  'Adroyth Mathebula',
#  'Adu Minister',
#  'Aduako Kwame',
#  'Aduanaba Kwame Nipah',
#  'Adun Teresa',
#  'Aduragbemi Fayode',
#  'Advance Makudo',
#  'AdvetriX - Advertizing Simplified',
#  'Advice Manzini',
#  'Adwin Stokes',
#  'Adwoa Anani',
#  'Adwoa Emely',
#  'Adwoa Konadu Frimpong',
#  'Adwoa Shuga',
#  'Ady Ady',
#  'Adzo Gbekle',
#  'Adzo Mvambo',
#  'Aelita Morgenstern',
#  'Afamo Albert-Osagie',
#  'Affiong Okoko',
#  'Afia Akomea',
#  'Afia Henewaa',
#  'Afia Ohenewaa',
#  'Afolabi Abiola',
#  'Afolabi Adedoyin',
#  'Afolabi Ifeoluwa',
#  'Afolabi Obe',
#  'Afolake Arowolo',
#  'Afoley Adjin',
#  'Afribode Accomodation',
#  'AfricanProgrammer',
#  'Africana Mtfombeni',
#  'Afrix Concepts',
#  'Afriyie Adwubi Yaa',
#  'Afriyie Amoah',
#  'Afriyie Eric',
#  'Afrolic',
#  'Afua Okyere',
#  'Afusa Kobusinge',
#  'Agaba Philbert',
#  'Agaba Ppol',
#  'Agangan Christopher',
#  'Agatha Asare',
#  'Agatha Jones',
#  'Agatha Mumbua',
#  'Agatha Nnamani',
#  'Agatha Peter',
#  'Agatha Tozama-Sangqu',
#  'Agatha Zion',
#  'Agbaje Emmanuel',
#  'Agbalaya Basirat',
#  'Agbalu Al-Zahrah',
#  'Agbar Jasse',
#  'Agbedoza Settor Geoffrey',
#  'Agbenyenuse Godwin',
#  'Agbley Sampson',
#  'Agbo Divine',
#  'Agelebe Gift',
#  'Aggie cox',
#  'Aggrey Bright',
#  'Aggrey Makokha',
#  'Aghalar Gasimov',
#  'Aghmad Richards',
#  'Aglanu Samuel',
#  'Agnes Addison',
#  'Agnes Appiah-Sam',
#  'Agnes Benjamin',
#  'Agnes Eksteen',
#  'Agnes Ereri',
#  'Agnes Kalejaye',
#  'Agnes Laryea',
#  'Agnes Maphas',
#  'Agnes Michelle Magura',
#  'Agnes Mitei',
#  'Agnes Mwaura',
#  'Agnes Osei Asibye',
#  'Agnes Prempeh',
#  'Agnes Tshotlego',
#  'Agnes Wangui',
#  'Agnes Zondiwe Phiri',
#  'Agnieszka Krzyzanska',
#  'Agnieszka Zacharias',
#  'Agotu Worlanyo',
#  'Agu Prince Ejikeme',
#  'Agulanna Josemaria',
#  'Agyei Emmanuel',
#  'Agyekum Sylvester',
#  'Agyemang Badu Richard',
#  'Ahar Robert',
#  'Ahedor Oscar',
#  'Ahiagbedey Seyram',
#  'Ahimbisibwe Fredrick',
#  'Ahliman Abdullayev',
#  'Ahmad Abd El Basset',
#  'Ahmad Abuabeed',
#  'Ahmad Aminu',
#  'Ahmad Huseynli',
#  'Ahmad Kaouk',
#  'Ahmad Mahmoud Abubakar',
#  'Ahmad Sani',
#  'Ahmad Sani Lawan',
#  'Ahmad Soubhi',
#  'Ahmad Zulfikar',
#  'Ahmed Abusereya',
#  'Ahmed Babalola',
#  'Ahmed Coded_Tinx',
#  'Ahmed Darwish',
#  'Ahmed Farooqi',
#  'Ahmed Hassan',
#  'Ahmed Hussein',
#  'Ahmed Ibrahim',
#  'Ahmed Kweli',
#  'Ahmed Mohammed',
#  'Ahmed Moustafa',
#  'Ahmed Saab',
#  'Ahmed Vahed',
#  'Ahmed Young',
#  'Ahmed Yousuf',
#  'Ahmed Zubairu',
#  'Ahmed-Tijani Musa',
#  'Ahmet Oncu',
#  'Ahorli Emmanuel',
#  'Ahseh Max',
#  'Ahudiya Ukiwe',
#  'Aida Ivy',
#  'Aida mziray',
#  'Aidan Davis',
#  'Aiden Quade',
#  'Aidia Media',
#  'Aidoo Ezekiel Paintsil',
#  'Aigars Mahinovs',
#  'Aigbe Kendra',
#  'Aigbedion Eseosa Benjamin',
#  'Aigul Kussainova',
#  'Aija Trufane',
#  'Ailaigh Rebekah',
#  'Ailsa Ford',
#  'Aime Lobili',
#  'Aime Vihervaara',
#  'Aina Oyewonuola',
#  'Aine Martha',
#  'Aine Sandra',
#  'Ainembabazi Grace',
#  'Ainius P.',
#  'Airton Vargas',
#  'Aisha Ahmed',
#  'Aisha Ashanty',
#  'Aisha Badru',
#  'Aisha Barbra',
#  'Aisha Bello',
#  'Aisha Hameed',
#  'Aisha Kashina',
#  'Aisha Saleh .M.',
#  'Aisha Usman',
#  'Aisha Wezi Nakiyingi',
#  'Aisha Zalwango',
#  'Aishat Ahmed',
#  'Aishat Ibrahim',
#  'Aiti Mus',
#  'Aivar Hanniotti',
#  'Aivaras Kolvianec',
#  'Aivaras Zilvinskas',
#  'Aivo Jakobs',
#  'Aiyesha Deterville',
#  'Aj Aj',
#  'Ajanaku Abiodun',
#  'Ajang Madaki',
#  'Ajani Micheal',
#  'Ajawuihe Victor',
#  'Ajayi samuel',
#  'Ajewole Clement',
#  'Ajibo Sambrown',
#  'Ajibodu Gabriel O.',
#  'Ajibola Tolulope',
#  'Ajibonwa Peter',
#  'Ajisafe Oluwakemi Dorcas',
#  'Ajizaa Abas',
#  'Ajji Ausi',
#  'Ajmemes Kenya',
#  'Ajoke Emekene',
#  'Ajoke Olisa',
#  'Ajs Pro. Signs',
#  'Ajwad Domingo',
#  'Ak THEGOD',
#  'Akabogu Chike',
#  'Akakpo Divine',
#  'Akanbi Kabir',
#  'Akani Mabasa',
#  'Akani Mbhombhi',
#  'Akani Nkwinika',
#  'Akanke Bola',
#  'Akanyo Kelma',
#  'Akash Gulcharan',
#  'Akash Jain',
#  'Akash PT',
#  'Akatusasiira Beth',
#  'Akbar',
#  'Akeel Essack',
#  'Akeem',
#  'Akeem Adenuga',
#  'Akenzki Borja',
#  'Akh Nathon',
#  'Akha Ithemba',
#  'Akha. Vert Akha. Vert',
#  'Akhe S',
#  'Akhil Budhal',
#  'Akhona Dukuza',
#  'Akhona Nonkelela',
#  'Akhona Ntilashe',
#  'Akhona Petronella',
#  'Akhona Spika',
#  'Akhona xabanisa Xabanisa',
#  'Akidi Harriet',
#  'Akidiva Kevin',
#  'Akiela Isaacs',
#  'Akiki Uzamere',
#  'Akin Tayo',
#  'Akinbodewa Adebukola',
#  'Akindele Rasheed',
#  'Akingun Mofe Dominic',
#  'Akinkunle Akiode',
#  'Akinmameji Adebukola',
#  'Akinnagbe Adetokunbo Oluwagbenga',
#  'Akinola Odunlade',
#  'Akinola Wealthy',
#  'Akinrinola Ganiyat',
#  'Akinsanya Oluwaseun',
#  'Akinsanya Seyi Damilare',
#  'Akinsile Falana',
#  'Akintayo O. Adewale',
#  'Akintola Akinbobola',
#  'Akintomide Fadase',
#  'Akintoye Omowunmi',
#  'Akintunde Iyiola',
#  'Akintunde Sunday',
#  'Akintunde Wealth',
#  'Akinwale Ogunleye',
#  'Akinwumi Akintayo',
#  'Akinyemi Cheedah',
#  'Akinyemi Olayinka',
#  'Akn Bacolu',
#  'Ako Larbi Justice',
#  'Akoh David Ogacheko',
#  'Akolgo Clifford',
#  'Akom Darlington',
#  'Akorede Awotoye',
#  'Akornor Naomi',
#  'Akosua Asantewaa Awuah-Agyeman',
#  'Akosua Bemah',
#  'Akosua Boadi',
#  'Akosua Boatemaa',
#  'Akosua Danso',
#  'Akosua Enchill',
#  'Akosua Starling',
#  'Akoyon Temitope',
#  'Akpa Patience',
#  'Akpan Udo',
#  'Akto Z.',
#  'Aku-udo Nwodika',
#  'Akua',
#  'Akua Asante',
#  'Akua Botwe',
#  'Akua Dramadoll',
#  'Akua Odeibea',
#  'Akua Pokuah',
#  'Akua Sarkodie',
#  'Akua Serwaa Acheampong',
#  'Akuarh Phace',
#  'Akujobi Anselem',
#  'Akumagba Irene',
#  'Akumara Longwe',
#  'Akunai Frank',
#  'Akuoma Anyanwu',
#  'Akwara Oke',
#  'Akwuobi Chukwudi',
#  'Al Fu',
#  'Ala W',
#  'Alaa Mohammed',
#  'Alaa Raie',
#  'Alaa Totonji',
#  'Alabama Kitenge',
#  'Alabi Yinka',
#  'Alachia blank',
#  'Alahudeen Lottering',
#  'Alain Nnorom',
#  'Alain Rossier',
#  'Alain Thomas',
#  'Alamin Bello',
#  'Alan Barei',
#  'Alan Dam',
#  'Alan Domic',
#  'Alan Fuggle',
#  'Alan Pritchard',
#  'Alan Serrano',
#  'Alana K',
#  'Alana van Tonder',
#  'Alanas Malainskas',
#  'Alanas Malasinskas',
#  'Alar Merand',
#  'Alari Arro',
#  'Alaric Dryling',
#  'Alarnzo Kasandas',
#  'Alawode Mayowa',
#  'Alaye Jon Briggs',
#  'Alazar Desale',
#  'Alba Mtandwah',
#  'Albanus Wambua',
#  'AlberTinah Masikah',
#  'Albert Baron',
#  'Albert Darpoh',
#  'Albert Ekuvero',
#  'Albert Kamatombe',
#  'Albert Makamo',
#  'Albert Makhube',
#  'Albert Makhubo',
#  'Albert Manjese',
#  'Albert Mushi',
#  'Albert Nyarku',
#  'Albert Rukwava',
#  'Albert Thamane',
#  "Albert's Tech",
#  'Alberta Parker',
#  'Alberta Pinto',
#  'Albertas Urbonas',
#  'Albertina Lartey',
#  'Alcia Fernndez',
#  'Alda Lopes Moreira',
#  'Aldana Vlaskov',
#  'Aldemar Munoz',
#  'Aldens Nkhuwa',
#  'Aldine Minnies',
#  'Aldrin Van Staden',
#  'Ale Rechtork',
#  'Ale S',
#  'Alec Quinn',
#  'Alec Tomlin',
#  'Alee Umar',
#  'Aleeyah Novachenko',
#  'Alejandra Rendon',
#  'Alejandra Valdovinos',
#  'Alejandro Hernandez',
#  'Aleksandar Djordjevic',
#  'Aleksandar Ili',
#  'Aleksandar Matic',
#  'Aleksandar urii',
#  'Aleksander Gajek',
#  'Aleksandr Drozdov',
#  'Aleksandr Jaworski',
#  'Aleksandr Lapsin',
#  'Aleksandr Matvejchuk',
#  'Aleksandr Ostapenko',
#  'Aleksandr Terekhin',
#  'Aleksandr V',
#  'Aleksandr Vedenin',
#  'Aleksandr Zablockij',
#  'Aleksandr Zhuikov',
#  'Aleksandra Lalova',
#  'Aleksandras Sockis',
#  'Aleksandras Urbonas',
#  'Aleksandre Kartkhia',
#  'Aleksandrs Kirillovs',
#  'Aleksej Kazmin',
#  'Aleksejs Astafjevs',
#  'Aleksejs Ignatjevs',
#  'Aleksejs Semjonovs',
#  'Aleksey Zuev',
#  'Alen Tatic',
#  'Alena',
#  'Alessandro Sinibaldi',
#  'Alessia Novara',
#  'Alessia Patan',
#  'Alex',
#  'Alex Alex',
#  'Alex B',
#  'Alex BASS',
#  'Alex Baker',
#  'Alex Bartlett',
#  'Alex Burdusel',
#  'Alex C',
#  'Alex Calin',
#  'Alex Chapman',
#  'Alex Cioaba',
#  'Alex Cook',
#  ...]
