# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/enliktjioe/master-thesis-2021/blob/main/notebooks/safe_feature_extraction.ipynb)

# %% [markdown]
# # Preparation
#
# - wget http://nlp.stanford.edu/software/stanford-postagger-full-2016-10-31.zip
# - put in `references/re_2017_johann_et-al` (private files, licensed by the author)
# - Update in `FE_Safe.py` variable `path_to_model` and `path_to_jar` with absolute path to its directory
#
#
# **Required libraries**:
# ```
# import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
# ```

# %%
# import nltk
# nltk.download('stopwords')
# nltk.download('punkt')

import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/developer/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Python path referencing
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/references/re_2017_johann_et-al")
    
import FE_SAFE as fs
# print(sys.path)

# %% [markdown]
# ## [Test] Manual Copy Paste Review

# %%
# %%time


# example_review = """
#         I love bolt. I don’t use uber often because one ride even if it’s short is like £11. Whereas from my high street to my house is £3. Not only that but their drivers are SUPER friendly! I was sick one day (my first time using bolt) and the driver was so understanding and encouraged me throughout my journey. Bolt is 100% recommended by me. I don’t write reviews so that’s how you know I defiantly recommend it. My Instagram name is: TeeKezi if you wish to get in contact with me about bolt. I’m not an ambassador 😂 or anything like that. Just super happy with the service I have been receiving x,5,Love it
#     """

# #     feature_extractor = SAFE()
# feature_extractor = fs.SAFE()
# feature_extractor.extract_from_review(example_review)
# Out:
# CPU times: user 900 ms, sys: 101 ms, total: 1 s
# Wall time: 15 s
# {'ambassador anything',
#  'day driver understanding',
#  'encourage throughout journey',
#  'get contact bolt',
#  'instagram name teekezi',
#  'receive x',
#  'street house',
#  'write review'}

# %% [markdown]
# ## Data Pre-Processing

# %%
import pandas as pd

# %%
bolt_path = "../review_mining/csv_output/1_bolt/bolt_google_playstore_review.csv"
uber_path = "../review_mining/csv_output/2_uber/uber_google_playstore_review.csv"
blablacar_path = "../review_mining/csv_output/3_blablacar/blablacar_google_playstore_review.csv"
cabify_path = "../review_mining/csv_output/4_cabify/cabify_google_playstore_review.csv"
via_path = "../review_mining/csv_output/5_via/via_google_playstore_review.csv"

getaround_path = "../review_mining/csv_output/6_getaround/getaround_google_playstore_review.csv"
ola_path = "../review_mining/csv_output/7_olacabs/olacabs_google_playstore_review.csv"
taxieu_path = "../review_mining/csv_output/8_taxieu/taxieu_google_playstore_review.csv"
freenow_path = "../review_mining/csv_output/9_freenow/freenow_google_playstore_review.csv"
yandexgo_path = "../review_mining/csv_output/10_yandexgo/yandexgo_google_playstore_review.csv"

review_col = [4] # column that contains review text
number_of_rows = 100 # for testing, only used the first 100 rows of csv file

# %%
review_bolt = pd.read_csv(bolt_path, usecols=review_col, nrows = number_of_rows)
review_bolt = review_bolt.content.str.cat(sep='; ') # source = https://stackoverflow.com/a/33280080/2670476

review_uber = pd.read_csv(uber_path, usecols=review_col, nrows = number_of_rows)
review_uber = review_uber.content.str.cat(sep='; ') 

review_blablacar = pd.read_csv(blablacar_path, usecols=review_col, nrows = number_of_rows)
review_blablacar = review_blablacar.content.str.cat(sep='; ') 

review_cabify = pd.read_csv(cabify_path, usecols=review_col, nrows = number_of_rows)
review_cabify = review_cabify.content.str.cat(sep='; ') 

review_via = pd.read_csv(via_path, usecols=review_col, nrows = number_of_rows)
review_via = review_via.content.str.cat(sep='; ')

review_getaround = pd.read_csv(getaround_path, usecols=review_col, nrows = number_of_rows)
review_getaround = review_getaround.content.str.cat(sep='; ')

review_ola = pd.read_csv(ola_path, usecols=review_col, nrows = number_of_rows)
review_ola = review_ola.content.str.cat(sep='; ') 

review_taxieu = pd.read_csv(taxieu_path, usecols=review_col, nrows = number_of_rows)
review_taxieu = review_taxieu.content.str.cat(sep='; ') 

review_freenow = pd.read_csv(freenow_path, usecols=review_col, nrows = number_of_rows)
review_freenow = review_freenow.content.str.cat(sep='; ') 

review_yandexgo = pd.read_csv(yandexgo_path, usecols=review_col, nrows = number_of_rows)
review_yandexgo = review_yandexgo.content.str.cat(sep='; ')

# %%
review_yandexgo
# Out:
# 'In general, the app is awesome, but there are a couple of issues which don\'t give me the desired user experience. 1. The map is delaying from the driver\'s map, and is lagging when the driver gets another route than the one on the map. 2. I can\'t add MasterCard cards which were issued by another bank other than YooMoney (the issue is that I have a YooMoney card and a Visa one issued by anoyher bank, and I want to add another card issued by the same bank, which is MasterCard, and I can\'t add it); Bad expirience in Chisinau. Price at the end of the trip differs from the offered at the beginning. In my case was +20%. My wife faced similar situation. It doesn\'t matter there\'s traffic jump or not.; This is the worst experience one can have with the Taxi app. Fares are almost always wrong, navigation doesn\'t work neither for driver, nor for user taxi is always in the wrong place and if you can\'t get to the place they are at the app still charges you full rate. Most of the employed drivers are rude and some even criminal. Also sometimes APP RANDOMLY CHARGES SMALL AMOUNTS OF MONEY FROM CARDS, IN HOPES YOU WON\'T NOTICE!; OK in the beginning but now gets worse with every update and use. This last time (and the final) it asks me where I want to go and sends the taxi there instead of to where I am. Waste of my time, waste of driver\'s time. 5 texts trying to cancel went nowhere. At 70 years old it\'s easier to carry my groceries the kilometers from the supermarket than deal with this app.; Impossible to rate a driver if you dismissed a popup (especially if you ordered a taxi for someone you need time to get feedback from the person, but the app force you to do reply immediately. This should be available from order history at least during 24h after the ride). Very good UX, minimum of clicks required.; I use courrier functionality. The courier does not see the info in the field "sender". Pls make these info more visible for the courier. The app lacks chat with the courier, which is convenient to send to the courrier IMs with order no. etc. Would be also great to have integration with telegram or whatsapp to send IMs directly from this messengers to the app (courier); Drivers are ok, cars are ok, customer service- fail. You use e-service, but can\'t get e-receipt for ride. Customer service can not assist you, only a lot of useless words. If you are in Baltic states better use BOLT! Same navigation, same price, and you receive you receipt right after ride.; Great app, but there are a few map delays.; Becareful of this app.. often the taxis will part 45 minutes away so you have to walk and then they charge you extra waiting time I asked what the problem was they tell me the system takes them to the wrong address; Used the app very often, but after I changed my phone can\'t set-up my account. SMS with verification code doesn\'t arrive. Wrote to support but got no response.; App is ok but often shows the incorrect position on the map(30-60 meters away from actual location), while Navitel/Google Maps show more precise position on the map; All good. One suggestion - to add the option to choose female driver. I, personally, would be willing to wait longer for a female driver to feel secure, especially at night.; List of partners does not load. After an unpleasant experience, I wanted to blacklist a carrier but am unable because the list of partners will not load.; Great taxi service app, really simple. Also you can share the app to friends and get free rides which is always awesome!!!; The worst taxi app I ever used. Doesn\'t point right address and then fees me with more than half of the price of the ride.; Bad service, charge me for waiting and almost missed my flight, not correct location for me and driver claim i got my ride.; Cost efficient and very simple to use; Very poor utilization of gps . Always stuck at one place doesn\'t move around; the app billed me for the tip although I opted out from doing so at the end of my trip; An ama ...

# %% [markdown]
# # Google Play Store Reviews

# %% [markdown]
# ## Bolt

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_bolt)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 524 ms, sys: 2.02 s, total: 2.54 s
# Wall time: 6min 3s
# {'accept request',
#  'accept request drive',
#  'accept take ride',
#  'accept untrained manner',
#  'accord minute',
#  'add chat room',
#  'address program',
#  'airport look',
#  'allocate location pick',
#  'allow book journey',
#  'allow user browse',
#  'appear box',
#  'apply request ride',
#  'appreciate promo',
#  'arrival price',
#  'arrive destination time fee',
#  'arrive half way road',
#  'arrive pick location charge',
#  'arrive pickup',
#  'arrive wait',
#  'ask destination',
#  'ask destination rider',
#  'ask strange question',
#  'assert legal right',
#  'assist driver information',
#  'attempt contact customer support',
#  'avoid last trip',
#  'avoid pick customer',
#  'become 20min',
#  'bolt client',
#  'bolt ride',
#  'call customer support',
#  'cancel driver',
#  'cancel job end book',
#  'cancel ride',
#  'cancel ride report issue',
#  'cancel service',
#  'cancel trip',
#  'cancel trip book',
#  'car color',
#  'catch flight',
#  'cause afraid thing',
#  'change attitude',
#  'change leave option',
#  'charge high price',
#  'charge place',
#  'charge trip order',
#  'charge wait time font',
#  'chat option',
#  'cheat u',
#  'choose start point journey',
#  'come pick',
#  'come plizzzzzzzzz change',
#  'communication service standard',
#  'compare competitor car',
#  'compare transport company',
#  'complain driver',
#  'confirm correct figure',
#  'contact team',
#  'continue go',
#  'cruise trip',
#  'cry rate',
#  'customer charge',
#  'customer service',
#  'customer service bad',
#  'deceive u',
#  'deduct bank account report',
#  'depend area rider',
#  'dereva work',
#  'deserve 1star charge',
#  'deserve award',
#  'determine viechle type',
#  'direction refuel',
#  'disappear pick',
#  'disappear show',
#  'disappoint bolt bolt',
#  'disappoint download',
#  'distrust encouraging thievery',
#  'driver call',
#  'driver car color',
#  'driver catch ride',
#  'driver drive',
#  'driver patient',
#  'driver refuse',
#  'driver scar u',
#  'driving person profile',
#  'embark journey',
#  'employ people',
#  'end bolt week',
#  'end call driver',
#  'enjoy service',
#  'escalate arrival',
#  'expect time arrival',
#  'experience driver',
#  'experience today',
#  'experience yesterday driver bill',
#  'fail show',
#  'fare rate',
#  'find cheap uber option',
#  'find convenient time',
#  'find driver',
#  'follow gps',
#  'forget pick phone driver',
#  'freeze typing address',
#  'fun drive bolt',
#  'generate response',
#  'get call leave rush',
#  'get charge',
#  'get charge traffic',
#  'get computer',
#  'get discount',
#  'get discount show',
#  'get driver',
#  'get family member',
#  'get location price',
#  'get number',
#  'get promotional offer email',
#  'get request guess',
#  'get response',
#  'get rid today gps',
#  'get ride park',
#  'get service',
#  'get trip',
#  'get unknown error message',
#  'get vehicle',
#  'give bad rating',
#  'give driver',
#  'give feedback',
#  'give figure',
#  'give flimsy excuse',
#  'give price destination',
#  'give promotion',
#  'give ranking',
#  'give request',
#  'give u guy',
#  'go back tip driver',
#  'go book',
#  'go dont',
#  'go driver',
#  'go section airport',
#  'go something service',
#  'go work hope bolt',
#  'guy breed',
#  'happen countless number time',
#  'happen time',
#  'happen twice day',
#  'identify car',
#  'improve precision pick location',
#  'improve reimbursement part',
#  'improve since start',
#  'include map',
#  'include number',
#  'introduce customer service centre',
#  'invite friend',
#  'keep change',
#  'keep change start address',
#  'keep driver wait',
#  'keep level customer experience',
#  'keep mess reason',
#  'keep nice attitude',
#  'keep quiet',
#  'keep work fact data',
#  'kill rap',
#  'kind annoy',
#  'know driver',
#  'know pay',
#  'know place',
#  'know problem u',
#  'know read map',
#  'know rude call',
#  'lack driver',
#  'like wish guy',
#  'load ride',
#  'load time',
#  'lodge complaint bolt',
#  'lodge complaint mean driver',
#  'lose item driver refuse',
#  'lose money people',
#  'make business',
#  'make impossible make complaint',
#  'make sence',
#  'make sure person',
#  'make sure u',
#  'make way',
#  'manner trip finish reason',
#  'map function',
#  'mean minimum 5min',
#  'mean pay',
#  'mention make',
#  'mess address',
#  'month goodness driver',
#  'n way choice',
#  'naira change',
#  'naira end pay',
#  'naira traffic delay',
#  'nigeria market',
#  'nothing resolve',
#  'observe driver charge',
#  'occasion trip cape town',
#  'pay card',
#  'pay cash card',
#  'pay initial rate',
#  'pick location',
#  'pick wrong people',
#  'pm today',
#  'price discount',
#  'price way',
#  'promo run moment',
#  'promotion price',
#  'provide bad service attitude',
#  'provide price range trip',
#  'put u',
#  'rate driver',
#  'rate ull',
#  'receive single discount account',
#  'recommend anyone',
#  'recommend service',
#  'recycle bin',
#  'register card debit trip',
#  'reply driver support',
#  'report matter',
#  'request matter time day',
#  'request ride',
#  'request upto',
#  'resolve issue',
#  'ride fee driver',
#  'rider block',
#  'road condition',
#  'road kirinya estimation',
#  'save whole lot embarrassment',
#  'say customer service change',
#  'say disgust service',
#  'say driver',
#  'say safety measure ability',
#  'say something',
#  'say sorry nothing',
#  'scamming force take',
#  'scooter leave middle pathway',
#  'see bolt',
#  'see car request',
#  'see friend',
#  'see price fee',
#  'see prise',
#  'see way',
#  'seem care',
#  'service fine',
#  'service jus read review',
#  'set around cape town',
#  'set location',
#  'settle content',
#  'show address',
#  'show different destination',
#  'show estimate amount destination',
#  'something end',
#  'speak someone',
#  'specify wait bolt',
#  'stand outside mall',
#  'star rating driver',
#  'star support',
#  'star wuld',
#  'start week everything',
#  'stick amount',
#  'stop bolt',
#  'struggle first time',
#  'switch language',
#  'take book',
#  'take extra money people',
#  'take home',
#  'take location drop',
#  'take long driver',
#  'take long move map',
#  'take long route',
#  'take look',
#  'take ride',
#  'take taxi ride',
#  'take way',
#  'talk support',
#  'tell exact location',
#  'tell pay',
#  'tell u take card',
#  'test phone issue',
#  'thing baffle',
#  'thing change life',
#  'thing customer',
#  'thing notice prenook trip',
#  'time driver',
#  'time lift',
#  'time management world class',
#  'time pick',
#  'time request ride',
#  'time stand wait driver',
#  'traffic cause customer',
#  'trip charge',
#  'trip plain',
#  'turn locator',
#  'type destination typing slot',
#  'typing destination field',
#  'uber ride sharing service',
#  'understand situation country',
#  'vet driver',
#  'waiting driver',
#  'way 2weeks',
#  'work communication driver passenger',
#  'work wait'}

# %% [markdown]
# ## Uber

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_uber)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 384 ms, sys: 1.37 s, total: 1.76 s
# Wall time: 4min 7s
# {'4x rate original',
#  'accept driver',
#  'accept ride',
#  'accept ride feel',
#  'accept trip waste time',
#  'accomplish simple task',
#  'accuse customer',
#  'add different credit card',
#  'address issue',
#  'agree ride',
#  'allow select search',
#  'area upgrade',
#  'arrive charge',
#  'ask charge value',
#  'ask close issue',
#  'ask money',
#  'ask pin',
#  'ask response charge credit',
#  'ask wan',
#  'attempt tip driver',
#  'balance time book ride',
#  'benifited trip',
#  'book moto car',
#  'book schedule today',
#  'bounce ride request',
#  'brilliance speed elegance',
#  'cab service price',
#  'cairn taxi mob',
#  'call cab',
#  'call customer care',
#  'call support',
#  'cancel book',
#  'cancel charge',
#  'cancel price order price',
#  'cancel ride',
#  'cancel ride book',
#  'cancel time',
#  'cancel trip',
#  'cancel trip fare',
#  'cancel trip n amount',
#  'cancel trip section',
#  'cancel trip uber',
#  'care customer',
#  'cause r',
#  'charge ride',
#  'cheat people trust',
#  'come location call u',
#  'come pick location',
#  'come pick wait bus',
#  'comment favorite carpool alot',
#  'complain charge',
#  'complain customer service',
#  'confirm driver',
#  'connect partner driver ride',
#  'connect ride',
#  'credit ride',
#  'customer experience',
#  'customer report',
#  'customer service',
#  'customer support email',
#  'cut driver money thing',
#  'day uber',
#  'deduct nt gud autoes',
#  'delete account lyft',
#  'delete reinstall',
#  'deny uber',
#  'detect gps',
#  'dismiss company',
#  'display driver contact detail',
#  'display vehicle information driver',
#  'dollar difference',
#  'dollar taxi',
#  'driver answer call',
#  'driver cooperative',
#  'driver reach pick point',
#  'driver time',
#  'drop desire location',
#  'enter payment info',
#  'evoke service',
#  'expect auto',
#  'fee show',
#  'figure request ride',
#  'fill fuel',
#  'find close driver',
#  'find driver leave',
#  'find option nyc service',
#  'find problem',
#  'find request ride',
#  'form payment',
#  'freeze insert phone number',
#  'fun driver',
#  'get benefit',
#  'get book issue',
#  'get charge',
#  'get destination',
#  'get issue resolve',
#  'get location',
#  'get lyft',
#  'get money',
#  'get payment time',
#  'get pick',
#  'get ride',
#  'get start',
#  'give credibility',
#  'give credit',
#  'give ultimate experience',
#  'go charge',
#  'go ola service',
#  'go pay',
#  'happen future',
#  'happen last month',
#  'happen many time',
#  'hope uber',
#  'hour everytime uber',
#  'include charge',
#  'initiate ride',
#  'install lyft',
#  'issue customer resolve fill',
#  'iv uber',
#  'job guy',
#  'keep freezing',
#  'keep freezing type destination',
#  'keep uber fraud',
#  'kind uber surcharge',
#  'know hv charge',
#  'know problem',
#  'know uber',
#  'life saver',
#  'locate middle vistula river',
#  'look employee',
#  'make available driver',
#  'make clear read complaint',
#  'make money',
#  'make phone',
#  'mark name',
#  'mcd toll delhi',
#  'min book',
#  'minute car',
#  'minute customer',
#  'minute driver',
#  'minute leave',
#  'misidentifing pick location',
#  'month reply',
#  'n bt driver',
#  'n time price',
#  'order taxi',
#  'pay various credit card',
#  'payment method',
#  'pin correct pickup location',
#  'platinum member',
#  'platinum member customer service',
#  'pop message show issue',
#  'price reach destination',
#  'provide facility',
#  'put right location',
#  'quality driver ride show',
#  'reality cant',
#  'recommend anyone travel',
#  'recommend lyft',
#  'recommend uber',
#  'rely emergency',
#  'report issue driver cancelation',
#  'reporting choice',
#  'ride experience thks',
#  'ride past',
#  'ride waste',
#  'sale tsx building beliaghata',
#  'say 3weeks',
#  'say car',
#  'say sorry driver',
#  'say third grade service',
#  'schedule ride',
#  'schedule ride lot cheap',
#  'search position',
#  'see number',
#  'seem way comment problem',
#  'send message pick point',
#  'send message ride',
#  'send stock message',
#  'service uber',
#  'show payment method',
#  'solve longtime user',
#  'solve problem',
#  'something fair',
#  'star rating rate',
#  'steal alot money',
#  'straw wait',
#  'support customer',
#  'support staff refuse',
#  'support work respond issue',
#  'switch lyft uber',
#  'take action behaviour driver',
#  'take care customer',
#  'take mucb time',
#  'take much time',
#  'take much time driver',
#  'take several stop',
#  'take time',
#  'take toll tax',
#  'take week',
#  'tell call support',
#  'tell sorry order process',
#  'travel cab',
#  'trip function',
#  'tsxo fair',
#  'uber driver',
#  'uber happy uber',
#  'uber trust uber',
#  'update issue',
#  'venmo google',
#  'verify email account',
#  'wait hurry guy',
#  'want book',
#  'want knos problem',
#  'want register uber',
#  'way address',
#  'way resolve problem',
#  'whine driver',
#  'work day'}

# %% [markdown]
# ## Blablacar

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_blablacar)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 605 ms, sys: 1.97 s, total: 2.58 s
# Wall time: 6min 10s
# {'afford fuel drive',
#  'afford full cab charge',
#  'allow location',
#  'allow log',
#  'appear screen',
#  'application india turn something',
#  'application user',
#  'ask around 3k route',
#  'ask double amount quote',
#  'ask fair charge',
#  'ask high price',
#  'ask log stick',
#  'ask money',
#  'ask pupose visit',
#  'attract customer mention',
#  'block driver',
#  'book hop ride',
#  'boon covid',
#  'bother trip detail',
#  'budget blablacars',
#  'business model india',
#  'cab driver',
#  'cab service',
#  'cancel book',
#  'cancel driver',
#  'cancel driver promise',
#  'cancel many number trip',
#  'cancel plan travel',
#  'cancel ride',
#  'cancel ride book ride',
#  'cancel ride dont travel',
#  'cancel ride pickup time',
#  'cancel travel plan',
#  'cancel trip',
#  'cancel trip block seat',
#  'cancel trip journey',
#  'canceling last hour',
#  'car driver',
#  'car nothing',
#  'car owner',
#  'car pool',
#  'charge lot',
#  'charge ride',
#  'charge route',
#  'choose language currency',
#  'come customer',
#  'come dont',
#  'come time',
#  'come way',
#  'concept implementation booking work',
#  'concept improvement lot work',
#  'confirm reinstall',
#  'confirm travel',
#  'connect way traveller',
#  'consider choice payment',
#  'contact price',
#  'continue blablacar',
#  'continue valuable customer',
#  'couple time change',
#  'covid situation mode transport',
#  'create disturbance traveller',
#  'create huge panic',
#  'create ride',
#  'cut cost travel',
#  'date selection option',
#  'decide fare',
#  'deny pick',
#  'depend available ride offer',
#  'detail driver',
#  'develop mode',
#  'developer stop activity',
#  'disappoint price driver',
#  'download apk',
#  'drive comfort',
#  'driver pick phone ring',
#  'driver show',
#  'earn additional buck traveler',
#  'engage people car people',
#  'enter fee',
#  'experience book ride driver',
#  'experience car pool',
#  'experience driver rider',
#  'explain bpmn team',
#  'explain problem user',
#  'face issue',
#  'facility u',
#  'fake profile taxi',
#  'feel safe passenger',
#  'find new contact',
#  'find ride check status',
#  'find ride rider',
#  'find solution',
#  'find way switch',
#  'follow zerowaste economy possibility',
#  'get amount toll charge',
#  'get company',
#  'get destination',
#  'get drop way destination',
#  'get excellent car owner',
#  'get fare detail',
#  'get ride',
#  'get something people',
#  'get support',
#  'give opportunity someone',
#  'give rating',
#  'give room book',
#  'happen without notice',
#  'hope resolve',
#  'improve lot usability',
#  'improve term application',
#  'include fake person',
#  'issue blabla l ast',
#  'issue driver',
#  'join platform',
#  'km hyderabad delhi',
#  'know fare amount pasengers',
#  'know fare pickup point',
#  'know judge',
#  'leave bad part',
#  'license permission insurance',
#  'location pickup point',
#  'location requirement',
#  'log issue',
#  'look option',
#  'lot flaw',
#  'lot taxi driver',
#  'maintain transparency',
#  'make 1200inr',
#  'make break rule community',
#  'make friend fun ride',
#  'make much fraud',
#  'make new friend',
#  'make sure work',
#  'make transportation business blablacar',
#  'make ur car',
#  'market user sign ups',
#  'meet cool people ecology',
#  'meet interesting people',
#  'mind people',
#  'minute make wait',
#  'miss important option',
#  'miss surety',
#  'modify people',
#  'moment book ride call',
#  'n b russia',
#  'needed community',
#  'offer ride',
#  'option custom fare',
#  'option online',
#  'option travel',
#  'passenger driver',
#  'payment gate',
#  'plan journey',
#  'post ride',
#  'post trip',
#  'price call book trip',
#  'problem increase',
#  'publish taxi driver',
#  'push notification someone',
#  'put limit charge',
#  'reason sm text',
#  'recommend others',
#  'reduce cost',
#  'reduce travell time cost',
#  'rely travel',
#  'require updation',
#  'resolve problem',
#  'respect treat',
#  'respond many time',
#  'result job',
#  'revise rating',
#  'ride 9am',
#  'ride person',
#  'ride post travel',
#  'ride sharing',
#  'rider route',
#  'run office',
#  'save cost saving introduction',
#  'save fuel company',
#  'say huge amount',
#  'say sorry driver',
#  'search download everytime',
#  'seater bus jaguar',
#  'secured trip',
#  'see backend tag',
#  'see bus',
#  'see choice timing pocket',
#  'see contact',
#  'see problem',
#  'see travel',
#  'seem problem',
#  'select alternative route',
#  'send cab',
#  'send car',
#  'set maximum limit fair',
#  'share friend colleague',
#  'share ride detail',
#  'show weird text',
#  'show x price',
#  'specify route driver',
#  'star bcoz',
#  'start useful traveller',
#  'suffer lot',
#  'suggest people',
#  'suspend multiple time reason',
#  'system mess',
#  'take action driver',
#  'take action type person',
#  'take care',
#  'take much time',
#  'take negative advantage',
#  'take phone language',
#  'taxi driver reach',
#  'tell 5x price',
#  'thanx price wish',
#  'thing outstation drive agent',
#  'time end phone',
#  'time finish payment',
#  'time problem',
#  'time public transport',
#  'time share',
#  'today book',
#  'tool anyone',
#  'travel car',
#  'travel different city',
#  'travel many time commute',
#  'travel service',
#  'travel solution',
#  'traveller offer',
#  'underscore fullstops',
#  'update reinstall problem',
#  'value mention dashboard',
#  'verification authentication people',
#  'verify bot',
#  'verymuch cost effective',
#  'want taxi',
#  'want travel',
#  'want work share email',
#  'way driver',
#  'web experience',
#  'week show',
#  'write message'}

# %% [markdown]
# ## Cabify

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_cabify)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 877 ms, sys: 3.39 s, total: 4.27 s
# Wall time: 10min 29s
# {'45min cab',
#  '600mb data',
#  'accept cash',
#  'accept order',
#  'accord customer service estimate',
#  'add account',
#  'add anything',
#  'add bad customer service',
#  'add payment method charge',
#  'add ride start',
#  'add spanish uk',
#  'agree driver course',
#  'agree fare mention',
#  'airport trip',
#  'allow pay',
#  'allow pay cash cc',
#  'amount time',
#  'anything card charge',
#  'apologize everybody meeting',
#  'appear account preauthorization',
#  'approve due eu regulation',
#  'arrive charge',
#  'arrive early meeting',
#  'arrive sudden order',
#  'ask change route',
#  'ask code',
#  'ask money',
#  'ask refund',
#  'ask wait',
#  'authorization spanish',
#  'avoid service stay uber',
#  'base experience review cabify',
#  'beginning trip',
#  'bisol taxi ride',
#  'blow battery life',
#  'book cab',
#  'book ride',
#  'break developer care',
#  'bus didnt',
#  'business model',
#  'business refuse',
#  'cab phone',
#  'cabify charge journey',
#  'cabify experience',
#  'cabify lot',
#  'calculate journey price',
#  'call taxi',
#  'call text driver reserve',
#  'cancel account',
#  'cancel driver',
#  'cancel journey',
#  'cancel ride',
#  'cancel trip',
#  'cancel trip charge amount',
#  'cancel trip refund',
#  'cancel way',
#  'cancellation fee',
#  'car map',
#  'car problem',
#  'car seat',
#  'carry passenger pet',
#  'charge 22mxn',
#  'charge account',
#  'charge credit card',
#  'charge reservation show',
#  'charge twice price',
#  'chase city',
#  'check movo scooter',
#  'chilling winter',
#  'city ring',
#  'city south area',
#  'clown trust',
#  'collect ride money',
#  'come distance',
#  'communication number',
#  'compare competitor',
#  'competition cabify',
#  'concept city',
#  'confirm meeting point',
#  'consider amount complaint regard',
#  'contact customer',
#  'contact response',
#  'continue drive drop airport',
#  'cop journey cost maximum',
#  'create account disgust',
#  'create account order',
#  'create confusion',
#  'create incident number charge',
#  'create multiple stop trip',
#  'credit issue',
#  'customer service',
#  'customer service hope ride',
#  'cycling driver',
#  'day route time',
#  'deactivate leave',
#  'deactivate option',
#  'depend cabify',
#  'digit code email email',
#  'disappoint negative review',
#  'discount voucher',
#  'disregard problem none business',
#  'drive charged way estimate',
#  'drive scam',
#  'driver block saw gps',
#  'driver drive past',
#  'driver log trip',
#  'driver picture name',
#  'driver professional',
#  'driver start',
#  'driving application world',
#  'drop offs',
#  'drop road leave',
#  'edit reinstall repeat complaint',
#  'edit response developer comment',
#  'email spanish',
#  'embarassed generic answer',
#  'encounter work',
#  'end car',
#  'end late wedding',
#  'end trip price',
#  'end wait',
#  'eur reason',
#  'exercise frustration',
#  'expected time 5mins',
#  'experience fare state fare',
#  'experience madrid',
#  'expose information ciber attack',
#  'extend reach',
#  'fact developer',
#  'find driver',
#  'find option name',
#  'find picking location',
#  'find relief',
#  'find someone',
#  'fine big deal',
#  'follow stupid instruction',
#  'follow ups spanish',
#  'friend report issue',
#  'function offer ride',
#  'fund charge',
#  'get answer',
#  'get assistance assistance',
#  'get cab',
#  'get car',
#  'get car charge',
#  'get charge',
#  'get charge ride',
#  'get day',
#  'get error',
#  'get message',
#  'get message account',
#  'get money',
#  'get overcharge',
#  'get pay',
#  'get pay privilege application',
#  'get place case',
#  'get problem order cab',
#  'get refund',
#  'get reinburced cabify',
#  'get resolution',
#  'get ride',
#  'get taxi',
#  'give access phone device',
#  'give approval',
#  'give correct address atocha',
#  'give direction',
#  'give driver',
#  'give email address',
#  'give error rout',
#  'give feedback work',
#  'give new code',
#  'give star',
#  'give vage answer',
#  'go except say driver',
#  'go pick somebody',
#  'go ride',
#  'go setup verification process',
#  'go wrong destination',
#  'grab gojek',
#  'happen barcelona airport',
#  'happen leave',
#  'happen since year',
#  'hour account',
#  'hour advance noone show',
#  'hour report',
#  'hour ride',
#  'hour way cost',
#  'ignore email',
#  'include option driver',
#  'indicate application',
#  'indicate finish',
#  'insist customer',
#  'insist force',
#  'introduce multiple stop route',
#  'issue driver',
#  'issue order',
#  'journey end',
#  'journey price',
#  'keep put queue',
#  'keep search',
#  'kind problem',
#  'know detail',
#  'know many driver area',
#  'know someone',
#  'know way make pay',
#  'lack information voucher usage',
#  'learn ride hail',
#  'let order',
#  'level competency',
#  'locate taxi',
#  'log email',
#  'look feel',
#  'look like scam',
#  'look photo',
#  'lose object',
#  'lose object vehicle',
#  'lose patience',
#  'lose phone',
#  'lose train plane',
#  'lost object',
#  'make account',
#  'make amendment booking',
#  'make couple request drop',
#  'make journey',
#  'make multiple destination trip',
#  'make order',
#  'make reservation wish something',
#  'make sense',
#  'make stop',
#  'make stop cab bad',
#  'make sure read instruction',
#  'make time driver leave',
#  'make wait',
#  'mean leave queue',
#  'meeting point',
#  'message customer service',
#  'message support agent leydi',
#  'metered abundant cabify',
#  'mexico city',
#  'minute charge',
#  'miscalculate charge',
#  'miss trip',
#  'navigation break',
#  'notify wait',
#  'occur change password',
#  'opt email promotion notification',
#  'option 4pax',
#  'order cab',
#  'order cab day',
#  'order car',
#  'order taxi',
#  'paste excuse',
#  'pay cash',
#  'pay credit',
#  'pay driver cash',
#  'payment refund look',
#  'pending transaction credit card',
#  'person issue',
#  'pester notification spanish promotion',
#  'phone work',
#  'pickup point',
#  'place order',
#  'point reserve cabify',
#  'portion suck',
#  'prepare wait',
#  'price airport',
#  'price water wifi',
#  'process answer',
#  'promo code',
#  'provide service',
#  'provide transportation',
#  'put pick location',
#  'reach final destination',
#  'react event',
#  'reason case plan',
#  'reason control bank account',
#  'receive advertising',
#  'receive copy',
#  'receive coupon',
#  'receive daily email',
#  'receive email',
#  'receive email confirmation',
#  'receive email say',
#  'receive information email',
#  'receive mail',
#  'receive message',
#  'receive message matter',
#  'receive sm',
#  'receive verification code',
#  'recommend anybody',
#  'recommend anyone',
#  'recommend application',
#  'recommend download',
#  'refresh ride',
#  'refund ride',
#  'refuse refund',
#  'remove credit card reason',
#  'remove mailing list',
#  'repeat script',
#  'reply spanish',
#  'reply support team',
#  'reservation baby car seat',
#  'reserve ride',
#  'reset password',
#  'respond action',
#  'response complaint',
#  'response month',
#  'ride time',
#  'ride witch',
#  'samsung a40 android',
#  'save day',
#  'save people time',
#  'say account',
#  'say account block',
#  'say big print',
#  'say car',
#  'say driver',
#  'say first ride',
#  'say high vulnerability',
#  'say nokia',
#  'say open issue',
#  'schedule pick time',
#  'schedule time driver',
#  'search cabify',
#  'see driver rating',
#  'see price',
#  'send cab',
#  'send driver',
#  'send form fill ride',
#  'send passport',
#  'send phone sm code',
#  'send request support team',
#  'send support ticket english',
#  'service account block account',
#  'service alicante',
#  'service customer care',
#  'service issue',
#  'service joke',
#  'service lot',
#  'service spain',
#  'service support',
#  'show driver spot u',
#  'show real location driver',
#  'show search screen',
#  'sign upto',
#  'speak spanish catala',
#  'spout cut',
#  'spread word',
#  'start fight',
#  'start search',
#  'steal customer',
#  'stop reply account block',
#  'stop service',
#  'stop work',
#  'straw handling payment',
#  'submit form',
#  'suppose aware pick',
#  'suspend without explaination travel',
#  'system work driver',
#  'take complaint customer service',
#  'take default',
#  'take discount code',
#  'take driver',
#  'take hour',
#  'take regular taxi',
#  'take responsibility charge',
#  'take ride end uber',
#  'take route',
#  'take screen',
#  'take survey edit',
#  'take taxi money',
#  'take trip discount money',
#  'talk human course',
#  'taxi barcelona',
#  'taxi cabify',
#  'taxi drive airport',
#  'taxi driver',
#  'taxi spain',
#  'taxi work',
#  'tell account lock',
#  'tell availability',
#  'tell cabify go airport',
#  'tell driver',
#  'tell error',
#  'tell work',
#  'texted driver',
#  'time driver',
#  'time email link',
#  'time end pay',
#  'time hotel',
#  'time issue application',
#  'time problem',
#  'time refund charge',
#  'time row',
#  'time user cabify account',
#  'translate english google',
#  'translate life saver time',
#  'trip cabify',
#  'trip return',
#  'uber bolt',
#  'uber taxi',
#  'understand order',
#  'uninstalled instal error',
#  'upcoming taxi',
#  'update customer service work',
#  'update idea',
#  'update order',
#  'update order ride',
#  'wait 5min driver',
#  'wait minute',
#  'wait park car light',
#  'wait second experience',
#  'wait street request',
#  'want feedback',
#  'want information',
#  'want money',
#  'want risk wait cab',
#  'want set trip',
#  'want wait',
#  'warn eu regulation',
#  'warn nothing',
#  'warning pay price',
#  'warning user cabify option',
#  'waste time',
#  'way run company',
#  'wheelchair anything something driver',
#  'wil competitor',
#  'wish uber',
#  'work city',
#  'write pleased figure',
#  'year cabify'}

# %% [markdown]
# ## Via

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_via)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 803 ms, sys: 2.77 s, total: 3.57 s
# Wall time: 8min 37s
# {'accept cashapp',
#  'accept payment',
#  'account system',
#  'add card',
#  'add payment',
#  'addition fact wait time',
#  'address customer issue',
#  'airport service',
#  'align bullet trainsarrivals',
#  'allow book ride',
#  'allowed maximum fare way',
#  'amaze fast pick time',
#  'appreciate guy',
#  'appreciate payment plan offer',
#  'area dc',
#  'area question',
#  'arlington texas',
#  'ask money',
#  'ask rate ride',
#  'assign driver',
#  'authorization book seat',
#  'base pricing neighborhood travel',
#  'bit crapshot',
#  'book car',
#  'book ride',
#  'bus route cut',
#  'bust u turn',
#  'bye guy',
#  'call customer',
#  'call customer support',
#  'caltrain commute',
#  'cancel charge',
#  'cancel driver',
#  'cancel ride',
#  'cancel ride option car',
#  'cancel ride order lyft',
#  'cancelation fee decline',
#  'car price tho',
#  'catch credit card company',
#  'cause late event driver',
#  'charge ride book',
#  'charge show fee',
#  'city u',
#  'come complicated user interface',
#  'come distance',
#  'come experience service year',
#  'come mercedes others',
#  'come rating',
#  'come safe location',
#  'company lead',
#  'confirm destination drop',
#  'connect account system',
#  'consider driver delay',
#  'continue increase',
#  'coordinate movement',
#  'cost ride',
#  'cover commute base fare',
#  'create account business',
#  'create account dont',
#  'customer walk driver',
#  'cut call second',
#  'dc morning commute',
#  'destination area',
#  'difference quality proffesionalism',
#  'division street bad',
#  'dollar case',
#  'dollar week',
#  'download interact',
#  'driver consideration',
#  'driver fine',
#  'driver pass exact location',
#  'driver phone number',
#  'driver show',
#  'effect rating leave',
#  'email support',
#  'enter address book car',
#  'enter cc info',
#  'enter pick address destination',
#  'error message',
#  'estimate arrival time',
#  'eta driver',
#  'everything zone',
#  'everytime order ride',
#  'expand coverage area',
#  'experience technical difficulty',
#  'express service',
#  'fail wait',
#  'fare discount',
#  'find corner',
#  'find driver',
#  'find heck',
#  'find okay method',
#  'find price',
#  'find wait customer',
#  'find way',
#  'flip side schedule',
#  'follow rout',
#  'forget password button',
#  'frustrating operation',
#  'get around jersey city',
#  'get around time',
#  'get bad bad',
#  'get car',
#  'get clunky pick',
#  'get corner',
#  'get empty van',
#  'get error message',
#  'get error say',
#  'get home',
#  'get lyft run',
#  'get message email',
#  'get money',
#  'get nothing',
#  'get notification',
#  'get notification driver',
#  'get pay',
#  'get private ride dollar',
#  'get ride',
#  'get solo ride',
#  'get text message',
#  'get work cost',
#  'give driver',
#  'give low rating',
#  'give money business',
#  'give passenger',
#  'give u chance',
#  'go cost',
#  'go court',
#  'go effort',
#  'go nice transportation',
#  'go ride',
#  'go struggle figure ride',
#  'go way passenger',
#  'gps system',
#  'guess stick lyft',
#  'handicapped people',
#  'happen bus show',
#  'hassle hand',
#  'head work',
#  'headlight talk driver',
#  'hear passenger',
#  'hit message',
#  'home pickup',
#  'hope pay',
#  'hour ride',
#  'hour ride rout',
#  'inconvenience driver stop',
#  'inform cutoff point',
#  'initiate change',
#  'injury system',
#  'issue lyft uber turn',
#  'issue wait time',
#  'jump nearby address',
#  'keep change pickup address',
#  'keep mind',
#  'keep work management driver',
#  'kind transportation',
#  'know city',
#  'know kind gps',
#  'know obvious make',
#  'know recent ride',
#  'know stop',
#  'leave review uber',
#  'let log',
#  'let people',
#  'let poor driver',
#  'live small town',
#  'lock account',
#  'look route pickup vehicle',
#  'lose customer',
#  'lyft uber',
#  'lyft uber worth',
#  'make convenient driver',
#  'make driver',
#  'make dumb route',
#  'make question service',
#  'make ride',
#  'make safe driver',
#  'make sense',
#  'make trip time',
#  'make wait',
#  'make walk corner',
#  'map area pick drop',
#  'map work',
#  'meet driver',
#  'message notification',
#  'mile street',
#  'min appointment',
#  'min attempt ride',
#  'min response',
#  'min trip',
#  'minute fairground',
#  'minute pickup',
#  'minute ride',
#  'minute start window',
#  'minute wait',
#  'misrepresent time',
#  'money hold',
#  'navigate efficient way',
#  'occasion wait',
#  'order cab',
#  'order cab service log',
#  'part city',
#  'pas value',
#  'pass doesnt',
#  'pay low shi service',
#  'pay ride',
#  'payment method',
#  'phone number call email',
#  'pick call',
#  'pick point',
#  'pick someone corner trouble',
#  'pick spot block',
#  'pick time',
#  'pick train stop',
#  'pick ups',
#  'pickup estimate',
#  'pickup eta',
#  'pickup location',
#  'pickup spot',
#  'plan trip hour advance',
#  'pm head appointment',
#  'pm van',
#  'point store',
#  'premise service',
#  'price car driver experience',
#  'price competitor',
#  'price increase',
#  'pricing model',
#  'problem language',
#  'problem pick people',
#  'problem test charge',
#  'problem upgrade',
#  'put address',
#  'put driver',
#  'put location phone',
#  'raise price month',
#  'raise price pas',
#  'reason service',
#  'reccomend anyone service',
#  'receive compensation',
#  'receive refund',
#  'receive ride',
#  'receive service',
#  'recognize phone number',
#  'recommend anyone',
#  'recommend service',
#  'recommend waste time',
#  'recover email',
#  'recruit driver idaho fall',
#  'register account',
#  'rely service work something',
#  'remove reinstall',
#  'request pick',
#  'request refund',
#  'request ride today eta',
#  'request uber lyft',
#  'require overage charge',
#  'rerouted via drop',
#  'reschedule ride',
#  'ride comfty',
#  'ride sharing experience',
#  'ride way overprice',
#  'rideshare program',
#  'run inefficient route',
#  'run risk pay money',
#  'save location',
#  'save pricing uber',
#  'say across street',
#  'say check internet connection',
#  'say design',
#  'say driver',
#  'say driver road',
#  'say kind problem account',
#  'say live rep',
#  'say minute',
#  'schedule plenty time',
#  'see first word',
#  'see location car',
#  'see much trip',
#  'see pricing book ride',
#  'seek charge',
#  'seem issue',
#  'seem low amount',
#  'seem raise price',
#  'send email wait',
#  'serve area',
#  'serve peak hour',
#  'service arlington resident',
#  'service start',
#  'service virginia',
#  'set address',
#  'set drop address',
#  'set nightmare',
#  'setup account call',
#  'shared ride',
#  'shared ride door door',
#  'sharing ride',
#  'show message',
#  'show via say move',
#  'smh worth',
#  'star price',
#  'start day',
#  'start difficult work charge',
#  'start hire driver',
#  'stop wrong location',
#  'strand call favor',
#  'suppose pick point',
#  'system error end',
#  'take biggs terrace',
#  'take break wait pick',
#  'take destination',
#  'take dozen',
#  'take driver',
#  'take hour',
#  'take money',
#  'take notification history',
#  'take shared ride',
#  'take time show guess',
#  'tell happy viametro stl',
#  'tell people service',
#  'tell problem email support',
#  'tell ride',
#  'tell text driver email',
#  'thing price',
#  'time cab',
#  'time call driver',
#  'time charge',
#  'time company experience',
#  'time customer',
#  'time driver',
#  'time estimate',
#  'time estimation pick way',
#  'time fine',
#  'time point',
#  'time ride',
#  'time schedule',
#  'time shuttle evening',
#  'time user',
#  'timing estimate',
#  'tip selection',
#  'today request ride',
#  'train bus station',
#  'transit check card luck',
#  'transit right',
#  'transportation price increase',
#  'trip w stress',
#  'u travel',
#  'uber lyft',
#  'upcoming ride',
#  'wait 48hrs',
#  'wait arrival time',
#  'wait long time',
#  'wait month appointment',
#  'wait recompense',
#  'wait time',
#  'wait time option ride',
#  'wait time pick',
#  'wait timevariesi',
#  'walk car feel',
#  'want b pick',
#  'want last rate',
#  'want pay transportation point',
#  'want u',
#  'want wait',
#  'washington dc',
#  'waste time',
#  'way contact driver',
#  'work gps'}

# %% [markdown]
# ## Getaround

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_getaround)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 581 ms, sys: 2.24 s, total: 2.82 s
# Wall time: 6min 59s
# {'accept booking',
#  'access message',
#  'add option payment',
#  'adjust due covid',
#  'adjust price',
#  'adjust price rental',
#  'allow stuff access function',
#  'alot owner crook',
#  'amaze product',
#  'appear search result',
#  'appreciate idea',
#  'area car stand',
#  'arrange responsive connectivity',
#  'arrive owner',
#  'ask getaround',
#  'ask receipt fuel filling',
#  'authorisation car rental',
#  'availability calender',
#  'avoid company cost',
#  'avoid pay',
#  'avoid unless ton time',
#  'block account',
#  'book car',
#  'book collection drop',
#  'book vehicle',
#  'booking car',
#  'booking check',
#  'booking misery',
#  'booking time',
#  'box work',
#  'call multiple time',
#  'call owner',
#  'call service drivy',
#  'cancel car freeze bone',
#  'cancel rental',
#  'cancel reservation',
#  'cancel trip',
#  'cancellation reason car',
#  'car area',
#  'car book drivy',
#  'car drive car',
#  'car half bar gasoline',
#  'car hire company',
#  'car owner',
#  'car rental service',
#  'car thing',
#  'car time',
#  'card work',
#  'checking process',
#  'choose car web site',
#  'choose option',
#  'choose option cash',
#  'choose option pay cash',
#  'chunk pay',
#  'circus start',
#  'client desk',
#  'collect car',
#  'come account',
#  'come drivy',
#  'come money',
#  'commit client',
#  'company delight',
#  'company process way',
#  'company total',
#  'compare endless process',
#  'condition owner',
#  'consider leave getaround',
#  'contact emergency number',
#  'contact support owner',
#  'contract sign',
#  'customer service',
#  'customer service saga',
#  'day girlfriend',
#  'day rental',
#  'depress leave',
#  'die new user agreement',
#  'disappoint couple service',
#  'disappoint mileage cap',
#  'discover fine month',
#  'driver car',
#  'driving history',
#  'emergency situation',
#  'enable camera',
#  'end late plan car',
#  'enjoy time',
#  'euro end',
#  'euro return car',
#  'everything search',
#  'exist owner',
#  'exist request',
#  'experience application',
#  'experience getaround',
#  'experience turo',
#  'explain situation',
#  'explain whole problem',
#  'explanation end',
#  'expose underwear',
#  'extend rent period',
#  'fact scrap rim parking',
#  'feel like price gouging',
#  'find availability',
#  'find car',
#  'find car problem',
#  'find couple thing spot',
#  'find exact location car',
#  'find guy',
#  'find reservation',
#  'find whole experience smooth',
#  'follow extra surcharge',
#  'follow progress',
#  'frustrating upload',
#  'fuel return',
#  'fuel tank',
#  'generate check code',
#  'get account',
#  'get angry upset',
#  'get answer',
#  'get around penislise car',
#  'get around regulation',
#  'get car',
#  'get car damage',
#  'get charge holiday',
#  'get discount car',
#  'get documentation',
#  'get fleece reason',
#  'get hold',
#  'get information',
#  'get lovely car',
#  'get reply owner chase',
#  'get speeding ticket trust',
#  'getaround refuse',
#  'give car',
#  'give cash',
#  'give discount',
#  'give information',
#  'give owner',
#  'give star',
#  'give time',
#  'go although saw success',
#  'go car hire',
#  'go little quest',
#  'go loop chase rabbit',
#  'go pickup car',
#  'go refund',
#  'go several continent',
#  'go traditional car rental',
#  'greediness getaround team',
#  'hang helpline',
#  'hour validate profile',
#  'idea top',
#  'imagine rental rate',
#  'improve information vehicle',
#  'include among country drive',
#  'inform profile',
#  'instance book',
#  'intended first time experience',
#  'keep way',
#  'know getaround take money',
#  'know leave car',
#  'know payment ok',
#  'lack ux work level',
#  'lash rain',
#  'lend car',
#  'let access centre',
#  'let book',
#  'life everything',
#  'litre refuelling fee',
#  'locate car',
#  'location display didnt work',
#  'lose book',
#  'lose someone',
#  'lot day trip',
#  'make huge loss worth',
#  'make mistake everything fine',
#  'make new confirmation',
#  'make pay',
#  'make proof emphasis',
#  'make sure everything look',
#  'manuel gearbox',
#  'mention website',
#  'mile drop point',
#  'minute booking',
#  'miss experience vacation france',
#  'money car',
#  'navigate whole process',
#  'night flash shlould',
#  'nightmare car book',
#  'nobody pick phone',
#  'nothing dispute',
#  'notice contact',
#  'open picture',
#  'option car',
#  'pass time',
#  'pay car',
#  'pay cash',
#  'pay hefty fee',
#  'peace mind party',
#  'person book',
#  'phone line',
#  'phone owner',
#  'photo car data',
#  'pick 24th dec log',
#  'pick car clock',
#  'pick respond',
#  'platform rent car van',
#  'pleasure drive',
#  'point start',
#  'predecessor competitor',
#  'price day',
#  'price place',
#  'price range',
#  'price rule',
#  'problem hold deposit',
#  'problem setteling account',
#  'prompt day car',
#  'provide explanation',
#  'rate acceptance',
#  'readiness set account',
#  'receive email car rental',
#  'receive refund',
#  'receive rent car',
#  'recognise business',
#  'recommend car',
#  'recommend friend poor',
#  'recommend rent car',
#  'reduce car ownership',
#  'refuel thing',
#  'refuelling fee',
#  'refund leave',
#  'rely respond email',
#  'remain available owner',
#  'remedy offer',
#  'remember flash',
#  'rent 9seat car',
#  'rent car',
#  'rent private owner rent',
#  'rental company',
#  'reply request',
#  'report malfunction vehicle owner',
#  'require improvement',
#  'reservation experience',
#  'result loose hour',
#  'retake picture take',
#  'ring getaround hour',
#  'ruin christmas',
#  'save headache',
#  'say ah look',
#  'say due modification car',
#  'say passport driver license',
#  'say unable unlock car',
#  'schedule maintenance',
#  'see car',
#  'see detail car rent',
#  'see location',
#  'seem ethical compromise',
#  'seem fine theory',
#  'selecting list',
#  'selection car',
#  'self service car',
#  'sell monster',
#  'send blurry picture',
#  'send fund verification',
#  'send proof',
#  'service offer driver',
#  'service register price',
#  'service work customer service',
#  'sharing economy',
#  'show excessive dirt',
#  'show proof fill car',
#  'sit around twiddle thumb',
#  'smartphone lock',
#  'speeding ticket getaround',
#  'spend age',
#  'start idea car owner',
#  'start rent',
#  'start rental button',
#  'start time',
#  'start upload',
#  'steer clear service',
#  'suggest book',
#  'suggest developer',
#  'support guy getaround',
#  'suppose work way hotel',
#  'take account',
#  'take money account',
#  'take money respond',
#  'take photo car',
#  'take picture',
#  'take picture fuel inficator',
#  'take picture mileage',
#  'take sign',
#  'take total bill',
#  'take unlike car company',
#  'tell insurance cover',
#  'tell u',
#  'throw unplanned overdraft',
#  'time amount',
#  'time assistance',
#  'time experience',
#  'time pay book',
#  'time rent way',
#  'trip moment pick',
#  'u stress',
#  'understand condition',
#  'understand deal',
#  'unlocking system nightmare work',
#  'update etc etc',
#  'update people',
#  'verification process',
#  'verification profile',
#  'verify account',
#  'verify despite website',
#  'vet driver',
#  'wait vain hour',
#  'wait verification',
#  'want rent vehicle',
#  'way advertising price',
#  'way rent share kind',
#  'way share license detail',
#  'way sticking',
#  'week getaround',
#  'wien notice croatia',
#  'word thief',
#  'work car car',
#  'work fine',
#  'zipcar cheap'}

# %% [markdown]
# ## Ola

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_ola)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 704 ms, sys: 2.52 s, total: 3.22 s
# Wall time: 7min 49s
# {'accept request',
#  'accept ride',
#  'accept ride time car',
#  'accept trip',
#  'accept ur request destination',
#  'account ola support team',
#  'add cover',
#  'add discount',
#  'add money',
#  'add ola money',
#  'add popup',
#  'allow book',
#  'answer call happend',
#  'appear payment section',
#  'apply coupon',
#  'apply end pay',
#  'arrive destination',
#  'ask cash',
#  'ask cash payment car',
#  'ask customer',
#  'ask drop location',
#  'ask drop place',
#  'ask extra money',
#  'ask final destination',
#  'ask gor money cash',
#  'ask happnd book car',
#  'ask login',
#  'ask money',
#  'ask otp',
#  'ask phone',
#  'ask rating',
#  'ask toll tax',
#  'ask u',
#  'assume ola money',
#  'authorization fake company',
#  'auto driver',
#  'beg refund',
#  'behaviour disgust guy',
#  'beware people hacking account',
#  'block payment',
#  'blunder show payment detail',
#  'boking charge r',
#  'bolt kapten uber',
#  'book airport',
#  'book auto',
#  'book auto cab refuse',
#  'book cab',
#  'book fare show',
#  'book fraudency',
#  'book initiate booking',
#  'book ola',
#  'book ola bike service',
#  'book ride cab move',
#  'book ride professional',
#  'book show price r',
#  'book taxi lock',
#  'broked midle ride hour',
#  'cab experience',
#  'cab service provider',
#  'cache clearing data',
#  'call number',
#  'call ola customer care',
#  'call option',
#  'cancel book',
#  'cancel booking',
#  'cancel cab',
#  'cancel charge cancellation charge',
#  'cancel charge money',
#  'cancel cheek charge',
#  'cancel driver',
#  'cancel driver ola',
#  'cancel end',
#  'cancel first driver',
#  'cancel next day',
#  'cancel per wish',
#  'cancel phone',
#  'cancel reason',
#  'cancel ride',
#  'cancel ride fare',
#  'cancel ride reason',
#  'cancel thrice',
#  'cancel trip',
#  'cancel trip bcos inconvenience',
#  'car ride',
#  'car service',
#  'carry extra helmet',
#  'case emergency',
#  'catch taxi',
#  'change pay',
#  'charge bill',
#  'charge cancellation fee',
#  'charge issue',
#  'charge r',
#  'charge trip start driver',
#  'chat option customer care',
#  'cheat driver partner',
#  'cheat pas',
#  'cheat passenger',
#  'cheat people money',
#  'choose high price option',
#  'choose route charge',
#  'choose weather condition distance',
#  'co passenger',
#  'collect data',
#  'come fare',
#  'come pick point force',
#  'come place',
#  'company book cab',
#  'company mentality',
#  'compare normal day',
#  'compensate driver',
#  'complain 13th jan',
#  'complain block account',
#  'complain manytimes',
#  'confirm look',
#  'confirm trip fare rate',
#  'consider child mention',
#  'couple day',
#  'crpf camp',
#  'curry resolve',
#  'customer care',
#  'customer perspective',
#  'customer service',
#  'customer service bad',
#  'customer supoort bed',
#  'customer support',
#  'day book auto',
#  'day hyderabad',
#  'deal issue post trip',
#  'define template reply',
#  'delete payment detail',
#  'deny pickup say',
#  'developer bad',
#  'disappear ride section after4',
#  'disappear screen',
#  'disappoint first impression',
#  'disappointed ola',
#  'discount offer',
#  'dnt solution',
#  'drain phone',
#  'drive wrong direction',
#  'driver passenger',
#  'driver stop',
#  'drop charge r',
#  'email way',
#  'enable gps share',
#  'end pay',
#  'end waste',
#  'enhance knowledge read',
#  'enter like session',
#  'enter system',
#  'error message',
#  'establish ola',
#  'estimate cost',
#  'everything fine',
#  'expect amount ride end',
#  'expect bill',
#  'experience auto ride',
#  'experience book',
#  'experience take',
#  'expire mean hell',
#  'exploit opportunity',
#  'fact travel',
#  'faith advertising',
#  'fare destination',
#  'find cab',
#  'find driver',
#  'find option pay',
#  'find ride',
#  'follow map',
#  'get amount',
#  'get cab',
#  'get cancellation penalty gift',
#  'get change',
#  'get charge',
#  'get confirmation message',
#  'get driver map',
#  'get drop',
#  'get fine',
#  'get fraud',
#  'get location call',
#  'get main menu',
#  'get message cab',
#  'get multiple ride',
#  'get pick point',
#  'get profit',
#  'get resolve',
#  'get ride book',
#  'get screen turn',
#  'get strike book',
#  'give assurance mail',
#  'give benefit doubt',
#  'give book cab',
#  'give company',
#  'give problem',
#  'give resolution',
#  'give signup discount',
#  'give single star',
#  'give time start drive',
#  'give u',
#  'go around business',
#  'go book show vehicle',
#  'go cash payment',
#  'go delhi rest faze',
#  'go destination',
#  'go ola',
#  'go outide book',
#  'go uber',
#  'guy call',
#  'half hour',
#  'half year',
#  'happen multiple time driver',
#  'harrassing customer',
#  'hear none client',
#  'hire cab',
#  'hoax promise',
#  'hold book ride driver',
#  'hour journey charge 570rs',
#  'hour reach home',
#  'hour wait',
#  'improve platform',
#  'incentive issue',
#  'increase charge reach destination',
#  'inform cab',
#  'inform u',
#  'input address track location',
#  'insist destination call',
#  'insist u pay cash',
#  'involve trick customer time',
#  'keep search',
#  'km contact customer care',
#  'km detour',
#  'know destination',
#  'know drop location',
#  'know lie',
#  'know nothing driver',
#  'learn something uber regard',
#  'let contact',
#  'limit customer helpline',
#  'list car',
#  'login account',
#  'lot driver',
#  'make fast service traffic',
#  'make payment',
#  'make payment ride payment',
#  'make u wait',
#  'make wait',
#  'manage issue',
#  'matter time place ride',
#  'mean charge start u',
#  'mean executive',
#  'meet ola fleet',
#  'memory problem anything',
#  'min cut call',
#  'min go',
#  'minute time waste',
#  'miss trip',
#  'money wallet account history',
#  'monopoly service time',
#  'month msg show phone',
#  'month start show work',
#  'n cheater driver',
#  'none rival',
#  'nothing book',
#  'nothing work fine',
#  'notify driver',
#  'ola charge',
#  'ola promise account recovery',
#  'ola rider',
#  'opt ola share',
#  'opt save option',
#  'option feedback raise',
#  'option ride show trip',
#  'outstation ride',
#  'part google navigation',
#  'partner application lot improvement',
#  'passenger look alternative',
#  'paste address notepad',
#  'pay cancellation',
#  'payment method',
#  'payment mode suck',
#  'payment ola money',
#  'pending complaint',
#  'persist dumb server',
#  'person pay money throuhg',
#  'pester due pay',
#  'petrol pump nd',
#  'pick open state',
#  'pick point call driver',
#  'plz check ola',
#  'poly bag ola cab',
#  'pop alert payment',
#  'prefer ola',
#  'privacy hell option',
#  'prove payment plz look',
#  'provide driver',
#  'provide problem',
#  'provide refund circumstance charge',
#  'provide service',
#  'purpose pay r',
#  'r cancellation',
#  'raise concern support team',
#  'rating list',
#  'reach leave',
#  'reach pune airport',
#  'reach u call reply',
#  'receive charge',
#  'receive code sm',
#  'recenty problem',
#  'recognize location service',
#  'recomend day',
#  'recommend service',
#  'referral code',
#  'refund amount',
#  'regard amit suck',
#  'register link',
#  'reject ride',
#  'request ola management',
#  'require gps',
#  'resending otp request otp',
#  'resolve issue',
#  'response auto driver',
#  'response support',
#  'ride driver',
#  'ride fine',
#  'ride finish driver',
#  'ride ola cab auto',
#  'ride pas',
#  'rideshare mob',
#  'route show trip',
#  'run money moron',
#  'rupee pay maximum',
#  'save child',
#  'save hassle',
#  'save payment detail',
#  'save time money',
#  'say 18mins',
#  'say 50rs cancelation fee',
#  'say fill cng',
#  'say location',
#  'say ola',
#  'say peak time charge',
#  'say wait 10mins',
#  'screenshot n screen',
#  'search address address bar',
#  'search one',
#  'security customer care support',
#  'sedan taxi bike mini',
#  'see amount pay',
#  'send option',
#  'service poor',
#  'share gps data',
#  'show auto',
#  'show cab',
#  'show entire address',
#  'show entire address copy',
#  'show gps',
#  'show hidden charge',
#  'show number ride',
#  'show ride',
#  'show software',
#  'show vehicle',
#  'solve customer care',
#  'solve issue',
#  'something simple',
#  'spamming message',
#  'speak driver',
#  'spend lot time',
#  'stnding place',
#  'strike today',
#  'stuff ola',
#  'submit billing discount correction',
#  'submit fare correction',
#  'submit work',
#  'suggest anyone',
#  'suggest ola people',
#  'support system',
#  'support transfer call',
#  'surprise bad',
#  'switch gps',
#  'take age',
#  'take auto ola say',
#  'take driver',
#  'take effort call',
#  'take long route',
#  'take ola',
#  'take ride',
#  'take u destination',
#  'take uber',
#  'tell anything',
#  'tell destination',
#  'tell wrong refuse',
#  'theres way raise anyone',
#  'threaten legal action',
#  'throw message state cab',
#  'time access login',
#  'time book',
#  'time book ola auto',
#  'time cab',
#  'time face',
#  'time stop',
#  'time ticket',
#  'today book',
#  'today friend wife travel',
#  'today ola',
#  'traffic jam driver',
#  'travel ola cab today',
#  'trick pay cancellation fee',
#  'turn location service',
#  'uber way',
#  'uber work',
#  'understand limit',
#  'understand ola driver',
#  'understand people book ride',
#  'understand problem',
#  'understand show',
#  'update application',
#  'user driver',
#  'verify whole address',
#  'voucher disregard invitation',
#  'wait atleast',
#  'wait charge',
#  'wait issue resolve',
#  'wait solution',
#  'waiting response',
#  'want go',
#  'want goo',
#  'want pay',
#  'want talk',
#  'waste time',
#  'wating long time',
#  'write detail'}

# %% [markdown]
# ## Taxi.eu

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_taxieu)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 416 ms, sys: 1.52 s, total: 1.94 s
# Wall time: 4min 49s
# {'accept order',
#  'accept paypal payment',
#  'add bank detail',
#  'add guy girl',
#  'airport charge',
#  'alles user country',
#  'allow contact driver',
#  'allow pay',
#  'amount quote traffic',
#  'arrival time',
#  'avoid kill battery',
#  'believe horrible understatement',
#  'blame u book',
#  'book pay taxi',
#  'book taxi',
#  'book taxi didnt',
#  'book taxi kindda purpose',
#  'booking driver idea',
#  'call support',
#  'call taxi',
#  'call taxi company',
#  'cancel cab point',
#  'cancel pick location ride',
#  'cancel ride',
#  'cancel sudden make service',
#  'cancel u',
#  'cancel without notice',
#  'cancellation feature',
#  'change language',
#  'charged meter',
#  'choose pay',
#  'click say',
#  'come google',
#  'communicate driver',
#  'compare offer',
#  'compare uber',
#  'confirm email',
#  'confirm exact address',
#  'confirm pickup',
#  'connect u',
#  'date satnav system',
#  'decency respond anybody',
#  'deliver promise',
#  'developer response',
#  'disappoint correct profile',
#  'dispatch centre',
#  'dispatch service',
#  'driver claim',
#  'driver show information',
#  'error message german',
#  'estimate cost',
#  'expect ditch',
#  'explain multiple time response',
#  'fashion way driver drive',
#  'find address',
#  'find lot',
#  'find way driver dosen',
#  'fire programers',
#  'forget last destination',
#  'für luzern',
#  'geart job',
#  'get cab',
#  'get charge',
#  'get idea cost',
#  'get offer taxi',
#  'get taxi',
#  'give destination',
#  'give error message',
#  'go service rate',
#  'gor travel',
#  'gps location pick',
#  'hotel tourist',
#  'indicate taxi',
#  'inform operator',
#  'know car show',
#  'know destination',
#  'know payment',
#  'learn something',
#  'listen response',
#  'locate address',
#  'locate correct car',
#  'lose reason',
#  'make difference trip munich',
#  'make mistake',
#  'make reservation',
#  'manage change language',
#  'min max taxi',
#  'minute pick',
#  'minute reality',
#  'nothing work',
#  'notify navigation system',
#  'notify wait time',
#  'offer service relyable',
#  'option child seat',
#  'option pay',
#  'order cab',
#  'order taxi',
#  'pass destination address driver',
#  'pay amount order history',
#  'pay cash',
#  'payment card work',
#  'peace junk',
#  'person taxi turn',
#  'phone call',
#  'phone epic battery life',
#  'pick location',
#  'pick point flicker',
#  'pick point pick address',
#  'price application driver price',
#  'problem side',
#  'problem side problem',
#  'proceed trick',
#  'process processing',
#  'process wire',
#  'protect lazy self',
#  'provide address',
#  'provide u taxi',
#  'put hold epoch',
#  'receive sm',
#  'receive today',
#  'recommend people',
#  'regard payment',
#  'register sm limit reach',
#  'rely book taxi feature',
#  'remove changelog',
#  'request time taxi',
#  'ride start way',
#  'route paris',
#  'route wheile',
#  'say business refund',
#  'say pathetic customer service',
#  'say pick point',
#  'say way',
#  'say wrong number',
#  'see navigation system',
#  'seem long distance',
#  'seem show',
#  'seem taxi',
#  'seem user interface',
#  'sell location data',
#  'send incorrect location driver',
#  'send sm',
#  'send sm activation code',
#  'send trip receipt email',
#  'send verification code',
#  'send verification uk number',
#  'service feedback reservation',
#  'set different card',
#  'show fare estimate',
#  'show wrong address',
#  'sip cup coffee',
#  'sit load screen',
#  'speak english fact',
#  'speak german',
#  'star ride',
#  'stick process call taxi',
#  'suggest dont',
#  'support eu country',
#  'take account',
#  'take long route',
#  'take taxi order',
#  'tap call button',
#  'taxi berlin',
#  'taxi country taxi',
#  'taxi driver charge u',
#  'taxi eu group',
#  'taxi schedule hour schedule',
#  'taxi service',
#  'taxy call center',
#  'tell approximate fare',
#  'tell different thing',
#  'tell driver work',
#  'tell taxi company',
#  'tell taxi order',
#  'tell u',
#  'text message',
#  'time book taxi copenhagen',
#  'time service',
#  'track cab',
#  'trip price',
#  'type location name take',
#  'u drop',
#  'update since android',
#  'verify phone',
#  'verify phone number',
#  'wait time taxi',
#  'waiting wait',
#  'want late edit',
#  'want prebook',
#  'way contact driver cab',
#  'way sign phone number',
#  'week work',
#  'wife wait',
#  'word background',
#  'work card',
#  'work chance amsterdam',
#  'work google pixel phone',
#  'write comment driver'}

# %% [markdown]
# ## Free Now

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_freenow)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 555 ms, sys: 2.06 s, total: 2.61 s
# Wall time: 6min 16s
# {'accept card',
#  'accept card method payment',
#  'accept cash',
#  'accept job',
#  'accept next booking drive',
#  'ad card',
#  'addison lee',
#  'allow pay card',
#  'allow prebook',
#  'android reply pick location',
#  'anyone leave ring',
#  'anyone test release',
#  'argue pick point n',
#  'arrive bangladesh pull',
#  'arrive claim taxi',
#  'arrive say',
#  'arrive unlike call cab',
#  'arrive wrong place u',
#  'ask drive taxi',
#  'ask login page',
#  'ask taxi',
#  'authorize bank',
#  'autofill downside',
#  'avoid cost',
#  'bill multiple time',
#  'bit trouble route',
#  'book cab',
#  'book make',
#  'book taxi',
#  'booking next morning',
#  'cab fare',
#  'call driver park',
#  'calling result',
#  'cancel dont show',
#  'cancel ride',
#  'cancel taxi',
#  'cancel trip',
#  'cancel trip leave',
#  'cancel wrong charge',
#  'card revolut aib',
#  'carry pet',
#  'carry supermarket thats',
#  'change card',
#  'charge cancellation fee',
#  'charge leave charge fee',
#  'check online taxi service',
#  'claim right',
#  'client ur expense',
#  'come driver',
#  'come route book cab',
#  'company payment method colleague',
#  'compete company',
#  'confirm pay',
#  'confirm payment end trip',
#  'consider amount hand change',
#  'contact driver',
#  'contact driver romania',
#  'contact driver text',
#  'contact support',
#  'cross street scout minute',
#  'customer service',
#  'customer service number',
#  'customer support',
#  'customer support phone number',
#  'deiver start meter',
#  'driver charge',
#  'driver customer service',
#  'driver end charge',
#  'driver leave',
#  'driver lie call',
#  'driver line call',
#  'driver location',
#  'driver reach address',
#  'driver refuse',
#  'dublin call',
#  'enable pick',
#  'end pay',
#  'enter start destination',
#  'euro airport guy',
#  'euro minimum',
#  'expect time',
#  'expect u',
#  'experience overall',
#  'experience smooth',
#  'eye sight',
#  'felt like hold ransom',
#  'filter option child seat',
#  'find alternative option',
#  'find book nothing',
#  'find fill',
#  'find free cab',
#  'find general area',
#  'find problem time',
#  'find taxi',
#  'follow ups',
#  'frustrate taxi driver',
#  'fund issue',
#  'generate trouble driver reach',
#  'get cancellation fee',
#  'get charge',
#  'get charge trip',
#  'get destination bill',
#  'get discount',
#  'get load screen',
#  'get notification',
#  'get notification ride',
#  'get occasional cancellation price',
#  'get past captcha point',
#  'get pay',
#  'get stick',
#  'get taxi',
#  'get taxi rate',
#  'get time',
#  'give blame',
#  'give discount',
#  'give error',
#  'give estimate',
#  'give feedback',
#  'give option call driver',
#  'give point',
#  'give price',
#  'give quote',
#  'give voucher',
#  'go heavy bag',
#  'go parallel road',
#  'go wrong address',
#  'go wrong place',
#  'hang around age lot',
#  'happt service car',
#  'hitch ride driver show',
#  'improve lot',
#  'include bank card',
#  'indicate price journey',
#  'kapten point transfer',
#  'keep call',
#  'keep default driver',
#  'keep service',
#  'keep start',
#  'know saturated marketplace',
#  'leave choice request account',
#  'leave outside freezing',
#  'let log email address',
#  'let price',
#  'license plate number',
#  'living travel hertfordshire',
#  'load time',
#  'log ticket',
#  'login signup email address',
#  'london surrey idea',
#  'look hassle order taxi',
#  'lose promo code end',
#  'lose train',
#  'make booking',
#  'make difficult resolve',
#  'make feel',
#  'make life bad',
#  'make mistake',
#  'make order',
#  'make payment',
#  'make request',
#  'make ride',
#  'make travel',
#  'meter destination drive',
#  'miss trip payment',
#  'molly michael',
#  'month pay card',
#  'move drive',
#  'option poland',
#  'overcharge credit card',
#  'pay card',
#  'pay ride',
#  'payment hold',
#  'phone price',
#  'pick location',
#  'pick location driver',
#  'pick map',
#  'price info ripoff',
#  'pricing charge',
#  'problem card',
#  'problem driver',
#  'problem taxi driver couldnt',
#  'promo code cant',
#  'protect costumer',
#  'protect option',
#  'provide land line number',
#  'put free promo',
#  'reach destination',
#  'rebook difficult time',
#  'recommend price',
#  'register detail',
#  'register sign register',
#  'reimburse driver',
#  'reinstall several time issue',
#  'reply customer service',
#  'reply message',
#  'rest claim',
#  'run late appointment',
#  'save u',
#  'say account',
#  'say couldnt',
#  'say normal price',
#  'say outside car',
#  'school way',
#  'see page',
#  'see street name number',
#  'send message',
#  'service didnt',
#  'service quality',
#  'set wrong location',
#  'show bumpy taxi icon',
#  'show taxi country',
#  'show taxi map',
#  'solution customer support',
#  'solve captcha puzzle',
#  'solve issue contact form',
#  'spend wait',
#  'star minimum',
#  'start free deal issue',
#  'start look driver',
#  'stick home page',
#  'submit request',
#  'suggest detailed card',
#  'suppose pay situation hurry',
#  'surge sunday afternoon',
#  'surge total',
#  'take 6minutes',
#  'take different route',
#  'take hassle pay etc',
#  'take long route',
#  'take risk future',
#  'take taxi cost',
#  'talk customer service phone',
#  'talk wait taxi',
#  'taxi company',
#  'taxi driver',
#  'taxi fee',
#  'taxi service',
#  'taxi yesterday',
#  'tell capiten',
#  'tell option',
#  'tell payment method',
#  'text option',
#  'thing order',
#  'time arrival time',
#  'time driver',
#  'time hail cab',
#  'time kapten',
#  'time press',
#  'time take',
#  'time taxi',
#  'time work service',
#  'trip take',
#  'uber call',
#  'uber pay xtra',
#  'understand change',
#  'understand wait time',
#  'update address order',
#  'update november',
#  'update redesign',
#  'update review',
#  'upset u',
#  'value fare',
#  'value money',
#  'vip customer problem',
#  'wait call someone phone',
#  'wait long time',
#  'wait outside 100m',
#  'wait third strike',
#  'wait time show',
#  'walk luggage',
#  'want rip',
#  'want rude driver',
#  'way contact',
#  'way map',
#  'wife thing start yesterday',
#  'withdraw money',
#  'work way',
#  'write review order taxi'}

# %% [markdown]
# ## Yandex Go

# %%
# %%time

feature_extractor = fs.SAFE()
feature_extractor.extract_from_review(review_yandexgo)
# Out:
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# Warning: parsing empty text
# CPU times: user 407 ms, sys: 1.32 s, total: 1.73 s
# Wall time: 4min 11s
# {'accept cash',
#  'accept payment card',
#  'add card payment',
#  'add functionality taxi',
#  'add mastercard card issue',
#  'add option',
#  'add payment method',
#  'anvil delivery',
#  'area map driver',
#  'ask problem',
#  'ask u annoy',
#  'assist lot',
#  'await time application',
#  'bill tip',
#  'burn cpu lot problem',
#  'cancel taxi online payment',
#  'car right',
#  'card uzbekistan',
#  'case anything',
#  'change phone set account',
#  'charge cc',
#  'charge full rate',
#  'charge problem',
#  'charge wait time',
#  'choose female driver',
#  'contradict gps location',
#  'couple issue',
#  'courrier functionality',
#  'credit card',
#  'customer rat',
#  'customer service',
#  'customer service reply none',
#  'customer support',
#  'cuz data origin',
#  'delete card uninstall',
#  'depressed clean driver',
#  'differ offer',
#  'dismiss pop',
#  'dismiss popup',
#  'driver armenia',
#  'driver display 810rsd',
#  'driver experience',
#  'driver gentleman',
#  'driver kind cooperative',
#  'driver mean',
#  'driver phone work',
#  'driver pick ride',
#  'driver push button say',
#  'driver user taxi',
#  'eat lavka',
#  'economy car',
#  'economy ride',
#  'economy service',
#  'editing review change',
#  'employ driver',
#  'expect chase driver',
#  'find cab',
#  'fixed rate airport',
#  'food delivery',
#  'food store promotion taxi',
#  'fun break leg',
#  'garbage ride hail service',
#  'get car',
#  'get free ride',
#  'get place',
#  'get refund charge',
#  'get response',
#  'get ride',
#  'give desire user experience',
#  'give promo code',
#  'give sweet talk care',
#  'go customer service',
#  'go separate function',
#  'go u',
#  'go wrong way',
#  'gps work',
#  'hear occam razor',
#  'hire order taxi service',
#  'im car',
#  'integration telegram whatsapp',
#  'jack trade',
#  'kazakhstan bad interface',
#  'keep pop',
#  'lack chat courier',
#  'list partner load',
#  'location etc',
#  'location stand customer service',
#  'look order',
#  'make info',
#  'map delay',
#  'matter traffic jump',
#  'messenger driver ok',
#  'minute charge',
#  'minute request return money',
#  'miss flight',
#  'miss pick point',
#  'navigation map accuracy',
#  'navigation map guide user',
#  'navigation price',
#  'navigation work',
#  'opt end trip',
#  'order history',
#  'order taxi someone time',
#  'pay money',
#  'pay ride score',
#  'place move',
#  'platform taxi',
#  'prediction time',
#  'price end trip',
#  'provide money ride',
#  'provide otp system',
#  'push notification',
#  'put card payment method',
#  'put phone',
#  'rate driver',
#  'rate ride',
#  'realize armenian people',
#  'receipt ride',
#  'receive receipt',
#  'recommend belarus',
#  'rely customer service',
#  'remove passenger rating',
#  'resemble screenshots',
#  'rest thanks',
#  'say many people',
#  'say move',
#  'say phone screen',
#  'say problem',
#  'say taxi service',
#  'say truth',
#  'say unpaid ride cover',
#  'see special navigation application',
#  'seem charge',
#  'seem static howere call',
#  'seem super buggy',
#  'send driver route',
#  'send ims',
#  'send taxi',
#  'service charge wait',
#  'service point',
#  'set pickup point',
#  'share friend',
#  'show precise position map',
#  'show screenshots',
#  'show sm limit',
#  'sm verification code',
#  'sort payment system',
#  'speak armenia language',
#  'state bolt',
#  'suffer passenger',
#  'support service',
#  'switch turn',
#  'system driver',
#  'take money',
#  'take money card',
#  'take ride',
#  'take wrong address',
#  'taxi launch ok',
#  'taxi part',
#  'taxi service',
#  'tell bank',
#  'tell system',
#  'time taxi',
#  'today pay cash',
#  'translation text',
#  'understand local language move',
#  'update yandex',
#  'utilization gps',
#  'ux minimum',
#  'uzbekistan programme issue map',
#  'vpn phone struggle',
#  'wait time taxi',
#  'walk charge',
#  'want blacklist carrier',
#  'want go',
#  'way order taxi',
#  'work fine',
#  'write phone screen',
#  'write support',
#  'yandex armenian driver',
#  'yandex food instance limit'}
