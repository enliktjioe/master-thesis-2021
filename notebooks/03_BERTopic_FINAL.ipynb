# %% [markdown]
# # Libraries and Functions

# %%
from utils import * 

import numpy as np
import pandas as pd
from pprint import pprint
import os


# Models
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# Coherence Scores
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.option_context('display.max_colwidth', 500);

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)


config = get_config('config.yaml')

# %%
# reference from https://github.com/MaartenGr/BERTopic/pull/95
# with little modification

def preprocess_text(documents):
    """ Basic preprocessing of text
    Steps:
        * Lower text
        * Replace \n and \t with whitespace
        * Only keep alpha-numerical characters
    """
    cleaned_documents = [doc.lower() for doc in documents]
    cleaned_documents = [doc.replace("\n", " ") for doc in cleaned_documents]
    cleaned_documents = [doc.replace("\t", " ") for doc in cleaned_documents]
    cleaned_documents = [re.sub(r'[^A-Za-z0-9 ]+', '', doc) for doc in cleaned_documents]
    cleaned_documents = [doc if doc != "" else "emptydoc" for doc in cleaned_documents]
    return cleaned_documents

def get_coherence_score(documents, bertopic_model, coherence=None):

    """ Getting a coherence score for the topics generated by the model

    Steps : 
          * Clean documents using inbuilt preprocessing
          * Initialize inbuilt CountVectorizer
          * Build a dictionary using tokens from the tokenized clean documents
          * Get all topic words from all topics, build a coherence model
    """

    if coherence == None:
        coherence = 'c_v'

    cleaned_documents = preprocess_text(documents)
    
    n_gram_range: Tuple[int, int] = (1, 1)
    vectorizer_model = CountVectorizer(ngram_range=n_gram_range)
    vectorizer_model.fit(cleaned_documents)
    tokenizer = vectorizer_model.build_tokenizer()

    words = vectorizer_model.get_feature_names()
    tokens = [tokenizer(doc) for doc in cleaned_documents]
    dictionary = corpora.Dictionary(tokens)
    corpus = [dictionary.doc2bow(token) for token in tokens]
    topic_words_ = [[words for words, _ in bertopic_model.get_topic(topic)] for topic in range(len(set(topics))-1)]

    coherence_model = CoherenceModel(topics=topic_words_, 
                                     texts=tokens,
                                     corpus=corpus,
                                     dictionary=dictionary,
                                     coherence=coherence)

    return coherence_model.get_coherence()

# %% [markdown]
# # BOLT

# %% [markdown]
# ## P1

# %%
# Import dataset
import pandas as pd
df = pd.read_csv(config['csv_input_local']['bolt_apple_google_p1'], index_col=0)
df = df.reset_index(drop=True)
reviews = df.review.tolist()
# reviews = reviews[:500] # testing purpose
len(reviews)
# Out:
# 40365

# %%
# %%time
# from bertopic import BERTopic

# # topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
# # topics, probs = topic_model.fit_transform(reviews)
# topic_model = BERTopic(language="english", nr_topics=20, low_memory=True, verbose=True)
# topics, _ = topic_model.fit_transform(reviews)
# Out:
# Batches:   0%|          | 0/1262 [00:00<?, ?it/s]
# 2021-08-04 13:02:49,149 - BERTopic - Transformed documents to Embeddings
# 2021-08-04 13:03:14,531 - BERTopic - Reduced dimensionality with UMAP
# 2021-08-04 13:03:18,536 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2021-08-04 13:04:17,529 - BERTopic - Reduced number of topics from 533 to 21
# Wall time: 6min 37s

# %%
# # Save model
# # topic_model.save("my_model.pt")
# topic_model.save("bert_topic_model/bolt_model_p1.pt", save_embedding_model=True)
# Out:
# C:\Users\enlik\Miniconda3\lib\site-packages\scipy\sparse\_index.py:126: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# Load model
my_model = BERTopic.load("bert_topic_model/bolt_model_p1.pt")

# %%
freq = my_model.get_topic_info(); freq.head(50)
# Out:
#     Topic  Count                                     Name
# 0      -1  15473                    -1_my_this_but_driver
# 1       0   2949      0_drivers_friendly_good_comfortable
# 2       1   2371            1_app_good_efficient_reliable
# 3       2   1989                       2_its_good_app_bad
# 4       3   1602              3_nice_good_best_affordable
# 5       4   1600          4_convenient_safe_easy_reliable
# 6       5   1586             5_cool_perfect_awesome_great
# 7       6   1346           6_service_good_taxify_services
# 8       7   1252  7_taxi_transport_transportation_scooter
# 9       8   1211          8_promo_discounts_discount_code
# 10      9   1061               9_location_map_gps_address
# 11     10    969                10_he_driver_phone_taxify
# 12     11    946           11_uber_cheaper_cheap_download
# 13     12    900      12_price_affordable_prices_reliable
# 14     13    832                13_great_best_better_than
# 15     14    780                  14_sms_code_network_app
# 16     15    754            15_driver_friendly_nice_great
# 17     16    732            16_bolt_cancel_drivers_driver
# 18     17    699         17_experience_great_bolt_amazing
# 19     18    679              18_ride_rides_enjoyed_enjoy
# 20     19    634          19_time_minutes_arrival_waiting

# %%
for i in range(0,len(freq)-1):
  # print(i)
  print('topic ' + str(i))
  print(my_model.get_topic(i))  # Select the most frequent topic
# Out:
# topic 0
# [('drivers', 0.08483268317658517), ('friendly', 0.061256985127860875), ('good', 0.04623332321830574), ('comfortable', 0.028928759762077226), ('nice', 0.022631936902603362), ('clean', 0.020030568921783787), ('affordable', 0.016525760814026423), ('cars', 0.016375921382931213), ('safe', 0.015993049944134623), ('polite', 0.015892808067911535)]
# topic 1
# [('app', 0.0809225845715478), ('good', 0.07169981099578354), ('efficient', 0.06411615020857608), ('reliable', 0.05511894613799441), ('service', 0.02956842489689534), ('effective', 0.028308170183610898), ('nice', 0.02763999397548431), ('useful', 0.024212180593615046), ('improvement', 0.02315495769631944), ('quick', 0.01771591790391122)]
# topic 2
# [('its', 0.03686758100706647), ('good', 0.030037301541939426), ('app', 0.029993735495083603), ('bad', 0.021852866905742955), ('service', 0.020456276628614597), ('customer', 0.01717985326970436), ('poor', 0.017055123113305044), ('ghana', 0.01592559311170013), ('kenya', 0.015587212066281933), ('dont', 0.014119504787217747)]
# topic 3
# [('nice', 0.1309700505217993), ('good', 0.08279189966908018), ('best', 0.07774806656118802), ('affordable', 0.05948537037169726), ('satisfactory', 0.059420707233063204), ('great', 0.055456078239746666), ('love', 0.045567941464857945), ('cool', 0.0372011824678615), ('amazing', 0.03672380331306118), ('loved', 0.022714720410283152)]
# topic 4
# [('convenient', 0.07489997454471467), ('safe', 0.06580540973875575), ('easy', 0.059792284946632766), ('reliable', 0.04399640728275027), ('account', 0.03956830959293357), ('affordable', 0.03770889450373207), ('easier', 0.021062272931907926), ('app', 0.020290544887452935), ('slow', 0.018820139311839554), ('cheap', 0.013124464053013207)]
# topic 5
# [('cool', 0.3250048365032621), ('perfect', 0.1875818986537715), ('awesome', 0.1255988960111025), ('great', 0.05409646382377454), ('fantastic', 0.04559852466024875), ('wonderful', 0.02478890748153054), ('excellent', 0.020306356226111967), ('color', 0.017144349537139537), ('colour', 0.015772329321692168), ('car', 0.015729814764877094)]
# topic 6
# [('service', 0.09864065723238792), ('good', 0.06409840395286875), ('taxify', 0.05773760226791049), ('services', 0.05689760589433284), ('best', 0.04165459735088436), ('great', 0.03954103945953279), ('affordable', 0.034150121837777755), ('excellent', 0.03387955732882522), ('perfect', 0.01774815508995213), ('google', 0.015480014066997639)]
# topic 17
# [('experience', 0.17523790265768754), ('great', 0.10387678162618269), ('bolt', 0.061273846997281785), ('amazing', 0.04260507479350777), ('wonderful', 0.03284400320404047), ('service', 0.029781920955231727), ('experiences', 0.024971600988820435), ('awesome', 0.02128524998949794), ('app', 0.021028804409400772), ('ride', 0.017121220882236877)]
# topic 18
# [('ride', 0.10526865844596184), ('rides', 0.06482646174722038), ('enjoyed', 0.05378023333888548), ('enjoy', 0.05367764756902698), ('bolt', 0.035999499342918566), ('enjoying', 0.03356085703561724), ('drivers', 0.02017429014682248), ('riding', 0.01812863204898821), ('trips', 0.016089204519108675), ('driver', 0.015539410256290442)]
# topic 19
# [('time', 0.06454018874304092), ('minutes', 0.0549408890819638), ('arrival', 0.03834669358992291), ('waiting', 0.03332123519652196), ('wait', 0.03139809336549635), ('min', 0.025353960012870522), ('arrive', 0.023906523472051525), ('mins', 0.019355730702021755), ('times', 0.018471796472028602), ('minute', 0.018213641578493003)]

# %%
# my_model.visualize_topics()

# %%
# my_model.visualize_heatmap(n_clusters=20, width=1000, height=1000)

# %% [markdown]
# ### Get Coherence Score

# %%
get_coherence_score(reviews, my_model)
# Out:
# 0.4410106989450021

# %% [markdown]
# ## P2

# %%
# Import dataset
import pandas as pd
df = pd.read_csv(config['csv_input_local']['bolt_apple_google_p2'], index_col=0)
df = df.reset_index(drop=True)
reviews = df.review.tolist()
# reviews = reviews[:500] # testing purpose
len(reviews)
# Out:
# 17930

# %%
# %%time
# from bertopic import BERTopic

# # topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
# # topics, probs = topic_model.fit_transform(reviews)
# topic_model = BERTopic(language="english", nr_topics=20, low_memory=True, verbose=True)
# topics, _ = topic_model.fit_transform(reviews)
# Out:
# Batches:   0%|          | 0/561 [00:00<?, ?it/s]
# 2021-08-04 13:21:35,143 - BERTopic - Transformed documents to Embeddings
# 2021-08-04 13:21:47,190 - BERTopic - Reduced dimensionality with UMAP
# 2021-08-04 13:21:50,221 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2021-08-04 13:22:13,817 - BERTopic - Reduced number of topics from 264 to 21
# Wall time: 2min 31s

# %%
# # Save model
# topic_model.save("bert_topic_model/bolt_model_p2.pt", save_embedding_model=True)
# Out:
# C:\Users\enlik\Miniconda3\lib\site-packages\scipy\sparse\_index.py:126: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# Load model
my_model = BERTopic.load("bert_topic_model/bolt_model_p2.pt")

# %%
# freq = my_model.get_topic_info(); freq.head(50)
# Out:
#     Topic  Count                                    Name
# 0      -1   4366                  -1_this_my_driver_that
# 1       0   1805          0_drivers_friendly_good_driver
# 2       1   1142                1_service_code_promo_app
# 3       2    891               2_uber_taxify_drivers_app
# 4       3    874          3_time_minutes_waiting_arrival
# 5       4    790                 4_great_its_think_grace
# 6       5    759     5_prices_affordable_discounts_price
# 7       6    748         6_perfect_experience_love_great
# 8       7    732   7_service_exceptional_great_excellent
# 9       8    686              8_ride_rides_enjoyed_enjoy
# 10      9    621       9_efficient_reliable_safe_service
# 11     10    587   10_bolt_transport_love_transportation
# 12     11    571            11_love_nice_loving_pleasant
# 13     12    570                    12_bolt_card_my_have
# 14     13    489                13_location_map_gps_pick
# 15     14    443  14_awesome_amazing_fantastic_wonderful
# 16     15    443             15_great_app_nice_efficient
# 17     16    436       16_job_service_customer_excellent
# 18     17    355             17_driver_trip_charged_ride
# 19     18    319                  18_keep_work_app_money
# 20     19    303       19_improvement_app_network_update

# %%
# my_model.visualize_topics()

# %%
# my_model.visualize_heatmap(n_clusters=20, width=1000, height=1000)

# %% [markdown]
# ### Get Coherence Score

# %%
get_coherence_score(reviews, my_model)
# Out:
# 0.4151859968841558

# %% [markdown]
# ## P3

# %%
# Import dataset
import pandas as pd
df = pd.read_csv(config['csv_input_local']['bolt_apple_google_p3'], index_col=0)
df = df.reset_index(drop=True)
reviews = df.review.tolist()
# reviews = reviews[:500] # testing purpose
len(reviews)
# Out:
# 10785

# %%
# %%time
# from bertopic import BERTopic

# # topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
# # topics, probs = topic_model.fit_transform(reviews)
# topic_model = BERTopic(language="english", nr_topics=20, low_memory=True, verbose=True)
# topics, _ = topic_model.fit_transform(reviews)
# Out:
# Batches:   0%|          | 0/338 [00:00<?, ?it/s]
# 2021-08-04 12:24:15,634 - BERTopic - Transformed documents to Embeddings
# 2021-08-04 12:24:21,703 - BERTopic - Reduced dimensionality with UMAP
# 2021-08-04 12:24:22,132 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2021-08-04 12:24:31,458 - BERTopic - Reduced number of topics from 103 to 21
# Wall time: 1min 43s

# %%
# # Save model
# # topic_model.save("my_model.pt")
# topic_model.save("bert_topic_model/bolt_model_p3.pt", save_embedding_model=True)

# %%
# Load model
my_model = BERTopic.load("bert_topic_model/bolt_model_p3.pt")

# %%
# my_model.topics
# Out:
# {-1: [('app', 0.018353204641459606),
#   ('my', 0.016679866022725625),
#   ('driver', 0.015753801934949206),
#   ('on', 0.01485196499772251),
#   ('your', 0.012536687454366514),
#   ('service', 0.012335311559943295),
#   ('ride', 0.012250616571304954),
#   ('drivers', 0.012044195580789677),
#   ('trip', 0.011666838177053471),
#   ('be', 0.011023728757457999)],
#  0: [('drivers', 0.06191044168497363),
#   ('friendly', 0.0500010120485949),
#   ('good', 0.046331205045209205),
#   ('nice', 0.030445943712041762),
#   ('driver', 0.027910788752815312),
#   ('cars', 0.021509001279395097),
#   ('safe', 0.01866213358189536),
#   ('clean', 0.017881654417416598),
#   ('excellent', 0.017044106172922076),
#   ('polite', 0.014187469581955218)],
#  1: [('app', 0.05698491537237867),
#   ('drivers', 0.048502691102256246),
#   ('good', 0.03560001868590272),
#   ('friendly', 0.023154923412571426),
#   ('awesome', 0.0222456674635554),
#   ('nice', 0.01989353292091475),
#   ('cars', 0.014434753055681973),
#   ('driver', 0.014255213811518399),
#   ('easy', 0.014197367806384394),
#   ('car', 0.011861024281028667)],
#  2: [('prices', 0.051916778157969176),
#   ('discounts', 0.04241370062280415),
#   ('price', 0.041484229985401466),
#   ('good', 0.024641789447995992),
#   ('app', 0.023640061047584707),
#   ('discount', 0.022020153120444128),
#   ('ride', 0.01983380307297235),
#   ('service', 0.019171098350237416),
#   ('affordable', 0.015614631270700256),
#   ('rates', 0.014759606732432833)],
#  3: [('service', 0.19111044307212577),
#   ('reliable', 0.07256350478882131),
#   ('great', 0.07197259839696465),
#   ('excellent', 0.07152047528194029),
#   ('good', 0.07119834364507642),
#   ('services', 0.05284980419790382),
#   ('efficient', 0.04849311444685839),
#   ('exceptional', 0.021052337047314497),
#   ('friendly', 0.017195764823541706),
#   ('wonderful', 0.01654308750551566)],
#  4: [('ride', 0.11716220657124657),
#   ('rides', 0.1055897929445039),
#   ('enjoyed', 0.05685916979826965),
#   ('enjoy', 0.03464346698856645),
#   ('affordable', 0.027744782443480137),
#   ('enjoying', 0.026271824494728705),
#   ('nice', 0.024763236500741276),
#   ('safe', 0.024029112484937144),
#   ('app', 0.02370224787068023),
#   ('comfortable', 0.019389410694379286)],
#  5: [('bolt', 0.05807936590433009),
#   ('was', 0.0194194696136442),
#   ('driver', 0.017612470184134154),
#   ('but', 0.015160059088240205),
#   ('have', 0.014928249243120773),
#   ('with', 0.014857606984020626),
#   ('on', 0.01441492871019387),
#   ('he', 0.012949391962137177),
#   ('had', 0.012069048938396878),
#   ('dont', 0.011767770772483196)],
#  6: [('efficient', 0.11326881164141364),
#   ('reliable', 0.05827701064870664),
#   ('app', 0.05320534347239224),
#   ('good', 0.034966277707423096),
#   ('fast', 0.03485194204351189),
#   ('slow', 0.028512055532501163),
#   ('network', 0.020756390427296784),
#   ('always', 0.013164969808887548),
#   ('effective', 0.012979619560229614),
#   ('keeps', 0.012643820517220952)],
#  7: [('experience', 0.0787880461459695),
#   ('keep', 0.07637125526259066),
#   ('enjoy', 0.06412677487008203),
#   ('love', 0.06397121899281087),
#   ('work', 0.04307913240944928),
#   ('enjoying', 0.042026314455241916),
#   ('loving', 0.03497682560485478),
#   ('always', 0.029271821363069155),
#   ('professional', 0.022517672277906676),
#   ('enjoyed', 0.019490581875914226)],
#  8: [('bolt', 0.13850480489099026),
#   ('experience', 0.02475937710648095),
#   ('good', 0.020622830930882356),
#   ('awesome', 0.019944759636815818),
#   ('great', 0.01824253814363389),
#   ('drivers', 0.017531894635111036),
#   ('use', 0.016296623451426916),
#   ('friendly', 0.01628859158865218),
#   ('amazing', 0.014805233272203082),
#   ('recommend', 0.014196171145916689)],
#  9: [('affordable', 0.42856834157375695),
#   ('good', 0.07210492604861159),
#   ('efficient', 0.0695733312096621),
#   ('nice', 0.06095565907874776),
#   ('service', 0.05181651225222209),
#   ('great', 0.04412308210987169),
#   ('services', 0.03971727956240794),
#   ('excellent', 0.027843160756497717),
#   ('convenient', 0.021947140137610132),
#   ('convenience', 0.012002153651773484)],
#  10: [('location', 0.0397535165213593),
#   ('app', 0.028300529025390857),
#   ('pick', 0.02374165681182572),
#   ('my', 0.019996720121952673),
#   ('kenya', 0.018709480267641493),
#   ('where', 0.017475731849375696),
#   ('its', 0.01629089972043492),
#   ('drivers', 0.013990172809008111),
#   ('your', 0.013342543320270937),
#   ('driver', 0.013263650510408292)],
#  11: [('taxify', 0.06740485167910053),
#   ('taxi', 0.03721494805553798),
#   ('my', 0.016060391216718817),
#   ('this', 0.014907452141736133),
#   ('cab', 0.014214581989217422),
#   ('drivers', 0.014011735131024687),
#   ('uber', 0.01386526513350975),
#   ('service', 0.013317167755063301),
#   ('your', 0.012263095588195687),
#   ('app', 0.012192013692839771)],
#  12: [('driver', 0.028892827688099216),
#   ('he', 0.027541130117846084),
#   ('my', 0.026043523887830624),
#   ('code', 0.024169634288751428),
#   ('sms', 0.02369828011089662),
#   ('phone', 0.022928748341206992),
#   ('number', 0.01827564288271389),
#   ('cancel', 0.01753749359728047),
#   ('had', 0.016570992224454455),
#   ('on', 0.01538699693091138)],
#  13: [('transport', 0.0847471250608154),
#   ('transportation', 0.07066681760569456),
#   ('trips', 0.05507032666791048),
#   ('easy', 0.04327891179721276),
#   ('great', 0.03907799627195516),
#   ('trip', 0.03421678345293828),
#   ('travel', 0.031154431320928516),
#   ('good', 0.031043231915858557),
#   ('move', 0.024286968791566072),
#   ('safe', 0.022179329882745617)],
#  14: [('minutes', 0.051438924253022066),
#   ('time', 0.049206617161817734),
#   ('waiting', 0.03478927658638564),
#   ('wait', 0.030472129936379804),
#   ('driver', 0.02540135148189338),
#   ('min', 0.025251402704047125),
#   ('times', 0.02252937838775585),
#   ('minute', 0.019939631514443012),
#   ('uber', 0.01729493313900126),
#   ('mins', 0.014457401116519253)],
#  15: [('gps', 0.09326632857884552),
#   ('map', 0.08553661199894516),
#   ('location', 0.051147425030932656),
#   ('maps', 0.03351760696120055),
#   ('locations', 0.023793906951272915),
#   ('google', 0.01802056204099799),
#   ('drivers', 0.016338221119660833),
#   ('cant', 0.01535336832915078),
#   ('needs', 0.015158919935455917),
#   ('driver', 0.014867406022262969)],
#  16: [('uber', 0.1679246488236844),
#   ('better', 0.07953273021850663),
#   ('cheaper', 0.030622580708479202),
#   ('more', 0.0282444523281139),
#   ('prices', 0.027819688819472967),
#   ('much', 0.023604157361078064),
#   ('app', 0.020458821211890868),
#   ('cars', 0.014666052732938329),
#   ('drivers', 0.014315419201400656),
#   ('expensive', 0.013503676233546117)],
#  17: [('card', 0.09513739728869373),
#   ('payment', 0.04262072828008316),
#   ('account', 0.026126199493644135),
#   ('app', 0.023606664362152904),
#   ('bank', 0.020522654410053836),
#   ('cant', 0.020073177303320908),
#   ('money', 0.017669017611717776),
#   ('credit', 0.017474816728047682),
#   ('blocked', 0.01602198199067151),
#   ('cards', 0.015826023527175898)],
#  18: [('rude', 0.050565273048626264),
#   ('drivers', 0.04664812230863774),
#   ('they', 0.032738816047451276),
#   ('worst', 0.02420954031537321),
#   ('your', 0.020413259940021213),
#   ('their', 0.019484063293896074),
#   ('useless', 0.016290025407033053),
#   ('dont', 0.01587391813818086),
#   ('customers', 0.0158199748505098),
#   ('driver', 0.013265225017828806)],
#  19: [('promo', 0.12638326092805618),
#   ('promos', 0.06576867854424598),
#   ('code', 0.06404522464593025),
#   ('promotions', 0.0401870528995715),
#   ('codes', 0.03990556290241182),
#   ('love', 0.024369347950553052),
#   ('free', 0.02356128242646483),
#   ('app', 0.018114488663925395),
#   ('scam', 0.015045440123236135),
#   ('dont', 0.014456604018700425)]}

# %%
freq = my_model.get_topic_info(); freq.head(50)
# Out:
#     Topic  Count                                    Name
# 0      -1   3371                     -1_app_my_driver_on
# 1       0   1920            0_drivers_friendly_good_nice
# 2       1    467             1_app_drivers_good_friendly
# 3       2    455           2_prices_discounts_price_good
# 4       3    429      3_service_reliable_great_excellent
# 5       4    428              4_ride_rides_enjoyed_enjoy
# 6       5    362                   5_bolt_was_driver_but
# 7       6    360           6_efficient_reliable_app_good
# 8       7    304            7_experience_keep_enjoy_love
# 9       8    298          8_bolt_experience_good_awesome
# 10      9    291        9_affordable_good_efficient_nice
# 11     10    286                 10_location_app_pick_my
# 12     11    275                  11_taxify_taxi_my_this
# 13     12    240                    12_driver_he_my_code
# 14     13    231  13_transport_transportation_trips_easy
# 15     14    190            14_minutes_time_waiting_wait
# 16     15    189                15_gps_map_location_maps
# 17     16    182             16_uber_better_cheaper_more
# 18     17    174             17_card_payment_account_app
# 19     18    167              18_rude_drivers_they_worst
# 20     19    166         19_promo_promos_code_promotions

# %%
# for i in range(0,len(freq)-1):
#   # print(i)
#   print('topic ' + str(i))
#   print(my_model.get_topic(i))  # Select the most frequent topic

# %%
# my_model.visualize_topics()

# %%
# my_model.visualize_heatmap(n_clusters=20, width=1000, height=1000)

# %% [markdown]
# ### Get Coherence Score

# %%
get_coherence_score(reviews, my_model)
# Out:
# 0.4518213156209174

# %% [markdown]
# # ALL

# %% [markdown]
# ## P3

# %%
# Import dataset
import pandas as pd
df = pd.read_csv(config['csv_input_local']['all_reviews_p3'], index_col=0)
df = df.reset_index(drop=True)
reviews = df.review.tolist()
# reviews = reviews[:500] # testing purpose
len(reviews)
# Out:
# 29813

# %%
# %%time
from bertopic import BERTopic

# topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
# topics, probs = topic_model.fit_transform(reviews)
topic_model = BERTopic(language="english", nr_topics=20, low_memory=True, verbose=True)
topics, _ = topic_model.fit_transform(reviews)
# Out:
# Batches:   0%|          | 0/932 [00:00<?, ?it/s]
# 2021-08-05 10:47:25,698 - BERTopic - Transformed documents to Embeddings
# 2021-08-05 10:47:40,320 - BERTopic - Reduced dimensionality with UMAP
# 2021-08-05 10:47:43,857 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2021-08-05 10:48:05,944 - BERTopic - Reduced number of topics from 221 to 21
# Wall time: 6min 18s

# %%
# Save model
# topic_model.save("my_model.pt")
topic_model.save("bert_topic_model/all_model_p3.pt", save_embedding_model=True)
# Out:
# C:\Users\enlik\Miniconda3\lib\site-packages\scipy\sparse\_index.py:126: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# Load model
my_model = BERTopic.load("bert_topic_model/all_model_p3.pt")

# %%
freq = my_model.get_topic_info(); freq.head(50)
# Out:
#     Topic  Count                                     Name
# 0      -1  12166                   -1_app_my_this_drivers
# 1       0   1653                    0_uber_my_driver_that
# 2       1   1606                       1_ola_ride_cab_bla
# 3       2   1561            2_drivers_great_good_friendly
# 4       3   1481                   3_uber_great_good_love
# 5       4   1195                   4_ride_rides_app_enjoy
# 6       5   1127                  5_easy_use_app_language
# 7       6    941     6_service_great_excellent_experience
# 8       7    931            7_driver_friendly_nice_polite
# 9       8    853               8_location_gps_map_address
# 10      9    727               9_price_prices_service_app
# 11     10    723                   10_via_taxi_cab_taxify
# 12     11    699       11_affordable_discounts_good_great
# 13     12    693  12_travel_transport_nice_transportation
# 14     13    662          13_efficient_reliable_good_fast
# 15     14    558                  14_bolt_with_drivers_my
# 16     15    494            15_cancel_drivers_ride_driver
# 17     16    493                  16_taxi_cab_app_booking
# 18     17    455               17_charged_scam_money_ride
# 19     18    402                18_code_promo_free_promos
# 20     19    393         19_customer_service_rude_drivers

# %%
for i in range(0,len(freq)-1):
  # print(i)
  print('topic ' + str(i))
  print(my_model.get_topic(i))  # Select the most frequent topic
# Out:
# topic 0
