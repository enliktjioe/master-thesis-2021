# %%
# https://www.geeksforgeeks.org/draw-a-horizontal-bar-chart-with-matplotlib/
import matplotlib.pyplot as plt
y=['one', 'two', 'three', 'four', 'five']
 
# getting values against each value of y
x=[5,24,35,67,12]
plt.barh(y, x)
 
# setting label of y-axis
plt.ylabel("pen sold")
 
# setting label of x-axis
plt.xlabel("price")
plt.title("Horizontal bar graph")
plt.show()

# %%
# https://www.geeksforgeeks.org/draw-a-horizontal-bar-chart-with-matplotlib/
import matplotlib.pyplot as plt
y=['Reporting Issues','Customer Support','Driver Service','Feature Request','Location','Payment','Praising Features','Pricing','Promotion','Purpose of Ride','Ride Exp','Safety','Time']
 
# getting values against each value of y
x=[4,4,13,6,4,6,24,3,11,4,10,3,9]
# x.sort()
plt.barh(y, x)
 
# setting label of y-axis
plt.ylabel("Topic Name")
 
# setting label of x-axis
plt.xlabel("percentage(%)")
plt.title("Horizontal bar graph")
plt.show()
