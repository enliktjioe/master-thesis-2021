# %%
# for macOS 10.12.6 issue - urllib and “SSL: CERTIFICATE_VERIFY_FAILED” Error
# solution: https://stackoverflow.com/a/28052583/2670476
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import pandas as pd
import yaml

# %%
config_file = open('config.yaml')
config = yaml.load(config_file, Loader=yaml.FullLoader)

# %%
# review_colname = 'content'
review_colname = config['review_colname']

df = pd.read_csv('csv_output/3_blablacar/blablacar-carpooling-and-bus_de_apple_appstore_review.csv', usecols=review_colname)
df
# Out:
#                                                  review
# 0     Die App ist generell prima und übersichtlich. ...
# 1     Grundsätzlich bin ich froh über BlaBlaCar, wei...
# 2     Wie im Titel bereits erwähnt, haben sich die S...
# 3     Ich habe mich vor dem Update für paar Sachen r...
# 4     Ganz ehrlich, ich bin extrem begeistert. Vor e...
# ...                                                 ...
# 7175  Mehr braucht man nicht.Suche ist einfach und ü...
# 7176  Blablacar an sich ist prima. Allerdings ist di...
# 7177  Ab dem 26.11 wird die Konkurrenz kostenpflicht...
# 7178  Tolle App, einfach zu handhaben und eine echte...
# 7179  Alternative zu Mitfahrgelegenheiten.de. Die Ap...
#
# [7180 rows x 1 columns]

# %%
df.to_excel('xls_output/test.xlsx')

# %%
df = pd.read_excel('xls_output/test_en_translation.xlsx')

# %%
df
# Out:
#                                               Unnamed: 0  \
# 0                                                      0
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12673                                                NaN
# 12674                                                NaN
# 12675                                                NaN
# 12676  Text-to-speech function is limited to 200 char...
# 12677                                                NaN
#
#                                                   review  \
# 0      The app is generally great and clear. I have a...
# 1      - Sometimes the app gets stuck when you want t...
# 2      - better suggestions for meeting points along ...
# 3      - I wanted to take two people with me and I to...
# 4      - Can I rate passengers who cancel at very sho...
# ...                                                  ...
# 12673                                                NaN
# 12674                                                NaN
# 12675                                                NaN
# 12676                                                NaN
# 12677                                                NaN
#
#                                   Unnamed: 2 Unnamed: 3
# 0                                        NaN        NaN
# 1                                        NaN        NaN
# 2                                        NaN        NaN
# 3                                        NaN        NaN
# 4                                        NaN        NaN
# ...                                      ...        ...
# 12673                                    NaN        NaN
# 12674                                    NaN        NaN
# 12675                                    NaN        NaN
# 12676                                    NaN        NaN
# 12677  Options : History : Feedback : Donate      Close
#
# [12678 rows x 4 columns]
